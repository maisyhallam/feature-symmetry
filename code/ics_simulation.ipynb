# %%
import csv # for writing dataframes to csv
import random # for making a random choice
import os # for scanning directories
import itertools
import string # for generating strings
from collections import Counter

import kintypes as kt # bringing large lists of kin types into the namespace
import math # for calculating logs
import pandas as pd
import re

testing = True # set to True to run code blocks with tests and examples
filtering = False # set to True to run the filtering process

# %% [markdown]
# # Internal co-selection
#
# Internal co-selection refers to the tendency for kinship systems to have cross-generational consistency in the terminological distinctions or mergers that are made. That is, if your parents' elder brothers share a kin term, then so too will their children. Or if your parents' sisters are distinguished from your parents' brothers, so too will their children be distinguished.
#
# Imagine a kinship system like so: as in English, you call your parents' brothers are  *uncles*, and their sisters *aunts*. You call the child of your uncle a *chuncle*, and the child of your aunt a *chaunt*. Thus, you make the same sorts of distinctions among your parents' siblings' generation of kin as are made among your own generation of kin - and you can be certain about which children belong to which parents as a result. This is an example of internal co-selection.
#
# In this notebook, we will gather information about the robustness of this tendency cross-linguistically, using data from Kinbank, a global database of kin terminology. We will also create simulations of existing kinship systems to find out whether internal co-selection is more common in kinship systems cross-linguistically (for a given amount of terminological variation) than we would expect by chance.
#
# We will measure internal co-selection in terms of the **mutual information** between Generation N and Generation N+1 in a particular kinship system. That tells us how much information can be gained from one generation by observing the other - how certain we can be about which children 'go with' which parents. This can be calculated as the **entropy** of one generation (how much unpredictable variation there is) minus the **conditional entropy** between the two generations (how much unpredictability remains in one generation after observing another).
#
# ## The procedure
#
# To calculate the mutual information (MI) of a particular kinship system, we must perform the following steps:
#
# 1. Extract kin terminology data from Kinbank for this language.
# 2. Condense the full kinship system down to the terms we are interested in: Ego's generation and Ego's parents' generation.
# 3. Calculate the probabilities of each kin term within the generation in which it belongs; and the probabilities of each parent-child pair.
# 4. Calculate entropy, conditional entropy, subtract them from each other to get the mutual information of the system.
#
# After we get that going, we can do these same calculations on simulated kinship systems.
#
# ### Extract kin terminology from Kinbank
#
# First, let's actually load our data in. The following function `get_kb_files()` pulls the full list of Kinbank filenames. Later, we can iterate through these to generate MI values for every language in our dataset.

# %%
def get_kb_files(path) -> list:
    files = []
    directory = os.scandir(path)
    for file in directory:
        files.append(file.name)
    return files

all_kb_files = get_kb_files('../languages/kinbank')

# %% [markdown]
# Using one of these filenames, we can extract the kin terminology from that file and populate a dictionary with it. We're only interested in two columns from the Kinbank data: `parameter`, which contains a short code indicating a **kin type**, and `word`, which contains the **kin term** associated with that kin type. An example of a row in the English data would be `mMeB, uncle`, where `mMeB` means 'male speaker's mother's older brother', and `uncle` is the term associated with that person.

# %%
def get_kin_terms(filepath: str) -> dict:
    kin_system = {}
    with open(filepath, encoding='utf8') as f:
        csv_reader = csv.DictReader(f)
        next(csv_reader) # to skip the header row
        for line in csv_reader:
            kin_type = line['parameter']
            kin_term = line['word']
            kin_system[kin_type] = kin_term
    return kin_system

# %% [markdown]
# Let's pick a random kinship system to test with throughout this notebook.

# %%
if testing:
    
    random.seed(47) # set a seed for reproducibility

    file = random.choice(all_kb_files) # pick a random filename from all_kb_files

    filepath = '../languages/kinbank/' # the filepath where the kinbank files are kept

    k = get_kin_terms(filepath + file)

    print(file,k)
# Out:
# Nogai_noga1249.csv {'mG': 'karɨndas', 'mB': 'adanas', 'mZ': 'karɨndas', 'myB': 'ini', 'myZ': 'siŋli', 'mF': 'ata', 'mM': 'ana', 'mC': 'tuwgailar', 'mS': 'kede', 'mD': 'kɨz', 'mFF': 'atay', 'mFM': 'tetey', 'mMF': 'atay', 'mMM': 'tetey', 'mSS': 'yiyen', 'mSD': 'yiyеn kɨz', 'mDS': 'yiyen', 'mDD': 'yiyеn kɨz', 'mFB': 'akay', 'mFZ': 'abay', 'mMB': 'nagaš akay', 'mMZ': 'abay', 'mBS': 'yiyen', 'mBD': 'yiyеn kɨz', 'mZS': 'yiyen', 'mZD': 'yiyеn kɨz', 'mFZD': 'bölе', 'mFBD': 'bölе', 'mMBD': 'bölе', 'mMZD': 'bölе', 'mFBS': 'bölе', 'mFZS': 'bölе', 'mMBS': 'bölе', 'mMZS': 'bölе', 'mH': 'kiew', 'mW': 'pišе', 'mHF': 'kaynata', 'mHM': 'kaynana', 'mWF': 'kaynata', 'mWM': 'kaynana', 'mSW': 'kеšеk', 'mDH': 'kiеw', 'meB': 'adanas', 'meZ': 'karɨndas', 'mFeB': 'akay', 'mFyB': 'akay', 'mFeZ': 'abay', 'mFyZ': 'abay', 'mMeZ': 'abay', 'mMyZ': 'abay', 'mMeB': 'nagaš akay', 'mMyB': 'nagaš akay', 'meBS': 'yiyen', 'myBS': 'yiyen', 'meBD': 'yiyеn kɨz', 'myBD': 'yiyеn kɨz', 'meZS': 'yiyen', 'myZS': 'yiyen', 'meZD': 'yiyеn kɨz', 'myZD': 'yiyеn kɨz', 'mFeBS': 'bölе', 'mFyBS': 'bölе', 'mFeZS': 'bölе', 'mFyZS': 'bölе', 'mFeBD': 'bölе', 'mFyBD': 'bölе', 'mFeZD': 'bölе', 'mFyZD': 'bölе', 'mMeBS': 'bölе', 'mMyBS': 'bölе', 'mMeZS': 'bölе', 'mMyZS': 'bölе', 'mMeBD': 'bölе', 'mMyBD': 'bölе', 'mMeZD': 'bölе', 'mMyZD': 'bölе', 'mFBeS': 'bölе', 'mFByS': 'bölе', 'mFZeS': 'bölе', 'mFZyS': 'bölе', 'mFBeD': 'bölе', 'mFByD': 'bölе', 'mFZeD': 'bölе', 'mFZyD': 'bölе', 'mMBeS': 'bölе', 'mMByS': 'bölе', 'mMZeS': 'bölе', 'mMZyS': 'bölе', 'mMBeD': 'bölе', 'mMByD': 'bölе', 'mMZeD': 'bölе', 'mMZyD': 'bölе', 'fG': 'karɨndas', 'fB': 'adanas', 'fZ': 'karɨndas', 'fyB': 'ini', 'fyZ': 'siŋli', 'fF': 'ata', 'fM': 'ana', 'fC': 'tuwgailar', 'fS': 'kede', 'fD': 'kɨz', 'fFF': 'atay', 'fFM': 'tetey', 'fMF': 'atay', 'fMM': 'tetey', 'fSS': 'yiyen', 'fSD': 'yiyеn kɨz', 'fDS': 'yiyen', 'fDD': 'yiyеn kɨz', 'fFB': 'akay', 'fFZ': 'abay', 'fMB': 'nagaš akay', 'fMZ': 'abay', 'fBS': 'yiyen', 'fBD': 'yiyеn kɨz', 'fZS': 'yiyen', 'fZD': 'yiyеn kɨz', 'fFZD': 'bölе', 'fFBD': 'bölе', 'fMBD': 'bölе', 'fMZD': 'bölе', 'fFBS': 'bölе', 'fFZS': 'bölе', 'fMBS': 'bölе', 'fMZS': 'bölе', 'fH': 'kiew', 'fW': 'pišе', 'fHF': 'kaynata', 'fHM': 'kaynana', 'fWF': 'kaynata', 'fWM': 'kaynana', 'fSW': 'kеšеk', 'fDH': 'kiеw', 'feB': 'adanas', 'feZ': 'karɨndas', 'fFeB': 'akay', 'fFyB': 'akay', 'fFeZ': 'abay', 'fFyZ': 'abay', 'fMeZ': 'abay', 'fMyZ': 'abay', 'fMeB': 'nagaš akay', 'fMyB': 'nagaš akay', 'feBS': 'yiyen', 'fyBS': 'yiyen', 'feBD': 'yiyеn kɨz', 'fyBD': 'yiyеn kɨz', 'feZS': 'yiyen', 'fyZS': 'yiyen', 'feZD': 'yiyеn kɨz', 'fyZD': 'yiyеn kɨz', 'fFeBS': 'bölе', 'fFyBS': 'bölе', 'fFeZS': 'bölе', 'fFyZS': 'bölе', 'fFeBD': 'bölе', 'fFyBD': 'bölе', 'fFeZD': 'bölе', 'fFyZD': 'bölе', 'fMeBS': 'bölе', 'fMyBS': 'bölе', 'fMeZS': 'bölе', 'fMyZS': 'bölе', 'fMeBD': 'bölе', 'fMyBD': 'bölе', 'fMeZD': 'bölе', 'fMyZD': 'bölе', 'fFBeS': 'bölе', 'fFByS': 'bölе', 'fFZeS': 'bölе', 'fFZyS': 'bölе', 'fFBeD': 'bölе', 'fFByD': 'bölе', 'fFZeD': 'bölе', 'fFZyD': 'bölе', 'fMBeS': 'bölе', 'fMByS': 'bölе', 'fMZeS': 'bölе', 'fMZyS': 'bölе', 'fMBeD': 'bölе', 'fMByD': 'bölе', 'fMZeD': 'bölе', 'fMZyD': 'bölе'}

# %% [markdown]
# Our random language is Nogai, a Turkic language spoken in Southeastern European Russia, Kazakhstan, Uzbekistan, Ukraine, Bulgaria, Romania and Turkey. But as we can see from printing the system, there's a lot of extra kin terms here that we don't need for our experiment today. We're only interested in Ego and Ego's parents' generations, but the system contains kin types like `mS` (male speaker's son) or `mDD` (make speaker's daughter's daughter). In the next section, we'll reduce `k` down to just the terms we're interested in.
#
# ### Condense the system down
#
# The list of possible **kin types** is far larger and more unwieldy than the set of **kin terms** in any language. For instance, while 'father's elder brother' and 'father's younger brother' are not distinguished in English (both take the term *uncle*), these distinctions are indeed encoded by terminology in other languages, like Hindi.
#
# In the Kinbank datasets, kin types are recorded even if they are not distinguished terminologically in a given language. Thus, the English data has an entry for father's elder and younger brothers, and for father's elder and younger brother's sons and daughters. As a result, our dictionary `k` will have many duplicate entries. To avoid overinflating the amount of variation in each language later on, we want to filter out these duplicate entries at this point.
#
# Instead, in `kintypes.py`, another file in this directory, I have created some data structures which group together kin types - so father's brother, father's elder brother, and father's younger brother are grouped together. The following code takes these data structures, compares them against the full kinship system we extracted above, and in the case of a match within these groups, it discards any duplicates and takes only the first matching entry.
#
# We do this separately for Ego's generation and Ego's parents' generation because we want the Ego generation entries to match their parents - that is, we only want to have mother's elder brother's son if we also have mother's elder brother in the system. We also check whether the terms are the same if the speaker is male or female - if so, we take the male speaker terms by default.

# %%
def filter_mf(filtered_ks):
    for x,y in zip(kt.m_speaker,kt.f_speaker):
        if x in filtered_ks and y in filtered_ks:
            if filtered_ks[x] == filtered_ks[y]:
                del(filtered_ks[y]) # leave male speaker as default
            else:
                pass
        else:
            pass

# %%
def filter_age(ks):
    filtered_ks = {}
    for group in kt.age_split:
        if group[1] in ks and group[2] in ks:
            if ks[group[1]] == ks[group[2]]:
                filtered_ks[group[1]] = ks[group[1]] # leave elder as default
            else:
                filtered_ks[group[1]] = ks[group[1]]
                filtered_ks[group[2]] = ks[group[2]]
        elif group[0] in ks:
            filtered_ks[group[0]] = ks[group[0]]
        else:
            pass
    
    return filtered_ks

# %% [markdown]
# Filtering all the kinship systems AND running the MI calculations proves to be quite taxing on memory, so instead of filtering in situ, we're going to save all the filtered kinship systems to csv files. We can then read the data from them using the `get_kin_terms` function. So we'll need some infrastructure for writing the data to a csv file:

# %%
def write_headers(file):
    with open(file, 'a') as csv_file:
        csvwriter = csv.writer(csv_file)
        csvwriter.writerow(['parameter','word'])
        
def save_to_csv(file,data):
    filename = '../languages/kinbank-filter/' + file
    with open(filename, 'a', encoding="utf8") as csv_file:
        csvwriter = csv.writer(csv_file)
        write_headers(filename)
        for kt in data:
            csvwriter.writerow([kt,data[kt]])

# %% [markdown]
# And now we can neatly package our `get_kin_terms` function, our filtering functions, and our writing to csv functions.

# %%
def filter_ks(file):
    ks = get_kin_terms('../languages/kinbank/' + file)        
    
    filtered_ks = filter_age(ks)
    
    filter_mf(filtered_ks)
    
    for entry in filtered_ks:
        if ',' in filtered_ks[entry]:
            filtered_ks[entry] = filtered_ks[entry].split(',')[0]

    if filtered_ks:
        save_to_csv(file,filtered_ks)
       
    return filtered_ks

# %%
if testing:
    k = filter_ks(file)
    print(k)
# Out:
# {'mM': 'ana', 'mF': 'ata', 'mMeB': 'nagaš akay', 'mFeB': 'akay', 'mMeZ': 'abay', 'mFeZ': 'abay', 'meB': 'adanas', 'myB': 'ini', 'meZ': 'karɨndas', 'myZ': 'siŋli', 'mMBeS': 'bölе', 'mMeBS': 'bölе', 'mMyBS': 'bölе', 'mFBeS': 'bölе', 'mFeBS': 'bölе', 'mFyBS': 'bölе', 'mMZeS': 'bölе', 'mMeZS': 'bölе', 'mMyZS': 'bölе', 'mFZeS': 'bölе', 'mFeZS': 'bölе', 'mFyZS': 'bölе', 'mMBeD': 'bölе', 'mMeBD': 'bölе', 'mMyBD': 'bölе', 'mFBeD': 'bölе', 'mFeBD': 'bölе', 'mFyBD': 'bölе', 'mMZeD': 'bölе', 'mMeZD': 'bölе', 'mMyZD': 'bölе', 'mFZeD': 'bölе', 'mFeZD': 'bölе', 'mFyZD': 'bölе'}

# %% [markdown]
# And loop that over every Kinbank file:
#
# **NOTE: if you're reading this, then this process is already done! You'll find the files in `../languages/kinbank-filter/`**

# %%
if filtering:
    for file in all_kb_files:
        ks = filter_ks(file)
        print(file,ks)

# %% [markdown]
# Now we have our kinship system filtered for relevant terms and duplicates, we also want to create a data structure that pairs up these terms for us. In `kintypes`, you will also find **a list of pairs of kin types**, where the first element in the pair is a parent type, and the second is their child; e.g. `mMeB` and `mMeBD` (mother's elder brother and mother's elder brother's daughter). We will be filtering our full kinship system `k` according to this list of pairs. This is because we're interested in whether kinship systems maintain patterns of terminological distinctions and mergers across these two generations, we will need to know which parent terms 'go with' which child terms.
#
# The following function takes a kinship system as input, and outputs a list of tuples. The first element in the tuple is the parent term, the second is the corresponding child term.
#
# We also perform a check on the number of different kin types from Ego's parents' generation included across all the pairs in the kinship system. As has been established, the Kinbank data is very broad but not 100% complete for every language recorded. So, if the only pairs we are able to extract from the data include Ego's mother and father **and no other member of Ego's parents' generation** we will not continue to analyse this language, as this is not sufficient evidence to identify internal co-selection.

# %%
def get_pairs(ks: dict) -> list:
    pairs_of_terms = []
    parent_types = []

    for pair in kt.ics_pairs:
        if pair[0] in ks and pair[1] in ks:
            pairs_of_terms.append((ks[pair[0]],ks[pair[1]]))
            parent_types.append(pair[0])
                
    if len(set(parent_types)) > 2 : 
        return pairs_of_terms

# %% [markdown]
# But for our calculations, we'll still need to know which terms belong to which generation. Luckily, we know that the 0th element in each tuple is from Ego's parents' generation and the 1st element is from Ego's generation. So we can happily split these tuples down the middle and populate two lists with the terms.

# %%
def split_pairs(pairs: list) -> list:
    gn = []
    gn1 = []
    for pair in pairs:
        gn.append(pair[1])
        gn1.append(pair[0])
    
    return gn,gn1

# %% [markdown]
# To illustrate what these functions do, let's test them out with our random kinship system, `k`.

# %%
if testing:
    print(k)
    k_pairs = get_pairs(k)
    print(k_pairs)
# Out:
# {'mM': 'ana', 'mF': 'ata', 'mMeB': 'nagaš akay', 'mFeB': 'akay', 'mMeZ': 'abay', 'mFeZ': 'abay', 'meB': 'adanas', 'myB': 'ini', 'meZ': 'karɨndas', 'myZ': 'siŋli', 'mMBeS': 'bölе', 'mMeBS': 'bölе', 'mMyBS': 'bölе', 'mFBeS': 'bölе', 'mFeBS': 'bölе', 'mFyBS': 'bölе', 'mMZeS': 'bölе', 'mMeZS': 'bölе', 'mMyZS': 'bölе', 'mFZeS': 'bölе', 'mFeZS': 'bölе', 'mFyZS': 'bölе', 'mMBeD': 'bölе', 'mMeBD': 'bölе', 'mMyBD': 'bölе', 'mFBeD': 'bölе', 'mFeBD': 'bölе', 'mFyBD': 'bölе', 'mMZeD': 'bölе', 'mMeZD': 'bölе', 'mMyZD': 'bölе', 'mFZeD': 'bölе', 'mFeZD': 'bölе', 'mFyZD': 'bölе'}
# ['mM', 'mM', 'mM', 'mM', 'mF', 'mF', 'mF', 'mF', 'mMeB', 'mMeB', 'mFeB', 'mFeB', 'mMeZ', 'mMeZ', 'mFeZ', 'mFeZ']
# [('ana', 'adanas'), ('ana', 'ini'), ('ana', 'karɨndas'), ('ana', 'siŋli'), ('ata', 'adanas'), ('ata', 'ini'), ('ata', 'karɨndas'), ('ata', 'siŋli'), ('nagaš akay', 'bölе'), ('nagaš akay', 'bölе'), ('akay', 'bölе'), ('akay', 'bölе'), ('abay', 'bölе'), ('abay', 'bölе'), ('abay', 'bölе'), ('abay', 'bölе')]

# %%
if testing:
    test = {'mM': 'blabla',
        'mF': 'blabla',
        'mB': 'beepbeep',
        'mZ': 'boopboop'}
    test_pairs = get_pairs(test)
    print(test_pairs)
# Out:
# ['mM', 'mM', 'mF', 'mF']
# None

# %%
if testing:
    
    k_gn,k_gn1 = split_pairs(k_pairs)

    print("Ego's generation: ", k_gn, '\n')

    print("Ego's parents' generation: ", k_gn1)
# Out:
# Ego's generation:  ['adanas', 'ini', 'karɨndas', 'siŋli', 'adanas', 'ini', 'karɨndas', 'siŋli', 'bölе', 'bölе', 'bölе', 'bölе', 'bölе', 'bölе', 'bölе', 'bölе']
#
# Ego's parents' generation:  ['ana', 'ana', 'ana', 'ana', 'ata', 'ata', 'ata', 'ata', 'nagaš akay', 'nagaš akay', 'akay', 'akay', 'abay', 'abay', 'abay', 'abay']

# %% [markdown]
# `get_pairs()` gives us a long list of pairs, with lots of repetition. This is because some kin types will correspond to the same kin term in a language. For example, in English, mother's elder brother, mother's younger brother, father's elder brother and father's younger brother all correspond to the term 'uncle'. All of those people's children correspond to the word 'cousin'! So we'll end up with duplicate entries for these terms in some languages, but not all.
#
# `split_pairs()` takes this long list of pairs and sorts it into terms that belong to Ego's generation and terms that belong to Ego's parents' generation. Importantly, since the order of the `pairs` list is preserved when we run `split_generations()`, we can still work out which terms form a parent-child pair by indexing `gn` and `gn1`.
#
# Now we have our data structures, we can start to do some calculations.
#
# ### Calculating probabilities

# %% [markdown]
# To calculate entropy, we need a probability distribution over the terms in one single generation of a kinship system. So let's start with a function that can calculate the probability of a particular term.
#
# Given a term and the full list of terms in the same generation, this function counts how many times that term exists in `generation` and divides that by the total length of `generation`.

# %%
def probability(term: str, generation: list) -> float:
    #print(generation.count(term),len(generation))
    return generation.count(term)/len(generation)

# %% [markdown]
# So if we pick a term at random from our Nogai kinship system, it will output the probability of picking that term.

# %%
if testing:
    k_term = random.choice(k_gn1)
    print(k_term, probability(k_term,k_gn1))
# Out:
# ana 0.25

# %% [markdown]
# When calculating mutual information, we also need the **conditional entropy** of our system. To calculate this, we will need not only the probabilities of terms in a generation, but also the **joint probabilities** of every pair of terms across those two generations. In other words, we need to calculate the probabilities of our `pairs` output by `get_pairs`.
#
# Given two terms, this function counts how many pairs made of those two terms exist in `pairs`, then divides that by the total length of `pairs`.

# %%
def joint_probability(term1: str, term2: str, pairs: list) -> float:
    pair = (term1,term2)
    return pairs.count(pair)/len(pairs)

# %% [markdown]
# Once again, we can test this with a random pair from our Nogai list of pairs:

# %%
if testing:
    sum_jp = []
    for pair in set(k_pairs):
        jp = joint_probability(pair[0],pair[1],k_pairs)
        sum_jp.append(jp)
        print(pair, jp)
    print(sum(sum_jp))
# Out:
# ('ata', 'ini') 0.0625
# ('ata', 'siŋli') 0.0625
# ('ana', 'karɨndas') 0.0625
# ('ana', 'adanas') 0.0625
# ('ana', 'ini') 0.0625
# ('ana', 'siŋli') 0.0625
# ('nagaš akay', 'bölе') 0.125
# ('akay', 'bölе') 0.125
# ('ata', 'karɨndas') 0.0625
# ('abay', 'bölе') 0.25
# ('ata', 'adanas') 0.0625
# 1.0

# %% [markdown]
# Now we can calculate probabilities, we can use these functions to calculate entropy, conditional entropy, and mutual information.
#
# ### Calculating entropy and mutual information
#
# Entropy is defined as
#
# **INSERT EQUATION HERE LOL**
#
# or, in English, it is the inverse sum over a distribution X of the probability of y * the log probability of y.
#
# Entropy is a measure of the average level of uncertainty about the possible outcomes of a variable.
#
# The functions we defined above only calculate a single probability at a time, so our next functions will need to iterate over the kinship system in order to have a full probability distribution. First, let's define a function that will iterate over a generation of the kinship system to output the entropy of that generation.
#
# Note: we only need one generation's entropy score to calculate mutual information - we will make the arbitrary choice to calculate the entropy of Ego's parents' generation later in this notebook.

# %%
def entropy(generation: list) -> list:
    entropy = 0
    for term in set(generation): # using a set as we want to count each unique term only once
        p = probability(term,generation)
        #print('entropy of',term,p*math.log(p))
        entropy += p*math.log2(p)
    return -entropy

# %%
if testing:
    print(entropy(k_gn1))
# Out:
# 2.25

# %% [markdown]
# Moving on, conditional entropy is defined as
#
# **ANOTHER EQUATION PLEASE**
#
# or in English, the inverse sum over two distributions Y and X of the probability of each y * the log probability of each y given x.
#
# Conditional entropy is the amount of information needed to describe the outcome of a random variable Y given that we already know the value of another random variable X.
#
# To calculate it, we need the joint probability of each pair (given by `joint_probability()`) and the probability of one member of that pair (given by `probability()`). We can then calculate the conditional probability of parent term given child term as the joint probability of those terms over the probability of the parent term.
#
# As before, we will define a function that iterates over all pairs to output the conditional entropy of Ego's generation given Ego's parents' generation.

# %%
def conditional_entropy(gn: list, pairs:list) -> float:
    entropy = 0
    for x,y in set(pairs): # x = parent, y = child
        p_xy = joint_probability(x,y,pairs)
        p_y = probability(y,gn)
        if p_xy > 0 and p_y > 0:
            #print('p(', x, '|', y,') = ', p_xy/p_y, 'p(y) = ', p_y)
            entropy += p_xy * math.log2(p_xy/p_y)
    return -entropy

# %%
if testing:
    print(conditional_entropy(k_gn,k_pairs))
# Out:
# 1.25

# %% [markdown]
# Finally, mutual information is defined as
#
# **LAST EQUATION**
#
# or in English, entropy of X minus the conditional entropy of X given Y.
#
# In this study, it is equal to the entropy of Ego's parents' generation minus the conditional entropy of Ego's parents' generation given Ego's generation. It tells us how much mutual dependence there is between these two generations; i.e. how much we can know about one by observing the other.
#
# So long as we make sure to input the right entropy and conditional entropy values, we only need a simple function for this one:

# %%
def mutual_information(pairs: list):
    gn,gn1 = split_pairs(pairs)
    e = entropy(gn1)
    ce = conditional_entropy(gn,pairs)
    mi = e - ce
    return mi

# %%
if testing:
    print(mutual_information(k_pairs))
# Out:
# 1.0

# %% [markdown]
# And there we have it! Step 4 complete. We can now take any (filtered) Kinbank file and output the mutual information between Ego's generation and Ego's parents' generation in that language.
#
# But right at the beginning of this notebook, I mentioned using **simulations** to test the robustness of our claim that languages exhibit internal co-selection in their kinship systems. These simulations give us a baseline with which to compare the MI scores of real languages. Do languages across the world have greater mutual information between two generations than we would expect by chance?
#
# ## Simulations
#
# If we want to argue that internal co-selection is a product of cultural evolution, we need to dispel the possibility that it occurs by chance.
#
# To get an idea of how much information would be shared between two generations purely by chance, we need to create some randomly generated kinship systems. We can compare the MI of these simulations to the real languages to see whether the real languages have significantly greater mutual information between generations.
#
# An important aspect of MI that we have not discussed so far: it is dependent on the amount of variation within the kinship system. A system with only one unique term in each generation would have MI of 0, which seems pretty terrible! But given this very limited variation (indeed, no variation), 0 is the highest MI such a language could have. As such, we perhaps need to modify our claim that kinship systems have "high MI" to be more specific: kinship systems in the wild have high MI *for the amount of variation in terminology they have*.
#
# To compare real languages to simulations, we need a simulation which maintains the number of terms while randomising which child terms pair with which parent terms. To do this, we will take each language in our data, and randomly scramble which terms go with which types (within generation). This will randomise the syncretisms within the generations while maintaining the same amount of variation across the system overall.
#
# To do this, we need to take the following steps:
#
# 1. Extract the kinship system of a language from kinbank (check!)
# 2. Filter the two generations we are interested in (check!)
# 3. Randomly reassign the kinship terms to new types.
# 4. Repeat the process a bunch of times for each language.
#
# We already have the infrastructure for the first two! `get_kin_terms()`,  `get_pairs()` and `split_pairs()` will do this for us. So let's skip to 3, and write a function that randomises which terms form pairs, assuming that we have already extracted the kinship system and filtered the relevant pairs.
#
# Remember that the order of `pairs` is preserved when we run `split_pairs()`. So when we pass `gn` and `gn1` to `shuffle_pairs()`, we know that we can re-unite our pairs by using the same index. Equally, when we shuffle `gn` and `gn1` in place, we know that we can safely combine them to make a new, randomised pair in place of the 'real' Nogai pair.

# %%
def shuffle_pairs(gn,gn1):
    random.shuffle(gn)
    random.shuffle(gn1)
    #print(Counter(gn))
    random_pairs = []
    for x,y in zip(gn,gn1):
        random_pairs.append((y,x))
    return random_pairs

# %%
# def shuffle_pairs(pairs):
#     gn,gn1 = split_pairs(pairs)
#     random.shuffle(gn)
#     print(Counter(gn))
#     random_pairs = []
    
#     for pair in set(pairs):
#         #print(term)
#         #for i in range(gn1.count(term)): # however many times this term forms a unique pair
#         new_pair = pick_new_pair(random_pairs,gn,pair[0])
#         for i in range(pairs.count(pair)):
#             random_pairs.append(new_pair)
        
            
#     return random_pairs

# %%
# def shuffle_pairs(pairs):
#     gn,gn1 = split_pairs(pairs)
#     print(Counter(gn))
#     new_pairs = []
#     for pair in set(pairs):
#         choices = list(set(gn))
#         random_term = random.choice(choices)
#         new_pair = (pair[0],random_term)
#         print(new_pair)
#         for x in pairs:
#             if x == pair:
#                 new_pairs.append(new_pair)
#     #print(new_pairs)
#     return new_pairs

# %%
def pick_new_pair(random_pairs,gn,term):
    choices = gn
    random_term = random.choice(choices)
    pair = (term,random_term)
    if pair in random_pairs:
        return pick_new_pair(random_pairs,choices,term)
    else:
        gn.remove(random_term)
        return pair

# %%
if testing:
    sim_pairs = shuffle_pairs(k_gn,k_gn1)
    sim_gn,sim_gn1 = split_pairs(sim_pairs)
    print(Counter(sim_gn))
    print(k_pairs,sim_pairs)
# Out:
# Counter({'bölе': 8, 'siŋli': 2, 'ini': 2, 'adanas': 2, 'karɨndas': 2})
# [('ana', 'adanas'), ('ana', 'ini'), ('ana', 'karɨndas'), ('ana', 'siŋli'), ('ata', 'adanas'), ('ata', 'ini'), ('ata', 'karɨndas'), ('ata', 'siŋli'), ('nagaš akay', 'bölе'), ('nagaš akay', 'bölе'), ('akay', 'bölе'), ('akay', 'bölе'), ('abay', 'bölе'), ('abay', 'bölе'), ('abay', 'bölе'), ('abay', 'bölе')] [('ana', 'bölе'), ('ata', 'siŋli'), ('ata', 'ini'), ('akay', 'adanas'), ('abay', 'bölе'), ('akay', 'bölе'), ('nagaš akay', 'karɨndas'), ('abay', 'bölе'), ('ana', 'karɨndas'), ('nagaš akay', 'bölе'), ('ata', 'ini'), ('abay', 'bölе'), ('ana', 'adanas'), ('ata', 'siŋli'), ('ana', 'bölе'), ('abay', 'bölе')]

# %% [markdown]
# Now we can treat `sim_pairs` just as we treated `pairs`! Let's calculate the entropy, conditional entropy, and mutual information of this simulated system.

# %%
if testing:
    sim_gn,sim_gn1 = split_pairs(sim_pairs)
    e = entropy(sim_gn1)
    ce = conditional_entropy(sim_gn,sim_pairs)
    mi = mutual_information(sim_pairs)
    print(e,ce,mi)
# Out:
# 2.25 1.4528195311147831 0.7971804688852169

# %%
if testing:
    sim_pairs = shuffle_pairs(k_gn,k_gn1)
    sim_gn,sim_gn1 = split_pairs(sim_pairs)
    e = entropy(sim_gn1)
    ce = conditional_entropy(sim_gn,sim_pairs)
    mi = mutual_information(sim_pairs)
    print(e,ce,mi)
    print(len(k_pairs),len(sim_pairs))
# Out:
# 2.25 1.375 0.875
# 16 16

# %% [markdown]
# Wait! Some of these values are exactly the same as the real Nogai kinship system! I thought this was a randomised simulation - what gives?
#
# Variation gives! Entropy remains the same regardless, because the amount of variation in the simulation **does not change** by design.
#
# The MI of these two systems (and by extension, the conditional entropy) **does** vary, which is what we want. Let's try with another language:

# %%
if testing:
    file2 = random.choice(all_kb_files)
    print(file2)
    k2 = filter_ks(file2)

    k2_pairs = get_pairs(k2)
    print(k2)
    k2_gn,k2_gn1 = split_pairs(k2_pairs)
    k2_e = entropy(k2_gn1)
    k2_ce = conditional_entropy(k2_gn,k2_pairs)
    k2_mi = mutual_information(k2_pairs)
    
    k2_sim = shuffle_pairs(k2_gn,k2_gn1)
    k2_sim_gn,k2_sim_gn1 = split_pairs(k2_sim)
    k2_sim_e = entropy(k2_sim_gn1)
    k2_sim_ce = conditional_entropy(k2_sim_gn,k2_sim)
    k2_sim_mi = mutual_information(k2_sim)
    
    print('Sungwaloge:', k2_e,k2_ce,k2_mi)
    print('Simulation:',k2_sim_e,k2_sim_ce,k2_sim_mi)
    
    print(len(k2_sim),len(k2_pairs))
    
    for i in k2_pairs:
        if i not in k2_sim:
            print(i)
            
    for i in k2_sim:
        if i not in k2_pairs:
            print(i)
# Out:
# Morgan1871_Iowä_iowa1245.csv
# {'mM': 'heenʼ-nä', 'mF': 'heenʼ-kä', 'mMeB': 'heen-jaʼ-kä', 'mFeB': 'heenʼ-kä', 'mMeZ': 'heenʼ-nä', 'mFeZ': 'heen-tooʼ-me', 'meB': 'he-yenʼ-nä', 'myB': 'heen-thun̤ʼ-ga', 'meZ': 'he-yuʼ-nä', 'myZ': 'heen-tan̤ʼ-ya', 'mMBeS': 'heen-jaʼ-kä', 'mFBeS': 'he-yenʼ-nä', 'mFByS': 'heen-thun̤ʼ-ga', 'mMZeS': 'he-yenʼ-nä', 'mMZyS': 'heen-thun̤ʼ-ga', 'mFZeS': 'heen-toansʼ-ka', 'mFZyS': 'heen-toasʼ-ka', 'mMBeD': 'heenʼ-nah', 'mMByD': 'heenʼ-nä', 'mFBeD': 'he-yuʼ-nä', 'mFByD': 'heen-tanʼ-ya', 'mMZeD': 'hee-uʼ-nä', 'mMZyD': 'heen-tan̤ʼ-ya', 'mFZeD': 'heen-toasʼ-ka-me', 'fyB': 'e-chunʼ-cha', 'feZ': 'heen-tan̤ʼ-ga', 'fyZ': 'heen-tun̤ʼ-ga', 'fFByS': 'e-chunʼ-cha', 'fMZyS': 'e-chunʼ-cha', 'fFZeS': 'hee-yin̤ʼ-ga', 'fFBeD': 'heen-tan̤ʼ-ga', 'fFByD': 'heen-tun̤ʼ-ga', 'fMZeD': 'heen-tan̤ʼ-ga', 'fMZyD': 'heen-tun̤ʼ-ya', 'fFZeD': 'heen-yun̤ʼ-ga'}
# Sungwaloge: 1.0 0.9999999999999997 3.3306690738754696e-16
# Simulation: 1.0 0.4285714285714285 0.5714285714285715
# 14 14
# ('heenʼ-nä', 'he-yenʼ-nä')
# ('heenʼ-nä', 'he-yuʼ-nä')
# ('heenʼ-kä', 'heen-tan̤ʼ-ya')
# ('heenʼ-kä', 'e-chunʼ-cha')

# %% [markdown]
# Now we see that while the entropy of our new language, Sungwaloge, and its simulation are equal, the conditional entropy for the simulation is greater and therefore the mutual information of the simulation is lower. What about if we did this 1000 times? How often would the mutual information of the simulation be lower then?
#
# ## Tidying up
#
# We have all the pieces we need now to calculate MI and simulate kinship systems - all we need to do is write a few more functions that stick all of those pieces together in a neat parcel.
#
# First, a function that takes pairs and spits out entropy, conditional entropy, and MI:

# %% [markdown]
# Second, a function that builds a simulated list of pairs when we pass in a kinship system:

# %%
def simulate_ks(ks: dict) -> list:
    pairs = get_pairs(ks)
    if pairs:
        gn,gn1 = split_pairs(pairs)
        simulation = shuffle_pairs(gn,gn1)
        return simulation

# %%
def write_data(pairs,results):
    gn,gn1 = split_pairs(pairs)
    egn = entropy(gn)
    egn1 = entropy(gn1)
    ce = conditional_entropy(gn,pairs)
    mi = mutual_information(pairs)
    
    results['mutual_information'] = mi
    results['entropy_gn'] = egn
    results['entropy_gn1'] = egn1
    results['conditional_entropy'] = ce
    results['variation_gn'] = len(set(gn))
    results['variation_gn1'] = len(set(gn1))
    results['number_of_pairs'] = len(set(pairs))
    
    return results

# %% [markdown]
# And a couple of functions that put everything together, saves the results to a separate file, and output a `pandas` dataframe so that we can take a good look. `ics_simulation` takes the full list of Kinbank filenames, extracts the relevant kin terms, performs the randomisation simulation on it a specified number of times, calculates entropy, conditional entropy, and MI for each simulation, and saves all that data to a separate file. It also performs some regex magic on the filename so that we get each language's unique code as well as each language's name in full.

# %%
def ics_simulation(filepath,all_files:list, times):
    df = []
    
    for file in all_files:
        match = re.search('[a-z]{4}[0-9]{4}', file)
        code = match.group()
        language = file.split('_' + code)[0]
        
        ks = get_kin_terms(filepath + file)
        
        for i in range(times):
            pairs = simulate_ks(ks)
            if pairs:
                results = {}
                results['language'] = language
                results['simulation_code'] = code + '_' + str(i)
                results['simulation'] = 'Y'
                write_data(pairs,results)

                df.append(results)
    
    pd.DataFrame(df).to_csv('../data/raw/ics_sims.csv',index=False)
    
    return pd.DataFrame(df)

# %% [markdown]
# `ics_real` performs similarly to `ics_simulation`, but instead of performing the randomisation, it calculates entropy, conditional entropy, and MI for the language as-is. It does this for every file in the Kinbank data and saves the data to a separate file.

# %%
def ics_real(filepath,all_files):
    df = []
    
    for file in all_files:
        print(file)
        match = re.search("[a-z]{4}[0-9]{4}[a-z]?", file)
        code = match.group()
        language = file.split('_' + code)[0]
        
        ks = get_kin_terms(filepath + file)

        pairs = get_pairs(ks)
        print(pairs)

        if pairs: # if pairs is not empty
            mi = mutual_information(pairs)

            results = {}
            results['language'] = language
            results['simulation_code'] = code + '_REAL'
            results['simulation'] = 'N'
            write_data(pairs,results)

            df.append(results)
        
    pd.DataFrame(df).to_csv('../data/raw/ics_real.csv',index=False)
    print(len(df))
    
    return pd.DataFrame(df)

# %% [markdown]
# ## Let's go!
#
# If we want to create a dataset from the real language data, we just have to run:

# %%
filter_filepath = '../languages/kinbank-filter/' # the filepath where the kinbank files are kept
filtered_kb_files = get_kb_files(filter_filepath)

ics_real(filter_filepath,filtered_kb_files)
# Out:
# 'Are'are_area1240.csv
# [('mama-na', 'hahone-na'), ('mama-na', "wa'a-na"), ('mama-na', "wa'a-na"), ('nike-na', 'ura-na'), ('nike-na', 'ura-na'), ('mama-na', 'hahone-na'), ('mama-na', "'āsi-na")]
# Abui_abui1241.csv
# None
# Achinese_achi1257.csv
# None
# Achuar_achu1249.csv
# [('apa', ''), ('apa', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', '')]
# Aché_ache1246.csv
# [('apã', "key'y"), ('apã', 'tywy'), ('apã', "key'y"), ('apã', 'tywy'), ('tuty', 'tuty ray'), ('tuty', 'tuty radjy'), ('ãpã', 'ãpã ray'), ('ãpã', 'ãpã radjy'), ('ei', 'ei memby'), ('ei', 'ei memby'), ('ei', 'ei memby'), ('ei', 'ei memby'), ('ãpã', 'ãpã ray'), ('ãpã', 'ei pawe radjy')]
# Adang_adan1251.csv
# [('-imang', '-matu'), ('-imang', "-di'"), ('-imang sel', '-matu'), ('-imang sel', '-matu'), ('-imang sel', '-matu'), ('-imang sel', '-matu'), ('-ife', '-matu'), ('-ife', '-matu'), ('-ife', '-matu'), ('-ife', '-matu'), ('-imang', '-matu'), ('-imang', "-di'")]
# Adnyamathanha_adny1235.csv
# [('papie', 'oowellie'), ('papie', 'pilhali'), ('papie', 'yacka'), ('papie', 'pilhali'), ('ngamarna', 'papapa'), ('ngamarna', 'papapa'), ('ataapi', 'papapa'), ('ataapi', 'ngaparla')]
# Aghul_aghu1253.csv
# [('dad', 'ču'), ('dad', 'bic’i ču'), ('dad', 'či'), ('dad', 'bic’i ču'), ('adad', 'čibxar'), ('adad', 'čibxar'), ('adad', 'čibxar'), ('adad', 'čibxar'), ('abab', 'čibxar'), ('abab', 'čibxar'), ('abab', 'čibxar'), ('abab', 'čibxar')]
# Agob-Ende-Kawam_agob1244.csv
# None
# Aguaruna_agua1253.csv
# [('apag', 'yac̷u-g'), ('apag', 'uba-g'), ('yac̷u-t', "i'ka 'yac̷u-t"), ('yac̷u-t', "i'ka 'yac̷u-t"), ("apa-'hu yači", "i'ka 'yac̷u-t"), ("apa-'hu yači", "i'ka 'yac̷u-t"), ('uma-yui', "i'ka 'yac̷u-t"), ('uma-yui', "i'ka 'yac̷u-t"), ("apa-'hu uma-yi", "i'ka 'yac̷u-t"), ("apa-'hu uma-yi", "i'ka 'yac̷u-t")]
# Akhvakh_Northern_Akhvakh__akhv1239.csv
# [('ima', 'wac̄i'), ('ima', 'ink̄ʼʷaw wac̄i'), ('ima', 'yac̄i'), ('ima', 'ink̄ʼʷay yac̄i'), ('ilow wac̄i', 'yac̄iqʼabi'), ('ilow wac̄i', 'yac̄iqʼabi'), ('imowa wac̄i', 'yac̄iqʼabi'), ('imowa wac̄i', 'yac̄iqʼabi'), ('iloy yac̄i', 'yac̄iqʼabi'), ('iloy yac̄i', 'yac̄iqʼabi'), ('imoy yac̄i', 'yac̄iqʼabi'), ('imoy yac̄i', 'yac̄iqʼabi')]
# Akkadian_akka1240.csv
# None
# Aklanon_akla1241.csv
# [('amá(h)', 'igmánghod'), ('amá(h)', 'manghod'), ('táta', 'igkámpod'), ('táta', 'igkámpod'), ('táta', 'igkámpod'), ('táta', 'igkámpod'), ('óra(h)', 'igkámpod'), ('óra(h)', 'igkámpod'), ('óra(h)', 'igkámpod'), ('óra(h)', 'igkámpod'), ('amá(h)', 'manong'), ('amá(h)', 'igmánghod')]
# Alangan_alan1249.csv
# [('mamang', 'magtalkaka'), ('mamang', 'magtalkaka'), ('papa', 'insan'), ('papa', 'insan'), ('papa', 'insan'), ('papa', 'insan'), ('akbáy', 'insan'), ('akbáy', 'insan'), ('akbáy', 'insan'), ('akbáy', 'insan'), ('mamang', 'magtalkaka'), ('mamang', 'magtalkaka')]
# Albanian_alba1267.csv
# [('babë', 'apë'), ('babë', 'vëlla'), ('babë', 'mommë'), ('babë', 'motër'), ('ungj', 'kushëri'), ('ungj', 'kushërirë'), ('xhaxha', 'kushëri'), ('xhaxha', 'kushërirë'), ('teze', 'kushëri'), ('teze', 'kushërirë'), ('emtë', 'kushëri'), ('emtë', 'kushërirë')]
# Albanian_Tosk__tosk1239.csv
# [('at', "və'la"), ('at', 'motər'), ('at', 'lʸoče'), ('dayə', "kušə'ri"), ('dayə', "kušə'ri"), ("ǰa'ǰa", "kušə'ri"), ("ǰa'ǰa", "kušə'ri"), ('teze', "kušə'ri"), ('teze', "kušə'ri"), ('halə', "kušə'ri"), ('halə', "kušə'ri")]
# Alyawarr_alya1239.csv
# [('akngiya', 'awiyatja'), ('akngiya', 'aytiyatja'), ('akngiya', 'angkuriya'), ('akngiya', 'aytiyatja'), ('apmaliya', 'apmaliya'), ('apmaliya', 'amiya'), ('awuniya', 'angkiliya'), ('awuniya', 'altjiliya')]
# Amharic_amha1245.csv
# [('abbat', 'tallaq wändem'), ('abbat', 'wändem'), ('abbat', 'tallaq ehet'), ('abbat', 'ehet'), ('aggot', 'yä-aggot lej'), ('aggot', 'yä-aggot lej'), ('aggot', 'yä-aggot lej'), ('aggot', 'yä-aggot lej'), ('akest', 'yä-akest lej'), ('akest', 'yä-akest lej'), ('akest', 'yä-akest lej'), ('akest', 'yä-akest lej')]
# Amis_amis1246.csv
# None
# Ampibabo_Lauje_ampi1237.csv
# [('siama', "sia'ang"), ('siama', 'tuai'), ("somama' -onyo", 'lulus sangaing'), ("somama' -onyo", 'lulus sangaing'), ("somama' -onyo", 'lulus sangaing'), ("somama' -onyo", 'lulus sangaing'), ('sitete', 'lulus sangaing'), ('sitete', 'lulus sangaing'), ('sitete', 'lulus sangaing'), ('sitete', 'lulus sangaing'), ('siama', "sia'ang"), ('siama', 'tuai')]
# Anambé_anam1249.csv
# None
# Ancient_Greek_anci1242.csv
# [('patḗr', 'kasígnētos'), ('patḗr', 'kasignḗtē'), ('theîos', 'anepsiós'), ('theîos', 'anepsiḗ'), ('theîos', 'anepsiós'), ('theîos', 'anepsiḗ'), ('tēthís', 'anepsiós'), ('tēthís', 'anepsiḗ'), ('tēthís', 'anepsiós'), ('tēthís', 'anepsiḗ')]
# Andi_andi1255.csv
# [('ima', 'woc̄i'), ('ima', 'mičʼi woc̄i'), ('ima', 'yoc̄i'), ('ima', 'mičʼi yec̄i (yoc̄i)'), ('iluƛi woc̄i', 'yacʔal'), ('iluƛi woc̄i', 'yacʔal'), ('imuy woc̄i', 'yacʔal'), ('imuy woc̄i', 'yacʔal'), ('iluƛi yoc̄i (yec̄i)', 'yacʔal'), ('iluƛi yoc̄i (yec̄i)', 'yacʔal'), ('imuy yoc̄i (yec̄i)', 'yacʔal'), ('imuy yoc̄i (yec̄i)', 'yacʔal')]
# Anejom_anei1239.csv
# [('etma-', 'natahen'), ('mata-', 'nega'), ('mata-', 'nega'), ('etma-', 'etwa-'), ('etma-', 'nega'), ('risi-', 'ega-'), ('risi-', 'ega-'), ('risi-', 'natahen'), ('risi-', 'ega-'), ('etma-', 'nataman'), ('etma-', 'etwa-')]
# Angaite_anga1316.csv
# None
# Aniwa_aniw1237.csv
# [('caku tata', 'tuku awe taurumatua'), ('caku tata', 'tuku kawe'), ('kaka', 'tuku tariki'), ('kaka', 'tuku fine'), ('mahaway', 'ta fungoku'), ('mahaway', 'cakwa: fine'), ('caku tata', 'tuku só'), ('caku tata', 'tuku só'), ('caku tata', 'ta kawe'), ('caku tata', 'ta kawe')]
# Anuta_anut1237.csv
# [('tamana', 'kave'), ('tuatina', 'taina'), ('tuatina', 'kave'), ('tamana', 'taina'), ('tamana', 'kave'), ('pae', 'taina'), ('pae', 'kave'), ('makitanga', 'taina'), ('makitanga', 'kave'), ('tamana', 'kave'), ('tamana', 'taina')]
# Arabana_arab1267.csv
# [('neia', 'sthutti'), ('neia', 'kupaka'), ('neia', 'kuppali'), ('neia', 'kupaka'), ('ngamakarti', 'withiwa'), ('ngamakarti', 'pilya'), ('ngawili', 'withiwa'), ('ngawili', 'pilya')]
# Arabana_arab1267a.csv
# None
# Araki_arak1252.csv
# [('ta', 'veroha-'), ('ta', 'verasi-'), ('lala', 'naru-'), ('lala', 'venaru-'), ('ta', 'vodai-'), ('ta', 'vesohori-'), ('puá', 'vodai-'), ('puá', 'vesohori-'), ('tetei-', 'ta'), ('tetei-', 'vesohori-'), ('ta', 'roha-'), ('ta', 'rasi-')]
# Araweté_araw1273.csv
# [('to', "heči'i"), ('to', "či'i"), ('to', 'heni'), ('toti', 'tiwã'), ('toti', 'tiwã'), ('to dɨ͂', "he či'i"), ('to dɨ͂', 'heni'), ('hi dɨ', "he či'i"), ('hi dɨ', 'heni'), ('đađe', 'tiwã'), ('đađe', 'tiwã'), ('to', 'čiwi'), ('to', "heči'i"), ('to', "či'i")]
# Archi_arch1244.csv
# [('diya', 'ušdu'), ('diya', 't’it̄u ušdu'), ('diya', 'došdur'), ('diya', 't’it̄ur došdur'), ('buwan ušdu', 'šekert̄u'), ('buwan ušdu', 'šekert̄ur'), ('ummun ušdu', 'šekert̄u'), ('ummun ušdu', 'šekert̄ur'), ('buwan došdur', 'šekert̄u'), ('buwan došdur', 'šekert̄ur'), ('ummun došdur', 'šekert̄u'), ('ummun došdur', 'šekert̄ur')]
# Aria_(Mouk-Aria)_mouk1240a.csv
# None
# Arizona_Yaqui_yaqu1251a.csv
# None
# Armenian_nucl1235.csv
# [('hayr', 'ełbayr'), ('hayr', "k'uyr"), ("k'eri", "k'eru tła"), ("k'eri", "k'eru ałǰik"), ('horełbayr', 'horełbor tła'), ('horełbayr', 'horełbor ałǰik'), ("morak'uyr", "morak'roǰ tła"), ("morak'uyr", "morak'roǰ ałǰik"), ("horak'uyr", "horak'roǰ tła"), ("horak'uyr", "horak'roǰ ałǰik")]
# Arosi_aros1241.csv
# None
# Asera_aser1237.csv
# None
# Assamese_assa1263.csv
# [('bopai', 'kƆkai'), ('bopai', 'bhaiti'), ('bopai', 'bhani'), ('momai', 'kākai bhāi'), ('dādei', 'kākai'), ('khuṛā', 'kākai'), ('māhī', 'kākai bhāi'), ('pehi', 'kākai')]
# Asu_Tanzania__asut1235.csv
# [('vava', 'ṃjinåwa ṃbaha'), ('vava', 'ṃjinåwa ṃdori'), ('vava', 'rumbúrya ṃbaha'), ('vava', 'rumbúrya ṃdori'), ('abu ṃbaha', 'mjinåwa'), ('abu ṃbaha', 'rumbúrya'), ('abu ṃdori', 'mjinåwa'), ('abu ṃdori', 'rumbúrya'), ('vava ṃkulu', 'mjinåwa'), ('vava ṃkulu', 'rumbúrya'), ('vava ṃdori', 'mjinåwa'), ('vava ṃdori', 'rumbúrya'), ('ṃkúlú', 'mjinåwa'), ('ṃkúlú', 'rumbúrya'), ('ṃdódo', 'mjinåwa'), ('ṃdódo', 'rumbúrya'), ('éngå ṃbaha', 'mjinåwa'), ('éngå ṃbaha', 'rumbúrya'), ('éngå ṃdori', 'mjinåwa'), ('éngå ṃdori', 'rumbúrya')]
# Atayal_atay1247.csv
# None
# Atchin_atch1238.csv
# [('mätuän', 'nötin mätuän'), ('mätuän', 'nötin mätuän'), ('tlmä-n', 'tasi-n'), ('mirä-', 'tasi-n'), ('mirä-', 'tasi-n'), ('te', 'tutuʃän'), ('te', 'tasi-n')]
# Atoni_(Uab_Meto)_uabm1237.csv
# [('amaf', 'fetof'), ('atoni amaf', 'fe lalan'), ('babaf', 'fe lalan'), ('amaf', 'tataf'), ('ainaf', "ba'ef"), ('babaf', 'mone lalan'), ('babaf', "ba'ef"), ('amaf', 'nauf'), ('amaf', 'tataf'), ('amaf', 'olif')]
# Atsugewi_atsu1245.csv
# [('tata', 'romikeni'), ('tata', "t'ida"), ('tsimi', 'tokhopi'), ('tsimi', 'tokhopi'), ('nipstir', 'tokhopi'), ('nipstir', 'tokhopi'), ('midi', 'tokhopi'), ('midi', 'tokhopi'), ('petcir', 'tokhopi'), ('petcir', 'tokhopi')]
# Atta_atta1244.csv
# None
# Avar_Ancux__ancu1238.csv
# [('emen', 'wac̄'), ('emen', 'tʼinaw wac̄'), ('emen', 'yac̄'), ('emen', 'tʼinay yac̄'), ('bubal wac̄', 'yacaʕal'), ('bubal wac̄', 'yacaʕal'), ('ʕeʕe', 'yacaʕal'), ('ʕeʕe', 'yacaʕal'), ('bubal yac̄', 'yacaʕal'), ('bubal yac̄', 'yacaʕal'), ('dadal yac̄', 'yacaʕal'), ('dadal yac̄', 'yacaʕal')]
# Avar_Andalal__anda1281.csv
# [('ima', 'woc̄i'), ('ima', 'mičʼi woc̄i'), ('ima', 'yoc̄i'), ('ima', 'mičʼi yec̄i (yoc̄i)'), ('iluƛi woc̄i', 'yacʔal'), ('iluƛi woc̄i', 'yacʔal'), ('imuy woc̄i', 'yacʔal'), ('imuy woc̄i', 'yacʔal'), ('iluƛi yoc̄i (yec̄i)', 'yacʔal'), ('iluƛi yoc̄i (yec̄i)', 'yacʔal'), ('imuy yoc̄i (yec̄i)', 'yacʔal'), ('imuy yoc̄i (yec̄i)', 'yacʔal')]
# Avar_avar1256.csv
# [('dada', 'vatsi'), ('dada', "t'inav vats"), ('dada', 'jats'), ('dada', "t'inay yats"), ('bubal vats', 'yatsalai'), ('bubal vats', 'yatsalai'), ('dadal vats', 'yatsalai'), ('dadal vats', 'yatsalai'), ('bybai yats', 'yatsalai'), ('bybai yats', 'yatsalai'), ('dadal jats', 'yatsalai'), ('dadal jats', 'yatsalai')]
# Avar_Batlux__batl1238.csv
# [('emen', 'wac'), ('emen', 'hitʼina wac'), ('emen', 'yac'), ('emen', 'hitʼina yac'), ('daci', 'yacħal'), ('daci', 'yacħal'), ('daci', 'yacħal'), ('daci', 'yacħal'), ('unqʼa', 'yacħal'), ('unqʼa', 'yacħal'), ('unqʼa', 'yacħal'), ('unqʼa', 'yacħal')]
# Avar_Hid_dialect__hidd1238.csv
# [('enso', 'was̄'), ('enso', 'hitʼino was̄'), ('enso', 'yas̄'), ('enso', 'hitʼine yas̄'), ('ebelaɬul was̄', 'yas̄ʕal'), ('ebelaɬul was̄', 'yas̄ʕal'), ('insol was̄', 'yas̄ʕal'), ('insol was̄', 'yas̄ʕal'), ('ebelaɬul yas̄', 'yas̄ʕal'), ('ebelaɬul yas̄', 'yas̄ʕal'), ('ensol (insol) yas̄', 'yas̄ʕal'), ('ensol (insol) yas̄', 'yas̄ʕal')]
# Avatime_avat1244.csv
# None
# Avava_(Bangasa_Dialect)_katb1237.csv
# [('mom', 'vivining'), ('mom', 'livinging'), ('ndat tanai', 'atung (nggöt)'), ('ndat tanai', 'atung (nggöt)'), ('galam', 'momlenei'), ('galam', 'galele'), ('mom', 'maning'), ('mom', 'tuang avin'), ('mom', 'tasing avin')]
# Avava_(Niviar_Dialect)_katb1237b.csv
# [('mama', 'vivine'), ('bimbi', 'nattna'), ('bimbi', 'nattna'), ('nggalele', 'mamalele'), ('nggalele', 'nggalele'), ('mama', 'man-')]
# Avava_katb1237a.csv
# None
# Avaz_Khunzakh__kunz1243.csv
# [('en', 'vats'), ('en', "g'it-ina vats"), ('en', 'jats'), ('en', "g'it-ina jats"), ("elel'ul vats", 'iatsg-al'), ("elel'ul vats", 'iatsg-al'), ('insul vats', 'iatsg-al'), ('insul vats', 'iatsg-al'), ("unk'achu", 'iatsg-al'), ("unk'achu", 'iatsg-al'), ("unk'achu", 'iatsg-al'), ("unk'achu", 'iatsg-al')]
# Avestan_aves1237.csv
# None
# Avá_Canoeiro_avac1239.csv
# None
# Awetí_awet1244.csv
# [('hapái', 'itatiý'), ('hapái', 'itiwýt'), ('hapái', 'inhýt'), ('awái', '0'), ('awái', '0'), ('hapáiiwyt', '0'), ('hapáiiwyt', '0'), ('0', '0'), ('0', '0'), ('aieié', '0'), ('aieié', '0'), ('hapái', 'ikiwýt'), ('hapái', 'itatét'), ('hapái', 'ikypiýt')]
# Ayiwo_ayiw1239.csv
# [('tumä', 'siwe'), ('giängä', 'gibo'), ('giängä', 'sibo'), ('tumä', 'gite'), ('tumä', 'siwe'), ('isä', 'gite'), ('isä', 'siwe'), ('siwe', 'gibo'), ('siwe', 'sibo'), ('tumä', 'ginuwe'), ('tumä', 'site')]
# Ayoreo_ayor1240.csv
# [("daa-'ye", "hõ'ra-i"), ("daa-'ye", "de'saai"), ("daa-'ye", "nee'ro"), ("daa-'ye", "i'naamia"), ("nira'mai", "hõ'ra-i"), ("nira'mai", "hõ'ra"), ("dake'raai", "hõ'ra-i"), ("dake'raai", "hõ'ra"), ("daa'terama", "hõ'ra-i"), ("daa'terama", "hõ'ra"), ("i'n̥o-gaa'te", "hõ'ra-i"), ("i'n̥o-gaa'te", "hõ'ra")]
# Aztec_clas1250.csv
# None
# Bacanese_Malay_(Bacan)_baca1243.csv
# [('papa dantjanaka', 'pasanakan'), ('papa dantjanaka', 'pasanakan'), ('papa dèkèa', 'pasanakan'), ('papa dèkèa', 'pasanakan'), ('dado', 'pasanakan'), ('dado', 'pasanakan'), ('dado', 'pasanakan'), ('dado', 'pasanakan')]
# Badimaya_badi1246.csv
# None
# Bafia_bafi1243.csv
# None
# Bahonsuai_baho1237.csv
# None
# Bahvalal_bagv1239.csv
# [('ima', 'was̄'), ('ima', 'mukʼuw was̄'), ('ima', 'yas̄'), ('ima', 'mukʼuy yas̄'), ('ilaɬiɬ was̄', 'yas̄āb'), ('ilaɬiɬ was̄', 'yas̄āb'), ('imaš̄uw was̄', 'yas̄āb'), ('imaš̄uw was̄', 'yas̄āb'), ('ilaɬiɬ yas̄', 'yas̄āb'), ('ilaɬiɬ yas̄', 'yas̄āb'), ('imaš̄uy yas̄', 'yas̄āb'), ('imaš̄uy yas̄', 'yas̄āb')]
# Balaesang_bala1314.csv
# None
# Balangao_bala1310.csv
# None
# Balinese_bali1278.csv
# [('rerama', 'embok'), ('rerama', 'adi'), ('nanang', 'misanan'), ('nanang', 'misanan'), ('rerama', 'misanan'), ('rerama', 'misanan'), ('nanang', 'misanan'), ('nanang', 'misanan'), ('rerama', 'misanan'), ('rerama', 'misanan'), ('meme', 'misanan'), ('meme', 'misanan'), ('bibi', 'misanan'), ('bibi', 'misanan'), ('meme', 'misanan'), ('meme', 'misanan'), ('bibi', 'misanan'), ('bibi', 'misanan'), ('rerama', 'bli'), ('rerama', 'adi')]
# Bali_Congo__bali1274.csv
# None
# Bali_DRC__bali1275.csv
# None
# Balochi_balo1260.csv
# [('mama', 'trizatk'), ('mama', 'trizatk'), ('baba', 'naxozatk'), ('baba', 'naxozatk'), ('masi', 'trizatk'), ('masi', 'trizatk'), ('pupu', 'trizatk'), ('pupu', 'trizatk')]
# Bamun_bamu1253.csv
# None
# Bandjalang_band1339.csv
# [('taari', 'gaguhng'), ('taari', 'bana:m'), ('taari', 'nunang'), ('taari', 'wabunj'), ('ga:waŋ', 'yirbuŋ'), ('ga:waŋ', 'yirpung'), ('ma:maŋ', 'ji:rbuŋ'), ('ma:maŋ', 'ji:rbuŋgan'), ('waduŋ', 'ji:rbuŋ'), ('waduŋ', 'ji:rbuŋgan'), ('ŋaruɲ', 'ji:rbuŋ'), ('ŋaruɲ', 'yirpung'), ('taari', 'nana:ŋ')]
# Banjar_banj1239.csv
# [('abah', 'kaka'), ('abah', 'ading'), ('dangsanak uma', 'sapupu sekali'), ('dangsanak uma', 'sapupu sekali'), ('dangsanak abah', 'sapupu sekali'), ('dangsanak abah', 'sapupu sekali'), ('dangsanak uma', 'sapupu sekali'), ('dangsanak uma', 'sapupu sekali'), ('dangsanak abah', 'sapupu sekali'), ('dangsanak abah', 'sapupu sekali'), ('abah', 'kaka'), ('abah', 'ading')]
# Bannock_bann1248.csv
# None
# Bannoni_bann1247.csv
# [('tama', 'kenanak'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('tama', 'kenanak')]
# Barabet_(Hano)_hano1246a.csv
# [('zimang (tita)', 'sizing'), ('mezang', 'maring'), ('mezang', 'sizing'), ('zimang (tita)', 'maring'), ('zimang (tita)', 'sizing'), ('dahing', 'maring'), ('dahing', 'sizing'), ('wawa', 'maring'), ('wawa', 'sizing'), ('zimang (tita)', 'sizing'), ('zimang (tita)', 'maring')]
# Bardi_bard1254.csv
# None
# Bario_Kelabit_bari1288.csv
# [('tama', 'kenanak'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('menakan', 'kanid'), ('tama', 'kenanak')]
# Bari_bari1297.csv
# [('aataida', 'asari'), ('aataida', 'aša'), ('abāma akbaĩ', 'sāya ša'), ('abāma akbaĩ', 'sāya ša'), ('aisī okarā', 'sāya ša'), ('aisī okarā', 'sāya ša'), ('abāma si', 'sāya ša'), ('abāma si', 'sāya ša'), ('ataida si', 'sāya ša'), ('ataida si', 'sāya ša')]
# Barok_(Karu)_baro1253.csv
# None
# Basque_basq1248.csv
# [('aita', "a'naie"), ('aita', "ã'hispa"), ("a'ma-ren a'naie", "kü'süɲa"), ("a'ma-ren a'naie", "kü'süɲa"), ("ai'ta-ren a'naie", "kü'süɲa"), ("ai'ta-ren a'naie", "kü'süɲa"), ("a'ma-ren ã'hispa", "kü'süɲa"), ("a'ma-ren ã'hispa", "kü'süɲa"), ("ai'ta-ren a'reba", "kü'süɲa"), ("ai'ta-ren a'reba", "kü'süɲa")]
# Basque_west1508.csv
# [('aita', 'anaia'), ('aita', 'arreba nagusia'), ('aita', 'arreba gaztea'), ('osaba', 'lehengusua'), ('osaba', 'lehengusina'), ('osaba', 'lehengusua'), ('osaba', 'lehengusina'), ('izeko', 'lehengusua'), ('izeko', 'lehengusina'), ('izeko', 'lehengusua'), ('izeko', 'lehengusina'), ('aita', 'neba nagusia'), ('aita', 'neba gatzea'), ('aita', 'ahizpa')]
# Batak_Toba_bata1289.csv
# [('among', 'akang boru'), ('among', 'anggi'), ('tulang', 'akang bawa'), ('tulang', 'pariban'), ('among tua', 'akang bawa'), ('among tua', 'akang boru'), ('amonguda', 'anggi'), ('amonguda', 'anggi'), ('inangtua', 'akang bawa'), ('inangtua', 'akang boru'), ('inangbaju', 'anggi'), ('inangbaju', 'anggi'), ('namboru', 'akang bawa'), ('namboru', 'akang boru'), ('among', 'akang bawa'), ('among', 'anggi')]
# Batanga_bata1285.csv
# [('paya', 'ntodu ami'), ('paya', 'ndembé ami'), ('paya', 'sita'), ('paya', 'iluhu'), ('ntodu wa nyangwé', 'bahongwé ya momo da ntodu wa nyangwé'), ('ntodu wa nyangwé', 'bahongwé ya ndito da ntodu wa nyangwé'), ('ndembé wa nyangwé', 'bahongwé ya momo da ndembé wa nyangwé'), ('ndembé wa nyangwé', 'bahongwé ya ndito da ndembé wa nyangwé'), ('ntodu wa hangwé', 'bahangwé ya momo da ntodu wa hangwé'), ('ntodu wa hangwé', 'bahangwé ya ndito da ntodu wa hangwé'), ('ndembé wa hangwé', 'bahangwé ya momo da ndembé wa hangwé'), ('ndembé wa hangwé', 'bahangwé ya ndito da ndembé wa hangwé'), ('sita wa nyangwé', 'banyangwé ya momo da sita wa nyangwé'), ('sita wa nyangwé', 'banyangwé ya ndito da sita wa nyangwé'), ('iluhu ya nyangwé', 'banyangwé ya momo'), ('iluhu ya nyangwé', 'banyangwé ya ndito'), ('sita wa hangwé', 'banyongwé ya momo da sita wa hangwé'), ('sita wa hangwé', 'banyongwé ya ndito da sita wa hangwé'), ('nyongwé', 'banyongwé ya momo'), ('nyongwé', 'banyongwé ya ndito')]
# Bats_Tsova_Tush__bats1242.csv
# [('dad', 'waš'), ('dad', 'k̛ac̛k̛ux waš'), ('dad', 'yaš'), ('dad', 'k̛ac̛k̛ux yaš'), ('nānwaš', 'šice'), ('nānwaš', 'šice'), ('dādwaš', 'šice'), ('dādwaš', 'šice'), ('nānes', 'šice'), ('nānes', 'šice'), ('maym(i)', 'šice'), ('maym(i)', 'šice')]
# Bau-Jagoi_Bidayuh_baub1235.csv
# None
# Baure_baur1253.csv
# None
# Belarusian_bela1254.csv
# [("bác'ka", 'brat'), ("bác'ka", 'sjastrá'), ("dzjádz'ka", 'dvajúradny brat'), ("dzjádz'ka", 'dvajúradnaja sjastrá'), ("dzjádz'ka", 'dvajúradny brat'), ("dzjádz'ka", 'dvajúradnaja sjastrá'), ('cëtka', 'dvajúradny brat'), ('cëtka', 'dvajúradnaja sjastrá'), ('cëtka', 'dvajúradny brat'), ('cëtka', 'dvajúradnaja sjastrá')]
# Bemba_bemb1257.csv
# [('tata', 'mukalamba'), ('tata', 'mwaice'), ('tata', 'nkashi'), ('yama', 'abafyala'), ('yama', 'abafyala'), ('mayosenge', 'abafyala'), ('mayosenge', 'abafyala'), ('tata', 'baice bakalamba'), ('tata', 'baice')]
# Bena_Tanzania__bena1262.csv
# [('yaya', 'muhisi'), ('yaya', 'muhisi'), ('dada', 'mama'), ('dada', 'muhasa'), ('dada mdodo', 'munununa'), ('dada mdodo', 'muhasa'), ('mayi', 'muhasa'), ('mayi mdodo', 'muhasa'), ('yuvahengi', 'muhisi'), ('yuvahengi', 'muhisi')]
# Bende_bend1258.csv
# [('táata', 'múkulwåna'), ('táata', 'ílúmbú lyane'), ('múkwetú', 'muyaleya'), ('múkwetú', 'muyaleya'), ('sêngé', 'muyaleya'), ('sêngé', 'muyaleya'), ('táata', 'ikololyane'), ('táata', 'jóójó')]
# Bengali_beng1280.csv
# [('bābā', 'dada'), ('bābā', 'bhāi'), ('bābā', 'didi'), ('bābā', 'bon'), ('māmā', 'mamato-bhai'), ('māmā', 'mamato-bon'), ('jeṭha-moshay', 'jeṭhtato-bhai'), ('jeṭha-moshay', 'jaṭhtato-bon'), ('khuda', 'khudtato-bhai'), ('khuda', 'khudtato-bon'), ('mashi-ma', 'mashtato-bhai'), ('mashi-ma', 'mashtato-bon'), ('pishi-ma', 'pishtato-bhai'), ('pishi-ma', 'pishtato-bon')]
# Bera_bera1259.csv
# [('mîkí', 'homioné'), ('mîkí', 'moto'), ('mîkí', 'alwané'), ('mîkí', 'moto'), ('noko', 'moko'), ('noko', 'moko'), ('om-epa', 'moko'), ('om-epa', 'moko'), ('mot-epa', 'moko'), ('mot-epa', 'moko'), ('om-ema', 'moko'), ('om-ema', 'moko'), ('mot-ema', 'moko'), ('mot-ema', 'moko'), ('kola', 'moko'), ('kola', 'moko')]
# Bezhta_bezh1248.csv
# [('abo', 'is'), ('abo', 'itʼino is'), ('abo', 'isi'), ('abo', 'itʼino isi'), ('iyos is', 'waccal'), ('iyos is', 'yaccal'), ('abos is', 'waccal'), ('abos is', 'yaccal'), ('iyoisi', 'waccal'), ('iyoisi', 'yaccal'), ('aboisi', 'waccal'), ('aboisi', 'yaccal')]
# Biak_biak1248.csv
# None
# Bierebo_bier1244.csv
# None
# Big_Nambas_bign1238.csv
# [('tatei', 'evünök'), ('tatei', 'tivalök'), ('vavwe', 'tet lalou'), ('vavwe', 'vavwe lil'), ('tatei', 'manök'), ('tatei', 'tivalök'), ('tatei', 'tivalök nöngk')]
# Big_Nambas_bign1238a.csv
# None
# Bihari_biha1245.csv
# None
# Bila_bila1255.csv
# [('èpá', 'homioné'), ('èpá', "apua'i a motoa"), ('èpá', 'alwané'), ('èpá', "apua'i a motoa"), ('noko', 'sono'), ('noko', 'sono'), ('moteba', 'namami'), ('moteba', 'namami'), ('omeba', 'namami'), ('omeba', 'namami'), ('om-ema', 'namami'), ('om-ema', 'namami'), ('mot-ema', 'namami'), ('mot-ema', 'namami'), ("alwa'e na epa", 'sono'), ("alwa'e na epa", 'sono'), ('moto e na epa', 'sono'), ('moto e na epa', 'sono')]
# Bilibil_bilb1241.csv
# [('mam', 'kak'), ('wajan', 'daowǎlín'), ('wajan', 'daowǎlín'), ('taman', 'gei'), ('taman', 'gei'), ('tinan', 'gei'), ('tinan', 'gei'), ('nǐmbin', 'daowǎlín'), ('nǐmbin', 'daowǎlín'), ('mam', 'kak'), ('mam', 'kak')]
# Bindal_bind1236.csv
# None
# Bininj_Kun-wok_gunw1252.csv
# None
# Binukid_(Talaandig-Binukid)_binu1244.csv
# [('amay', 'atebay'), ('amay', 'atebay'), ('abang', 'maqama'), ('abang', 'atebay'), ('abang', 'maqama'), ('abang', 'atebay'), ('idang', 'maqama'), ('idang', 'atebay'), ('idang', 'maqama'), ('idang', 'atebay'), ('amay', 'maqama'), ('amay', 'maqama'), ('amay', 'magulang ha bahi'), ('amay', 'manghed ha bahi')]
# Birhor_birh1242.csv
# None
# Biri_biri1256.csv
# [('yabu', 'kutta'), ('yabu', 'wupa'), ('yabu', 'waŋgubaya'), ('yabu', 'gadha'), ('galŋa', 'gangan(a)'), ('galŋa', 'gangan(a)'), ('galŋa', 'muguni'), ('galŋa', 'muguni'), ('bibi', 'maŋan(hi)'), ('bibi', 'maŋan(hi)')]
# Bit_bitt1240.csv
# [('ʔoiŋ mɨih hân', 'ʔuei ʔait'), ('ʔoiŋ mɨih hân', 'ʔuei ʔait'), ('ʔoiŋ diŋ', 'ʔuei ʔait'), ('ʔoiŋ diŋ', 'ʔuei ʔait'), ('meʔ sâi', 'ʔuei ʔait'), ('meʔ sâi', 'ʔuei ʔait'), ('meʔ mɨih', 'ʔuei ʔait'), ('meʔ mɨih', 'ʔuei ʔait')]
# Blagar_blag1240.csv
# [('-imang', '-edi'), ('-imang era', '-ebheang'), ('-imang era', '-ebheang'), ('-imang', '-kaku'), ('-imang', '-edi'), ('-iva', '-kaku'), ('-iva', '-edi'), ('-imang', '-edi'), ('-imang', '-kaku')]
# Boano_(Sulawesi)_boan1243.csv
# [('iamang', 'taddakona'), ('iamang', "tuai' -na"), ('pogiamangan', 'utas komiinsan'), ('pogiamangan', 'utas komiinsan'), ('pogiamangan', 'utas komiinsan'), ('pogiamangan', 'utas komiinsan'), ('iamang', 'taddakona'), ('iamang', "tuai' -na")]
# Boers_afri1274.csv
# [('vader', 'broer'), ('vader', 'suster'), ('oom', 'neef'), ('oom', 'niggie'), ('oom', 'neef'), ('oom', 'niggie'), ('tante', 'neef'), ('tante', 'niggie'), ('tante', 'neef'), ('tante', 'niggie')]
# Bontok_bont1247.csv
# [('ama', 'ötad'), ('ama', 'ötad'), ('alitau', 'kayim'), ('alitau', 'kayim'), ('alitau', 'kayim'), ('alitau', 'kayim'), ('mother', 'kayim'), ('mother', 'kayim'), ('mother', 'kayim'), ('mother', 'kayim'), ('ama', 'ötad'), ('ama', 'ötad')]
# Breton_bret1244.csv
# [('tad', 'breur'), ('tad', "c'hoar"), ('eontr kompez', 'kenderv'), ('eontr kompez', 'keniterv'), ('eontr kompez', 'kenderv'), ('eontr kompez', 'keniterv'), ('moereb gompez', 'kenderv'), ('moereb gompez', 'keniterv'), ('moereb gompez', 'kenderv'), ('moereb gompez', 'keniterv')]
# Brooke's_Point_Palawano_broo1239.csv
# None
# Brunei-Sabah_Malay_(Malay)_saba1263.csv
# [('bapa', 'lusud sa tian'), ('bapa', 'lusud sa tian'), ('bapa sudara', 'pupu'), ('bapa sudara', 'pupu'), ('bapa sudara', 'pupu'), ('bapa sudara', 'pupu'), ('mak muda', 'pupu'), ('mak muda', 'pupu'), ('mak muda', 'pupu'), ('mak muda', 'pupu'), ('bapa', 'lusud sa tian'), ('bapa', 'lusud sa tian')]
# Budukh_budu1248.csv
# [('ada', 'q̄ardaš'), ('ada', 'mikʼe šid'), ('ada', 'šidir'), ('ada', 'mikʼe šidir'), ('dayi', 'šidir'), ('dayi', 'šidir'), ('emi', 'šidir'), ('emi', 'šidir'), ('xala', 'šidir'), ('xala', 'šidir'), ('ʕama', 'šidir'), ('ʕama', 'šidir')]
# Budza_budz1238.csv
# None
# Buhid_buhi1245.csv
# [('mama', 'duasayan'), ('mama', 'duasayan'), ('bapa', 'insan'), ('bapa', 'insan'), ('bapa', 'insan'), ('bapa', 'insan'), ('baáy', 'insan'), ('baáy', 'insan'), ('baáy', 'insan'), ('baáy', 'insan'), ('mama', 'duasayan'), ('mama', 'duasayan')]
# Buin_buin1247.csv
# [('moka', 'noonoi'), ('moka', 'noonoi'), ('paapa', 'aapore'), ('paapa', 'aapore'), ('aagu', 'aapore'), ('aagu', 'aapore'), ('moka', 'noonoi'), ('moka', 'noonoi')]
# Bukat_buka1261.csv
# [('amak', 'arik'), ('aki', 'aken'), ('aki', 'aken'), ('aki', 'aken'), ('aki', 'aken'), ('ipui', 'aken'), ('ipui', 'aken'), ('ipui', 'aken'), ('ipui', 'aken'), ('amak', 'arik')]
# Bukusu_buku1249.csv
# [('paapa', 'ómukhulu'), ('paapa', 'ómuro'), ('paapa', 'ómukhulu'), ('paapa', 'ómuro'), ('khóóchá', 'waanda'), ('khóóchá', 'yaaya'), ('paapa', 'waanda'), ('paapa', 'yaaya'), ('ómuro', 'waanda'), ('ómuro', 'yaaya'), ('maayi', 'waanda'), ('maayi', 'yaaya'), ('ómuro', 'waanda'), ('ómuro', 'yaaya'), ('seenge', 'waanda'), ('seenge', 'yaaya')]
# Bulgarian_bulg1262.csv
# [('bašta', 'batko'), ('bašta', 'brat'), ('bašta', 'kaka'), ('bašta', 'sestra'), ('vujčo', 'bratovčed'), ('vujčo', 'bratovčedka'), ('čičo', 'bratovčed'), ('čičo', 'bratovčedka'), ('tetka', 'bratovčed'), ('tetka', 'bratovčedka'), ('lelja', 'bratovčed'), ('lelja', 'bratovčedka')]
# Buli_buli1256.csv
# [('toewai', 'fano'), ('toewai', 'fano maping'), ('toewai', 'fano'), ('toewai', 'fano maping'), ('fofai', 'fano'), ('fofai', 'fano maping'), ('fofai', 'fano'), ('fofai', 'fano maping')]
# Bunganditj_bung1264.csv
# [('mam', 'tjati'), ('mam', 'nyuwiyar'), ('ngami', 'nariki'), ('ngami', 'nariki'), ('mami', 'nariki'), ('mami', 'nariki'), ('papi', 'nariki'), ('papi', 'nariki'), ('mungayn', 'nariki'), ('mungayn', 'nariki'), ('yawuri', 'miritkil nuratji'), ('yawuri', 'nguper'), ('mam', 'warkali'), ('mam', 'tuwati')]
# Bungku_bung1269.csv
# [('tuˀa', 'tukaka'), ('tuˀa', 'tuai'), ('lakiˀama', 'poteha'), ('lakiˀama', 'poteha'), ('lakiˀama', 'poteha'), ('lakiˀama', 'poteha'), ('lakiˀina', 'poteha'), ('lakiˀina', 'poteha'), ('lakiˀina', 'poteha'), ('lakiˀina', 'poteha'), ('tuˀa', 'tukaka'), ('tuˀa', 'tuai')]
# Bunun_bunu1267.csv
# None
# Burmese_nucl1310.csv
# None
# Buru_(Indonesia)_buru1303.csv
# None
# Bushoong_bush1247.csv
# [('tata', 'pangi'), ('tata', 'pangi'), ('baba', 'baba'), ('baba', 'genge'), ('ngola muota', 'baba'), ('ngola muota', 'genge'), ('yaya', 'baba'), ('yaya', 'genge'), ('fatata', 'baba'), ('fatata', 'genge')]
# Butmas-Tur_butm1237.csv
# None
# Bwaidoga_bwai1243.csv
# None
# Cahuilla_cahu1264.csv
# [('táata', 'is-ka'), ('táata', '-wáxalˠ'), ('tas', "ñuk'u"), ('tas', "ñuk'u"), ('kum', 'pas'), ('kum', 'kis'), ('mas', 'yul'), ('mas', 'nawal'), ('nes', 'pas'), ('nes', 'kis'), ('yes', 'yul'), ('yes', 'nawal')]
# Carolinians_caro1242.csv
# None
# Car_Nicobarese_carn1240.csv
# None
# Casiguran_Dumagat_Agta_casi1235.csv
# [("'ama", "'aka"), ("'ama", "'wadi"), ('amay', "'pensan"), ('amay', "'pensan"), ('amay', "'pensan"), ('amay', "'pensan"), ("'dada", "'pensan"), ("'dada", "'pensan"), ("'dada", "'pensan"), ("'dada", "'pensan"), ("'ama", "'aka"), ("'ama", "'wadi")]
# Cayubaba_cayu1262.csv
# None
# Cebuano_cebu1242.csv
# [('úyung', 'súun ig-'), ('úyung', 'manghud'), ('uyuan', 'igtagsa'), ('uyuan', 'igtagsa'), ('uyuan', 'igtagsa'), ('uyuan', 'igtagsa'), ('anti', 'igtagsa'), ('anti', 'igtagsa'), ('anti', 'igtagsa'), ('anti', 'igtagsa'), ('úyung', 'súun ig-'), ('úyung', 'manghud')]
# Central_Aymara_cent2142.csv
# None
# Central_Cagayan_Agta_cent2084.csv
# [('dama-', 'kábayán'), ('úte', 'kasinsin'), ('úte', 'kasinsin'), ('úte', 'kasinsin'), ('úte', 'kasinsin'), ('masina', 'kasinsin'), ('masina', 'kasinsin'), ('masina', 'kasinsin'), ('masina', 'kasinsin'), ('dama-', 'kalakyán'), ('dama-', 'kaka-'), ('dama-', 'wagi')]
# Central_Kurdish_cent1972.csv
# [('baok', 'bra'), ('baok', 'khusk'), ('khal', 'khaloaza'), ('khal', 'khaloaza'), ('mam', 'amoaza'), ('mam', 'amoaza'), ('pur', 'purza'), ('pur', 'purza'), ('pur', 'purza'), ('pur', 'purza')]
# Central_Melanau_cent2101.csv
# [('tama', 'janek mahau tika'), ('tua', 'jipo'), ('tua', 'jipo'), ('tua', 'jipo'), ('tua', 'jipo'), ('tebuso', 'jipo'), ('tebuso', 'jipo'), ('tebuso', 'jipo'), ('tebuso', 'jipo'), ('tama', 'tadei lai'), ('tama', 'janek mahau tadei')]
# Central_Sama_cent2092.csv
# [("ama'", 'siyaka'), ("ama'", 'siyali'), ("bapa'", 'kaki'), ("bapa'", 'kaki'), ("bapa'", 'kaki'), ("bapa'", 'kaki'), ("babu'", 'kaki'), ("babu'", 'kaki'), ("babu'", 'kaki'), ("babu'", 'kaki'), ("ama'", 'siyaka'), ("ama'", 'siyali')]
# Central_Subanen_(Subanung)_cent2089.csv
# None
# Central_Tagbanwa_cent2090.csv
# [('amiy', 'ilog'), ('amiy', 'ilog'), ('amiy', 'ilog'), ('amiy', 'ilog'), ('iniy', 'ilog'), ('iniy', 'ilog'), ('iniy', 'ilog'), ('iniy', 'ilog'), ('ama', 'kapatid')]
# Chamalal_cham1309.csv
# [('ima', 'wac'), ('ima', 'mikʼuwus̄ wac'), ('ima', 'yac'), ('ima', 'mikʼiyis̄ yac'), ('iluƛ wac', 'yacāb'), ('iluƛ wac', 'yacāb'), ('imu wac', 'yacāb'), ('imu wac', 'yacāb'), ('iluƛ yac', 'yacāb'), ('iluƛ yac', 'yacāb'), ('imi yac', 'yacāb'), ('imi yac', 'yacāb')]
# Chamalal_Gigatli__giga1238.csv
# [('ima', 'woci'), ('ima', 'tʼano woci'), ('ima', 'yaci'), ('ima', 'tʼane yaci'), ('iluɬi wocu', 'yacab'), ('iluɬi wocu', 'yacab'), ('imuɬi wocu', 'yacab'), ('imuɬi wocu', 'yacab'), ('babacu', 'yacab'), ('babacu', 'yacab'), ('dadacu', 'yacab'), ('dadacu', 'yacab')]
# Chamarro_cham1312.csv
# [('tata', 'chêla'), ('tio', 'primo'), ('tio', 'prima'), ('tio', 'primo'), ('tio', 'prima'), ('tía', 'primo'), ('tía', 'prima'), ('tía', 'primo'), ('tía', 'prima'), ('tata', 'chêlo')]
# Chavacano_chav1241.csv
# [('tata', 'hermana manang'), ('tata', 'hermana'), ('tio', 'primo'), ('tio', 'prima'), ('tio', 'primo'), ('tio', 'prima'), ('tia', 'primo'), ('tia', 'prima'), ('tia', 'primo'), ('tia', 'prima'), ('tata', 'hermano manung'), ('tata', 'hermano')]
# Cha_palaa_chac1249.csv
# None
# Cheke_Holo_chek1238.csv
# None
# Chemehuevi_chem1251.csv
# None
# Chenchu_chen1255.csv
# None
# Chepang_chep1245.csv
# None
# Chimariko_chim1301.csv
# [('itcila', 'uluida'), ('magola', 'antxala'), ('magola', 'antxala'), ('magola', 'antxala'), ('magola', 'antxala'), ('mutala', 'antxala'), ('mutala', 'antxala'), ('uluida', 'antxala'), ('uluida', 'antxala')]
# Chipaya_chip1262.csv
# None
# Chiricahua_mesc1238.csv
# [('cìtàˑ', 'cìkìs'), ('cìtàˑ', "cílà'"), ("cìdài'", 'cìkìs'), ("cìdài'", "cílà'"), ("cìdèˑdéˑ'", 'cìkìs'), ("cìdèˑdéˑ'", "cílà'"), ("cìdài'", 'cìkìs'), ("cìdài'", "cílà'"), ("cìdèˑdéˑ'", 'cìkìs'), ("cìdèˑdéˑ'", 'cìɣóyé')]
# Chiriguano_east2555.csv
# [('ché-ru', 'che-rɨkéɨ'), ('ché-ru', 'che-rɨ́wɨ'), ('ché-ru', 'che-rɨ́ke'), ('ché-ru', '0'), ('che-tútɨ', 'r-ɨkeɨ'), ('che-tútɨ', 'r-ɨkeɨ'), ('-tutɨ', 'r-ɨkeɨ'), ('-tutɨ', 'r-ɨkeɨ'), ('che-sɨ́́i', 'r-ɨkeɨ'), ('che-sɨ́́i', 'r-ɨkeɨ'), ('che-yéiche', 'r-ɨkeɨ'), ('che-yéiche', 'r-ɨkeɨ'), ('ché-ru', '(če-)r-ɨwɨ'), ('ché-ru', 'che-pɨ́kɨ')]
# Chokwe_chok1245.csv
# [('matu', 'musonyi'), ('matu', 'musonyi'), ('tata wa songo', 'pangi'), ('tata wa songo', 'ndumbu'), ('mama wa songo', 'pangi'), ('mama wa songo', 'ndumbu'), ('tata pwo', 'musonyi'), ('tata pwo', 'musonyi')]
# Chuukese_(Trukese)_chuu1238.csv
# None
# Cinta_Larga_cint1239.csv
# [('pyyp', 'kyptï'), ('pyyp', 'matkyp'), ('pyyp', 'kyptï'), ('pyyp', 'matkyp'), ('gaj', 'kyptï'), ('gaj', 'matkyp'), ('zobyi', 'opip'), ('zobyi', 'pakaj'), ('terit', 'terit'), ('pyyp', 'zoakyp'), ('pyyp', 'majtï'), ('terit', 'koko'), ('pyyp', 'zoakyp'), ('pyyp', 'majtï'), ('gaj', 'zoakyp'), ('gaj', 'majtï')]
# Coastal_Yuki_yuki1243b.csv
# None
# Cocama_Cocamilla_coca1259.csv
# [('patiri', 'imua'), ('patiri', 'kunia'), ('pai', 'ima'), ('pai', 'kunia'), ('pai', 'ima'), ('pai', 'kunia'), ('mamakira', 'ima'), ('mamakira', 'kunia'), ('mamakira', 'ima'), ('mamakira', 'kunia'), ('patiri', 'kiwira'), ('patiri', 'paya')]
# Cocopa_coco1261.csv
# [("enyiku'", 'hidjisa'), ("enyiku'", 'inyathus'), ('enyikwa', 'iLya'), ('enyikwa', 'ilya'), ('whinyiwit', 'kûsa'), ('whinyiwit', 'hidjisa'), ('whinyiskau', 'inyahul'), ('whinyiskau', 'ilya'), ('enyûsi', 'kûsa'), ('enyimu', 'ilya'), ('enyipi', 'iLya'), ('enyipi', 'hidjisa'), ("enyiku'", 'kûsa'), ("enyiku'", 'inyahul')]
# Cofan_cofa1242.csv
# None
# Colloquial_Malay_mala1479.csv
# [('bapak', 'kakak'), ('bapak', 'adek'), ('bapak penakan', 'kakak'), ('bapak penakan', 'kakak'), ('bapak penakan', 'kakak'), ('bapak penakan', 'kakak'), ('emak penakan', 'kakak'), ('emak penakan', 'kakak'), ('emak penakan', 'kakak'), ('emak penakan', 'kakak')]
# Colorado_Ute_utee1244a.csv
# None
# Comanche_coma1245.csv
# [('ahpï', "pabi'i"), ('ahpï', "tami'"), ('ahpï', "paci'"), ('ahpï', "nami'"), ("ara'", 'haic'), ("ara'", 'paci'), ('api', 'haic'), ('api', 'paci'), ('pia', 'haic'), ('pia', 'paci'), ('paha', 'haic'), ('paha', 'paci')]
# Copper_Inuit_copp1244.csv
# [('aappak', 'angayuk'), ('aappak', 'nukaq'), ('aappak', 'aliqa'), ('aappak', 'nayak'), ('', 'angak'), ('', 'arnarvik'), ('', 'angak'), ('', 'arnarvik'), ('', 'angak'), ('', 'arnarvik'), ('', 'angak'), ('', 'arnarvik'), ('aappak', 'ani'), ('aappak', 'aqqaluaq'), ('aappak', 'angayuk'), ('aappak', 'nukaq')]
# Cora_elna1235.csv
# None
# Cornish_corn1251.csv
# None
# Cotabato_Manobo_cota1241.csv
# None
# Cruzeño_cruz1243.csv
# None
# Cubeo_cube1242.csv
# [('pacumacu', 'yócu'), ('pacumacu', 'yóco'), ('pacomaco', 'yócu'), ('pacomaco', 'yóco'), ('parīmu', 'jíchumacu'), ('parīmu', 'jímaco')]
# Cupeño_cupe1243.csv
# [('-na', 'páʂma'), ('-na', 'kanima'), ('-na', 'qísma'), ('-na', '-wáxalˠi'), ('táʂma', 'nukma'), ('táʂma', 'nukma'), ('kum', 'pasma'), ('kum', 'kisma'), ('meš', 'kanima'), ('meš', 'wahali'), ('neʂ', 'pasma'), ('neʂ', 'kisma'), ('yéʂma', 'kanima'), ('yéʂma', 'wahali'), ('-pah(a)', 'nukma'), ('-pah(a)', 'nukma')]
# Cusco_Quechua_cusc1236.csv
# [('yaya.', 'wayqe'), ('yaya.', 'pana'), ('kaka', 'kuncha'), ('kaka', 'qayri pana'), ("sullk'a mama", 'qayri'), ("sullk'a mama", 'qayri pana'), ('ipa.', 'qayri'), ('ipa.', 'qayri pana'), ('yaya.', 'tura'), ('yaya.', 'ñaña.')]
# Czech_czec1258.csv
# [('otec', 'bratr'), ('otec', 'sestra'), ('strýc', 'bratranec'), ('strýc', 'sestřenice'), ('strýc', 'bratranec'), ('strýc', 'sestřenice'), ('teta', 'bratranec'), ('teta', 'sestřenice'), ('teta', 'bratranec'), ('teta', 'sestřenice')]
# Daakie_port1286.csv
# None
# Dakaka_daka1243.csv
# [('taata', 'meteseli'), ('taata', 'bivian'), ('taata', 'meteseli'), ('naana', 'bivian'), ('naana', 'meteseli'), ('nó', 'udun'), ('nó', 'waawu'), ('taata', 'munukuli'), ('taata', 'bivian')]
# Dalabon_ngal1292.csv
# None
# Dampelas_damp1237.csv
# [('siamang', "sia'a"), ('siamang', 'tuai'), ('posiamaung', 'pontolituai sembiti'), ('posiamaung', 'pontolituai sembiti'), ('posiamaung', 'pontolituai sembiti'), ('posiamaung', 'pontolituai sembiti'), ('posinaung', 'pontolituai sembiti'), ('posinaung', 'pontolituai sembiti'), ('posinaung', 'pontolituai sembiti'), ('posinaung', 'pontolituai sembiti'), ('siamang', "sia'a"), ('siamang', 'tuai')]
# Dandami_Maria_dand1238.csv
# [('tāppe', 'akkā'), ('tāppe', 'hellār'), ('māmā', 'marriyō'), ('māmā', 'mandāri'), ('ātō', 'marriyo'), ('ātō', 'mandāri'), ('tāppe', 'dādā'), ('tāppe', 'tamō')]
# Danish_dani1285.csv
# [('far', 'bror'), ('far', 'lillebror'), ('far', 'søster'), ('far', 'lillesøster'), ('morbror', 'søskendebarn'), ('morbror', 'søskendebarn'), ('farbror', 'søskendebarn'), ('farbror', 'søskendebarn'), ('moster', 'søskendebarn'), ('moster', 'søskendebarn'), ('faster', 'søskendebarn'), ('faster', 'søskendebarn')]
# Dargwa_Chirag__chir1284.csv
# [('dat̄e', 'uc̄e'), ('dat̄e', 'nikʼel uc̄e'), ('dat̄e', 'ruc̄e'), ('dat̄e', 'nikʼel ruc̄e'), ('dat̄iq’ar', 'ruc̄iq’ar'), ('dat̄iq’ar', 'ruc̄iq’ar'), ('dat̄iq’ar', 'ruc̄iq’ar'), ('dat̄iq’ar', 'ruc̄iq’ar'), ('šiq’an', 'ruc̄iq’ar'), ('šiq’an', 'ruc̄iq’ar'), ('šiq’an', 'ruc̄iq’ar'), ('šiq’an', 'ruc̄iq’ar')]
# Dargwa_Itsari__itsa1239.csv
# [('t̄at̄i', 'uc̄i'), ('t̄at̄i', 'nuqʼe uc̄i'), ('t̄at̄i', 'ruc̄i'), ('t̄at̄i', 'nuqʼe ruc̄i'), ('ac̄i', 'kʼʷini uc̄iqʼar'), ('ac̄i', 'kʼʷini uc̄iqʼar'), ('ac̄i', 'kʼʷini uc̄iqʼar'), ('ac̄i', 'kʼʷini uc̄iqʼar'), ('azay', 'kʼʷini uc̄iqʼar'), ('azay', 'kʼʷini uc̄iqʼar'), ('azay', 'kʼʷini uc̄iqʼar'), ('azay', 'kʼʷini uc̄iqʼar')]
# Dari_dari1249.csv
# [('pedar', 'barādar'), ('pedar', 'xāhar'), ('dāi', 'pesær-dayi'), ('dāi', 'doxtær-dayi'), ('amu', 'pesær-æmu'), ('amu', 'doxtær-æmu'), ('xāle', 'pesær-xale'), ('xāle', 'doxtær-xale'), ('amme', 'pesær-æmme'), ('amme', 'doxtær-æmme')]
# Degexit_an_dege1248.csv
# None
# Dehong_deho1238.csv
# None
# Dehu_dehu1237.csv
# None
# DeneTha_South_Slavey__sout2959.csv
# [('setá', 'gundee héʔi'), ('setá', 'sechílé'), ('setá', 'sembade'), ('setá', 'sedéa'), ('seʔeh', 'sóot’į'), ('seʔeh', 'sóot’į'), ('seʔeh', 'sóot’į'), ('seʔeh', 'sóot’į'), ('sǫ héʔi', 'sóot’į'), ('sǫ héʔi', 'sóot’į'), ('ehmbée héʔi', 'sóot’į'), ('ehmbée héʔi', 'sóot’į')]
# Dene_Suliné_chip1261.csv
# [('abá', 'sare'), ('abá', 'sedézé'), ('seʔe', 'sela'), ('seʔe', 'sela'), ('seʔe', 'sela'), ('seʔe', 'sela'), ('sâk’íe nî', 'sela'), ('sâk’íe nî', 'sela'), ('sâk’íe nî', 'sela'), ('sâk’íe nî', 'sela'), ('abá', 'sunaghe'), ('abá', 'sechÿle')]
# De_kwana_Maquiritari__maqu1238.csv
# [('haha', '-nuwā-dɨ'), ('haha', 'šīʔčɨ'), ('yawo', 'yāʔko'), ('yawo', 'yāʔko'), ('haha', 'yāʔko'), ('haha', 'yāʔko'), ('denɨ', 'yāʔko'), ('denɨ', 'yāʔko'), ('waynɲeʔney', 'yāʔko'), ('waynɲeʔney', 'yāʔko')]
# Dharumbal_dhar1248.csv
# None
# Dharumbal_dhar1248a.csv
# None
# Dhuwal-Dhuwala_(Yolngu)_dhuw1248.csv
# [('bäpa', 'yapa'), ('ŋapipi', 'galay'), ('ŋapipi', 'galay'), ('bäpa', 'yapa'), ('ŋandi', 'yapa'), ('mukul bäpa', 'dhuway'), ('mukul bäpa', 'dhuway'), ('bäpa', 'wäwa'), ('bäpa', 'yukuyuku'), ('bäpa', 'yukuyuku')]
# Dhuwal_dhuw1249.csv
# [('mu:rri', 'wa:wa'), ('mu:rri', 'gutha'), ('mu:rri', 'mirdiku'), ('ngapipi7', 'mulirriɲ7'), ('ngapipi7', 'mulirriɲ7'), ('mu:kul', 'mulirriɲ7'), ('mu:kul', 'mulirriɲ7'), ('mu:rri', 'yapa'), ('mu:rri', 'gutha')]
# Digo_digo1243.csv
# [('baba', 'mvyere'), ('baba', 'mdide'), ('baba', 'mvyere'), ('baba', 'mdide'), ('aphu', 'mkpwoi'), ('aphu', 'mkpwoi'), ('baba mvyere', 'mwenenu'), ('baba mvyere', 'mwenenu'), ('baba mdide', 'mwenenu'), ('baba mdide', 'mwenenu'), ('mayo mvyere', 'mwenenu'), ('mayo mvyere', 'mwenenu'), ('mayo mdide', 'mwenenu'), ('mayo mdide', 'mwenenu'), ('shangazi', 'mkpwoi'), ('shangazi', 'mkpwoi')]
# Ding_ding1239.csv
# [('taa', 'ŋkur wu kup'), ('taa', 'mukoom'), ('taa', 'ijℇ'), ('taa', 'mukoom'), ('mpja', 'mwátaá'), ('mpja', 'mwátaá'), ('taa koom', 'mwátaá'), ('taa koom', 'mwátaá'), ('maa koom', 'mwátaá'), ('maa koom', 'mwátaá'), ('taa mukaar', 'mwátaá'), ('taa mukaar', 'mwátaá')]
# Diyari_dier1241.csv
# [('ngapiṛi', 'niyi'), ('ngapiṛi', 'ngathata'), ('ngapiṛi', 'kaku'), ('ngapiṛi', 'ngathata'), ('kaka', 'kami'), ('kaka', 'kami'), ('will', 'puyuru'), ('will', 'puyuru'), ('yapa', 'kami'), ('yapa', 'kaku'), ('papa', 'kami')]
# Diyari_dier1241a.csv
# [('ngapiri', 'kaku'), ('ngapiri', 'natarta'), ('yandri waka', 'kami'), ('yandri waka', 'kami'), ('ngapiri', 'natata'), ('ngapiri', 'natata'), ('titnaRa', 'puyurru'), ('titnaRa', 'puyurru'), ('papa', 'kami'), ('papa', 'kami'), ('ngapiri', 'nhiyi'), ('ngapiri', 'nartala'), ('kaka', 'karti'), ('tyipi', 'papa'), ('tyipi', 'kaku'), ('papa', 'kami')]
# Djambarrpuyngu_djam1256.csv
# [('tyawurlpa', 'waawa'), ('tyawurlpa', 'yukuyuku'), ('tyawurlpa', 'yapa'), ('tyawurlpa', 'yukuyuku'), ("ngapipi\\'", 'ngarnarnawa'), ("ngapipi\\'", 'ngarnarnawa'), ('muukul', 'nganapa'), ('muukul', 'nganapa')]
# Djapu_dhuw1249.csv
# None
# Djinang_djin1253.csv
# [('nyarraka', 'wuwi'), ('nyarraka', 'yukuyuku'), ('nyarraka', 'muginyinymigi'), ('gaykiy', 'minini'), ('gaykiy', 'minini'), ('nyarraka', 'kalikali'), ('nyarraka', 'gurrung')]
# Djinang_djin1253a.csv
# [('djirra', 'gaditi'), ('gaykiy', 'minini'), ('gaykiy', 'minini'), ('bapipi', 'bapipagirang budjirrbi'), ('bapipi', 'bapipagirang budjirrbi'), ('djirra', 'wuwi'), ('djirra', 'gulmiki')]
# Dobu_dobu1241.csv
# [('wana', 'nibana'), ('wana', 'nibana'), ('tamana', 'tasina'), ('sinana', 'nibana'), ('sinana', 'nibana'), ('tamana', 'tasina')]
# Dogrib_dogr1252.csv
# None
# Dondo_dond1249.csv
# [('siuma', "sia'a"), ('siuma', 'tuai'), ('ponsiamaan', 'sounga'), ('ponsiamaan', 'sounga'), ('ponsiamaan', 'sounga'), ('ponsiamaan', 'sounga'), ('ponsiamaan', 'sounga'), ('ponsiamaan', 'sounga'), ('ponsiamaan', 'sounga'), ('ponsiamaan', 'sounga'), ('ponsinaan', 'sounga'), ('ponsinaan', 'sounga'), ('ponsinaan', 'sounga'), ('ponsinaan', 'sounga'), ('ponsinaan', 'sounga'), ('ponsinaan', 'sounga'), ('ponsinaan', 'sounga'), ('ponsinaan', 'sounga'), ('siuma', "sia'a"), ('siuma', 'tuai')]
# Duala_dual1243.csv
# [('sángó', 'múnasángo boso'), ('sángó', 'múnasángo ngoka'), ('sángó', 'múnasángo boso'), ('sángó', 'múnasángo ngoka'), ("mulál'a tokitoki", 'mulalo'), ("mulál'a tokitoki", 'mulalo'), ('sángó nusadi', 'mulalo'), ('ǹangó ińsadi', 'bána na bána'), ('ǹangó ińsadi', 'mola'), ('ǹangó nusadi', 'mulalo')]
# Duma_duma1253.csv
# None
# Duna_duna1248.csv
# None
# Dupaningan_Agat_dupa1235.csv
# None
# Dutch_dutc1256.csv
# [('vader', 'broer'), ('vader', 'zus'), ('oom', 'neef'), ('oom', 'nicht'), ('oom', 'neef'), ('oom', 'nicht'), ('tante', 'neef'), ('tante', 'nicht'), ('tante', 'neef'), ('tante', 'nicht')]
# Duungidjawu_duun1241.csv
# None
# Dyirbal_dyir1250.csv
# [('ŋuma(ndi)', 'bayi mugirray'), ('ŋuma(ndi)', 'bayi yabuju'), ('ŋuma(ndi)', 'balan yayin'), ('ŋuma(ndi)', 'balan jaman'), ('bayi mugu', 'balan ñubi'), ('bayi mugu', 'balan waymin'), ('bayi gaya', 'bayi wuribu'), ('bayi gaya', 'balan guyugan'), ('bayi bimu', 'bayi mugirray'), ('bayi bimu', 'balan yayin'), ('bayi ŋuma', 'bayi yabuju'), ('bayi ŋuma', 'balan jaman'), ('balan mugunan', 'bayi mugirray'), ('balan mugunan', 'balan yayin'), ('jarraga', 'bayi yabuju'), ('jarraga', 'balan jaman'), ('balan bimu', 'balan ñubi'), ('balan bimu', 'balan waymin'), ('balan ŋalban', 'bayi wuribu'), ('balan ŋalban', 'balan guyugan')]
# Dzonghka_Lhop_dzon1239.csv
# None
# Dzonghka_Sha_dzon1239.csv
# None
# Dzonghka_Wang_wang1287.csv
# None
# Délįne_nort2942.csv
# [("įt'á", 'sedare'), ("įt'á", 'sedə'), ('seʔe', 'ełechileke'), ('seʔe', 'ełedә́ke'), ('setąa', 'ełechileke'), ('setąa', 'ełedә́ke'), ('sebée', 'ełechileke'), ('sebée', 'ełedә́ke'), ('senǫǫ', 'ełechileke'), ('senǫǫ', 'ełedә́ke')]
# Eastern_Armenian_east2283.csv
# [('hayr', 'yeɣbayr'), ('hayr', 'pʰokʰr yeɣbayr'), ('hayr', 'kʰuyr'), ('hayr', 'pʰokʰ[ə]r kʰuyr'), ('moryeɣbayr', 'zarmuhi'), ('moryeɣbayr', 'zarmuhi'), ('horyeɣbayr', 'zarmuhi'), ('horyeɣbayr', 'zarmuhi'), ('morakʰuyr', 'zarmuhi'), ('morakʰuyr', 'zarmuhi'), ('horakʰuyr', 'zarmuhi'), ('horakʰuyr', 'zarmuhi')]
# Eastern_Pahari_Nepali__east1436.csv
# None
# Eastern_Yiddish_east2295.csv
# [('foter', 'bruder'), ('foter', 'yingerer bruder'), ('foter', 'švester'), ('foter', 'yingere švester'), ('(der) mames bruder', "(ge) švester'kind"), ('(der) mames bruder', "(ge) švester'kind"), ('(dem) tatns bruder', "(ge) švester'kind"), ('(dem) tatns bruder', "(ge) švester'kind"), ('(der) mames švester', "(ge) švester'kind"), ('(der) mames švester', "(ge) švester'kind"), ('(dem) tatns švester', "(ge) švester'kind"), ('(dem) tatns švester', "(ge) švester'kind")]
# Easter_Islanders_rapa1244.csv
# None
# East_Ambae_(Lolovoli)_east2443.csv
# None
# East_Futuna_east2447.csv
# [('tamana', "tua-nga'ane"), ("tu'a-tsinana", 'taina'), ("tu'a-tsinana", "tua-nga'ane"), ('tamana', 'taina'), ('tamana', "tua-nga'ane"), ('tsinana', 'taina'), ('tsinana', "tua-nga'ane"), ('masakitange', 'taina'), ('masakitange', "tua-nga'ane"), ('tamana', "tua-nga'ane"), ('tamana', 'taina')]
# East_Kave_east2516.csv
# [('aapa', 'mbali'), ('yaake', 'kaai'), ('yaake', 'kaai'), ('arombo', 'kaai'), ('arombo', 'kaai'), ('aapa', 'mbali'), ('aapa', 'aaki')]
# Ekonda_Mongo_ekon1238.csv
# [('fafa', 'botomolo'), ('fafa', 'bokune'), ('nyangobika', 'nkana'), ('nyangobika', 'nkana'), ('ise', 'nkana'), ('ise', 'nkana'), ('nyango', 'nkana'), ('nyango', 'nkana'), ('isomoto', 'nkana'), ('isomoto', 'nkana'), ('fafa', 'nkana')]
# Elamite_elam1244.csv
# None
# Ellice_tuva1244.csv
# [('tamana', 'taina matuaatu'), ('tamana', 'taina foolikiifoo'), ('tamana', 'tuangane matuaatu'), ('tamana', 'tuangane foolikiifoo'), ('tuatina', 'fakatau taina'), ('tuatina', 'fakatau tuangane'), ('tamana', 'fakatau taina'), ('tamana', 'fakatau tuangane'), ('maatua', 'fakatau taina'), ('maatua', 'fakatau tuangane'), ('maatua', 'fakatau taina'), ('maatua', 'fakatau tuangane'), ('tamana', 'tuangane matuaatu'), ('tamana', 'tuangane foolikiifoo'), ('tamana', 'taina matuaatu'), ('tamana', 'taina foolikiifoo')]
# Emae_(Mae)_emae1237.csv
# None
# Emau_(Emao_Island)_emau1237.csv
# [('mama', 'ngoreng'), ('lò', 'natung nanoe'), ('lò', 'natung nangòròn'), ('tètè', 'tay'), ('tètè', 'ngoreng'), ('mimi', 'natung nanoe'), ('mimi', 'natung nangòròn'), ('mama', 'tay')]
# Emerillon_emer1243.csv
# None
# Ende_(Papua_New_Guinea)_ende1235.csv
# [('baba', 'män'), ('pope', 'yäkäl'), ('pope', 'yäkäl'), ('mädaulle', 'yäkäl'), ('mädaulle', 'yäkäl'), ('meyang', 'yäkäl'), ('meyang', 'yäkäl'), ('mällpa yai', 'yäkäl'), ('mällpa yai', 'yäkäl'), ('mällpa', 'yäkäl'), ('mällpa', 'yäkäl'), ('mädaulle', 'yäkäl'), ('mädaulle', 'yäkäl'), ('näni', 'yäkäl'), ('näni', 'yäkäl'), ('baba', 'mang'), ('baba', 'mosen'), ('baba', 'mänyan')]
# English_stan1293.csv
# [('father', 'brother'), ('father', 'sister'), ('uncle', 'cousin'), ('uncle', 'cousin'), ('uncle', 'cousin'), ('uncle', 'cousin'), ('aunt', 'cousin'), ('aunt', 'cousin'), ('aunt', 'cousin'), ('aunt', 'cousin')]
# Epena_epen1239.csv
# None
# Erave_(South_Kewa)_erav1244.csv
# [('aapa', 'anya'), ('yaake', 'kaani'), ('yaake', 'kaani'), ('arobo', 'kaani'), ('arobo', 'kaani'), ('aapa', 'anya'), ('aapa', 'aaki')]
# Erzya_erzy1239.csv
# [('tʸetʸa', 'lʸelʸa'), ('tʸetʸa', 'yalaks'), ('tʸetʸa', 'patʸa'), ('tʸetʸa', 'sazor̃'), ('lʸelʸa', 'lʸelʸa'), ('lʸelʸa', 'lʸelʸa'), ('lʸelʸax', 'lʸelʸa'), ('lʸelʸax', 'lʸelʸa'), ('sɨr̃ʸkay', 'lʸelʸa'), ('sɨr̃ʸkay', 'lʸelʸa'), ('sɨr̃ʸkay', 'lʸelʸa'), ('sɨr̃ʸkay', 'lʸelʸa')]
# Estonian_esto1258.csv
# [('isa', 'wend'), ('isa', 'əde'), ('onu', 'onupoeg'), ('onu', 'onutütar̃'), ('lell', 'lellepoeg'), ('lell', 'lelletütar̃'), ('tædi', 'tædipoeg'), ('tædi', 'tæditütar̃'), ('sətse', 'sətsepoeg'), ('sətse', 'sətsetütar̃')]
# Eudeve_eude1234.csv
# None
# Eyak_eyak1241.csv
# None
# Fang_EG_fang1246.csv
# [('tare', 'nyamôre'), ('tare', 'mvara'), ('tare', 'ñkîa'), ('tare', 'ñgo zam'), ('nyandôm', 'monedzan'), ('nyandôm', 'kadzam'), ('tare', 'monedzan'), ('tare', 'kadzam'), ('nya', 'monedzan'), ('nya', 'kadzam'), ("son'a", 'monedzan'), ("son'a", 'kadzam')]
# Fefe_fefe1239.csv
# [('tšât', 'nzšàpmbi wá móàó mbááná'), ('tšât', 'ntsúàÜnzúú wáà móàómbááná'), ('tšât', 'nzšàpmbi wá mšñŠáà'), ('tšât', 'ntsúàÜnzúú wáà mšñŠáà'), ('múmæ̀mɔ̀', 'méŋ mɔ̄'), ('mbega', 'méŋ mɔ̄'), ('mumètálà', 'méŋ mɔ̄')]
# Fijian_fiji1243.csv
# [('tamaqu', 'genequ'), ('momo', 'tavalequ'), ('momo', 'davolaqu'), ('tamaqu', 'karuaqu'), ('tamaqu', 'karuaqu'), ('tinaqu', 'karuaqu'), ('tinaqu', 'karuaqu'), ('ganei', 'tavalequ'), ('ganei', 'davolaqu'), ('tamaqu', 'ganequ'), ('tamaqu', 'tuakaqu'), ('tamaqu', 'taciqu')]
# Finnic_finn1318.csv
# [('isæ', 'weli'), ('isæ', 'nuor̃empi weli'), ('isæ', 'sisko'), ('isæ', 'nuor̃empi sisar̃'), ('eno', 'ser̃kku'), ('eno', 'ser̃kku'), ('setæ', 'ser̃kku'), ('setæ', 'ser̃kku'), ('tæti', 'ser̃kku'), ('tæti', 'ser̃kku'), ('tæti', 'ser̃kku'), ('tæti', 'ser̃kku')]
# Finnish_finn1318.csv
# [('isä', 'veli'), ('isä', 'sisko'), ('eno', 'serkku'), ('eno', 'serkku'), ('setä', 'serkku'), ('setä', 'serkku'), ('täti', 'serkku'), ('täti', 'serkku'), ('täti', 'serkku'), ('täti', 'serkku')]
# Fipa_fipa1238.csv
# [('ïtaata', 'unniina'), ('ïtaata', 'unnsiice'), ('inkwetu', 'unnfyaala'), ('inkwetu', 'unnfyaala'), ('ïmaangu', 'uwacane'), ('ïmaangu', 'uwacane'), ('ïmaangu seenje', 'unnfyaala'), ('ïmaangu seenje', 'unnfyaala'), ('ïtaata', 'unnsiice'), ('ïtaata', 'unniina')]
# FlindersIsland_flin1247.csv
# None
# Fordata_ford1242.csv
# [('yaman', ''), ('yaman', 'warin'), ('yaman', ''), ('', ''), ('', "a'an"), ('', "a'an"), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ("a'an", ''), ('', '')]
# Fortsenal_(Kiai)_fort1240.csv
# None
# Frisian_fris1239.csv
# [('heit', 'broer'), ('heit', 'sus'), ('heit', 'suske'), ('ome', 'neef'), ('ome', 'nicht'), ('ome', 'neef'), ('ome', 'nicht'), ('muoike', 'neef'), ('muoike', 'nicht'), ('muoike', 'neef'), ('muoike', 'nicht'), ('heit', 'broer'), ('heit', 'broerke')]
# Futuna-Aniwa_futu1245.csv
# [('tamana', 'kave'), ('taruana', 'rarakave'), ('taruana', 'rarakave'), ('amahavai', 'rarakave'), ('amahavai', 'rarakave'), ('tamana', 'kave'), ('tamana', 'so')]
# Futunans_east2447.csv
# ...
# Waropen_waro1242.csv
# None
# Warrnambool_warr1257.csv
# None
# Warta_Thuntai_gunt1241.csv
# None
# Warumungu_waru1265.csv
# [('kampatya', 'thigh1'), ('kampatya', 'shoulder2'), ('kampatya', 'kapurlu'), ('kampatya', 'kukkatyi'), ('ngamirni', 'wankili'), ('ngamirni', 'wankili'), ('piNaRi', 'wankili'), ('piNaRi', 'wankili')]
# Warungu_waru1264.csv
# None
# Waru_waru1266.csv
# None
# Wathwurrung_wath1238.csv
# None
# Watut_watu1246.csv
# [('lamaŋg', 'lewiŋg'), ('lamaŋg', 'laseŋg'), ('lamaŋg', 'jeniŋg kefi'), ('esiŋg', 'araŋg'), ('esiŋg', 'nafoŋg'), ('lamaŋg', 'lewiŋg'), ('lamaŋg', 'nafoŋg'), ('lenaŋg', 'lewiŋg'), ('lenaŋg', 'nafoŋg'), ('wagag', 'araŋg'), ('wagag', 'nafoŋg'), ('lamaŋg', 'lewiŋg'), ('lamaŋg', 'laseŋg')]
# Waurá_waur1244.csv
# [('-žɨ', "-tu-ka'ka"), ('-žɨ', '-se-žɨ'), ('-žɨ', '-tu-kaka-lu'), ('-žɨ', '-se-žu'), ("u'wa", "-tanu'le"), ("u'wa", "-tanu'le"), ('-žɨ', "-tanu'le"), ('-žɨ', "-tanu'le"), ('-ɨnu', "-tanu'le"), ('-ɨnu', "-tanu'le"), ("a'kɨ", "-tanu'le"), ("a'kɨ", "-tanu'le")]
# Wawonii_wawo1239.csv
# [('tama', 'tukaka'), ('tama', 'tußai'), ('maama', 'topisa'), ('maama', 'topisa'), ('maama', 'topisa'), ('maama', 'topisa'), ('naina', 'topisa'), ('naina', 'topisa'), ('naina', 'topisa'), ('naina', 'topisa'), ('tama', 'tukaka'), ('tama', 'tußai')]
# Wayampi_waya1270.csv
# None
# Wayuu_wayu1243.csv
# [('ta-ši', 'ta-waľa'), ('ta-ši', 'te-mɨľia'), ('ta-ši', 'ta-waľa'), ('ta-ši', 'ta-šunuu'), ('ta-ľaɨľa', 'ta-waľa'), ('ta-ľaɨľa', 'ta-waľa'), ('ta-ši', 'ta-waľa'), ('ta-ši', 'ta-waľa'), ('ta-aʔir̃ɨ', 'ta-waľa'), ('ta-aʔir̃ɨ', 'ta-waľa'), ('te-i (~ ta-i)', 'ta-waľa'), ('te-i (~ ta-i)', 'ta-waľa')]
# Weda_weda1240.csv
# [('momo', 'fono'), ('momo', 'fono-meping'), ('momo', 'fono'), ('momo', 'fono-meping'), ('baba', 'fono'), ('baba', 'fono-meping'), ('baba', 'fono'), ('baba', 'fono-meping')]
# Wersing_wers1238.csv
# None
# Western_Apache_west2615.csv
# [('cìtàˑ', 'cìdìjé'), ('cìtàˑ', 'cìdìjé'), ("cìdà'á", 'sìzéˑdé'), ("cìdà'á", 'cìlà'), ('cìdéjé', 'cìkìsń'), ('cìdéjé', 'cìlà'), ("cíkàˑ'á", 'cìkìsń'), ("cíkàˑ'á", 'cìlà'), ('cìdéjé', "cìłnàˑ'àˑc"), ('cìdéjé', 'sìzéˑdé')]
# Western_Armenian_homs1234.csv
# [('hayr', 'yeɣpayr'), ('hayr', 'pokr yeɣpayr'), ('hayr', 'kuyr'), ('hayr', 'b[ə]zdig kuyr'), ('moryeɣpayr', 'zarmuhi'), ('moryeɣpayr', 'zarmuhi'), ('horyeɣpayr', 'zarmuhi'), ('horyeɣpayr', 'zarmuhi'), ('morakuyr', 'zarmuhi'), ('morakuyr', 'zarmuhi'), ('horakuyr', 'zarmuhi'), ('horakuyr', 'zarmuhi')]
# Western_Bukidnon_Manobo_west2555.csv
# [('amey', 'etevey'), ('anggam', 'suled'), ('anggam', 'etevey'), ('anggam', 'suled'), ('anggam', 'etevey'), ("aya'", 'suled'), ("aya'", 'etevey'), ("aya'", 'suled'), ("aya'", 'etevey'), ('amey', "me'emahan"), ('amey', 'suled')]
# Western_Farsi_west2369.csv
# [('pedær', '[dɑdɑš]'), ('pedær', '[uka]'), ('pedær', 'hæmšire'), ('pedær', 'apa'), ('dãi', 'pesar-e-dãi'), ('dãi', 'doxtar-e-dãi'), ('[æmm]', 'pesar-e-amu'), ('[æmm]', 'doxtar-e-amu'), ('xãle', 'pesar-e-xãle'), ('xãle', 'doxtar-e-xãle'), ('amme', 'pesar-e-amme'), ('amme', 'doxtar-e-amme')]
# Western_Panjabi_west2386.csv
# [('pio', 'bhāyī'), ('pio', 'nikka prā'), ('pio', 'paiṇa'), ('pio', 'nikkī paiṇa'), ('māmū', 'cacera (bhāi)'), ('māmū', 'cacera (bhāi)'), ('tāyā', 'cacera (bhāi)'), ('tāyā', 'cacera (bhāi)'), ('māsī', 'cacera (bhāi)'), ('māsī', 'cacera (bhāi)'), ('bhūyā', 'cacera (bhāi)'), ('bhūyā', 'cacera (bhāi)')]
# Western_Pantar_lamm1241.csv
# [('-iar', '-aipang'), ('-irasi', "-'ar"), ('-irasi', '-baddang'), ('-iar', 'pang'), ('-iar', 'pang'), ('-iu', 'pang'), ('-iu', 'pang'), ('-irasi manne', "-'ar"), ('-irasi manne', '-baddang'), ('-iar', '-aipang'), ('-iar', "-i'e"), ('-iar', '-iaku')]
# Western_Shoshoni_west2622.csv
# None
# Western_Tawbuid_(Batangan)_west2559.csv
# [('mama', 'duksayan'), ('mama', 'duksayan'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('baáy', 'lagbä'), ('baáy', 'lagbä'), ('baáy', 'lagbä'), ('baáy', 'lagbä'), ('mama', 'duksayan'), ('mama', 'duksayan')]
# West_Coast_Bajau_west2560.csv
# [("emma'", "ka'"), ("emma'", "di'"), ("pa'", 'kaki'), ("pa'", 'kaki'), ("pa'", 'kaki'), ("pa'", 'kaki'), ("bu'", 'kaki'), ("bu'", 'kaki'), ("bu'", 'kaki'), ("bu'", 'kaki'), ("emma'", "ka'"), ("emma'", "di'")]
# West_Futuna_west2515.csv
# [('tamana', 'kave'), ('tojinana', 'safe'), ('tojinana', 'fakau magaro'), ('tamana', 'soa'), ('tamana', 'kave'), ('jinana', 'soa'), ('jinana', 'kave'), ('jina-ha-vae', 'safe'), ('jina-ha-vae', 'fakau magaro'), ('jina-ha-vae. maha-vae', 'safe'), ('jina-ha-vae. maha-vae', 'fakau magaro'), ('tamana', 'kave'), ('tamana', 'soa')]
# West_Kewa_west2599.csv
# [('aapa', 'mbani'), ('yaake', 'aai'), ('yaake', 'aai'), ('arombo', 'aai'), ('arombo', 'aai'), ('aapa', 'mbani'), ('aapa', 'aaki')]
# Whitesands_whit1269.csv
# None
# White_Mesa_Ute_utee1244b.csv
# None
# Wichí_wich1264.csv
# None
# WikMungkan_wikm1247.csv
# [('muka', 'moiya'), ('kala', 'kutth'), ('piny wantyinth', 'muuy'), ('piny wantyinth', 'muuy'), ('piny', 'muuy'), ('piny', 'muuy')]
# Wipi_wipi1242.csv
# None
# Wiradjuri_wira1262.csv
# [('babiin', 'gaagang'), ('babiin', 'gagamin'), ('babiin', 'mingaan'), ('babiin', 'minhi'), ('baggirn-Gan', 'wunarigayin'), ('baggirn-Gan', 'wunarigayin'), ('baggirn-Gan', 'wunarigayin'), ('baggirn-Gan', 'wunarigayin'), ('bunuwal', 'wunarigayin'), ('bunuwal', 'wunarigayin'), ('bunuwal', 'wunarigayin'), ('bunuwal', 'wunarigayin')]
# Wirangu_wira1265.csv
# [('muma', 'yunga'), ('muma', 'bangunu'), ('muma', 'gangguru'), ('muma', 'puyalu'), ('gamuRu', 'buldu'), ('gamuRu', 'buldu'), ('gany', 'marlany'), ('ganggiya', 'marlany'), ('gurndili', 'buldu'), ('gurndili', 'buldu')]
# Wiwirano_wiwi1237.csv
# None
# Wiyot_wiyo1248.csv
# [('yidjok', 'yibe'), ('yidjok', 'yibe'), ('yigatck', 'yibe'), ('yigatck', 'yibe'), ('yidjul', 'yibe'), ('yidjul', 'yibe'), ('yibauk', 'yibe'), ('yibauk', 'yibe')]
# Wogeo_woge1237.csv
# None
# Woiwurrung_woiw1237.csv
# None
# Woleaian_wole1240.csv
# None
# Wolio_woli1241.csv
# None
# Wulguru_wulg1239.csv
# [('abu', 'katha'), ('abu', 'dhambu'), ('abu', 'abari'), ('gawa', 'bunkany'), ('gawa', 'bunkany'), ('gawa', 'bunkany'), ('gawa', 'bunkany'), ('bulunggu', 'bunkany'), ('bulunggu', 'bunkany'), ('gayin', 'bunkany'), ('gayin', 'bunkany')]
# Wuvulu_Aua_wuvu1239.csv
# [('ʔama', 'lofu'), ('ʔama', 'ʔari'), ('ama', 'lofu'), ('ama', 'ʔari'), ('ʔama', 'lofu'), ('ʔama', 'ʔari'), ('ʔina', 'lofu'), ('ʔina', 'ʔari'), ('ʔina', 'lofu'), ('ʔina', 'ʔari'), ('ʔama', 'ʔari'), ('ʔama', 'tafi')]
# Xalangi_(Maevo_Vanuatu)_mari1426h.csv
# [('tita', 'fiⁿdae'), ('(j)aᵐbe', 'natu'), ('(j)aᵐbe', 'natu'), ('tita', 'tua'), ('tita', 'fiⁿdae'), ('ᵐbotai', 'tua'), ('ᵐbotai', 'fiⁿdae'), ('toa', 'toa'), ('toa', 'toa'), ('tita', 'fiⁿdae'), ('tita', 'tua')]
# Xaracuu_(Canala)_xara1244.csv
# None
# Xibe_xibe1242.csv
# [("ame'", "gege'"), ("ame'", 'nuN'), ("ame naxce'", 'jyalxi'), ("ame naxce'", 'jyalxi saχenji'), ("naxce'", 'jyalxi'), ("naxce'", 'jyalxi saχenji'), ("ambame'", 'jyalxi'), ("ambame'", 'jyalxi saχenji'), ("ajyame'", 'jyalxi'), ("ajyame'", 'jyalxi saχenji'), ("dexeme'", 'ina'), ("dexeme'", 'ina saχenji'), ("guxu'", 'ina'), ("guxu'", 'ina saχenji'), ("ame'", "age'"), ("ame'", 'du')]
# Yabem_yabe1254.csv
# [('tama', 'luò'), ('sa laŋgwa', 'gwadê'), ('sa laŋgwa', 'gwadêò'), ('tamasêga', 'têwa'), ('tamasêga', 'têwaò'), ('tênasêga', 'têwa'), ('tênasêga', 'luò'), ('saò àwêsêga', 'gwadê'), ('saò àwêsêga', 'gwadêò'), ('tama', 'luŋac'), ('tama', 'têwaò')]
# Yadhaykenu_yadh1237.csv
# None
# Yakan_yaka1277.csv
# [('amma', "pongtina'i"), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ('amma', "pongtina'i"), ('amma', 'kakka'), ('amma', 'sali')]
# Yaka_CAR__yaka1272.csv
# [('táé', 'kádí-wà-pàé'), ('táé', 'kádí-wà-mòétò'), ('kɔ̀kɔ̀', 'kádf'), ('kɔ̀kɔ̀', 'kádf'), ('táé', 'kádf'), ('táé', 'kádf'), ('kádí-wà-tàó-wà-pàé', 'kádf'), ('kádí-wà-tàó-wà-pàé', 'kádf'), ('ngúé', 'kádf'), ('ngúé', 'kádf')]
# Yaka_Pelende_Lonzo_yaka1269.csv
# [('gokash', 'bana'), ('gokash', 'kisoni'), ('gokash', 'kisoni'), ('gokash', 'kisoni'), ('tata nkento', 'tata'), ('tata nkento', 'pikanu')]
# Yalarnnga_yala1262.csv
# [('karlu', 'toweri'), ('karlu', 'kanamu'), ('karlu', 'thirrirri'), ('karlu', 'kanamu'), ('kurrirti', 'kangu'), ('kurrirti', 'kangu'), ('kurrirti', 'kangu'), ('kurrirti', 'kangu'), ('yimirti', 'kangu'), ('yimirti', 'kangu'), ('yimirti', 'kangu'), ('yimirti', 'kangu')]
# Yalarnnga_yala1262a.csv
# [('karlu', 'thirrirri'), ('karlu', 'kanamu'), ('kurrirti', 'kangu'), ('kurrirti', 'kangu'), ('marnu', 'kangu'), ('marnu', 'kangu'), ('yimirti', 'kangu'), ('yimirti', 'kangu'), ('karlu', 'thawirti'), ('karlu', 'kanamu')]
# Yamana_yama1264.csv
# [('tapwin', 'waym'), ('tapwin', 'ašouwa'), ('tapwin', 'way-kipa'), ('tapwin', 'uš-kipa'), ('tanowa', 'šamakuš'), ('tanowa', 'šamakuš'), ('tanowa', 'šamakuš'), ('tanowa', 'šamakuš'), ('tanowa-kipa', 'šamakuš'), ('tanowa-kipa', 'šamakuš'), ('tanowa-kipa', 'šamakuš'), ('tanowa-kipa', 'šamakuš')]
# Yamdena_yamd1240.csv
# [('ame', ''), ('ame', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', '')]
# Yami_Tao__yami1254.csv
# [('ama', 'kaka'), ('ama', 'wari'), ('ama', 'kaka'), ('ama', 'wari'), ('maran', 'kaposing'), ('maran', 'kaposing'), ('kaminan', 'kaposing'), ('kaminan', 'kaposing'), ('kaminan', 'kateysa'), ('kaminan', 'kateysa')]
# Yandruwandha_yand1253.csv
# [('ngapiri', 'nguthu'), ('ngapiri', 'ngathadi'), ('ngapiri', 'kaku'), ('ngapiri', 'ngathadi'), ('ngama', 'kami'), ('ngama', 'kami'), ('parli', 'kami'), ('parli', 'nhipa')]
# Yandruwandha_yand1253a.csv
# None
# Yanomámi_yano1262.csv
# None
# Yansi_yans1239.csv
# [('tåã', 'tɔ̀ɔ̀nyèèr'), ('tåã', 'tɔ̀ɔ̀kɔ̀ɔ̀m'), ('lém', 'tɔ̀ɔ̀kɔ̀ɔ̀m'), ('tɔ̀ɔ̀nyèèr', 'tɔ̀ɔ̀kɔ̀ɔ̀m'), ('etjul', 'tɔ̀ɔ̀kɔ̀ɔ̀m')]
# Yanyuwa_yany1243.csv
# [('winya', 'tyapapa'), ('winya', 'wunhaka'), ('winya', 'papa'), ('winya', 'wunhaka'), ('tyakaka', 'muntyumuntyu'), ('tyakaka', 'muntyumuntyu'), ('tyatiya', 'muntyumuntyu'), ('tyatiya', 'muntyumuntyu'), ('nana', 'muntyumuntyu'), ('nana', 'muntyumuntyu')]
# Yao_yaoo1241.csv
# None
# Yaqui_yaqu1251.csv
# None
# Yarluyandi_ngam1265.csv
# [('ngapiri', 'sthuju'), ('ngapiri', 'ngadara'), ('ngapiri', 'sthuttari'), ('ngapiri', 'ngadara'), ('kaka', 'kami'), ('kaka', 'kami'), ('papa', 'kami'), ('papa', 'kami')]
# Yavitero_yavi1244.csv
# None
# Yele_(Yélî_Dnye)_yele1255.csv
# [('mî', 'tîdê'), ('kênê', 'w:ââ'), ('kênê', 'w:ââ'), ('kââkââ', 'mbwó'), ('kââkââ', 'tîdê'), ('piye', 'mbwó'), ('piye', 'tîdê'), ('m:aam:ââ', 'mîchó'), ('m:aam:ââ', 'kââpyââ'), ('mî', 'tîdê'), ('mî', 'mbwó')]
# Yelmek_yelm1242.csv
# None
# Yerukula_yeru1240.csv
# None
# Yidiny_yidi1250.csv
# [('pimpi', 'yapa'), ('pimpi', 'yapatyipa'), ('pimpi', 'tyangkul'), ('kalnga', 'manka'), ('kalnga', 'manka'), ('tyutyum', 'manka'), ('tyutyum', 'manka')]
# Yidiny_yidi1250a.csv
# None
# Yindjibarndi_yind1247.csv
# [('papu', 'kurtaarra'), ('papu', 'marraa'), ('papu', 'thurtu'), ('papu', 'mayi'), ('mimi', 'nhuwa'), ('mimi', 'pinthi'), ('nyirti', 'nhuwa'), ('nyirti', 'pinthi')]
# Yir-Yoront_yiry1245.csv
# [('pi+ng', 'luqan+ng'), ('pi+ng', 'pann'), ('moqr', 'minhr-ng'), ('moqr', 'warn+ng'), ('kal+ng', 'minhr-ng'), ('kal+ng', 'warn+ng'), ('pi+ng', 'pulqa'), ('pi+ng', 'pann')]
# Yombe_yomb1244.csv
# [('tata', 'bakhomba'), ('tata', 'baphangi'), ('tata', 'bakhomba'), ('ngwa khazi', 'ngwa khazi'), ('ngwa khazi', 'bana bakhazi'), ('papa nkulutu', 'papa nketo'), ('papa nleki', 'papa nketo'), ('mama nkulutu', 'ngwa khazi'), ('mama nkulutu', 'bana bakhazi'), ('mama nleki', 'ngwa khazi'), ('mama nleki', 'bana bakhazi'), ('papa nketo', 'papa nketo')]
# Yorta_Yorta_yort1237.csv
# None
# Yucatec_Maya_yuca1254.csv
# [('yum', 'cic'), ('yum', 'idzin'), ('han', 'cic'), ('dze yum', 'mam'), ('dze na', 'mam'), ('yum', 'zucun'), ('yum', 'idzin')]
# Yugambal_(Yugambeh)_yuga1244.csv
# [('bijaŋ', 'nanahŋ'), ('kawaŋ', 'yirbul'), ('kawaŋ', 'yirbul'), ('bijaŋ', 'kudharaŋ'), ('bijaŋ', 'kudharaŋgan'), ('wadhuŋ', 'kudharaŋ'), ('wadhuŋ', 'kudharaŋgan'), ('ŋaruny', 'yirbul'), ('ŋaruny', 'yirbul'), ('bijaŋ', 'yirgahŋ')]
# Yugambeh_yugu1249.csv
# [('biyang', 'gaguhng'), ('biyang', 'panaam'), ('biyang', 'nunong'), ('biyang', 'yirrkaang'), ('kauung', 'yerrabool'), ('kauung', 'yerrabool'), ('biung', 'yerrabool'), ('biung', 'yerrabool'), ('ngaroon', 'yerrabool'), ('ngaroon', 'yerrabool'), ('ngaroon', 'yerrabool'), ('ngaroon', 'yerrabool')]
# Yuki_yuki1243.csv
# None
# Yukulta_(Ganggalida)_gang1267a.csv
# [('kan̪t̪at̪u', 'yakukat̪u'), ('kan̪t̪at̪u', 'palkatYi'), ('ŋamat̪u', 'putYirinta'), ('kapilitYu', 'putYirinta'), ('kan̪t̪at̪u', 'waŋkutu'), ('kan̪t̪at̪u', 'kunat̪u'), ('kan̪t̪at̪u', 'yakukat̪u'), ('kan̪t̪at̪u', 'kunat̪u')]
# Yulparija_yulp1239.csv
# [('yina', 'kuta'), ('yina', 'malatyu'), ('yina', 'nyarrumpa'), ('yina', 'malatyu'), ('waputyu', 'tyalapurtu'), ('waputyu', 'tyuwari'), ('yungkutyarra', 'tyalapurtu'), ('yungkutyarra', 'tyuwari')]
# Yuracare_yura1255.csv
# None
# Yurok_yuro1248.csv
# [('tot', 'nemit'), ('tot', 'neiku'), ('tot', 'nepin'), ('tot', 'neikeu'), ('netsim', 'nepa'), ('netsim', 'neweyits'), ('netsim', 'nepa'), ('netsim', 'neweyits'), ('netul', 'nepa'), ('netul', 'neweyits'), ('netul', 'nepa'), ('netul', 'neweyits')]
# Yuwaalaraay_gami1243.csv
# [('buwadjarr', 'd̪aga:n'), ('buwadjarr', 'galumaay'), ('buwadjarr', 'bawa(d̪i)'), ('buwadjarr', 'd̪awuran'), ('garugi:', 'thaatha'), ('garugi:', 'thaatha'), ('gamiyan', 'thaatha'), ('gamiyan', 'ngaaki')]
# Zabana_(Kia)_zaba1237.csv
# None
# Zigula_zigu1242.csv
# None
# Zinza_zinz1238.csv
# None
# Zulu_zulu1248.csv
# [('baba', 'dade'), ('malume', 'mzala'), ('malume', 'mzala'), ('baba omukulu', 'mfo'), ('baba omukulu', 'dade'), ('baba omncane', 'mfo'), ('baba omncane', 'dade'), ('mame', 'ukanina'), ('mame', 'ukanina'), ('babakazi', 'mzala'), ('babakazi', 'mzala'), ('baba', 'mne'), ('baba', 'mfo')]
# Zuni_zuni1245.csv
# None
# 651
#                  language simulation_code simulation  mutual_information  \
# 0                'Are'are   area1240_REAL          N            0.863121
# 1                  Achuar   achu1249_REAL          N            0.000000
# 2                    Aché   ache1246_REAL          N            1.950212
# 3                   Adang   adan1251_REAL          N            0.316689
# 4           Adnyamathanha   adny1235_REAL          N            1.155639
# ..                    ...             ...        ...                 ...
# 646  Yukulta_(Ganggalida)  gang1267a_REAL          N            0.811278
# 647             Yulparija   yulp1239_REAL          N            1.000000
# 648                 Yurok   yuro1248_REAL          N            0.918296
# 649           Yuwaalaraay   gami1243_REAL          N            1.155639
# 650                  Zulu   zulu1248_REAL          N            1.526235
#
#      entropy_gn  entropy_gn1  conditional_entropy  variation_gn  \
# 0      1.950212     0.863121            -0.000000             4
# 1     -0.000000     0.721928             0.721928             1
# 2      2.807355     1.950212            -0.000000             8
# 3      0.650022     1.584963             1.268273             2
# 4      2.155639     1.500000             0.344361             5
# ..          ...          ...                  ...           ...
# 646    2.250000     1.061278             0.250000             5
# 647    2.250000     1.500000             0.500000             5
# 648    2.251629     1.584963             0.666667             6
# 649    2.405639     1.500000             0.344361             6
# 650    2.199688     2.565448             1.039213             5
#
#      variation_gn1  number_of_pairs
# 0                2                4
# 1                2                2
# 2                4                8
# 3                3                4
# 4                3                6
# ..             ...              ...
# 646              3                6
# 647              3                7
# 648              3                8
# 649              3                7
# 650              6               10
#
# [651 rows x 10 columns]

# %% [markdown]
# And if we want to run a simulation on a single file:

# %%
ics_simulation(filepath,[file2],100)
# Out:
#                         language simulation_code simulation  \
# 0   Morgan1871_Iowä_iowa1245.csv      rgan1871_0          Y
# 1   Morgan1871_Iowä_iowa1245.csv      rgan1871_1          Y
# 2   Morgan1871_Iowä_iowa1245.csv      rgan1871_2          Y
# 3   Morgan1871_Iowä_iowa1245.csv      rgan1871_3          Y
# 4   Morgan1871_Iowä_iowa1245.csv      rgan1871_4          Y
# ..                           ...             ...        ...
# 95  Morgan1871_Iowä_iowa1245.csv     rgan1871_95          Y
# 96  Morgan1871_Iowä_iowa1245.csv     rgan1871_96          Y
# 97  Morgan1871_Iowä_iowa1245.csv     rgan1871_97          Y
# 98  Morgan1871_Iowä_iowa1245.csv     rgan1871_98          Y
# 99  Morgan1871_Iowä_iowa1245.csv     rgan1871_99          Y
#
#     mutual_information  entropy_gn  entropy_gn1  conditional_entropy  \
# 0              0.42218        2.75          1.0              0.57782
# 1              0.42218        2.75          1.0              0.57782
# 2              0.42218        2.75          1.0              0.57782
# 3              0.50000        2.75          1.0              0.50000
# 4              0.42218        2.75          1.0              0.57782
# ..                 ...         ...          ...                  ...
# 95             0.25000        2.75          1.0              0.75000
# 96             0.17218        2.75          1.0              0.82782
# 97             0.42218        2.75          1.0              0.57782
# 98             0.50000        2.75          1.0              0.50000
# 99             0.25000        2.75          1.0              0.75000
#
#     variation_gn  variation_gn1  number_of_pairs
# 0              7              2               11
# 1              7              2               11
# 2              7              2               11
# 3              7              2               10
# 4              7              2               11
# ..           ...            ...              ...
# 95             7              2               12
# 96             7              2               13
# 97             7              2               11
# 98             7              2               10
# 99             7              2               12
#
# [100 rows x 10 columns]

# %% [markdown]
# And finally, the full set of simulations from all the kinbank data, run 1000 times on each language.

# %%
ics_simulation(filter_filepath,filtered_kb_files,1000)
# Out:
#         language simulation_code simulation  mutual_information  entropy_gn  \
# 0       'Are'are      area1240_0          Y            0.291692    1.950212
# 1       'Are'are      area1240_1          Y            0.291692    1.950212
# 2       'Are'are      area1240_2          Y            0.291692    1.950212
# 3       'Are'are      area1240_3          Y            0.291692    1.950212
# 4       'Are'are      area1240_4          Y            0.291692    1.950212
# ...          ...             ...        ...                 ...         ...
# 650995      Zulu    zulu1248_995          Y            1.372389    2.199688
# 650996      Zulu    zulu1248_996          Y            1.218543    2.199688
# 650997      Zulu    zulu1248_997          Y            1.526235    2.199688
# 650998      Zulu    zulu1248_998          Y            1.372389    2.199688
# 650999      Zulu    zulu1248_999          Y            1.218543    2.199688
#
#         entropy_gn1  conditional_entropy  variation_gn  variation_gn1  \
# 0          0.863121             0.571429             4              2
# 1          0.863121             0.571429             4              2
# 2          0.863121             0.571429             4              2
# 3          0.863121             0.571429             4              2
# 4          0.863121             0.571429             4              2
# ...             ...                  ...           ...            ...
# 650995     2.565448             1.193060             5              6
# 650996     2.565448             1.346906             5              6
# 650997     2.565448             1.039213             5              6
# 650998     2.565448             1.193060             5              6
# 650999     2.565448             1.346906             5              6
#
#         number_of_pairs
# 0                     6
# 1                     6
# 2                     6
# 3                     6
# 4                     6
# ...                 ...
# 650995               11
# 650996               12
# 650997               10
# 650998               11
# 650999               12
#
# [651000 rows x 10 columns]

# %% [markdown]
# ### Notes
#
# *If a term only pairs with one other term in the real language, it should still only pair with one term in the simulation. What that term is can vary! But not how many terms it pairs with.
# *Maybe need to filter for meaningless duplicates e.g. English only has one term for meB and myB, but I'm still extracting both
#
# What would a function look like that filtered each language for the kin types it actually meaningfully has?

# %%
newk = filter_ks(k)

# %%
newk_pairs = get_pairs(newk)

newk_gn,newk_gn1 = split_pairs(newk_pairs)

print(newk_pairs)

# %%
print(entropy(newk_gn1), mutual_information(newk_pairs))

# %%
sim_newk = simulate_ks(newk)

# %%
snewk_gn,snewk_gn1 = split_pairs(sim_newk)

# %%
print(entropy(snewk_gn1),mutual_information(sim_newk))

# %%
print(newk_pairs,'\n\n',sim_newk)

print(Counter(newk_gn),Counter(snewk_gn))
