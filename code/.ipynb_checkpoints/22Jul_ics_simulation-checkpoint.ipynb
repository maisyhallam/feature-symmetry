# %%
import csv # for writing dataframes to csv
import random # for making a random choice
import os # for scanning directories
import itertools
import string # for generating strings
from collections import Counter

import kintypes as kt # bringing large lists of kin types into the namespace
import math # for calculating logs
# import pandas as pd
import re

testing = True # set to True to run code blocks with tests and examples
filtering = False # set to True to run the filtering process

# %% [markdown]
# # Internal co-selection
#
# Internal co-selection refers to the tendency for kinship systems to have cross-generational consistency in the terminological distinctions or mergers that are made. That is, if your parents' elder brothers share a kin term, then so too will their children. Or if your parents' sisters are distinguished from your parents' brothers, so too will their children be distinguished.
#
# Imagine a kinship system like so: as in English, you call your parents' brothers are  *uncles*, and their sisters *aunts*. You call the child of your uncle a *chuncle*, and the child of your aunt a *chaunt*. Thus, you make the same sorts of distinctions among your parents' siblings' generation of kin as are made among your own generation of kin - and you can be certain about which children belong to which parents as a result. This is an example of internal co-selection.
#
# In this notebook, we will gather information about the robustness of this tendency cross-linguistically, using data from Kinbank, a global database of kin terminology. We will also create simulations of existing kinship systems to find out whether internal co-selection is more common in kinship systems cross-linguistically (for a given amount of terminological variation) than we would expect by chance.
#
# We will measure internal co-selection in terms of the **mutual information** between Generation N and Generation N+1 in a particular kinship system. That tells us how much information can be gained from one generation by observing the other - how certain we can be about which children 'go with' which parents. This can be calculated as the **entropy** of one generation (how much unpredictable variation there is) minus the **conditional entropy** between the two generations (how much unpredictability remains in one generation after observing another).
#
# ## The procedure
#
# To calculate the mutual information (MI) of a particular kinship system, we must perform the following steps:
#
# 1. Extract kin terminology data from Kinbank for this language.
# 2. Condense the full kinship system down to the terms we are interested in: Ego's generation and Ego's parents' generation.
# 3. Calculate the probabilities of each kin term within the generation in which it belongs; and the probabilities of each parent-child pair.
# 4. Calculate entropy, conditional entropy, subtract them from each other to get the mutual information of the system.
#
# After we get that going, we can do these same calculations on simulated kinship systems.
#
# ### Extract kin terminology from Kinbank
#
# First, let's actually load our data in. The following function `get_kb_files()` pulls the full list of Kinbank filenames. Later, we can iterate through these to generate MI values for every language in our dataset.

# %%
def get_kb_files(path) -> list:
    files = []
    directory = os.scandir(path)
    for file in directory:
        files.append(file.name)
    return files

all_kb_files = get_kb_files('../languages/kinbank')

# %% [markdown]
# Using one of these filenames, we can extract the kin terminology from that file and populate a dictionary with it. We're only interested in two columns from the Kinbank data: `parameter`, which contains a short code indicating a **kin type**, and `word`, which contains the **kin term** associated with that kin type. An example of a row in the English data would be `mMeB, uncle`, where `mMeB` means 'male speaker's mother's older brother', and `uncle` is the term associated with that person.

# %%
def get_kin_terms(filepath: str) -> dict:
    kin_system = {}
    with open(filepath, encoding='utf8') as f:
        csv_reader = csv.DictReader(f)
        next(csv_reader) # to skip the header row
        for line in csv_reader:
            kin_type = line['parameter']
            kin_term = line['word']
            kin_system[kin_type] = kin_term
    return kin_system

# %% [markdown]
# Let's pick a random kinship system to test with throughout this notebook.

# %%
if testing:
    
    random.seed(47) # set a seed for reproducibility

    file = random.choice(all_kb_files) # pick a random filename from all_kb_files

    filepath = '../languages/kinbank/' # the filepath where the kinbank files are kept

    k = get_kin_terms(filepath + file)

    print(file,k)
# Out:
# Oriya_oriy1255.csv {'mFeB': 'dadda', 'mMyB': 'mamo', 'mFBS': 'puva-bhai', 'mFZS': 'pivasi-puva-bhai', 'mMBS': 'mamo-puva-bhai', 'mMZS': 'mausi-puva-bhai', 'mFeBS': 'kakāpua bhāi', 'mFyBS': 'puva-bhai', 'mFeZS': 'pivasi-puva-bhai', 'mFyZS': 'pivasi-puva-bhai', 'mMyBS': 'mamo-puva-bhai', 'mMeZS': 'mausi-puva-bhai', 'mMyZS': 'mausi-puva-bhai', 'mFZeS': 'pivasi-puva-bhai', 'mFZyS': 'pivasi-puva-bhai', 'mMBeS': 'mamo-puva-bhai', 'mMByS': 'mamo-puva-bhai', 'mMZeS': 'mausi-puva-bhai', 'mMZyS': 'mausi-puva-bhai', 'mZH': 'grāmahasaka', 'fMB': 'mamo', 'fFeB': 'dadda', 'fMyB': 'mamo', 'fFBS': 'puva-bhai', 'fFZS': 'pivasi-puva-bhai', 'fMBS': 'mamo-puva-bhai', 'fMZS': 'mausi-puva-bhai', 'fFeBS': 'kakāpua bhāi', 'fFyBS': 'puva-bhai', 'fFeZS': 'pivasi-puva-bhai', 'fFyZS': 'pivasi-puva-bhai', 'fMyBS': 'mamo-puva-bhai', 'fMeZS': 'mausi-puva-bhai', 'fMyZS': 'mausi-puva-bhai', 'fFZeS': 'pivasi-puva-bhai', 'fFZyS': 'pivasi-puva-bhai', 'fMBeS': 'mamo-puva-bhai', 'fMByS': 'mamo-puva-bhai', 'fMZeS': 'mausi-puva-bhai', 'fMZyS': 'mausi-puva-bhai', 'fZH': 'grāmahasaka', 'mB': 'bhai', 'mZ': 'bhauni', 'mF': 'bappa', 'mM': 'bou', 'mS': 'puvo', 'mD': 'zia', 'mFF': 'jeje-bapa', 'mMF': 'ajja', 'mMM': 'āī', 'mSS': 'nāti', 'mSD': 'natuni', 'mDS': 'nāti', 'mDD': 'natuni', 'mFZ': 'piusi', 'mMZ': 'mausi', 'mFyB': 'khudata', 'mFeZ': 'piusi', 'mFyZ': 'piusi', 'mMeZ': 'mausi', 'mMyZ': 'mausi', 'mBS': 'puttura', 'mBD': 'ziari', 'mZS': 'bhanaja', 'meBS': 'puttura', 'myBS': 'puttura', 'meBD': 'ziari', 'myBD': 'ziari', 'meZS': 'bhanaja', 'myZS': 'bhanaja', 'mW': 'stri', 'mHF': 'sasura', 'mWB': 'sala', 'mWZ': 'sali', 'mHB': 'diara', 'mHZ': 'nanad', 'mSW': 'bohu', 'mDH': 'jwai', 'fB': 'bhai', 'fZ': 'bhauni', 'fF': 'bappa', 'fM': 'bou', 'fS': 'puvo', 'fD': 'zia', 'fFF': 'jeje-bapa', 'fMF': 'ajja', 'fMM': 'āī', 'fSS': 'nāti', 'fSD': 'natuni', 'fDS': 'nāti', 'fDD': 'natuni', 'fFZ': 'piusi', 'fMZ': 'mausi', 'fFyB': 'khudata', 'fFeZ': 'piusi', 'fFyZ': 'piusi', 'fMeZ': 'mausi', 'fMyZ': 'mausi', 'fBS': 'puttura', 'fBD': 'ziari', 'fZS': 'bhanaja', 'feBS': 'puttura', 'fyBS': 'puttura', 'feBD': 'ziari', 'fyBD': 'ziari', 'feZS': 'bhanaja', 'fyZS': 'bhanaja', 'fW': 'stri', 'fHF': 'sasura', 'fWB': 'sala', 'fWZ': 'sali', 'fHB': 'diara', 'fHZ': 'nanad', 'fSW': 'bohu', 'fDH': 'jwai', 'meB': 'bɔṛɔ bha:i', 'meZ': 'bɔṛɔ bhɔuɳi:', 'myZ': 'sa:nɔ bhɔuɳi:', 'mFM': 'ǰeǰema', 'mMB': 'mamo', 'mMeB': 'mamo', 'mZD': 'bhanaji', 'meZD': 'bhanaji', 'myZD': 'bhanaji', 'mFZD': 'piusi-zia-bhauni', 'mMBD': 'mamo-zia-bhauni', 'mMZD': 'mausi-zia-bhauni', 'mFyBD': 'kakkoi-zia-bhauni', 'mFeZD': 'piusi-zia-bhauni', 'mFyZD': 'piusi-zia-bhauni', 'mMeBS': 'mamo-puva-bhai', 'mMeBD': 'mamo-zia-bhauni', 'mMyBD': 'mamo-zia-bhauni', 'mMeZD': 'mausi-zia-bhauni', 'mMyZD': 'mausi-zia-bhauni', 'mFBeS': 'jeṭhāpua', 'mFByS': 'kakkoi puva bhai', 'mFBeD': 'daddai-zia-bhauni', 'mFByD': 'kakkoi-zia-bhauni', 'mFZeD': 'piusi-zia-bhauni', 'mFZyD': 'piusi-zia-bhauni', 'mMBeD': 'mamo-zia-bhauni', 'mMByD': 'mamo-zia-bhauni', 'mMZeD': 'mausi-zia-bhauni', 'mMZyD': 'mausi-zia-bhauni', 'mH': 'bǝrǝ', 'mHM': 'sasu', 'mBW': 'bhai-vahu', 'feB': 'bɔṛɔ bha:i', 'feZ': 'bɔṛɔ bhɔuɳi:', 'fyZ': 'sa:nɔ bhɔuɳi:', 'fFM': 'ǰeǰema', 'fMeB': 'mamo', 'fZD': 'bhanaji', 'feZD': 'bhanaji', 'fyZD': 'bhanaji', 'fFZD': 'piusi-zia-bhauni', 'fMBD': 'mamo-zia-bhauni', 'fMZD': 'mausi-zia-bhauni', 'fFyBD': 'kakkoi-zia-bhauni', 'fFeZD': 'piusi-zia-bhauni', 'fFyZD': 'piusi-zia-bhauni', 'fMeBS': 'mamo-puva-bhai', 'fMeBD': 'mamo-zia-bhauni', 'fMyBD': 'mamo-zia-bhauni', 'fMeZD': 'mausi-zia-bhauni', 'fMyZD': 'mausi-zia-bhauni', 'fFBeS': 'jeṭhāpua', 'fFByS': 'kakkoi puva bhai', 'fFBeD': 'daddai-zia-bhauni', 'fFByD': 'kakkoi-zia-bhauni', 'fFZeD': 'piusi-zia-bhauni', 'fFZyD': 'piusi-zia-bhauni', 'fMBeD': 'mamo-zia-bhauni', 'fMByD': 'mamo-zia-bhauni', 'fMZeD': 'mausi-zia-bhauni', 'fMZyD': 'mausi-zia-bhauni', 'fH': 'bǝrǝ', 'fHM': 'sasu', 'fBW': 'bhai-vahu', 'mWF': 'sasura', 'mWM': 'sasu', 'fWF': 'sasura', 'fWM': 'sasu', 'myB': 'sa:nɔ bha:i', 'mP': 'pita:ma:ta:', 'mC': 'sɔnta:nɔ ...

# %% [markdown]
# As we can see from printing the system, there's a lot of extra kin terms here that we don't need for our experiment today. We're only interested in Ego and Ego's parents' generations, but the system contains kin types like `mS` (male speaker's son) or `mDD` (make speaker's daughter's daughter). In the next section, we'll reduce `k` down to just the terms we're interested in.
#
# ### Condense the system down
#
# The list of possible **kin types** is far larger and more unwieldy than the set of **kin terms** in any language. For instance, while 'father's elder brother' and 'father's younger brother' are not distinguished in English (both take the term *uncle*), these distinctions are indeed encoded by terminology in other languages, like Hindi.
#
# We want create a data structure that pairs up parent types with the corresponding child types. This is because we're interested in whether kinship systems maintain patterns of terminological distinctions and mergers across these two generations, we will need to know which parent terms 'go with' which child terms.
#
# In `kintypes`, you will find **a list of pairs of kin types**, where the first element in the pair is a parent type, and the second is their child; e.g. `mMeB` and `mMeBD` (mother's elder brother and mother's elder brother's daughter). We will be filtering our full kinship system according to this list of pairs; that is, both types in the pair need to be present to be counted in the MI calculation.
#
# The following function takes a kinship system as input, and outputs a list of tuples. The first element in the tuple is the parent term, the second is the corresponding child term.

# %%
def filter_ks(ks: dict) -> dict:
    filtered_ks = {}
    for pair in kt.ics_pairs:
        if pair[0] in ks and pair[1] in ks:
            filtered_ks[pair[0]] = ks[pair[0]]
            filtered_ks[pair[1]] = ks[pair[1]]
        else:
            pass

    return filtered_ks

# %%
def get_pairs(ks: dict) -> list:
    pairs_of_terms = []
    parent_types = []

    for pair in kt.ics_pairs:
        if pair[0] in ks and pair[1] in ks:
            pairs_of_terms.append((ks[pair[0]],ks[pair[1]]))
            parent_types.append(pair[0])
                
    return pairs_of_terms

# %% [markdown]
# But for our calculations, we'll still need to know which terms belong to which generation. Luckily, we know that the 0th element in each tuple is from Ego's parents' generation and the 1st element is from Ego's generation. So we can happily split these tuples down the middle and populate two lists with the terms.

# %%
def split_pairs(pairs: list) -> list:
    gn = []
    gn1 = []
    for pair in pairs:
        gn.append(pair[1])
        gn1.append(pair[0])
    
    return gn,gn1

# %% [markdown]
# To illustrate what these functions do, let's test them out with our random kinship system, `k`.

# %%
if testing:
    k_pairs = get_pairs(k)
    print(k_pairs)
# Out:
# [('bou', 'bɔṛɔ bha:i'), ('bou', 'sa:nɔ bha:i'), ('bou', 'bɔṛɔ bhɔuɳi:'), ('bou', 'sa:nɔ bhɔuɳi:'), ('bappa', 'bɔṛɔ bha:i'), ('bappa', 'sa:nɔ bha:i'), ('bappa', 'bɔṛɔ bhɔuɳi:'), ('bappa', 'sa:nɔ bhɔuɳi:'), ('mamo', 'mamo-puva-bhai'), ('mamo', 'mamo-zia-bhauni'), ('mamo', 'mamo-puva-bhai'), ('mamo', 'mamo-zia-bhauni'), ('dadda', 'kakāpua bhāi'), ('khudata', 'puva-bhai'), ('khudata', 'kakkoi-zia-bhauni'), ('mausi', 'mausi-puva-bhai'), ('mausi', 'mausi-zia-bhauni'), ('mausi', 'mausi-puva-bhai'), ('mausi', 'mausi-zia-bhauni'), ('piusi', 'pivasi-puva-bhai'), ('piusi', 'piusi-zia-bhauni'), ('piusi', 'pivasi-puva-bhai'), ('piusi', 'piusi-zia-bhauni'), ('bou', 'bɔṛɔ bha:i'), ('bou', 'sa:nɔ bha:i'), ('bou', 'bɔṛɔ bhɔuɳi:'), ('bou', 'sa:nɔ bhɔuɳi:'), ('bappa', 'bɔṛɔ bha:i'), ('bappa', 'sa:nɔ bha:i'), ('bappa', 'bɔṛɔ bhɔuɳi:'), ('bappa', 'sa:nɔ bhɔuɳi:'), ('mamo', 'mamo-puva-bhai'), ('mamo', 'mamo-zia-bhauni'), ('mamo', 'mamo-puva-bhai'), ('mamo', 'mamo-zia-bhauni'), ('dadda', 'kakāpua bhāi'), ('khudata', 'puva-bhai'), ('khudata', 'kakkoi-zia-bhauni'), ('mausi', 'mausi-puva-bhai'), ('mausi', 'mausi-zia-bhauni'), ('mausi', 'mausi-puva-bhai'), ('mausi', 'mausi-zia-bhauni'), ('piusi', 'pivasi-puva-bhai'), ('piusi', 'piusi-zia-bhauni'), ('piusi', 'pivasi-puva-bhai'), ('piusi', 'piusi-zia-bhauni')]

# %%
if testing:
    
    k_gn,k_gn1 = split_pairs(k_pairs)

    print("Ego's generation: ", k_gn, '\n')

    print("Ego's parents' generation: ", k_gn1)
# Out:
# Ego's generation:  ['bɔṛɔ bha:i', 'sa:nɔ bha:i', 'bɔṛɔ bhɔuɳi:', 'sa:nɔ bhɔuɳi:', 'bɔṛɔ bha:i', 'sa:nɔ bha:i', 'bɔṛɔ bhɔuɳi:', 'sa:nɔ bhɔuɳi:', 'mamo-puva-bhai', 'mamo-zia-bhauni', 'mamo-puva-bhai', 'mamo-zia-bhauni', 'kakāpua bhāi', 'puva-bhai', 'kakkoi-zia-bhauni', 'mausi-puva-bhai', 'mausi-zia-bhauni', 'mausi-puva-bhai', 'mausi-zia-bhauni', 'pivasi-puva-bhai', 'piusi-zia-bhauni', 'pivasi-puva-bhai', 'piusi-zia-bhauni', 'bɔṛɔ bha:i', 'sa:nɔ bha:i', 'bɔṛɔ bhɔuɳi:', 'sa:nɔ bhɔuɳi:', 'bɔṛɔ bha:i', 'sa:nɔ bha:i', 'bɔṛɔ bhɔuɳi:', 'sa:nɔ bhɔuɳi:', 'mamo-puva-bhai', 'mamo-zia-bhauni', 'mamo-puva-bhai', 'mamo-zia-bhauni', 'kakāpua bhāi', 'puva-bhai', 'kakkoi-zia-bhauni', 'mausi-puva-bhai', 'mausi-zia-bhauni', 'mausi-puva-bhai', 'mausi-zia-bhauni', 'pivasi-puva-bhai', 'piusi-zia-bhauni', 'pivasi-puva-bhai', 'piusi-zia-bhauni']
#
# Ego's parents' generation:  ['bou', 'bou', 'bou', 'bou', 'bappa', 'bappa', 'bappa', 'bappa', 'mamo', 'mamo', 'mamo', 'mamo', 'dadda', 'khudata', 'khudata', 'mausi', 'mausi', 'mausi', 'mausi', 'piusi', 'piusi', 'piusi', 'piusi', 'bou', 'bou', 'bou', 'bou', 'bappa', 'bappa', 'bappa', 'bappa', 'mamo', 'mamo', 'mamo', 'mamo', 'dadda', 'khudata', 'khudata', 'mausi', 'mausi', 'mausi', 'mausi', 'piusi', 'piusi', 'piusi', 'piusi']

# %% [markdown]
# `get_pairs()` gives us a long list of pairs.
#
# `split_pairs()` takes this long list of pairs and sorts it into terms that belong to Ego's generation and terms that belong to Ego's parents' generation. Importantly, since the order of the `pairs` list is preserved when we run `split_generations()`, we can still work out which terms form a parent-child pair by indexing `gn` and `gn1`.
#
# Now we have our data structures, we can start to do some calculations.
#
# ### Calculating probabilities

# %% [markdown]
# To calculate entropy, we need a probability distribution over the terms in one single generation of a kinship system. So let's start with a function that can calculate the probability of a particular term.
#
# Given a term and the full list of terms in the same generation, this function counts how many times that term exists in `generation` and divides that by the total length of `generation`.

# %%
def probability(term: str, generation: list) -> float:
    #print(generation.count(term),len(generation))
    return generation.count(term)/len(generation)

# %% [markdown]
# So if we pick a term at random from our Nogai kinship system, it will output the probability of picking that term.

# %%
if testing:
    print(k2_gn1)
    print(k2_gn)
    print(k2)
    for term in k2_gn1:
        print(term, probability(term,k2_gn1))
    for term in k2_gn:
        print(term,probability(term,k2_gn))
# Out:
# ['pii', 'pii', 'pii', 'appï', 'appï', 'appï', 'pii', 'pii', 'pii', 'pii', 'appï', 'appï', 'appï', 'appï']
# ['tami', 'paci', 'nammi', 'tami', 'paci', 'nammi', 'papi', 'tami', 'paci', 'nammi', 'papi', 'tami', 'paci', 'nammi']
# {'myB': 'paci', 'meZ': 'tami', 'myZ': 'paci', 'mF': 'appï', 'mM': 'pii', 'mC': 'tua', 'mS': 'tua', 'mD': "paitï''", 'mFF': 'kïnu', 'mFM': 'kaku', 'mMF': 'toko', 'mMM': 'hucci', 'mFB': 'hee', 'mFZ': 'paha', 'mMB': 'ata', 'mFeB': 'hee', 'mFyB': 'hee', 'mFeZ': 'paha', 'mFyZ': 'paha', 'mMeB': 'ata', 'mMyB': 'ata', 'mDH': 'monappï', 'mTW': 'wawa', 'feB': 'nammi', 'fyB': 'nammi', 'feZ': 'tami', 'fyZ': 'papi', 'fF': 'appï', 'fM': 'pii', 'fC': 'tua', 'fS': 'tua', 'fD': "paitï''", 'fFF': 'kïnu', 'fFM': 'kaku', 'fMF': 'toko', 'fMM': 'hucci', 'fFB': 'hee', 'fFZ': 'paha', 'fMB': 'ata', 'fFeB': 'hee', 'fFyB': 'hee', 'fFeZ': 'paha', 'fFyZ': 'paha', 'fMeB': 'ata', 'fMyB': 'ata', 'fH': 'kuha', 'fDH': 'monappï', 'fTW': 'wawa'}
# pii 0.5
# pii 0.5
# pii 0.5
# appï 0.5
# appï 0.5
# appï 0.5
# pii 0.5
# pii 0.5
# pii 0.5
# pii 0.5
# appï 0.5
# appï 0.5
# appï 0.5
# appï 0.5
# tami 0.2857142857142857
# paci 0.2857142857142857
# nammi 0.2857142857142857
# tami 0.2857142857142857
# paci 0.2857142857142857
# nammi 0.2857142857142857
# papi 0.14285714285714285
# tami 0.2857142857142857
# paci 0.2857142857142857
# nammi 0.2857142857142857
# papi 0.14285714285714285
# tami 0.2857142857142857
# paci 0.2857142857142857
# nammi 0.2857142857142857

# %% [markdown]
# When calculating mutual information, we also need the **conditional entropy** between the two generations of our system. To calculate this, we will need not only the probabilities of terms in a generation, but also the **joint probabilities** of every pair of terms across those two generations. In other words, we need to calculate the probabilities of our `get_pairs` output.
#
# Given two terms, this function counts how many pairs made of those two terms exist in `pairs`, then divides that by the total length of `pairs`.

# %%
def joint_probability(term1: str, term2: str, pairs: list) -> float:
    pair = (term1,term2)
    # print(pairs.count(pair)/len(pairs))
    return pairs.count(pair)/len(pairs)

# %% [markdown]
# Once again, we can test this with a random pair from our Nogai list of pairs:

# %%
if testing:
    sum_jp = []
    for pair in set(k2_pairs):
        print(pair)
        jp = joint_probability(pair[0],pair[1],k2_pairs)
        print(jp)
        sum_jp.append(jp)
        # print(pair, jp)
    print(sum_jp, sum(sum_jp))
# Out:
# ('indo', 'tukaka')
# 0.21428571428571427
# 0.21428571428571427
# ('oˀua', 'tuai')
# 0.2857142857142857
# 0.2857142857142857
# ('oˀua', 'tukaka')
# 0.21428571428571427
# 0.21428571428571427
# ('indo', 'tuai')
# 0.2857142857142857
# 0.2857142857142857
# [0.21428571428571427, 0.2857142857142857, 0.21428571428571427, 0.2857142857142857] 1.0

# %% [markdown]
# Now we can calculate probabilities, we can use these functions to calculate entropy, conditional entropy, and mutual information.
#
# ### Calculating entropy and mutual information
#
# Entropy (in bits) is defined as
#
# $$
# H(X) = -\sum_{x \in X}p(x) log_2p(x)
# $$
#
# or, in English, it is the inverse sum over a distribution X of the probability of y * the log probability of y.
#
# Entropy is a measure of the average level of uncertainty about the possible outcomes of a variable.
#
# The functions we defined above only calculate a single probability at a time, so our next functions will need to iterate over the kinship system in order to have a full probability distribution. First, let's define a function that will iterate over a generation of the kinship system to output the entropy of that generation.
#
# Note: we only need one generation's entropy score to calculate mutual information - we will make the arbitrary choice to calculate the entropy of Ego's parents' generation later in this notebook.

# %%
def entropy(generation: list) -> list:
    entropy = 0
    for term in set(generation): # using a set as we want to count each unique term only once
        p = probability(term,generation)
        #print('entropy of',term,p*math.log(p))
        entropy += p*math.log2(p)
    return -entropy

# %%
if testing:
    print(entropy(k_gn1))
# Out:
# 2.697474999535274

# %%
if testing:

# %% [markdown]
# Moving on, conditional entropy of Y given X is defined as
#
# $$
# H(Y|X) = -\sum_{x \in X,y \in Y}p(x,y) log_2 {p(x,y) \over p(x)}
# $$
#
# or in English, the inverse sum over two distributions Y and X of the probability of each y * the log probability of each y given x.
#
# Conditional entropy is the amount of information needed to describe the outcome of a random variable Y given that we already know the value of another random variable X.
#
# To calculate it, we need the joint probability of each pair (given by `joint_probability()`) and the probability of one member of that pair (given by `probability()`). We can then calculate the conditional probability of parent term given child term as the joint probability of those terms over the probability of the parent term.
#
# As before, we will define a function that iterates over all pairs to output the conditional entropy of Ego's generation given Ego's parents' generation.

# %%
def conditional_entropy(gn: list, pairs:list) -> float:
    entropy = 0
    for x,y in set(pairs): # x = parent, y = child
        p_xy = joint_probability(x,y,pairs)
        p_y = probability(y,gn)
        if p_xy > 0 and p_y > 0:
            #print('p(', x, '|', y,') = ', p_xy/p_y, 'p(y) = ', p_y)
            entropy += p_xy * math.log2(p_xy/p_y)
    return -entropy

# %%
if testing:
    print(conditional_entropy(k_gn,k_pairs))
# Out:
# 0.34782608695652173

# %% [markdown]
# Finally, mutual information is defined as
#
# $$
# I(X;Y) \equiv H(X) - H(X|Y)
# $$
#
# or in English, entropy of X minus the conditional entropy of X given Y.
#
# In this study, it is equal to the entropy of Ego's parents' generation minus the conditional entropy of Ego's parents' generation given Ego's generation. It tells us how much mutual dependence there is between these two generations; i.e. how much we can know about one by observing the other.
#
# So long as we make sure to input the right entropy and conditional entropy values, we only need a simple function for this one:

# %%
def mutual_information(pairs: list):
    gn,gn1 = split_pairs(pairs)
    e = entropy(gn1)
    ce = conditional_entropy(gn,pairs)
    mi = e - ce
    return mi

# %%
if testing:
    print(mutual_information(k_pairs))
# Out:
# 2.3496489125787523

# %% [markdown]
# And there we have it! Step 4 complete. We can now take any (filtered) Kinbank file and output the mutual information between Ego's generation and Ego's parents' generation in that language.
#
# But right at the beginning of this notebook, I mentioned using **simulations** to test the robustness of our claim that languages exhibit internal co-selection in their kinship systems. These simulations give us a baseline with which to compare the MI scores of real languages. Do languages across the world have greater mutual information between two generations than we would expect by chance?
#
# ## Simulations
#
# If we want to argue that internal co-selection is a product of cultural evolution, we need to dispel the possibility that it occurs by chance.
#
# To get an idea of how much information would be shared between two generations purely by chance, we need to create some randomly generated kinship systems. We can compare the MI of these simulations to the real languages to see whether the real languages have significantly greater mutual information between generations.
#
# An important aspect of MI that we have not discussed so far: it is dependent on the amount of variation within the kinship system. A system with only one unique term in each generation would have MI of 0, which seems pretty terrible! But given this very limited variation (indeed, no variation), 0 is the highest MI such a language could have. As such, we perhaps need to modify our claim that kinship systems have "high MI" to be more specific: kinship systems in the wild have high MI *for the amount of variation in terminology they have*.
#
# To compare real languages to simulations, we need a simulation which maintains the number of terms while randomising which child terms pair with which parent terms. To do this, we will take each language in our data, and randomly scramble which terms go with which types (within generation). This will randomise the syncretisms within the generations while maintaining the same amount of variation across the system overall.
#
# To do this, we need to take the following steps:
#
# 1. Extract the kinship system of a language from kinbank (check!)
# 2. Filter the two generations we are interested in (check!)
# 3. Randomly reassign the kinship terms to new types.
# 4. Repeat the process a bunch of times for each language.
#
# We already have the infrastructure for the first two! `get_kin_terms()`,  `get_pairs()` and `split_pairs()` will do this for us. So let's skip to 3, and write a function that randomises which terms form pairs, assuming that we have already extracted the kinship system and filtered the relevant pairs.
#
# Remember that the order of `pairs` is preserved when we run `split_pairs()`. So when we pass `gn` and `gn1` to `shuffle_pairs()`, we know that we can re-unite our pairs by using the same index. Equally, when we shuffle `gn` and `gn1` in place, we know that we can safely combine them to make a new, randomised pair in place of the 'real' Nogai pair.

# %%
def split_ks(ks):
    filtered_ks = filter_ks(ks)
    gn = {}
    gn1 = {}
    for entry in filtered_ks:
        if entry in kt.generation_n:
            gn[entry] = filtered_ks[entry]
        elif entry in kt.generation_n1:
            gn1[entry] = filtered_ks[entry]
        else:
            pass

    return gn,gn1

# %%
split_ks(k)
# Out:
# ({'meB': 'bɔṛɔ bha:i',
#   'myB': 'sa:nɔ bha:i',
#   'meZ': 'bɔṛɔ bhɔuɳi:',
#   'myZ': 'sa:nɔ bhɔuɳi:',
#   'mMeBS': 'mamo-puva-bhai',
#   'mMeBD': 'mamo-zia-bhauni',
#   'mMyBS': 'mamo-puva-bhai',
#   'mMyBD': 'mamo-zia-bhauni',
#   'mFeBS': 'kakāpua bhāi',
#   'mFyBS': 'puva-bhai',
#   'mFyBD': 'kakkoi-zia-bhauni',
#   'mMeZS': 'mausi-puva-bhai',
#   'mMeZD': 'mausi-zia-bhauni',
#   'mMyZS': 'mausi-puva-bhai',
#   'mMyZD': 'mausi-zia-bhauni',
#   'mFeZS': 'pivasi-puva-bhai',
#   'mFeZD': 'piusi-zia-bhauni',
#   'mFyZS': 'pivasi-puva-bhai',
#   'mFyZD': 'piusi-zia-bhauni',
#   'feB': 'bɔṛɔ bha:i',
#   'fyB': 'sa:nɔ bha:i',
#   'feZ': 'bɔṛɔ bhɔuɳi:',
#   'fyZ': 'sa:nɔ bhɔuɳi:',
#   'fMeBS': 'mamo-puva-bhai',
#   'fMeBD': 'mamo-zia-bhauni',
#   'fMyBS': 'mamo-puva-bhai',
#   'fMyBD': 'mamo-zia-bhauni',
#   'fFeBS': 'kakāpua bhāi',
#   'fFyBS': 'puva-bhai',
#   'fFyBD': 'kakkoi-zia-bhauni',
#   'fMeZS': 'mausi-puva-bhai',
#   'fMeZD': 'mausi-zia-bhauni',
#   'fMyZS': 'mausi-puva-bhai',
#   'fMyZD': 'mausi-zia-bhauni',
#   'fFeZS': 'pivasi-puva-bhai',
#   'fFeZD': 'piusi-zia-bhauni',
#   'fFyZS': 'pivasi-puva-bhai',
#   'fFyZD': 'piusi-zia-bhauni'},
#  {'mM': 'bou',
#   'mF': 'bappa',
#   'mMeB': 'mamo',
#   'mMyB': 'mamo',
#   'mFeB': 'dadda',
#   'mFyB': 'khudata',
#   'mMeZ': 'mausi',
#   'mMyZ': 'mausi',
#   'mFeZ': 'piusi',
#   'mFyZ': 'piusi',
#   'fM': 'bou',
#   'fF': 'bappa',
#   'fMeB': 'mamo',
#   'fMyB': 'mamo',
#   'fFeB': 'dadda',
#   'fFyB': 'khudata',
#   'fMeZ': 'mausi',
#   'fMyZ': 'mausi',
#   'fFeZ': 'piusi',
#   'fFyZ': 'piusi'})

# %%
def shuffle_ks(ks):
    gn_terms = []
    gn,gn1 = split_ks(ks)
    for term in gn:
        gn_terms.append(gn[term])

    random.shuffle(gn_terms)
    
    for i in range(len(gn)):
        # print(i)
        key = list(gn.keys())[i]
        ks[key] = gn_terms[i]

    return ks

# %%
print(shuffle_ks(k))
# Out:
# {'mFeB': 'dadda', 'mMyB': 'mamo', 'mFBS': 'puva-bhai', 'mFZS': 'pivasi-puva-bhai', 'mMBS': 'mamo-puva-bhai', 'mMZS': 'mausi-puva-bhai', 'mFeBS': 'piusi-zia-bhauni', 'mFyBS': 'mausi-zia-bhauni', 'mFeZS': 'mamo-zia-bhauni', 'mFyZS': 'kakkoi-zia-bhauni', 'mMyBS': 'pivasi-puva-bhai', 'mMeZS': 'mamo-zia-bhauni', 'mMyZS': 'piusi-zia-bhauni', 'mFZeS': 'pivasi-puva-bhai', 'mFZyS': 'pivasi-puva-bhai', 'mMBeS': 'mamo-puva-bhai', 'mMByS': 'mamo-puva-bhai', 'mMZeS': 'mausi-puva-bhai', 'mMZyS': 'mausi-puva-bhai', 'mZH': 'grāmahasaka', 'fMB': 'mamo', 'fFeB': 'dadda', 'fMyB': 'mamo', 'fFBS': 'puva-bhai', 'fFZS': 'pivasi-puva-bhai', 'fMBS': 'mamo-puva-bhai', 'fMZS': 'mausi-puva-bhai', 'fFeBS': 'mamo-puva-bhai', 'fFyBS': 'sa:nɔ bha:i', 'fFeZS': 'bɔṛɔ bhɔuɳi:', 'fFyZS': 'piusi-zia-bhauni', 'fMyBS': 'pivasi-puva-bhai', 'fMeZS': 'mausi-zia-bhauni', 'fMyZS': 'mausi-puva-bhai', 'fFZeS': 'pivasi-puva-bhai', 'fFZyS': 'pivasi-puva-bhai', 'fMBeS': 'mamo-puva-bhai', 'fMByS': 'mamo-puva-bhai', 'fMZeS': 'mausi-puva-bhai', 'fMZyS': 'mausi-puva-bhai', 'fZH': 'grāmahasaka', 'mB': 'bhai', 'mZ': 'bhauni', 'mF': 'bappa', 'mM': 'bou', 'mS': 'puvo', 'mD': 'zia', 'mFF': 'jeje-bapa', 'mMF': 'ajja', 'mMM': 'āī', 'mSS': 'nāti', 'mSD': 'natuni', 'mDS': 'nāti', 'mDD': 'natuni', 'mFZ': 'piusi', 'mMZ': 'mausi', 'mFyB': 'khudata', 'mFeZ': 'piusi', 'mFyZ': 'piusi', 'mMeZ': 'mausi', 'mMyZ': 'mausi', 'mBS': 'puttura', 'mBD': 'ziari', 'mZS': 'bhanaja', 'meBS': 'puttura', 'myBS': 'puttura', 'meBD': 'ziari', 'myBD': 'ziari', 'meZS': 'bhanaja', 'myZS': 'bhanaja', 'mW': 'stri', 'mHF': 'sasura', 'mWB': 'sala', 'mWZ': 'sali', 'mHB': 'diara', 'mHZ': 'nanad', 'mSW': 'bohu', 'mDH': 'jwai', 'fB': 'bhai', 'fZ': 'bhauni', 'fF': 'bappa', 'fM': 'bou', 'fS': 'puvo', 'fD': 'zia', 'fFF': 'jeje-bapa', 'fMF': 'ajja', 'fMM': 'āī', 'fSS': 'nāti', 'fSD': 'natuni', 'fDS': 'nāti', 'fDD': 'natuni', 'fFZ': 'piusi', 'fMZ': 'mausi', 'fFyB': 'khudata', 'fFeZ': 'piusi', 'fFyZ': 'piusi', 'fMeZ': 'mausi', 'fMyZ': 'mausi', 'fBS': 'puttura', 'fBD': 'ziari', 'fZS': 'bhanaja', 'feBS': 'puttura', 'fyBS': 'puttura', 'feBD': 'ziari', 'fyBD': 'ziari', 'feZS': 'bhanaja', 'fyZS': 'bhanaja', 'fW': 'stri', 'fHF': 'sasura', 'fWB': 'sala', 'fWZ': 'sali', 'fHB': 'diara', 'fHZ': 'nanad', 'fSW': 'bohu', 'fDH': 'jwai', 'meB': 'puva-bhai', 'meZ': 'puva-bhai', 'myZ': 'mamo-puva-bhai', 'mFM': 'ǰeǰema', 'mMB': 'mamo', 'mMeB': 'mamo', 'mZD': 'bhanaji', 'meZD': 'bhanaji', 'myZD': 'bhanaji', 'mFZD': 'piusi-zia-bhauni', 'mMBD': 'mamo-zia-bhauni', 'mMZD': 'mausi-zia-bhauni', 'mFyBD': 'sa:nɔ bha:i', 'mFeZD': 'mamo-zia-bhauni', 'mFyZD': 'sa:nɔ bhɔuɳi:', 'mMeBS': 'bɔṛɔ bhɔuɳi:', 'mMeBD': 'mamo-puva-bhai', 'mMyBD': 'mausi-puva-bhai', 'mMeZD': 'mausi-zia-bhauni', 'mMyZD': 'mamo-puva-bhai', 'mFBeS': 'jeṭhāpua', 'mFByS': 'kakkoi puva bhai', 'mFBeD': 'daddai-zia-bhauni', 'mFByD': 'kakkoi-zia-bhauni', 'mFZeD': 'piusi-zia-bhauni', 'mFZyD': 'piusi-zia-bhauni', 'mMBeD': 'mamo-zia-bhauni', 'mMByD': 'mamo-zia-bhauni', 'mMZeD': 'mausi-zia-bhauni', 'mMZyD': 'mausi-zia-bhauni', 'mH': 'bǝrǝ', 'mHM': 'sasu', 'mBW': 'bhai-vahu', 'feB': 'pivasi-puva-bhai', 'feZ': 'kakāpua bhāi', 'fyZ': 'mausi-zia-bhauni', 'fFM': 'ǰeǰema', 'fMeB': 'mamo', 'fZD': 'bhanaji', 'feZD': 'bhanaji', 'fyZD': 'bhanaji', 'fFZD': 'piusi-zia-bhauni', 'fMBD': 'mamo-zia-bhauni', 'fMZD': 'mausi-zia-bhauni', 'fFyBD': 'bɔṛɔ bha:i', 'fFeZD': 'kakkoi-zia-bhauni', 'fFyZD': 'kakāpua bhāi', 'fMeBS': 'sa:nɔ bhɔuɳi:', 'fMeBD': 'bɔṛɔ bha:i', 'fMyBD': 'mausi-puva-bhai', 'fMeZD': 'mamo-zia-bhauni', 'fMyZD': 'piusi-zia-bhauni', 'fFBeS': 'jeṭhāpua', 'fFByS': 'kakkoi puva bhai', 'fFBeD': 'daddai-zia-bhauni', 'fFByD': 'kakkoi-zia-bhauni', 'fFZeD': 'piusi-zia-bhauni', 'fFZyD': 'piusi-zia-bhauni', 'fMBeD': 'mamo-zia-bhauni', 'fMByD': 'mamo-zia-bhauni', 'fMZeD': 'mausi-zia-bhauni', 'fMZyD': 'mausi-zia-bhauni', 'fH': 'bǝrǝ', 'fHM': 'sasu', 'fBW': 'bhai-vahu', 'mWF': 'sasura', 'mWM': 'sasu', 'fWF': 'sasura', 'fWM': 'sasu', 'myB': 'mausi-puva-bhai', 'mP': 'pita:ma:ta:', 'mC': 'sɔnta:nɔ', 'fyB': 'pivasi-puva-b ...

# %%
# def shuffle_ks(ks):
#     gn_terms = []
#     pairs = get_pairs(ks)
#     for x,y in pairs:
#         gn_terms.append(y)

#     random.shuffle(gn_terms)

#     new_pairs = []

#     for i in range(len(pairs)):
#         new_pairs.append((pairs[i][0],gn_terms[i]))

#     return new_pairs

# %% [markdown]
# This should result in a version of our kinship system `k` where all of the generation n (Ego's generation) terms should be randomly shuffled w.r.t which keys they belong with. Everything else will remain the same. The terms we don't need for our analysis will be filtered out by our `get_pairs` function at a later stage.
#
# We don't need to shuffle the generation n+1 terms - shuffling one generation is sufficient to break any correlation between them. Because each term in ego's generation pairs uniquely with a parent term (but not vice versa) this prevents a situation where new kin categories are artificially created.

# %%
if testing:
    # print(shuffle_ks(k))
    #print(get_pairs(shuffle_ks(k)))
    print(split_pairs(get_pairs(shuffle_ks(k))))
# Out:
# (['mausi-puva-bhai', 'mausi-puva-bhai', 'bɔṛɔ bha:i', 'bɔṛɔ bhɔuɳi:', 'mausi-puva-bhai', 'mausi-puva-bhai', 'bɔṛɔ bha:i', 'bɔṛɔ bhɔuɳi:', 'pivasi-puva-bhai', 'mamo-puva-bhai', 'piusi-zia-bhauni', 'pivasi-puva-bhai', 'puva-bhai', 'mausi-zia-bhauni', 'sa:nɔ bhɔuɳi:', 'mamo-puva-bhai', 'bɔṛɔ bhɔuɳi:', 'mamo-puva-bhai', 'mausi-zia-bhauni', 'mamo-zia-bhauni', 'mausi-zia-bhauni', 'mamo-zia-bhauni', 'piusi-zia-bhauni', 'sa:nɔ bha:i', 'kakāpua bhāi', 'piusi-zia-bhauni', 'sa:nɔ bha:i', 'sa:nɔ bha:i', 'kakāpua bhāi', 'piusi-zia-bhauni', 'sa:nɔ bha:i', 'mausi-zia-bhauni', 'mausi-puva-bhai', 'pivasi-puva-bhai', 'mamo-puva-bhai', 'kakkoi-zia-bhauni', 'mausi-puva-bhai', 'kakkoi-zia-bhauni', 'mamo-zia-bhauni', 'bɔṛɔ bha:i', 'sa:nɔ bhɔuɳi:', 'pivasi-puva-bhai', 'kakāpua bhāi', 'piusi-zia-bhauni', 'puva-bhai', 'mamo-zia-bhauni'], ['bou', 'bou', 'bou', 'bou', 'bappa', 'bappa', 'bappa', 'bappa', 'mamo', 'mamo', 'mamo', 'mamo', 'dadda', 'khudata', 'khudata', 'mausi', 'mausi', 'mausi', 'mausi', 'piusi', 'piusi', 'piusi', 'piusi', 'bou', 'bou', 'bou', 'bou', 'bappa', 'bappa', 'bappa', 'bappa', 'mamo', 'mamo', 'mamo', 'mamo', 'dadda', 'khudata', 'khudata', 'mausi', 'mausi', 'mausi', 'mausi', 'piusi', 'piusi', 'piusi', 'piusi'])

# %%
if testing:
    sim = shuffle_ks(k)
    sim_pairs = get_pairs(sim)
    sim_gn,sim_gn1 = split_pairs(sim_pairs)
    # print(Counter(sim_gn))
    print(sim_pairs)
    print('\n\n', k_pairs)
# Out:
# [('bou', 'bɔṛɔ bhɔuɳi:'), ('bou', 'piusi-zia-bhauni'), ('bou', 'piusi-zia-bhauni'), ('bou', 'mausi-zia-bhauni'), ('bappa', 'bɔṛɔ bhɔuɳi:'), ('bappa', 'piusi-zia-bhauni'), ('bappa', 'piusi-zia-bhauni'), ('bappa', 'mausi-zia-bhauni'), ('mamo', 'bɔṛɔ bhɔuɳi:'), ('mamo', 'piusi-zia-bhauni'), ('mamo', 'kakkoi-zia-bhauni'), ('mamo', 'mamo-zia-bhauni'), ('dadda', 'kakkoi-zia-bhauni'), ('khudata', 'mamo-zia-bhauni'), ('khudata', 'sa:nɔ bha:i'), ('mausi', 'mausi-zia-bhauni'), ('mausi', 'sa:nɔ bhɔuɳi:'), ('mausi', 'pivasi-puva-bhai'), ('mausi', 'sa:nɔ bhɔuɳi:'), ('piusi', 'mausi-puva-bhai'), ('piusi', 'mamo-puva-bhai'), ('piusi', 'puva-bhai'), ('piusi', 'mamo-zia-bhauni'), ('bou', 'kakāpua bhāi'), ('bou', 'sa:nɔ bha:i'), ('bou', 'pivasi-puva-bhai'), ('bou', 'puva-bhai'), ('bappa', 'kakāpua bhāi'), ('bappa', 'sa:nɔ bha:i'), ('bappa', 'pivasi-puva-bhai'), ('bappa', 'puva-bhai'), ('mamo', 'mamo-puva-bhai'), ('mamo', 'bɔṛɔ bha:i'), ('mamo', 'piusi-zia-bhauni'), ('mamo', 'pivasi-puva-bhai'), ('dadda', 'kakāpua bhāi'), ('khudata', 'mamo-zia-bhauni'), ('khudata', 'mamo-puva-bhai'), ('mausi', 'mausi-puva-bhai'), ('mausi', 'mausi-puva-bhai'), ('mausi', 'mausi-zia-bhauni'), ('mausi', 'mausi-zia-bhauni'), ('piusi', 'bɔṛɔ bha:i'), ('piusi', 'mausi-puva-bhai'), ('piusi', 'mamo-puva-bhai'), ('piusi', 'pivasi-puva-bhai')]
#
#
#  [('bou', 'bɔṛɔ bha:i'), ('bou', 'sa:nɔ bha:i'), ('bou', 'bɔṛɔ bhɔuɳi:'), ('bou', 'sa:nɔ bhɔuɳi:'), ('bappa', 'bɔṛɔ bha:i'), ('bappa', 'sa:nɔ bha:i'), ('bappa', 'bɔṛɔ bhɔuɳi:'), ('bappa', 'sa:nɔ bhɔuɳi:'), ('mamo', 'mamo-puva-bhai'), ('mamo', 'mamo-zia-bhauni'), ('mamo', 'mamo-puva-bhai'), ('mamo', 'mamo-zia-bhauni'), ('dadda', 'kakāpua bhāi'), ('khudata', 'puva-bhai'), ('khudata', 'kakkoi-zia-bhauni'), ('mausi', 'mausi-puva-bhai'), ('mausi', 'mausi-zia-bhauni'), ('mausi', 'mausi-puva-bhai'), ('mausi', 'mausi-zia-bhauni'), ('piusi', 'pivasi-puva-bhai'), ('piusi', 'piusi-zia-bhauni'), ('piusi', 'pivasi-puva-bhai'), ('piusi', 'piusi-zia-bhauni'), ('bou', 'bɔṛɔ bha:i'), ('bou', 'sa:nɔ bha:i'), ('bou', 'bɔṛɔ bhɔuɳi:'), ('bou', 'sa:nɔ bhɔuɳi:'), ('bappa', 'bɔṛɔ bha:i'), ('bappa', 'sa:nɔ bha:i'), ('bappa', 'bɔṛɔ bhɔuɳi:'), ('bappa', 'sa:nɔ bhɔuɳi:'), ('mamo', 'mamo-puva-bhai'), ('mamo', 'mamo-zia-bhauni'), ('mamo', 'mamo-puva-bhai'), ('mamo', 'mamo-zia-bhauni'), ('dadda', 'kakāpua bhāi'), ('khudata', 'puva-bhai'), ('khudata', 'kakkoi-zia-bhauni'), ('mausi', 'mausi-puva-bhai'), ('mausi', 'mausi-zia-bhauni'), ('mausi', 'mausi-puva-bhai'), ('mausi', 'mausi-zia-bhauni'), ('piusi', 'pivasi-puva-bhai'), ('piusi', 'piusi-zia-bhauni'), ('piusi', 'pivasi-puva-bhai'), ('piusi', 'piusi-zia-bhauni')]

# %% [markdown]
# Now we can treat `sim_pairs` just as we treated `pairs`! Let's calculate the entropy, conditional entropy, and mutual information of this simulated system.

# %%
if testing:
    sim = shuffle_ks(k)
    sim_pairs = get_pairs(sim)
    sim_gn,sim_gn1 = split_pairs(sim_pairs)
    e = entropy(sim_gn1)
    ce = conditional_entropy(sim_gn,sim_pairs)
    mi = mutual_information(sim_pairs)
    print('Simulation: ', e,ce,mi)
    print('Real: ', entropy(k_gn1),conditional_entropy(k_gn,k_pairs),mutual_information(k_pairs))
# Out:
# Simulation:  2.697474999535274 1.6510508022190042 1.0464241973162696
# Real:  2.697474999535274 0.34782608695652173 2.3496489125787523

# %% [markdown]
# Wait! One of these values are exactly the same as the real kinship system! I thought this was a randomised simulation - what gives?
#
# Variation gives! Entropy remains the same regardless, because the amount of variation in the simulation **does not change** by design.
#
# The MI of these two systems (and by extension, the conditional entropy) **does** vary, which is what we want. Let's try with another language:

# %%
if testing:
    file2 = random.choice(all_kb_files)
    print(file2)
    # k2 = get_kin_terms(filepath + 'Shoshoni_shos1248.csv')
    k2 = get_kin_terms(filepath + file2)
    # print(k2)

    k2_pairs = get_pairs(k2)
    k2_gn,k2_gn1 = split_pairs(k2_pairs)
    print(Counter(k2_gn))
    k2_e = entropy(k2_gn1)
    k2_ce = conditional_entropy(k2_gn,k2_pairs)
    k2_mi = mutual_information(k2_pairs)
    
    k2_sim = shuffle_ks(k2)
    k2_sim_pairs = get_pairs(k2_sim)
    k2_sim_gn,k2_sim_gn1 = split_pairs(k2_sim_pairs)
    # print(k2_sim_gn)
    print(Counter(k2_sim_gn))
    k2_sim_e = entropy(k2_sim_gn1)
    k2_sim_ce = conditional_entropy(k2_sim_gn,k2_sim_pairs)
    k2_sim_mi = mutual_information(k2_sim_pairs)
    
    print('Real:', k2_e,k2_ce,k2_mi)
    print('Simulation:',k2_sim_e,k2_sim_ce,k2_sim_mi)
    
    print(len(k2_sim),len(k2_pairs))
    
    # for i in k2_pairs:
    #     if i not in k2_sim:
    #         print(i)
            
    # for i in k2_sim:
    #     if i not in k2_pairs:
    #         print(i)
# Out:
# De_kwana_Maquiritari__maqu1238.csv
# Counter({'yāʔko': 32, '-nuwā-dɨ': 4, 'šīʔčɨ': 4})
# Counter({'yāʔko': 35, 'šīʔčɨ': 3, '-nuwā-dɨ': 2})
# Real: 1.9709505944546686 1.7999999999999998 0.17095059445466876
# Simulation: 1.9709505944546686 1.8874247334256615 0.08352586102900705
# 165 40

# %% [markdown]
# Now we see that while the entropy of our new language and its simulation are equal, the conditional entropy for the simulation is greater and therefore the mutual information of the simulation is lower. What about if we did this 1000 times? How often would the mutual information of the simulation be lower then?
#
# ## Tidying up
#
# We have all the pieces we need now to calculate MI and simulate kinship systems - all we need to do is write a few more functions that stick all of those pieces together in a neat parcel.
#
# First, a function that takes pairs and spits out entropy, conditional entropy, and MI:

# %% [markdown]
# Second, a function that builds a simulated list of pairs when we pass in a kinship system:

# %%
# def simulate_ks(ks: dict) -> list:
#     pairs = get_pairs(ks)
#     if pairs:
#         gn,gn1 = split_pairs(pairs)
#         simulation = shuffle_pairs(gn,gn1)
#         return simulation

# %%
def write_data(pairs,results):
    gn,gn1 = split_pairs(pairs)
    egn = entropy(gn)
    egn1 = entropy(gn1)
    ce = conditional_entropy(gn,pairs)
    mi = mutual_information(pairs)
    
    results['mutual_information'] = mi
    results['entropy_gn'] = egn
    results['entropy_gn1'] = egn1
    results['conditional_entropy'] = ce
    results['variation_gn'] = len(set(gn))
    results['variation_gn1'] = len(set(gn1))
    results['number_of_pairs'] = len(set(pairs))
    
    return results

# %% [markdown]
# And a couple of functions that put everything together, saves the results to a separate file, and output a `pandas` dataframe so that we can take a good look. `ics_simulation` takes the full list of Kinbank filenames, extracts the relevant kin terms, performs the randomisation simulation on it a specified number of times, calculates entropy, conditional entropy, and MI for each simulation, and saves all that data to a separate file. It also performs some regex magic on the filename so that we get each language's unique code as well as each language's name in full.

# %%
def ics_simulation(families: list, filepath: str, times: int):
    df = []
    codes = []
    
    for family in families:
        all_files = get_kb_files(filepath + family)
    
        for file in all_files:
            match = re.search('[a-z]{4}[0-9]{4}[a-z]?', file)
            code = match.group()
            language = file.split('_' + code)[0]

            if code not in codes:
                codes.append(code)

                ks = get_kin_terms(filepath + family + '/' + file)

                for i in range(times):
                    sim = shuffle_ks(ks)
                    pairs = get_pairs(sim)
                    if pairs:
                        results = {}
                        results['language'] = language
                        results['language_family'] = family
                        results['code'] = code
                        results['simulation_code'] = code + '_' + str(i)
                        results['simulation'] = 'Y'
                        write_data(pairs,results)

                        df.append(results)
    
    #pd.DataFrame(df).to_csv('../data/raw/ics_sims_filtered.csv',index=False)
    #pd.DataFrame(df).to_csv('../data/raw/ics_sims_aus.csv',index=False)    
    #return pd.DataFrame(df)
    return df

# %% [markdown]
# `ics_real` performs similarly to `ics_simulation`, but instead of performing the randomisation, it calculates entropy, conditional entropy, and MI for the language as-is. It does this for every file in the Kinbank data and saves the data to a separate file.

# %%
def ics_real(families,filepath):
    df = []
    codes = []
    
    for family in families:
        all_files = get_kb_files(filepath +  family)
        
        for file in all_files:
            print(file)
            match = re.search("[a-z]{4}[0-9]{4}[a-z]?", file)
            code = match.group()
            language = file.split('_' + code)[0]

            if code not in codes:
                codes.append(code)

                ks = get_kin_terms(filepath + family + '/' + file)

                pairs = get_pairs(ks)
                print(pairs)

                if pairs: # if pairs is not empty
                    mi = mutual_information(pairs)

                    results = {}
                    results['language'] = language
                    results['language_family'] = family
                    results['code'] = code
                    results['simulation_code'] = code + '_REAL'
                    results['simulation'] = 'N'
                    write_data(pairs,results)

                    df.append(results)
        
    pd.DataFrame(df).to_csv('../data/raw/ics_real_filtered.csv',index=False)
    #pd.DataFrame(df).to_csv('../data/raw/ics_real_aus.csv',index=False)
    print(len(df))
    
    return pd.DataFrame(df)

# %% [markdown]
# ## Let's go!
#
# If we want to create a dataset from the full set of filtered language data, we just have to run:

# %%
families = ['Austronesian','Cariban','Dravidian','Indo-European','Nakh-Daghestanian','Nuclear Trans New Guinea',
            'Other','Pama-Nyungan','Pano-Tacanan','Salishan','Sino-Tibetan','Tai-Kadai','Tupian',
            'Turkic','Uralic','Uto-Aztecan']

filtered_filepath = '../languages/kinbank-filter/'

# %%
ics_real(families,filtered_filepath)
# Out:
# Maguindanao_(Magindonao_Moro)_magu1243.csv
# [('ama', 'kaka'), ('ama', 'ali'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud')]
# Malua_Bay_malu1245.csv
# [('tate', 'söghösök dövat'), ('bini', 'natök'), ('bini', 'natök'), ('vavwe', 'tate'), ('vavwe', 'vavwe'), ('tate', 'söghösök'), ('tate', 'lelei'), ('tate', 'tisuk waven')]
# Manam_mana1295.csv
# None
# Mangaia_mang1402.csv
# None
# Mangarevans_mang1401.csv
# [('motua', 'tuakana'), ('motua', 'teina'), ('motua', "tue'ine"), ('motua-nui', "tue'ine"), ('motua-iti', "tue'ine"), ('motua-nui', "tue'ine"), ('motua-iti', "tue'ine"), ('kui-nui', "tue'ine"), ('kui-iti', "tue'ine"), ('kui-nui', "tue'ine"), ('kui-iti', "tue'ine"), ('motua', 'tuagane'), ('motua', 'tuakana'), ('motua', 'teina')]
# Mangareva_mang1401.csv
# Mangei_(Sobjo)_mang1407.csv
# [('soesoe', 'kaka'), ('soesoe', 'kaka'), ('kolo', 'kaka'), ('kolo', 'kaka')]
# Manggarai_mang1405.csv
# None
# Maori_maor1246.csv
# [('matua', 'tuahine'), ('matua', 'tuakana'), ('matua', 'tuahine'), ('matua', 'teina'), ('matua', 'tuahine'), ('matua', 'tuakana'), ('matua', 'tuahine'), ('matua', 'teina'), ('matua', 'tuahine'), ('whaea', 'tuakana'), ('whaea', 'tuahine'), ('whaea', 'teina'), ('whaea', 'tuahine'), ('whaea', 'tuakana'), ('whaea', 'tuahine'), ('whaea', 'teina'), ('whaea', 'tuahine'), ('matua', 'tungaane'), ('matua', 'tuakana'), ('matua', 'teina'), ('matua', 'tungaane'), ('matua', 'tuakana'), ('matua', 'tungaane'), ('matua', 'tuakana'), ('whaea', 'tungaane'), ('whaea', 'tuakana'), ('whaea', 'tungaane'), ('whaea', 'tuakana')]
# Maragus_(Tape)_mara1399.csv
# None
# Maranao_(Lanao_Moro)_mara1404.csv
# [('ama', 'kaka'), ('ama', 'ari'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('ama', 'kaka'), ('ama', 'ari')]
# Marquesas_marq1246.csv
# None
# Marshallese_mars1254.csv
# None
# Maskelynes_mask1242.csv
# None
# Matukar_matu1261.csv
# [('tamau', 'lu'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('tamau', 'lu'), ('tamau', 'ka'), ('tamau', 'te')]
# Mekeo_(East)_meke1243d.csv
# None
# Mekeo_(North)_meke1243c.csv
# None
# Mekeo_(North-West)_meke1243a.csv
# None
# Mekeo_(West)_meke1243b.csv
# None
# Mekeo_meke1243.csv
# None
# Mekongga_meko1237.csv
# None
# Mele-Fila_(Ifira-Mele)_mele1250.csv
# [('emama', 'kave'), ('aua', 'kaleka'), ('aua', 'kaleka'), ('mamau', 'kaleka'), ('mamau', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('emama', 'kave'), ('emama', 'taina')]
# Menui_menu1237.csv
# None
# Merei_mere1242.csv
# None
# Merlav_merl1237.csv
# [('imama', 'tata'), ('moru', 'natu'), ('moru', 'natu'), ('ivev', 'natu'), ('ivev', 'natu'), ('imama', 'tata')]
# Minangkabau_mina1268.csv
# None
# Miningir_(Lunga)_mini1251.csv
# [('tamaná', 'tasiná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('tamaná', 'tasiná'), ('tamaná', 'tasinavaviná')]
# Mono-Alu_mono1273.csv
# None
# Morgan1871_Hawaiian_hawa1245.csv
# None
# Morgan1871_Kings_Mill_Islands_gilb1244.csv
# Morgan1871_Kusaien_kosr1238.csv
# Morgan1871_Maori_maor1246.csv
# Mori_Atas_mori1269.csv
# None
# Mori_Bawah_mori1268.csv
# [('ama', 'aka'), ('ama', 'uai'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('ama', 'aka'), ('ama', 'uai')]
# Moronene_moro1287.csv
# [('tama', 'tukaka'), ('tama', 'tuai'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('tama', 'tukaka'), ('tama', 'tuai')]
# Mortlockese_mort1237.csv
# [('saam', 'mwengeang'), ('tattalin saam', 'tattalin pwiipwi'), ('tattalin saam', 'tattalin mwengeang'), ('tattalin saam', 'tattalin pwiipwi'), ('tattalin saam', 'tattalin mwengeang'), ('tattalin iin', 'tattalin pwiipwi'), ('tattalin iin', 'tattalin mwengeang'), ('tattalin iin', 'tattalin pwiipwi'), ('tattalin iin', 'tattalin mwengeang'), ('saam', 'mwengeang'), ('saam', 'pwiipwi')]
# Mota_mota1237.csv
# [('tamak', 'tutuai'), ('maraui', 'natui'), ('maraui', 'natui'), ('vevegae', 'tamai'), ('vevegae', 'veve'), ('tamak', 'tutuai'), ('tamak', 'tuaga'), ('tamak', 'tasiu')]
# Motu_motu1246.csv
# None
# Mouk_mouk1240.csv
# [('ilau', 'lutno'), ('tumno', 'adou'), ('tumno', 'lutno'), ('babu', 'aten'), ('babu', 'aten'), ('babu', 'aten'), ('babu', 'aten'), ('babu', 'adou'), ('babu', 'lutno'), ('ilau', 'lutno'), ('ilau', 'atua'), ('ilau', 'agatno'), ('babu', 'adou')]
# Muduapa_(Vitu)_mudu1242.csv
# [('tama-na', 'livuk-'), ('tama-na', 'tazi kapou'), ('tama-na', 'tazi kapou'), ('vahapa-na', 'tazi kapou'), ('vahapa-na', 'tazi kapou'), ('tama-na', 'livuk-'), ('tama-na', 'tazi-na')]
# Muna_muna1247.csv
# [('ama', 'isa'), ('ama', 'ai'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('ama', 'isa'), ('ama', 'ai')]
# Munggava_(Rennell)_mung1271.csv
# [('tamana', 'tua-hine'), ('tua-tina', "ha'anga"), ('tua-tina', "ha'anga"), ('tua-tina', "ha'anga"), ('tua-tina', "ha'anga"), ('tinau', "ha'anga"), ('tinau', "ha'anga"), ('tamana', "tua-nga'ane"), ('tamana', 'tau-kete'), ('tamana', 'taina')]
# Mungiki_(Bellona)_mung1270.csv
# None
# Mussau-Emira_muss1246.csv
# None
# Mwotlap_motl1237.csv
# [('itmek', 'tētek'), ('itat', 'ithik'), ('itat', 'tētek'), ('itmek', 'ithik'), ('itmek', 'tētek'), ('itmek', 'ithik'), ('itmek', 'tētek'), ('ivēk', 'ithik'), ('ivēk', 'tētek'), ('ivēk', 'ithik'), ('ivēk', 'tētek'), ('titamas', 'ithik'), ('titamas', 'tētek'), ('titamas', 'ithik'), ('titamas', 'tētek'), ('itmek', 'tētek'), ('itmek', 'ithik'), ('itmek', 'tētek'), ('itmek', 'ithik'), ('ivēk', 'tētek'), ('ivēk', 'ithik'), ('titamas', 'tētek'), ('titamas', 'ithik')]
# Māori_maor1246.csv
# Nafsan_sout2856.csv
# None
# Nage_nage1237.csv
# None
# Nahavaq_sout2857.csv
# None
# Nakanai_naka1262.csv
# [('tama-(la)', 'hatavile-(la)'), ('hala-(la)', 'e-hatamale-(la)'), ('hala-(la)', 'hatavile-(la)'), ('tama-(la) uru', 'e-hatamale-(la)'), ('tama-(la) uru', 'hatavile-(la)'), ('tama-(la) bisi', 'e-hatamale-(la)'), ('tama-(la) bisi', 'hatavile-(la)'), ('tila uru', 'e-hatamale-(la)'), ('tila uru', 'hatavile-(la)'), ('tila bisi', 'e-hatamale-(la)'), ('tila bisi', 'hatavile-(la)'), ('hala-(la)', 'e-hatamale-(la)'), ('hala-(la)', 'hatavile-(la)'), ('hala-(la)', 'e-hatamale-(la)'), ('hala-(la)', 'hatavile-(la)'), ('tama-(la)', 'e-hatamale-(la)')]
# Nalik_(Lukuramau)_nali1244.csv
# [('tamang', 'dimafingu'), ('mogorugu', 'fagu'), ('mogorugu', 'kaiasgu'), ('tamang', 'diagu'), ('tamang', 'dimafingu'), ('kogol', 'fagu'), ('kogol', 'kaiasgu'), ('tamang', 'diagu'), ('tamang', 'diagu')]
# Nalik_(Madina)_nali1244b.csv
# [('mago', 'fafnagu'), ('mogorugu', 'fagu'), ('mogorugu', 'agasugu'), ('mago', 'fafnagu'), ('mago', 'fafnagu'), ('mago', 'fafnagu'), ('mago', 'duagu'), ('mago', 'fafnagu')]
# Namakura_nama1268.csv
# [('taman', 'ngkoren'), ('taman', 'ngkoren'), ('lolo', 'hivang'), ('lolo', 'vain'), ('lolo', 'hivang'), ('lolo', 'vain'), ('taman', 'hivang'), ('taman', 'vain'), ('taman', 'hivang'), ('taman', 'vain'), ('anuh', 'hivang'), ('anuh', 'vain'), ('anuh', 'hivang'), ('anuh', 'vain'), ('miim', 'hivang'), ('miim', 'vain'), ('miim', 'hivang'), ('miim', 'vain'), ('taman', 'suan'), ('taman', 'suan'), ('taman', 'ngkoren'), ('lolo', 'hivang'), ('lolo', 'vain'), ('taman', 'hivang'), ('taman', 'vain'), ('anuh', 'hivang'), ('anuh', 'vain'), ('miim', 'hivang'), ('miim', 'vain')]
# Namakura_nama1268b.csv
# None
# Naman_litz1237.csv
# [('tate', 'vövönungk'), ('bimbi', 'netungk'), ('bimbi', 'netungk'), ('vave', 'tat uve'), ('vave', 'vave'), ('tate', 'manungk'), ('tate', 'tugangk'), ('tate', 'naaruongk')]
# Nanggu_nang1262.csv
# None
# Nehan_neha1247.csv
# [('taman', 'tatahinalik'), ('kabin', 'turak'), ('kabin', 'turak'), ('kabin', 'matmatatahinaliki'), ('kabin', 'turak'), ('taman', 'tatahinalik'), ('taman', 'tahinalik')]
# Nengone_neng1238.csv
# [('caca', 'mama'), ('caca', 'resingen'), ('caca', 'reisingen'), ('caca', 'reisingen'), ('caca', 'reisingen'), ('hmaien', 'reisingen'), ('cekin', 'reisingen'), ('caca', 'mama'), ('caca', 'cel'), ('caca', 'reisingen')]
# Nese_nese1235.csv
# None
# Neve'ei_vinm1237.csv
# [('mamwe', 'vivinungk'), ('vimbi', 'natungk'), ('vimbi', 'natungk'), ('mamwe lamp', 'tuangk'), ('mamwe lamp', 'vivinungk'), ('mamwe', 'tasungk'), ('mamwe', 'vivinungk'), ('vavwe', 'lelel'), ('vavwe', 'vavwe'), ('mamwe', 'manungk'), ('mamwe', 'tuangk'), ('mamwe', 'tasungk')]
# Neve'ei_vinm1237a.csv
# None
# Neverver_ling1265.csv
# [('mama', 'vivin'), ('bibi tokhtokh', 'salan'), ('bibi tokhtokh', 'salan'), ('bibi lele', 'salan'), ('bibi lele', 'salan'), ('mama tokhtokh', 'salan'), ('mama tokhtokh', 'salan'), ('mama lele', 'salan'), ('mama lele', 'salan'), ('nida tokhtokh', 'salan'), ('nida tokhtokh', 'salan'), ('nida lele', 'salan'), ('nida lele', 'salan'), ('nida tokhtokh', 'mama'), ('nida tokhtokh', 'nida'), ('nida lele', 'mama'), ('nida lele', 'nida'), ('mama', 'tatan'), ('mama', 'tas(t)n')]
# Nguna_ngun1274.csv
# [('mama', 'ngoreng'), ('aloa', 'natungu nanoay'), ('aloa', 'nanungu nangoroy'), ('tétè', 'tay'), ('tétè', 'ngoreng'), ('mimi', 'mama'), ('mimi', 'mimi'), ('mama', 'tay')]
# Niuafo'ou_niua1240.csv
# None
# Niueans_niue1239.csv
# [('matua tane', 'taokete'), ('matua tane', 'tehina'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'taokete'), ('matua tane', 'tehina')]
# Niue_niue1239.csv
# North_Ambrym_nort2839.csv
# [('teta', 'talang'), ('mesong', 'mesong'), ('raheng', 'tubiung'), ('teta', 'talang')]
# North_Efate_(Nguna,_Nakanamanga)_nort2836.csv
# None
# North_Marquesan_nort2845.csv
# [('tunane', 'tuehine'), ('motua', 'tuehine'), ('teina motua', 'Tuaana'), ('teina motua', 'tuehine'), ('tuehine', 'tuehine')]
# North_Tanna_nort2847.csv
# None
# Numbami_numb1247.csv
# [('tama', 'lunewe'), ('wowa', 'gode'), ('wowa', 'godenewe'), ('tama', 'sika'), ('tama', 'lunewe'), ('mama kae', 'kapa'), ('mama kae', 'lunewe'), ('tina', 'sika'), ('tina', 'lunewe'), ('awa kae', 'kapa'), ('awa kae', 'lunewe'), ('wawe', 'gode'), ('wawe', 'godenewe'), ('tama', 'lu'), ('tama', 'sikanewe'), ('tama', 'kapowe'), ('tama', 'lu'), ('tama', 'sikanewe'), ('tina', 'lu'), ('tina', 'sikanewe')]
# Olal_olal1237.csv
# [('tete', 'taling'), ('mosong', 'tubung'), ('mosong', 'tubung'), ('idning', 'mabung'), ('idning', 'mabung'), ('tete', 'maningeri')]
# Old_Javanese_(Kawi)_kawi1241.csv
# None
# Old_Rapa_(Rapa)_rapa1245.csv
# None
# Ontong_Java_onto1237.csv
# [('kamaŋa', 'kaiŋa'), ('kamaŋa', "'ave"), ('lamoku', 'kaiŋa'), ('lamoku', "'ave"), ('kamaŋa', 'kaiŋa'), ('kamaŋa', "'ave"), ('kiŋa', 'kaiŋa'), ('kiŋa', "'ave"), ('kiŋa', 'kaiŋa'), ('kiŋa', "'ave"), ('kamaŋa', "'ave"), ('kamaŋa', 'kaiŋa')]
# Owa_(Santa_Ana)_owaa1237.csv
# None
# Padoe_pado1242.csv
# None
# Paici_paic1239.csv
# [('caa', 'ciè'), ('caa', 'aajii'), ('aunîa', 'böru'), ('aunîa', 'böru'), ('aunîa', 'böru'), ('aunîa', 'böru'), ('caa', 'ciè'), ('caa', 'ciè'), ('nyââ', 'aajii'), ('nyââ', 'aajii'), ('pankaa', 'böru'), ('pankaa', 'böru'), ('pankaa', 'böru'), ('pankaa', 'böru'), ('caa', 'ciè'), ('caa', 'aajii')]
# Paiwan_paiw1248.csv
# [('kama', 'kaka'), ('kama', 'kaka'), ('kama', 'kaka'), ('kama', 'kaka'), ('kama', 'kaka'), ('kina', 'kaka'), ('kina', 'kaka'), ('kina', 'kaka'), ('kina', 'kaka'), ('kama', 'kaka')]
# Palauan_pala1344.csv
# [('chadám', 'chochad(ák)'), ('desik', 'ngelekir a ruchad'), ('desik', 'ngelekir a ruchad'), ('desik', 'ngelekir a ruchad'), ('desik', 'ngelekir a ruchad'), ('desik', 'ngalekodám'), ('desik', 'ngalekodám'), ('desik', 'ngalekodám'), ('desik', 'ngalekodám'), ('chadám', 'chochad(ák)'), ('chadám', 'chudel(ék)'), ('chadám', 'merreng(ék)')]
# Paluai_balu1257.csv
# [('tama', 'patne'), ('nukna', 'pwai'), ('nukna', 'pwai'), ('tama', 'tou'), ('tama', 'patne'), ('tina', 'tou'), ('tina', 'patne'), ('sae', 'pwai'), ('sae', 'pwai'), ('tama', 'mwane'), ('tama', 'tou'), ('tama', 'nae')]
# Pama_(Paamanese)_paam1238.csv
# None
# Pampanga_(Kampampangan)_pamp1243.csv
# [('tatá', 'capatát á babaí'), ('bápa', 'písan'), ('bápa', 'písan'), ('bápa', 'písan'), ('bápa', 'písan'), ('dára', 'písan'), ('dára', 'písan'), ('dára', 'písan'), ('dára', 'písan'), ('tatá', 'capatát á laláqui')]
# Pangasinan_pang1290.csv
# [('pangamaen', 'eapinsan'), ('pangamaen', 'eapinsan'), ('pangamaen', 'eapinsan'), ('pangamaen', 'eapinsan'), ('panginaen', 'eapinsan'), ('panginaen', 'eapinsan'), ('panginaen', 'eapinsan'), ('panginaen', 'eapinsan'), ('ama', 'aguin laki')]
# Patani_pata1260.csv
# [('mama toewa', 'fono'), ('mama toewa', 'fono mpin'), ('mama toewa', 'fono'), ('mama toewa', 'fono mpin'), ('gowa', 'fono'), ('gowa', 'fono mpin'), ('gowa', 'fono'), ('gowa', 'fono mpin')]
# Pendau_pend1242.csv
# [('siama', "sia'ang"), ('siama', 'tuai'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('siama', "sia'ang"), ('siama', 'tuai')]
# Penrhyn_(Tongareva)_penr1237.csv
# None
# Petapa_Taje_taje1237a.csv
# None
# Pohnpeian_pohn1238.csv
# None
# Pohnpeian_pohn1238a.csv
# [('pahpa', 'rīali'), ('pahpa', 'wahn ohl pirien'), ('pahpa', 'wahn ohl pirien'), ('pahpa', 'wahn ohl pirien'), ('pahpa', 'wahn ohl pirien'), ('ihn', 'wahn lih pirien'), ('ihn', 'wahn lih pirien'), ('ihn', 'wahn lih pirien'), ('ihn', 'wahn lih pirien'), ('pahpa', 'rī')]
# Port_Sandwich_port1285.csv
# None
# Proto-Oceanic_ocea1241.csv
# None
# Pukapuka_puka1242.csv
# [('matua tane', 'kainga'), ('matua tane', 'taina'), ('matua tane', 'kainga wakama'), ('matua tane', 'taina'), ('matua tane', 'kainga wakama'), ('matua wawine', 'taina'), ('matua wawine', 'kainga wakama'), ('matua wawine', 'taina'), ('matua wawine', 'kainga wakama'), ('matua tane', 'kainga'), ('matua tane', 'taina')]
# Puluwatese_(Puluwat)_pulu1242.csv
# [('haam', 'mwéngeyáng'), ('pwi-', 'nawú-'), ('pwi-', 'nawú-'), ('haam', 'pwi-'), ('haam', 'mwéngeyáng'), ('yiin', 'pwi-'), ('yiin', 'mwéngeyáng'), ('yiin', 'haam'), ('yiin', 'yiin'), ('haam', 'mwéngeyáng'), ('haam', 'pwi-')]
# Puyuma_puyu1239.csv
# None
# Rade_(Rhade)_rade1240.csv
# None
# Raga_(Hano)_hano1246.csv
# [('tama', 'hogosi'), ('tama', 'tihi'), ('tarabe', 'nitu'), ('tarabe', 'nitu'), ('vwavwa', 'tama'), ('vwavwa', 'vwavwa'), ('tama', 'hogosi'), ('tama', 'tihi'), ('tama', 'tua')]
# Raga_(Hano_Thomas_Ennever)_hano1246b.csv
# [('tata', 'oɣosi'), ('bena', 'kuku'), ('bena', 'kuku'), ('tata', 'tua-mʷa'), ('tata', 'oɣosi'), ('mʷua', 'tua-mʷa'), ('mʷua', 'oɣosi'), ('fafʷa', 'tata'), ('fafʷa', 'fafʷa'), ('tata', 'oɣosi'), ('tata', 'tua-mʷa')]
# Rahambuu_raha1237.csv
# None
# Rakahanga-Manihiki_raka1237.csv
# None
# Rangiora_(NW_Tuamotus)_tuam1242.csv
# None
# Rapanui_(Easter_Island)_rapa1244.csv
# None
# Raroians_tuam1242.csv
# Rarotongan_(Cook_Islands_Maori)_raro1241.csv
# [('metua', "tua'ine"), ("'akapāpā", 'tuakana'), ("'akapāpā", "tua'ine"), ("'akapāpā", 'tuakana'), ("'akapāpā", "tua'ine"), ('metua', 'tungāne'), ('metua', 'tuakana'), ('metua', 'teina')]
# Ratagnon_rata1245.csv
# [('amang', 'magkabukto'), ('tiyo', 'pinsan'), ('tiyo', 'pinsan'), ('tiyo', 'pinsan'), ('tiyo', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('amang', 'magkabukto'), ('amang', 'magkabukto'), ('amang', 'magkabukto')]
# Rejang_(Rejangese)_reja1240.csv
# None
# Rennell_Islanders_renn1242.csv
# [('tamana', 'tuhahine'), ("tu'aatina", "ha'anga"), ("tu'aatina", 'tuhahine'), ('tamana', "tu'aatina"), ('tamana', 'tuhahine'), ('tinana', "tu'aatina"), ('tinana', 'tuhahine'), ('tinana', "ha'anga"), ('tinana', "ha'anga"), ('tamana', "tunga'ane"), ('tamana', "ta'okete"), ('tamana', 'taina')]
# Riuk_Bekati'_(Dayak)_beka1241.csv
# None
# Rotinese_Termanu__term1237.csv
# [('amak', 'kaäk'), ('amak', 'fadik'), ('amak', 'tolanok'), ('toök', 'feto selek'), ('ama kaäk', 'kaäk'), ('ama kaäk', 'feto daek'), ('ama fadik', 'fadik'), ('ama fadik', 'feto daek'), ('teök', 'tolano dadik'), ('teök', 'feto dadik'), ('amak', 'tolanok'), ('amak', 'kaäk'), ('amak', 'fadik')]
# Rotumans_rotu1241.csv
# [('oifā', 'sasigi mafua'), ('oifā', 'sasigi mokoī'), ('oifā', 'saghoni'), ('oifā', 'saghoni mokoī'), ('oifā', 'sasigi'), ('oifā', 'saghoni'), ('oifā', 'sasigi'), ('oifā', 'saghoni'), ('oihoni', 'sasigi'), ('oihoni', 'saghoni'), ('oihoni', 'sasigi'), ('oihoni', 'saghoni'), ('oifā', "sag'veveni"), ('oifā', "sag'veveni mokoī"), ('oifā', 'sasigi mafua'), ('oifā', 'sasigi mokoī')]
# Rotuman_rotu1241.csv
# Routa_rout1237.csv
# None
# Roviana_rovi1238.csv
# [('tama-na', 'vavene-na'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('tinana karokarovo', 'tasi-na karokarovo'), ('tinana karokarovo', 'tasi-na karokarovo'), ('tinana karokarovo', 'tasi-na karokarovo'), ('tinana karokarovo', 'tasi-na karokarovo'), ('tama-na', 'tasi-na'), ('tama-na', 'tasi-na')]
# Saaroa_saar1237.csv
# [("ama'a", 'alhalua alhaina'), ("ama'a", 'ilhimilavae alhaina'), ('tamalengale', 'turuua'), ('tamalengale', 'turuua'), ('tamalengale', 'turuua'), ('tamalengale', 'turuua'), ('tavanau', 'turuua'), ('tavanau', 'turuua'), ('tavanau', 'turuua'), ('tavanau', 'turuua'), ("ama'a", 'alhalua lhalhusa'), ("ama'a", 'lhimilavae lhalhusa')]
# Samoan_samo1305.csv
# [('tamā', 'uso'), ('tamā', 'tuafafine'), ('le tuagane o le tinā', 'uso'), ('le tuagane o le tinā', 'tuafafine'), ('le uso o le tamā', 'uso'), ('le uso o le tamā', 'tuafafine'), ('ilamutu', 'uso'), ('ilamutu', 'tuafafine'), ('tamā', 'tuagane'), ('tamā', 'use')]
# Samoan_samo1305a.csv
# None
# Sarangani_Blaan_sara1326.csv
# None
# Satawalese_sata1237.csv
# None
# Sawai_sawa1247.csv
# [('toea', 'fonoe'), ('toea', 'fonoe mepin'), ('toea', 'fonoe'), ('toea', 'fonoe mepin'), ('baba', 'fonoe'), ('baba', 'fonoe mepin'), ('baba', 'fonoe'), ('baba', 'fonoe mepin')]
# Sa_a_saaa1240.csv
# [("ma'a", 'asi-'), ("ma'a", 'asi-'), ('uweli', "di'i"), ('uweli', "di'i"), ('nike', "di'i"), ('nike', "di'i")]
# Sa_saaa1241.csv
# None
# Seke_(Ske)_seke1241.csv
# [('zmia', 'seze'), ('zmia', 'seze'), ('meza', 'mware'), ('meza', 'seze'), ('zmia', 'mware'), ('zmia', 'seze'), ('dahe', 'mware'), ('dahe', 'seze'), ('wwa', 'mware'), ('wwa', 'seze'), ('zmia', 'seze'), ('zmia', 'mware'), ('zmia', 'mware')]
# Senbarei_unua1237.csv
# [('tomongk', 'vevenungk'), ('metungk', 'natungk'), ('metungk', 'natungk'), ('resyongk', 'tomongk'), ('tomongk', 'avwa sungk'), ('tomongk', 'mwenengk'), ('tomongk', 'avwa sungk'), ('tomongk', 'tasingk')]
# Sie_(Sye)_siee1239.csv
# [('etmen', 'veven'), ('metan', 'alwon'), ('metan', 'alwon'), ('namou viroc', 'alwon'), ('namou viroc', 'alwon'), ('namou viroc', 'alwon'), ('namou viroc', 'alwon'), ('etmen', 'man'), ('etmen', 'avenhai')]
# Sikaiana_sika1261.csv
# [('tamana', 'kave'), ('tamana', 'taina'), ('tamana', 'kave'), ('tamana', 'taina'), ('tamana', 'kave'), ('tamana', 'taina'), ('tamana', 'kave'), ('tinna', 'taina'), ('tinna', 'kave'), ('tinna', 'taina'), ('tinna', 'kave'), ('tamana', 'kave'), ('tamana', 'taina'), ('tamana', 'kave'), ('tamana', 'taina')]
# Sika_sika1262.csv
# None
# Sonsorol_sons1242.csv
# [('tama-i', 'meaŋa-i'), ('bwidi ri neira-i', 'bwidi'), ('bwidi ri neira-i', 'bwidi'), ('bwidi ri papa-i', 'bwidi'), ('bwidi ri papa-i', 'bwidi'), ('tama-i', 'meaŋa-i')]
# Southeast_Ambrym_sout2859.csv
# [('tame', 'hinne'), ('metuo', 'mase'), ('metuo', 'avukokon'), ('pap', 'tu'), ('pap', 'hinne'), ('nine', 'tu'), ('nine', 'hinne'), ('tine', 'mase'), ('tine', 'avukokon'), ('tame', 'hinne'), ('tame', 'tu')]
# Southeast_Babar_sout2883.csv
# None
# Southwest_Tanna_sout2869.csv
# [('rɨm', 'kakə'), ('mɨra', 'kapa ier'), ('mɨra', 'kapa ier'), ('mɨra', 'p̃ia karɨn'), ('mɨra', 'kaka'), ('rɨm', 'kakə'), ('rɨm', 'p̃ia')]
# South_Efate_sout2856a.csv
# None
# South_Marquesan_sout2866.csv
# None
# South_Tuvaluan_(Vaitupu)_sout2865.csv
# [('tamana', 'tuangane'), ('tuatina', 'taina'), ('tuatina', 'tuangane'), ('tamana', 'taina'), ('tamana', 'tuangane'), ('matua', 'taina'), ('matua', 'tuangane'), ('matua', 'taina'), ('matua', 'tuangane'), ('tamana', 'tuangane'), ('tamana', 'loko'), ('tamana', 'loko')]
# Sula_Fagudu_sula1245.csv
# None
# Sula_Mangoli_mang1408.csv
# [('baba kōkō', 'akoe foekī nana'), ('baba tīnga', 'akoe foekī nana'), ('baba kōkō', 'akoe foekī nana'), ('goentamī nana', 'akoe foekī nana'), ('goentamī nana', 'akoe foekī nana')]
# Sundanese_sund1252.csv
# [('abah', 'lanceuk'), ('abah', 'adi'), ('ua', 'akang misan'), ('ua', 'akang misan'), ('emang', 'adi misan'), ('emang', 'adi misan'), ('ua', 'akang misan'), ('ua', 'akang misan'), ('emang', 'adi misan'), ('emang', 'adi misan'), ('ua', 'teteh misan'), ('ua', 'teteh misan'), ('embi', 'adi misan'), ('embi', 'adi misan'), ('ua', 'teteh misan'), ('ua', 'teteh misan'), ('embi', 'adi misan'), ('embi', 'adi misan'), ('abah', 'lanceuk'), ('abah', 'adi'), ('abah', 'lanceuk')]
# Sungagage_mari1426i.csv
# [('tata', 'soɣoti'), ('taˈrambe', 'ᵐboi'), ('taˈrambe', 'ᵐboi'), ('tata', 'tue-ŋgu'), ('tata', 'soɣoti'), ('ᵐbou', 'tue-ŋgu'), ('ᵐbou', 'soɣoti'), ('ᵐbʷarai', 'tata'), ('ᵐbʷarai', 'ᵐbʷarai'), ('tata', 'soɣoti'), ('tata', 'tue-ŋgu')]
# Sungwadaga_mari1426b.csv
# [('tata', 'totua'), ('tata', 'totua'), ('tata', 'ɸuβu'), ('tata', 'ɸuβu'), ('tata', 'tua'), ('tata', 'tutua'), ('toa', 'tua'), ('toa', 'tutua'), ('toa', 'ɸuβu'), ('toa', 'ɸuβu'), ('tata', 'totua'), ('tata', 'totua'), ('tata', 'tua'), ('ᵑgʷau', 'tutua'), ('ᵑgʷau', 'tua')]
# Sungwadia_mari1426a.csv
# [('ˈtata', 'ˈtotu'), ('mou', 'ᵐbua (mambisa)'), ('mou', 'ᵐbua (mambisa)'), ('tata', 'ˈβalu'), ('tata', 'ˈtotu'), ('ɸeβe', 'ˈβalu'), ('ɸeβe', 'ˈtotu'), ('ɸeɸe kuru', 'ᵐbua (mambisa)'), ('ɸeɸe kuru', 'ᵐbua (mambisa)'), ('ˈtata', 'ˈtotu'), ('ˈtata', 'ɸalu')]
# Sungwaloge_(Nalemba_Edward)_mari1426g.csv
# [('tata', 'finfiⁿdi'), ('taraᵐbe', 'tuatua tavalaxum'), ('taraᵐbe', 'tuatua tavalaxum'), ('tata', 'tua'), ('tata', 'finfiⁿdi'), ('ᵐbotai', 'tua'), ('ᵐbotai', 'finfiⁿdi'), ('raβe', 'tuatua tavalaxum'), ('raβe', 'tuatua tavalaxum'), ('tata', 'finfiⁿdi'), ('tata', 'tua')]
# Sungwaloge_(Nalemba_Simeone_Tari)_mari1426f.csv
# [('tata', 'fndĭŋ'), ('taraᵐbe', 'tə̆m'), ('taraᵐbe', 'tə̆m'), ('tata', 'tua'), ('tata', 'findiŋ'), ('ᵐbotai', 'tua'), ('ᵐbotai', 'findiŋ'), ('raβe', 'tə̆m'), ('raβe', 'tə̆m'), ('tata', 'fndĭŋ'), ('tata', 'tua')]
# Sungwaloge_(Navenvene)_mari1426d.csv
# [('tata', 'ɸindik'), ('mamou', 'tumtum'), ('mamou', 'tumtum'), ('toa', 'tumtum'), ('toa', 'tumtum'), ('tata', 'ɸindik'), ('tata', 'tua')]
# Sungwaloge_(Tauta)_mari1426e.csv
# [('tata', 'ɸindik'), ('mamou', 'tumtum'), ('mamou', 'tumtum'), ('tata', 'tua'), ('tata', 'ɸindik'), ('ᵐbʷau', 'tua'), ('ᵐbʷau', 'ɸindik'), ('blaktoa', 'tumtum'), ('blaktoa', 'tumtum'), ('tata', 'ɸindik'), ('tata', 'tuak'), ('tai (?)', 'ɸindik'), ('tai (?)', 'tua')]
# Sungwaloge_(Tawet)_mari1426c.csv
# [('ˈtata', 'ɸindi-k'), ('mamou', 'tumtum'), ('mamou', 'tumtum'), ('ˈtata', 'tua-k'), ('ˈtata', 'ɸindik'), ('ˈᵐbʷau', 'tua-k'), ('ˈᵐbʷau', 'ɸindi-k'), ('ˈraβe ˈkuru', 'tumtum'), ('ˈraβe ˈkuru', 'tumtum'), ('ˈtata', 'ɸindi-k'), ('ˈtata', 'tua-k')]
# Sunwadia_mari1426.csv
# None
# Tadyawan_tady1237.csv
# [('amang', 'tayali'), ('tayakí', 'talagbáy'), ('tayakí', 'talagbáy'), ('tayakí', 'talagbáy'), ('tayakí', 'talagbáy'), ('bî', 'talagbáy'), ('bî', 'talagbáy'), ('bî', 'talagbáy'), ('bî', 'talagbáy'), ('amang', 'tayali'), ('amang', 'tayali'), ('amang', 'tayali')]
# Tagalog_taga1270.csv
# [('ama-in', 'pinsan'), ('ama-in', 'pinsan'), ('ama-in', 'pinsan'), ('ama-in', 'pinsan'), ('ali', 'pinsan'), ('ali', 'pinsan'), ('ali', 'pinsan'), ('ali', 'pinsan')]
# Tahitians_tahi1242.csv
# [('metua tane', "tua'ana"), ('metua tane', 'teina'), ('metua tane', 'tuahine'), ('metua tane', 'tuahine'), ('metua tane', 'tuahine'), ('metua vahine', 'tuahine'), ('metua vahine', 'tuahine'), ('metua tane', "tua'ane"), ('metua tane', "tua'ana"), ('metua tane', 'teina')]
# Tahitian_tahi1242.csv
# Tajio_taji1246.csv
# [('siama', "sia'a"), ('siama', 'tuai'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('siama', "sia'a"), ('siama', 'tuai')]
# Takia_taki1248.csv
# [('tama-', 'lu-'), ('ngai', 'tei-'), ('ngai', 'lu-'), ('tama-', 'tei-'), ('tama-', 'lu-'), ('tna-', 'tei-'), ('tna-', 'lu-'), ('nbi', 'tei-'), ('nbi', 'lu-'), ('tama-', 'lu-'), ('tama-', 'tei-')]
# Takuu_taku1257.csv
# [('ilaamotu', 'kave'), ('ilaamotu', 'kave'), ('tamana', 'kave'), ('tamana', 'kave'), ('tamana', 'kave'), ('tamana', 'kave'), ('tinna', 'kave'), ('tinna', 'kave'), ('tamana', 'soa')]
# Talibabu_tali1262.csv
# None
# Talise_(Tolo)_tali1259.csv
# [('kaka', 'vavinena'), ('tsagina', 'kasina gare'), ('tsagina', 'vavinena'), ('kaka', 'kasina gare'), ('kaka', 'vavinena'), ('kaka', 'kasina gare'), ('kaka', 'vavinena'), ('lake', 'kasina gare'), ('lake', 'vavinena'), ('lake', 'kasina gare'), ('lake', 'vavinena'), ('tsagina', 'kasina gare'), ('tsagina', 'vavinena'), ('kaka', 'vavinena'), ('kaka', 'kasina daki'), ('kaka', 'vavinena'), ('kaka', 'kasina daki'), ('lake', 'vavinena'), ('lake', 'kasina daki')]
# Tamambo_malo1243.csv
# None
# Tanala_tana1285.csv
# [('anadhiandreny', 'anjaravady'), ('anadhiandreny', 'anjaravady'), ('rahalahiandraiko', 'rahalahy'), ('rahalahiandraiko', 'anabavy'), ('rahavaviandreny', 'rahalahy'), ('rahavaviandreny', 'anabavy'), ('anabavanbaba', 'anjaravady'), ('anabavanbaba', 'anabavy')]
# Tanampedagi_Taje_taje1237b.csv
# [('siama', "sia'ang"), ('siama', 'tuai'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('siama', "sia'ang"), ('siama', 'tuai')]
# Tangoa_(Movono)_tang1347.csv
# None
# Tasiko_tasi1237.csv
# [('arima', 'vino'), ('arima', 'naru'), ('arima', 'naru'), ('ane', 'naru'), ('ane', 'naru'), ('arima', 'ŋmano'), ('arima', 'ina')]
# Taumako_taum1237.csv
# [('hama', 'tahini'), ('ingoa', 'kave'), ('ingoa', 'tahini-kave'), ('hama', 'tokana'), ('hama', 'tahini'), ('hina', 'tokana'), ('hina', 'tahini'), ('hina', 'kave'), ('hina', 'tahini-kave'), ('hama', 'tungane'), ('hama', 'tokana'), ('hama', 'teina')]
# Tausug_(Sulu_Moro)_taus1251.csv
# [('ama', 'kaka'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('ama', 'kaka'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud')]
# Tausug_taus1251a.csv
# [("ama'", 'magulang'), ("ama'", 'manghud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("ama'", 'magulang'), ("ama'", 'manghud')]
# Tetum_(Tetun)_tetu1245.csv
# [('pai', 'abi'), ('pai', 'alin'), ('pai', 'maun'), ('pai', 'alin'), ('pai', 'alin'), ('aman', 'naan'), ('aman', 'naan'), ('inan', 'naan'), ('inan', 'naan')]
# Tetun_Dili_(Tetum)_tetu1246.csv
# None
# Thao_thao1240.csv
# None
# Tiale_tial1239.csv
# None
# Tialo_(Tomini)_tomi1243.csv
# [('siama -nyo', "sia'a"), ('siama -nyo', 'tuai -nyo'), ('ponsiamaan', 'soungaunga sepisa'), ('ponsiamaan', 'soungaunga sepisa'), ('ponsiamaan', 'soungaunga sepisa'), ('ponsiamaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('siama -nyo', "sia'a"), ('siama -nyo', 'tuai -nyo')]
# Tigak_tiga1245.csv
# None
# Tikopia_tiko1237.csv
# [('tamana', 'taina'), ('tamana', 'kave'), ('tuatina', 'taina'), ('tuatina', 'kave'), ('tamana', 'taina'), ('tamana', 'kave'), ('tinana', 'taina'), ('tinana', 'kave'), ('masikitaŋa', 'taina'), ('masikitaŋa', 'kave'), ('tamana', 'kave'), ('tamana', 'taina')]
# Tikopia_tiko1237a.csv
# [('tamana', 'kave'), ('tuatina', 'taina faka-pariki'), ('tuatina', 'kave faka-pariki'), ('tamana', 'taina faka-laui'), ('tamana', 'kave faka-laui'), ('tinana', 'taina faka-laui'), ('tinana', 'kave faka-laui'), ('masikitanga', 'taina faka-pariki'), ('masikitanga', 'kave faka-pariki'), ('tamana', 'kave'), ('tamana', 'taina')]
# Tirax_(Mae)_maee1241.csv
# None
# Tiri-Mea_(Grand_Couli)_tiri1258.csv
# [('audẽ', 'auhẽřẽ'), ('panea', 'auvae'), ('panea', 'auvae'), ('panea', 'auvae'), ('panea', 'auvae'), ('audẽ', 'auhẽřẽ'), ('audẽ', 'aušoo'), ('audẽ', 'auti'), ('panea', 'auvae'), ('panea', 'auvae')]
# Tokelau_toke1240.csv
# [('tamana', 'taina'), ('tamana', 'tuafafine'), ('tuatina', 'tuatina'), ('tuatina', 'tuatina'), ('tamana', 'taina'), ('tamana', 'tuafafine'), ('matua', 'taina'), ('matua', 'tuafafine'), ('matua', 'fakatau tuatina'), ('matua', 'fakatau tuatina'), ('tamana', 'tuagāne'), ('tamana', 'taina')]
# Tokelau_toke1240a.csv
# [('tamana', 'tua-fafine'), ('tamana', 'taina'), ('tamana', 'taina fetau taina'), ('maatua', 'taina'), ('maatua', 'tuafafine fetau taina'), ('matua sa', 'ilamutu'), ('matua sa', 'ilamutu'), ('matua sa', 'ilamutu'), ('matua sa', 'ilamutu'), ('tamana', 'tua-gane'), ('tamana', 'fetau-taina'), ('tamana', 'fetau-taina')]
# Tokotu'a_(Kabaena)_kaba1285.csv
# None
# Tolaki_tola1247.csv
# [('tama', 'kaka'), ('tama', 'andi'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('tama', 'kaka'), ('tama', 'andi')]
# Tomadino_toma1248.csv
# None
# Tombulu_tomb1243.csv
# [("ama'", "kaka' wēwēnē"), ("ama'", 'tuari wēwēnē'), ("ito'", "oki'-nē-mahtuari"), ("ito'", "oki'-nē-mahtuari"), ("ito'", "oki'-nē-mahtuari"), ("ito'", "oki'-nē-mahtuari"), ('mui', "oki'-nē-mahtuari"), ('mui', "oki'-nē-mahtuari"), ('mui', "oki'-nē-mahtuari"), ('mui', "oki'-nē-mahtuari"), ("ama'", "kaka' tuama"), ("ama'", 'tuari tuama')]
# Tongan_tong1325.csv
# [('tamai', "ta'okete"), ('tamai', 'tehina'), ('tamai', 'tuofefine'), ("fa'e tangata", 'tokoua'), ("fa'e tangata", 'tuofefine'), ("tu'asina", 'tokoua'), ("tu'asina", 'tuofefine'), ('tamai', 'tokoua'), ('tamai', 'tuofefine'), ("fa'e", 'tokoua'), ("fa'e", 'tuofefine'), ('mehekitanga', 'tokoua'), ('mehekitanga', 'tuofefine'), ('tamai', "tuonga'ane"), ('tamai', "ta'okete"), ('tamai', 'tehina')]
# Tongarevans_penr1237.csv
# Tonga_(Tonga_Islands)_tong1325.csv
# Tonsea_tons1240.csv
# [("ama'", 'kakak wewene'), ("ama'", 'tuari wewene'), ('ito', 'kasudu'), ('ito', 'kasudu'), ('ito', 'kasudu'), ('ito', 'kasudu'), ('mui', 'kasudu'), ('mui', 'kasudu'), ('mui', 'kasudu'), ('mui', 'kasudu'), ("ama'", "kaka' tuama"), ("ama'", 'tuari tuama')]
# Toqabaqita_toab1237.csv
# [('maamaqa', 'doqora'), ('maamaqa', 'doqora'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua')]
# Torete_tore1237.csv
# None
# Totoli_toto1304.csv
# [('amang ko-', 'tukka'), ('amang ko-', 'tuali'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('amang ko-', 'tukka'), ('amang ko-', 'tuali'), ('amang ko-', 'tukka'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan')]
# Tubuai_tubu1240.csv
# None
# Tukang_Besi_South_tuka1249.csv
# None
# Tulambatu_tula1253.csv
# None
# Tungag_tung1290.csv
# None
# Tuvalu_(Nanumea)_tuva1244.csv
# [('tamana', 'tuagane'), ('laamutu', 'fakataina'), ('laamutu', 'fakatuagane'), ('laamutu', 'fakataina'), ('laamutu', 'fakatuagane'), ('tamana', 'fakataina'), ('tamana', 'fakatuagane'), ('fakamaatua', 'fakataina'), ('fakamaatua', 'fakatuagane'), ('fakamaatua', 'fakataina'), ('fakamaatua', 'fakatuagane'), ('tamana', 'tuagane'), ('tamana', 'taina'), ('laamutu', 'fakatuagane'), ('laamutu', 'fakataina')]
# Ulawa_ulaw1237.csv
# [("ma'a", 'inie-'), ("ma'a", 'inie-'), ('uweli', 'ula-'), ('uweli', 'ula-'), ('nike', 'ula-'), ('nike', 'ula-')]
# Uma_Juman_(Kayan)_umaj1240.csv
# [('tama+n', '(pə)hari?+n duh (aiəŋ) aya?'), ('tama+n', '(pə)hari?+n duh (aiəŋ) (du)?uk'), ('tama+n', '(pə)hari?+n higət'), ('tama+n', '(pə)hari?+n higət'), ('tama+n', '(pə)hari?+n higət'), ('tama+n', '(pə)hari?+n higət'), ('hina+n', '(pə)hari?+n higət'), ('hina+n', '(pə)hari?+n higət'), ('hina+n', '(pə)hari?+n higət'), ('hina+n', '(pə)hari?+n higət'), ('tama+n', '(pə)hari?+n (l)aki? (aiəŋ) aya?'), ('tama+n', '(pə)hari?+n (l)aki (aiəŋ) (du)?uk')]
# Umiray_Dumaget_Agta_umir1236.csv
# None
# Unua_unua1237.csv
# Urak_Lawoi_urak1238.csv
# None
# Ura_urav1235.csv
# None
# Uripiv-Wala-Rano-Atchin_urip1239.csv
# [('tata suk', 'tsotsik'), ('mituk', 'natuk'), ('mituk', 'natuk'), ('tasu suk', 'tata suk'), ('tasu suk', 'tasu suk'), ('tata suk', 'tuak'), ('tata suk', 'tasik')]
# Vaekau-Taumako_pile1238.csv
# [('tamana', 'thuohine'), ('ingoa', 'kave'), ('ingoa', 'thuohine'), ('tamana', 'kave'), ('tamana', 'thuohine'), ('tamana', 'kave'), ('tamana', 'thuohine'), ('hinana', 'kave'), ('hinana', 'thuohine'), ('hinana', 'kave'), ('hinana', 'thuohine'), ('hinana', 'kave'), ('hinana', 'thuohine'), ('hinana', 'kave'), ('hinana', 'thuohine'), ('tamana', 'thungane'), ('tamana', 'thokana'), ('tamana', 'teina'), ('tamana', 'thungane'), ('tamana', 'kave'), ('hinana', 'thungane'), ('hinana', 'kave'), ('hinana', 'thungane'), ('hinana', 'kave')]
# Vao_vaoo1237.csv
# None
# Varisi_vari1239.csv
# None
# Vera'a_vera1241.csv
# None
# Vures_vure1239.csv
# None
# Waia_waia1242.csv
# None
# Wallisian_(East_Uvea)_wall1257.csv
# None
# Waropen_waro1242.csv
# None
# Waru_waru1266.csv
# None
# Watut_watu1246.csv
# [('lamaŋg', 'lewiŋg'), ('lamaŋg', 'laseŋg'), ('lamaŋg', 'jeniŋg kefi'), ('esiŋg', 'araŋg'), ('esiŋg', 'nafoŋg'), ('lamaŋg', 'lewiŋg'), ('lamaŋg', 'nafoŋg'), ('lenaŋg', 'lewiŋg'), ('lenaŋg', 'nafoŋg'), ('wagag', 'araŋg'), ('wagag', 'nafoŋg'), ('lamaŋg', 'lewiŋg'), ('lamaŋg', 'laseŋg')]
# Wawonii_wawo1239.csv
# [('tama', 'tukaka'), ('tama', 'tußai'), ('maama', 'topisa'), ('maama', 'topisa'), ('maama', 'topisa'), ('maama', 'topisa'), ('naina', 'topisa'), ('naina', 'topisa'), ('naina', 'topisa'), ('naina', 'topisa'), ('tama', 'tukaka'), ('tama', 'tußai')]
# Weda_weda1240.csv
# [('momo', 'fono'), ('momo', 'fono-meping'), ('momo', 'fono'), ('momo', 'fono-meping'), ('momo', 'fono'), ('momo', 'fono-meping'), ('momo', 'fono'), ('momo', 'fono-meping'), ('baba', 'fono'), ('baba', 'fono-meping'), ('baba', 'fono'), ('baba', 'fono-meping'), ('baba', 'fono'), ('baba', 'fono-meping'), ('baba', 'fono'), ('baba', 'fono-meping')]
# Western_Bukidnon_Manobo_west2555.csv
# [('amey', 'etevey'), ('anggam', 'suled'), ('anggam', 'etevey'), ('anggam', 'suled'), ('anggam', 'etevey'), ("aya'", 'suled'), ("aya'", 'etevey'), ("aya'", 'suled'), ("aya'", 'etevey'), ('amey', "me'emahan"), ('amey', 'suled')]
# Western_Tawbuid_(Batangan)_west2559.csv
# [('mama', 'duksayan'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('baáy', 'lagbä'), ('baáy', 'lagbä'), ('baáy', 'lagbä'), ('baáy', 'lagbä'), ('mama', 'duksayan'), ('mama', 'duksayan'), ('mama', 'duksayan')]
# West_Coast_Bajau_west2560.csv
# [("emma'", "ka'"), ("emma'", "di'"), ("pa'", 'kaki'), ("pa'", 'kaki'), ("pa'", 'kaki'), ("pa'", 'kaki'), ("bu'", 'kaki'), ("bu'", 'kaki'), ("bu'", 'kaki'), ("bu'", 'kaki'), ("emma'", "ka'"), ("emma'", "di'")]
# West_Futuna_west2515.csv
# [('tamana', 'kave'), ('tojinana', 'safe'), ('tojinana', 'fakau magaro'), ('tamana', 'soa'), ('tamana', 'kave'), ('jinana', 'soa'), ('jinana', 'kave'), ('jinana', 'soa'), ('jinana', 'kave'), ('jina-ha-vae', 'safe'), ('jina-ha-vae', 'fakau magaro'), ('jina-ha-vae. maha-vae', 'safe'), ('jina-ha-vae. maha-vae', 'fakau magaro'), ('tamana', 'kave'), ('tamana', 'soa'), ('jinana', 'kave'), ('jinana', 'soa'), ('jina-ha-vae', 'fakau magaro'), ('jina-ha-vae', 'maa')]
# Whitesands_whit1269.csv
# None
# Wiwirano_wiwi1237.csv
# None
# Wogeo_woge1237.csv
# None
# Woleaian_wole1240.csv
# None
# Wolio_woli1241.csv
# None
# Wuvulu_Aua_wuvu1239.csv
# [('ʔama', 'lofu'), ('ʔama', 'ʔari'), ('ama', 'lofu'), ('ama', 'ʔari'), ('ʔama', 'lofu'), ('ʔama', 'ʔari'), ('ʔina', 'lofu'), ('ʔina', 'ʔari'), ('ʔina', 'lofu'), ('ʔina', 'ʔari'), ('ʔama', 'ʔari'), ('ʔama', 'tafi')]
# Xalangi_(Maevo_Vanuatu)_mari1426h.csv
# [('tita', 'fiⁿdae'), ('(j)aᵐbe', 'natu'), ('(j)aᵐbe', 'natu'), ('tita', 'tua'), ('tita', 'fiⁿdae'), ('ᵐbotai', 'tua'), ('ᵐbotai', 'fiⁿdae'), ('toa', 'toa'), ('toa', 'toa'), ('tita', 'fiⁿdae'), ('tita', 'tua')]
# Xaracuu_(Canala)_xara1244.csv
# None
# Yabem_yabe1254.csv
# [('tama', 'luò'), ('sa laŋgwa', 'gwadê'), ('sa laŋgwa', 'gwadêò'), ('sa laŋgwa', 'gwadê'), ('sa laŋgwa', 'gwadêò'), ('tamasêga', 'têwa'), ('tamasêga', 'têwaò'), ('tamasêga', 'têwa'), ('tamasêga', 'têwaò'), ('tênasêga', 'têwa'), ('tênasêga', 'luò'), ('tênasêga', 'têwa'), ('tênasêga', 'luò'), ('saò àwêsêga', 'gwadê'), ('saò àwêsêga', 'gwadêò'), ('saò àwêsêga', 'gwadê'), ('saò àwêsêga', 'gwadêò'), ('tama', 'luŋac'), ('tama', 'luŋac'), ('tama', 'têwaò'), ('tama', 'têwaò'), ('tamasêga', 'têwa'), ('tamasêga', 'têwaò'), ('tênasêga', 'têwa'), ('tênasêga', 'luò')]
# Yakan_yaka1277.csv
# [('amma', "pongtina'i"), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ('amma', "pongtina'i"), ('amma', 'kakka'), ('amma', 'sali')]
# Yamdena_yamd1240.csv
# [('ame', ''), ('ame', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', '')]
# Yami_Tao__yami1254.csv
# [('ama', 'kaka'), ('ama', 'wari'), ('ama', 'kaka'), ('ama', 'wari'), ('maran', 'kaposing'), ('maran', 'kaposing'), ('kaminan', 'kaposing'), ('kaminan', 'kaposing'), ('kaminan', 'kateysa'), ('kaminan', 'kateysa')]
# Zabana_(Kia)_zaba1237.csv
# None
# De_kwana_Maquiritari__maqu1238.csv
# [('haha', '-nuwā-dɨ'), ('haha', 'šīʔčɨ'), ('yawo', 'yāʔko'), ('yawo', 'yāʔko'), ('haha', 'yāʔko'), ('haha', 'yāʔko'), ('denɨ', 'yāʔko'), ('denɨ', 'yāʔko'), ('waynɲeʔney', 'yāʔko'), ('waynɲeʔney', 'yāʔko')]
# Galibi_Carib_gali1262.csv
# [('yüman', 'irï'), ('yüman', 'pirï'), ('yüman', 'wawá'), ('yüman', 'xonen'), ('katobô', 'paman'), ('katobô', 'takanô'), ('', 'paman'), ('', 'takanô'), ('yüman', 'ymuru'), ('yüman', ''), ('sanon', ''), ('sanon', ''), ('yawôpirï', 'paman'), ('yawôpirï', 'takanô'), ('yüman', 'yayá'), ('yüman', 'tiom'), ('yüman', 'payrï'), ('yüman', 'pitï')]
# Macushi_macu1259.csv
# [('u-yun', 'uwi'), ('u-yun', 'u-yakon'), ('inton', 'piipi'), ('inton', 'piipi'), ('papai', 'piipi'), ('papai', 'piipi'), ('mamai', 'piipi'), ('mamai', 'piipi'), ('waʔnɨ', 'piipi'), ('waʔnɨ', 'piipi')]
# Panare_enap1235.csv
# [('yím', 'yakó'), ('yím', 'ñaʔtsú'), ('yawóng', 'puamó'), ('yawóng', 'maté'), ('yím', '-ɲasuk'), ('yím', 'ñaʔtsú'), ('sanéʔ', 'yakó'), ('sanéʔ', 'ñaʔtsú'), ('wañéne', 'puamó'), ('wañéne', 'maté')]
# Pemon_pemo1248.csv
# [('uyepotorï', 'urui'), ('uyepotorï', 'uyakon'), ('uyepotorï', 'uyenaru'), ('uyepotorï', 'maɂnon'), ('umui', ''), ('umui', ''), ('papai', ''), ('papai', ''), ('amai', ''), ('amai', ''), ('uwaɂnin', ''), ('uwaɂnin', ''), ('uyepotorï', 'uyaɂyeketï'), ('uyepotorï', 'moyi'), ('uyepotorï', 'upasi'), ('uyepotorï', 'uyakon')]
# Waimiri_Atroari_waim1253.csv
# [('yim”', 'mim'), ('yim”', 't”ka'), ('yim”', 'makba'), ('yim”', 't”ka'), ('ya', ''), ('ya', ''), ('y”mk”', ''), ('y”mk”', ''), ('sank”', ''), ('sank”', ''), ('w”h”', ''), ('w”h”', '')]
# Wai_Wai_waiw1244.csv
# [('yɨɨm', 'oy-akno'), ('yɨɨm', 'oy-eΦeka'), ('o-tam-ru', 'oy-akno'), ('o-tam-ru', 'oy-akno'), ('yɨɨm', 'oy-akno'), ('yɨɨm', 'oy-akno'), ('yɨ-son', 'oy-akno'), ('yɨ-son', 'oy-akno'), ('o-tam-ru', 'oy-akno'), ('o-tam-ru', 'oy-akno'), ('yɨɨm', 'oy-eΦeka'), ('yɨɨm', 'oy-akno')]
# Chenchu_chen1255.csv
# None
# Dandami_Maria_dand1238.csv
# [('tāppe', 'akkā'), ('tāppe', 'hellār'), ('māmā', 'marriyō'), ('māmā', 'mandāri'), ('ātō', 'marriyo'), ('ātō', 'mandāri'), ('tāppe', 'dādā'), ('tāppe', 'tamō')]
# Gondi_gond1265.csv
# None
# Kadar_kada1242.csv
# None
# Kodava_koda1255.csv
# [('appë', 'aṇṇë'), ('appë', 'tammaṇë'), ('appë', 'akkē'), ('appë', 'taṅge'), ('tamma:vën', 'ba:ven'), ('tamma:vën', 'madama'), ('tamma:vi', 'ba:ven'), ('tamma:vi', 'madama')]
# Koya_koya1251.csv
# [('bābo', 'dādāl'), ('bābo', 'tammūṇḍ'), ('bābo', 'tudal'), ('māmā', 'yeruḷ'), ('māmā', 'pekki'), ('pépe', 'tammuḍu'), ('pépe', 'piki'), ('pedi', 'tammuḍu'), ('pedi', 'piki'), ('kuci', 'tammuḍu'), ('kuci', 'piki'), ('poyé', 'yeruḷ'), ('poyé', 'pekki')]
# Kui_kuii1252.csv
# [('tanji', 'dada'), ('tanji', 'ambesa'), ('tanji', 'bāiḍi'), ('tanji', 'aṇgi'), ('ake boḍu', 'mrīgenju'), ('ake boḍu', 'mrīgali'), ('prehenḍa', 'ambesa'), ('prehenḍa', 'bāi'), ('kōka', 'ambesa'), ('kōka', 'bāi'), ('ama', 'ambesa'), ('ama', 'bāi')]
# Kurukh_kuru1302.csv
# None
# Kuvi_kuvi1243.csv
# [('aba', 'nana'), ('aba', 'poda'), ('mama', 'tada'), ('0', 'tada'), ('0', 'nana'), ('koki', 'nana'), ('aba', 'tada'), ('aba', 'arhi')]
# Malapandaram_mala1468.csv
# [('aia', 'annan'), ('aia', 'thambi'), ('aia', 'akkah'), ('aia', 'thankachi'), ('mama', 'mathani'), ('athai', 'machinan')]
# Malayalam_mala1464.csv
# None
# Morgan1871_Canarese_nucl1305.csv
# Morgan1871_Tamil_tami1289.csv
# Morgan1871_Telugu_telu1262.csv
# Northern_Gondi_nort2702.csv
# None
# Paliyan_pali1274.csv
# [('ayya', 'annan'), ('ayya', 'aniyan'), ('ayya', 'akka'), ('ayya', 'thankachi'), ('mama', 'macchan'), ('mama', 'madini'), ('mami', 'macchan'), ('mami', 'madini')]
# Tamil_tami1289.csv
# [('appā', 'ayyan'), ('appā', 'tampi'), ('appā', 'appi'), ('appā', 'taṅkai'), ('māmā', 'attān'), ('māmā', 'aṇṇi'), ('periappā', 'aṇṇā'), ('periappā', 'akkā'), ('cittāppā', 'tambi'), ('cittāppā', 'tankai'), ('periammā', 'aṇṇā'), ('periammā', 'akkā'), ('kunji', 'thampi'), ('kunji', 'tangai'), ('periattai', 'attān'), ('periattai', 'aṇṇi'), ('kunjattai', 'maccinaṉ'), ('kunjattai', 'koḻunti')]
# Telugu_telu1262.csv
# [('pita', 'tammuḍu'), ('pita', 'tammuDu'), ('pita', 'bhagini'), ('pita', 'celle'), ('māma', 'mardi'), ('māma', 'mardalu'), ('peddayya', 'tammuḍu'), ('peddayya', 'celle'), ('pinni', 'tammuḍu'), ('pinni', 'celle'), ('atta', 'mardi'), ('atta', 'mardalu')]
# Toda_toda1252.csv
# [('in', 'oṇ'), ('in', 'wïṛfed'), ('in', 'okn'), ('in', 'wïṛfed'), ('mun', 'mociny'), ('mun', 'mociny'), ('perwïḍin', 'mociny'), ('perwïḍin', 'mociny'), ('kïṟwïḍin', 'mociny'), ('kïṟwïḍin', 'mociny'), ('perwïḍaf', 'mociny'), ('perwïḍaf', 'mociny'), ('kïṟwïḍaf', 'mociny'), ('kïṟwïḍaf', 'mociny'), ('mimy', 'mociny'), ('mimy', 'mociny')]
# Yerukula_yeru1240.csv
# None
# Albanian_alba1267.csv
# [('babë', 'apë'), ('babë', 'vëlla'), ('babë', 'mommë'), ('babë', 'motër'), ('ungj', 'kushëri'), ('ungj', 'kushërirë'), ('xhaxha', 'kushëri'), ('xhaxha', 'kushërirë'), ('teze', 'kushëri'), ('teze', 'kushërirë'), ('emtë', 'kushëri'), ('emtë', 'kushërirë')]
# Albanian_Tosk__tosk1239.csv
# [('at', "və'la"), ('at', 'motər'), ('at', 'lʸoče'), ('dayə', "kušə'ri"), ('dayə', "kušə'ri"), ("ǰa'ǰa", "kušə'ri"), ("ǰa'ǰa", "kušə'ri"), ('teze', "kušə'ri"), ('teze', "kušə'ri"), ('halə', "kušə'ri"), ('halə', "kušə'ri")]
# Ancient_Greek_anci1242.csv
# [('patḗr', 'kasígnētos'), ('patḗr', 'kasignḗtē'), ('theîos', 'anepsiós'), ('theîos', 'anepsiḗ'), ('theîos', 'anepsiós'), ('theîos', 'anepsiḗ'), ('tēthís', 'anepsiós'), ('tēthís', 'anepsiḗ'), ('tēthís', 'anepsiós'), ('tēthís', 'anepsiḗ')]
# Armenian_nucl1235.csv
# [('hayr', 'ełbayr'), ('hayr', "k'uyr"), ("k'eri", "k'eru tła"), ("k'eri", "k'eru ałǰik"), ('horełbayr', 'horełbor tła'), ('horełbayr', 'horełbor ałǰik'), ("morak'uyr", "morak'roǰ tła"), ("morak'uyr", "morak'roǰ ałǰik"), ("horak'uyr", "horak'roǰ tła"), ("horak'uyr", "horak'roǰ ałǰik")]
# Assamese_assa1263.csv
# [('bopai', 'kƆkai'), ('bopai', 'bhaiti'), ('bopai', 'bhani'), ('momai', 'kākai bhāi'), ('dādei', 'kākai'), ('khuṛā', 'kākai'), ('māhī', 'kākai bhāi'), ('pehi', 'kākai')]
# Avestan_aves1237.csv
# None
# Balochi_balo1260.csv
# [('mama', 'trizatk'), ('mama', 'trizatk'), ('baba', 'naxozatk'), ('baba', 'naxozatk'), ('masi', 'trizatk'), ('masi', 'trizatk'), ('pupu', 'trizatk'), ('pupu', 'trizatk')]
# Belarusian_bela1254.csv
# [("bác'ka", 'brat'), ("bác'ka", 'sjastrá'), ("dzjádz'ka", 'dvajúradny brat'), ("dzjádz'ka", 'dvajúradnaja sjastrá'), ("dzjádz'ka", 'dvajúradny brat'), ("dzjádz'ka", 'dvajúradnaja sjastrá'), ('cëtka', 'dvajúradny brat'), ('cëtka', 'dvajúradnaja sjastrá'), ('cëtka', 'dvajúradny brat'), ('cëtka', 'dvajúradnaja sjastrá')]
# Bengali_beng1280.csv
# [('bābā', 'dada'), ('bābā', 'bhāi'), ('bābā', 'didi'), ('bābā', 'bon'), ('māmā', 'mamato-bhai'), ('māmā', 'mamato-bon'), ('jeṭha-moshay', 'jeṭhtato-bhai'), ('jeṭha-moshay', 'jaṭhtato-bon'), ('khuda', 'khudtato-bhai'), ('khuda', 'khudtato-bon'), ('mashi-ma', 'mashtato-bhai'), ('mashi-ma', 'mashtato-bon'), ('pishi-ma', 'pishtato-bhai'), ('pishi-ma', 'pishtato-bon')]
# Bihari_biha1245.csv
# None
# Boers_afri1274.csv
# [('vader', 'broer'), ('vader', 'suster'), ('oom', 'neef'), ('oom', 'niggie'), ('oom', 'neef'), ('oom', 'niggie'), ('tante', 'neef'), ('tante', 'niggie'), ('tante', 'neef'), ('tante', 'niggie')]
# Breton_bret1244.csv
# [('tad', 'breur'), ('tad', "c'hoar"), ('eontr kompez', 'kenderv'), ('eontr kompez', 'keniterv'), ('eontr kompez', 'kenderv'), ('eontr kompez', 'keniterv'), ('moereb gompez', 'kenderv'), ('moereb gompez', 'keniterv'), ('moereb gompez', 'kenderv'), ('moereb gompez', 'keniterv')]
# Bulgarian_bulg1262.csv
# [('bašta', 'batko'), ('bašta', 'brat'), ('bašta', 'kaka'), ('bašta', 'sestra'), ('vujčo', 'bratovčed'), ('vujčo', 'bratovčedka'), ('čičo', 'bratovčed'), ('čičo', 'bratovčedka'), ('tetka', 'bratovčed'), ('tetka', 'bratovčedka'), ('lelja', 'bratovčed'), ('lelja', 'bratovčedka')]
# Central_Kurdish_cent1972.csv
# ...
# Pauserna_paus1244.csv
# [('-túti', '-iké-ʔi'), ('-túti', '-iké-ʔi'), ('-túti', '-éiɲi'), ('-hí-ʔi', '-íʔi'), ('-hí-ʔi', '-éiɲi'), ('-átse', '-íʔi'), ('-u', '-kíwi'), ('-u', '-íke'), ('-u', '-pikíʔi')]
# Proto_Tupi_Guarani_tupi1276.csv
# None
# Sateré_Mawé_sate1243.csv
# [('wiawod', 'ohoti'), ('wiawod', 'maná'), ('wiawod', 'pian'), ('hamu', 'hamu'), ('hamu', 'itowoi'), ('itowoi', 'hamu'), ('itowoi', 'itowoi')]
# Sirionó_siri1273.csv
# [('éru', 'auóNge'), ('éru', 'auóNge'), ('ámi', 'akwaníndu'), ('ámi', 'yánde'), ('éru', 'auóNge'), ('ézi', 'auóNge'), ('ézi', 'auóNge'), ('ári', 'ámi'), ('ári', 'ári')]
# Suruí_suru1262.csv
# [('lob', 'ngóranãm'), ('lob', 'ngármẽy'), ('lob', 'mahd'), ('nisóa', 'máyxán'), ('nisóa', 'máyxán'), ('lob', 'máyxán'), ('lob', 'máyxán'), ('ni', 'máyxán'), ('ni', 'máyxán'), ('móyá', 'máyxán'), ('móyá', 'máyxán'), ('lob', 'lóa'), ('lob', 'ngóranãm'), ('lob', 'ngármẽy')]
# Tapirapé_tapi1254.csv
# None
# Tembé_temb1276.csv
# None
# Tenharim_tenh1241.csv
# [('apĩ-', "-reky'yra-"), ('apĩ-', "-rey'reta-"), ('apĩ-', '-rendyr-'), ('tutyr-', 'jajivembyr-'), ('tutyr-', 'jajivembyr-'), ('uvy-', 'nirun-'), ('uvy-', '-rendyr-'), ('yy-', 'nirun-'), ('yy-', '-rendyr-'), ('jaji-', 'jajivembyr-'), ('jaji-', 'jajivembyr-')]
# Tocantins_Asurini_toca1235.csv
# [('miangakee', "seryke'yra"), ('miangakee', 'serywyra'), ('miangakee', 'serenyra'), ('setotyra', "setotyra'yra"), ('setotyra', 'setotyrasyra'), ('miangakee', 'sekywyra'), ('miangakee', 'serenyra'), ('mihengee', 'serenyra'), ('sesasee', 'sesasémemyra'), ('sesasee', 'sesasémemyra'), ('miangakee', 'sekywyra'), ('miangakee', 'serykéra'), ('miangakee', "sepyky'yra"), ('mihákee', 'sekywyra')]
# Tupinambá_tupi1273.csv
# [('uba', 'enotara'), ('uba', 'ybyra'), ('uba', 'yquera'), ('uba', 'pyquyyra'), ('tutyra', 'tutyra'), ('uba', 'tutyra'), ('aixé', 'iyra')]
# Tupí_tupi1274.csv
# [('tuba', 'tendyra'), ('tutyra', 'tykyyra'), ('tutyra', 'tendyra'), ('tuba', 'tykyyra'), ('tuba', 'tendyra'), ('cyyra', 'tykyyra'), ('cyyra', 'tendyra'), ('aixé', 'tykyra'), ('aixé', 'tendyra'), ('tuba', 'kybyra'), ('tuba', 'kybykyra'), ('tuba', 'tykêra'), ('tuba', 'kypýy')]
# Wayampi_waya1270.csv
# None
# Kazakh_kaza1248.csv
# None
# Kumyk_kumy1244.csv
# [('ата', 'эр къардаш'), ('ата', 'эркъардаш'), ('ата', 'къызардаш'), ('ата', 'гиччи къызардаш'), ('агъасы', 'уьзукъари'), ('агъасы', 'уьзукъари'), ('агъасы', 'уьзукъари'), ('агъасы', 'уьзукъари'), ('эчуву', 'уьзукъари'), ('эчуву', 'уьзукъари'), ('эчуву', 'уьзукъари'), ('эчуву', 'уьзукъари')]
# Nogai_noga1249.csv
# [('ata', 'adanas'), ('ata', 'ini'), ('ata', 'karɨndas'), ('ata', 'siŋli'), ('nagaš akay', 'bölе'), ('nagaš akay', 'bölе'), ('akay', 'bölе'), ('akay', 'bölе'), ('abay', 'bölе'), ('abay', 'bölе'), ('abay', 'bölе'), ('abay', 'bölе')]
# North_Azerbaijani_nort2697.csv
# [('papa', 'gerdesh'), ('papa', 'kichik gerdesh'), ('papa', 'bachy'), ('papa', 'kichik bachy'), ('dajy', 'emigizi'), ('dajy', 'emigizi'), ('emi', 'emigizi'), ('emi', 'emigizi'), ('khala', 'emigizi'), ('khala', 'emigizi'), ('bibi', 'emigizi'), ('bibi', 'emigizi')]
# Turkish_nucl1301.csv
# [('baba', 'ağabey'), ('baba', 'kardeš'), ('baba', 'abla'), ('baba', 'kardeš'), ('dayı', 'kuzen'), ('dayı', 'kuzen'), ('amca', 'kuzen'), ('amca', 'kuzen'), ('teyze', 'kuzen'), ('teyze', 'kuzen'), ('hala', 'kuzen'), ('hala', 'kuzen')]
# Erzya_erzy1239.csv
# [('tʸetʸa', 'lʸelʸa'), ('tʸetʸa', 'yalaks'), ('tʸetʸa', 'patʸa'), ('tʸetʸa', 'sazor̃'), ('lʸelʸa', 'lʸelʸa'), ('lʸelʸa', 'lʸelʸa'), ('lʸelʸax', 'lʸelʸa'), ('lʸelʸax', 'lʸelʸa'), ('sɨr̃ʸkay', 'lʸelʸa'), ('sɨr̃ʸkay', 'lʸelʸa'), ('sɨr̃ʸkay', 'lʸelʸa'), ('sɨr̃ʸkay', 'lʸelʸa')]
# Estonian_esto1258.csv
# [('isa', 'wend'), ('isa', 'əde'), ('onu', 'onupoeg'), ('onu', 'onutütar̃'), ('lell', 'lellepoeg'), ('lell', 'lelletütar̃'), ('tædi', 'tædipoeg'), ('tædi', 'tæditütar̃'), ('sətse', 'sətsepoeg'), ('sətse', 'sətsetütar̃')]
# Finnic_finn1318.csv
# [('isæ', 'weli'), ('isæ', 'nuor̃empi weli'), ('isæ', 'sisko'), ('isæ', 'nuor̃empi sisar̃'), ('eno', 'ser̃kku'), ('eno', 'ser̃kku'), ('setæ', 'ser̃kku'), ('setæ', 'ser̃kku'), ('tæti', 'ser̃kku'), ('tæti', 'ser̃kku'), ('tæti', 'ser̃kku'), ('tæti', 'ser̃kku')]
# Finnish_finn1318.csv
# Ingrian_ingr1248.csv
# [('tatta isä', 'velloi'), ('tatta isä', 'siar'), ('enoi', 'seukkoi'), ('enoi', 'seukkoi'), ('tädä', 'seukkoi'), ('tädä', 'seukkoi'), ('täti', 'seukkoi'), ('täti', 'seukkoi'), ('täti', 'seukkoi'), ('täti', 'seukkoi')]
# Kazym_Berezover_Suryskarer_Khanty_khan1273.csv
# [('asʸi', 'yiwpux'), ('asʸi', 'apal'), ('asʸi', 'yiwewi'), ('asʸi', 'apalne'), ('wər̃tɨ', 'asewi'), ('wər̃tɨ', 'asewi'), ('yay', 'asewi'), ('yay', 'asewi'), ('nɨy', 'asewi'), ('nɨy', 'asewi'), ('or̃tne', 'asewi'), ('or̃tne', 'asewi')]
# kinura_ErzyaMordvin_erzy1239.csv
# kinura_Estonian_esto1258.csv
# kinura_Finnish_finn1318.csv
# kinura_ForestEnets_fore1265.csv
# [('eśi', 'aga kasa'), ('eśi', 'sooku'), ('eśi', 'ńabaku'), ('eśi', 'ṕɛb́i'), ('', ''), ('', ''), ('', ''), ('', ''), ('kađa', ''), ('kađa', ''), ('abaa', ''), ('abaa', ''), ('kađa', ''), ('kađa', ''), ('abaa', ''), ('abaa', ''), ('eśi', 'pɛ́b́i')]
# kinura_HillMari_west2392.csv
# [('ätʹa', 'əzä'), ('ätʹa', 'šolʹa'), ('ätʹa', 'äkä'), ('ätʹa', 'šə̑žar'), ('', ''), ('', ''), ('kuγuza', ''), ('kuγuza', ''), ('əzä', ''), ('əzä', ''), ('kuaka', ''), ('kuaka', ''), ('', ''), ('', ''), ('kuaka', ''), ('kuaka', ''), ('äkä', ''), ('äkä', '')]
# kinura_Hungarian_hung1274.csv
# [('atya', 'bátya'), ('atya', 'öcs'), ('atya', 'néne'), ('atya', 'húg'), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', '')]
# kinura_KazymKhanty_nort2672.csv
# [('jĭw', 'jaj'), ('jĭw', 'apśi'), ('jĭw', 'ŏpi'), ('jĭw', 'apәḷ-nɛ'), ('aki', ''), ('aki', ''), ('wǫrti', ''), ('wǫrti', ''), ('aki', ''), ('aki', ''), ('apśi', ''), ('apśi', ''), ('ĭmi', ''), ('ĭmi', ''), ('nĭj', ''), ('nĭj', ''), ('śaś-ŏpi', ''), ('śaś-ŏpi', ''), ('apәḷ-nɛ', 'χĭʌi'), ('apәḷ-nɛ', 'χĭʌ-nɛ')]
# kinura_KomiZyrian_komi1268.csv
# [('aj', ''), ('aj', ''), ('', ''), ('', ''), ('unaj', ''), ('unaj', ''), ('', ''), ('', ''), ('un', ''), ('un', ''), ('', ''), ('', ''), ('', ''), ('', '')]
# kinura_Livonian_livv1244.csv
# [('tǭți', ''), ('tǭți', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', '')]
# kinura_MeadowMari_gras1239.csv
# [('ača', 'iza'), ('ača', 'šolʹo'), ('ača', 'aka'), ('ača', 'šüžar'), ('kuγu čüčü', ''), ('kuγu čüčü', ''), ('čüčü', ''), ('čüčü', ''), ('kuγu čüčü', ''), ('kuγu čüčü', ''), ('iza', ''), ('iza', ''), ('koka', ''), ('koka', ''), ('akalijše', ''), ('akalijše', ''), ('koka', ''), ('koka', ''), ('aka', ''), ('aka', '')]
# kinura_MokshaMordvin_moks1248.csv
# [('tʹätʹä', 'alʹńaka'), ('tʹätʹä', 'väžńä'), ('tʹätʹä', 'ańaka'), ('tʹätʹä', 'sazər'), ('', ''), ('', ''), ('oćä', ''), ('oćä', ''), ('', ''), ('', ''), ('ščaka', ''), ('ščaka', ''), ('aka', ''), ('aka', ''), ('oću aka', ''), ('oću aka', ''), ('aka', ''), ('aka', '')]
# kinura_Nganasan_ngan1291.csv
# [('idʹaʔa', 'ńini̮'), ('idʹaʔa', 'ŋadʹa'), ('idʹaʔa', 'abaʔa'), ('idʹaʔa', 'ŋadʹa'), ('iśi', ''), ('iśi', ''), ('ti̮ti̮dʹa', ''), ('ti̮ti̮dʹa', ''), ('iśi', ''), ('iśi', ''), ('ńini̮', ''), ('ńini̮', ''), ('kotu', ''), ('kotu', ''), ('ŋaaga', ''), ('ŋaaga', ''), ('kotu', ''), ('kotu', ''), ('ŋahu', ''), ('ŋahu', '')]
# kinura_NorthSaami_nort2671.csv
# [('áhčči', 'stuorraviellja'), ('áhčči', 'uhcaviellja'), ('áhčči', 'stuorraoabbá'), ('áhčči', 'uhcaoabbá'), ('', ''), ('', ''), ('eahki', ''), ('eahki', ''), ('čeahci', ''), ('čeahci', ''), ('goaski', ''), ('goaski', ''), ('muoŧŧá', ''), ('muoŧŧá', ''), ('', ''), ('', '')]
# kinura_SkoltSaami_skol1241.csv
# [('eʹčč', ''), ('eʹčč', ''), ('', ''), ('', ''), ('jieʹǩǩ', ''), ('jieʹǩǩ', ''), ('čieʹcc', ''), ('čieʹcc', ''), ('kuäʹsǩǩ', ''), ('kuäʹsǩǩ', ''), ('mueʹđđ', ''), ('mueʹđđ', ''), ('', ''), ('', '')]
# kinura_SosvaMansi_nort2677.csv
# [('jaγ', 'kaŋk'), ('jaγ', 'kaš́'), ('jaγ', 'uwš́i'), ('jaγ', 'ɛ̄š́'), ('aki', ''), ('aki', ''), ('', ''), ('', ''), ('aki', ''), ('aki', ''), ('kaŋk', ''), ('kaŋk', ''), ('', ''), ('', ''), ('', ''), ('', '')]
# kinura_SouthSaami_sout2674.csv
# [('aehtjie', 'stoere-vïelle'), ('aehtjie', ''), ('aehtjie', 'stoere-åabpa'), ('aehtjie', ''), ('', ''), ('', ''), ('jiekie', ''), ('jiekie', ''), ('tjietsie', ''), ('tjietsie', ''), ('gåeskie', ''), ('gåeskie', ''), ('muahra', ''), ('muahra', ''), ('', ''), ('', '')]
# kinura_TundraNenets_nene1249.csv
# [('ŋæća', 'ńińeka'), ('ŋæća', 'ṕeb́a'), ('ŋæća', 'ńabako'), ('ŋæća', 'ṕeb́a'), ('jiŕi', ''), ('jiŕi', ''), ('tʹidʹa', ''), ('tʹidʹa', ''), ('jiŕi', ''), ('jiŕi', ''), ('ńaəka', ''), ('ńaəka', ''), ('ńeb́ah ńabako', ''), ('ńeb́ah ńabako', ''), ('ńeja', ''), ('ńeja', ''), ('', ''), ('', ''), ('ńabako', ''), ('ńabako', '')]
# kinura_Udmurt_udmu1245.csv
# [('ajï', 'ńuńu'), ('ajï', 'vi̮n'), ('ajï', 'aka'), ('ajï', 'suzer'), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', '')]
# kinura_Veps_veps1250.csv
# [('tat', 'veik'), ('tat', ''), ('tat', 'čižoi'), ('tat', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', '')]
# Komi_Zyrian_komi1268.csv
# Magyar_hung1274.csv
# Mansi_mans1258.csv
# [('asʸ', 'yaɣpɨɣ'), ('asʸ', 'apsʸi'), ('asʸ', 'yaɣaɣi'), ('asʸ', 'esʸ'), ('sasɨɣ', 'eŋk'), ('sasɨɣ', 'eŋk'), ('kaŋk', 'eŋk'), ('kaŋk', 'eŋk'), ('nɨy', 'eŋk'), ('nɨy', 'eŋk'), ('uwsʸi', 'eŋk'), ('uwsʸi', 'eŋk')]
# Mari_east2328.csv
# None
# Northern_Sami_nort2671.csv
# Selkup_selk1253.csv
# None
# Tundra_Nenets_nene1249.csv
# Udmurt_udmu1245.csv
# Veps_veps1250.csv
# Arizona_Yaqui_yaqu1251a.csv
# None
# Aztec_clas1250.csv
# None
# Bannock_bann1248.csv
# None
# Cahuilla_cahu1264.csv
# [('táata', 'is-ka'), ('táata', '-wáxalˠ'), ('tas', "ñuk'u"), ('tas', "ñuk'u"), ('kum', 'pas'), ('kum', 'kis'), ('mas', 'yul'), ('mas', 'nawal'), ('nes', 'pas'), ('nes', 'kis'), ('yes', 'yul'), ('yes', 'nawal')]
# Chemehuevi_chem1251.csv
# None
# Colorado_Ute_utee1244a.csv
# None
# Comanche_coma1245.csv
# [('ahpï', "pabi'i"), ('ahpï', "tami'"), ('ahpï', "paci'"), ('ahpï', "nami'"), ("ara'", 'haic'), ("ara'", 'paci'), ('api', 'haic'), ('api', 'paci'), ('pia', 'haic'), ('pia', 'paci'), ('paha', 'haic'), ('paha', 'paci')]
# Cora_elna1235.csv
# None
# Cupeño_cupe1243.csv
# [('-na', 'páʂma'), ('-na', 'kanima'), ('-na', 'qísma'), ('-na', '-wáxalˠi'), ('táʂma', 'nukma'), ('táʂma', 'nukma'), ('kum', 'pasma'), ('kum', 'kisma'), ('meš', 'kanima'), ('meš', 'wahali'), ('neʂ', 'pasma'), ('neʂ', 'kisma'), ('yéʂma', 'kanima'), ('yéʂma', 'wahali'), ('-pah(a)', 'nukma'), ('-pah(a)', 'nukma')]
# Eudeve_eude1234.csv
# None
# Gabrielino_tong1329.csv
# [('-nák', 'waa'), ('-nák', "pé'ec"), ('-nák', "óxo'"), ('-nák', "pí'ic"), ('kukma', 'waa'), ('kukma', 'waa'), ('más', 'waa'), ("(ny)ó'oš", 'waa'), ("(ny)ó'oš", 'waa')]
# Guarijio_huar1255.csv
# None
# Highland_Puebla_Nahuatl_high1278.csv
# None
# Hopi_hopi1249.csv
# None
# Hopi_S__hopi1249b.csv
# None
# Huastec_Nahuatl_huas1257.csv
# None
# Huichol_huic1243.csv
# None
# Kawaiisu_kawa1283.csv
# None
# Kitanemuk_serr1255b.csv
# None
# Lower_Pima_Pima_Bajo_pima1248.csv
# None
# Luiseńo_luis1253.csv
# [("-ná'", "páá'aʂ"), ("-ná'", 'péét'), ("-ná'", "qee'is"), ("-ná'", 'píít'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ('kamú', 'kwámay'), ('máʂ', 'má$'), ('núʂ', 'máay'), ('núʂ', 'máay'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum')]
# Mayo_mayo1264.csv
# None
# Mono_mono1275.csv
# None
# Morgan1871_Utahs_(Tabegwaches)_utes1238.csv
# Northern_Paiute_nort2954.csv
# None
# Northern_Tepehuan_nort2959.csv
# None
# North_Northern_Paiute_nort1551.csv
# None
# Opata_opat1246.csv
# [('mas', 'vapaci'), ('mas', 'vonigua'), ('mas', 'cotziguat'), ('mas', 'viniwa'), ('cutziguat', 'maguât'), ('cutziguat', 'maguât'), ('taiguat', 'maguât'), ('taiguat', 'maguât'), ('cumuguat', 'maguât'), ('cumuguat', 'maguât'), ('teviriguat', 'maguât'), ('teviriguat', 'maguât'), ('tepó', 'maguât'), ('tepó', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât')]
# Pima_de_Yepáchic_chih1238.csv
# None
# Pipil_pipi1250.csv
# None
# Serrano_serr1255.csv
# [("-na'", 'paar'), ("-na'", 'pö˞it'), ("-na'", '-qöö˞r'), ("-na'", 'piit'), ('taar', "puyu'"), ('taar', "noko'"), ('kuumu', 'pas'), ('kuumu', 'kör'), ('maq', 'prit'), ('maq', 'pit'), ('nïm', 'pas'), ('yïïr', 'prit')]
# Shoshoni_shos1248.csv
# None
# Southeastern_Tepehuano_sout2976.csv
# [('taat', 'xiix'), ('taat', 'xiku'), ('taat', 'xiix'), ('taat', 'jaduuñ'), ('kuuxi', 'jaduuñ'), ('kuuxi', 'jaduuñ'), ('tataalh', 'jaduuñ'), ('tataalh', 'jaduuñ'), ('kilhi', 'jaduuñ'), ('kilhi', 'jaduuñ'), ('jiikulh', 'jaduuñ'), ('jiikulh', 'jaduuñ')]
# Southern_Paiute_sout2969.csv
# [('moa', 'paci-'), ('moa', 'nami-(n)ci'), ('ai-', 'ai-'), ('ai-', 'ai-'), ('paha', 'ai-'), ('paá', 'ai-'), ('moa', 'papi-ci'), ('moa', 'cahkai')]
# Southern_Tepehuan_sout2975.csv
# None
# Southern_Tepehuan_W__sout2977.csv
# None
# Southern_Ute_utee1244.csv
# None
# Tarahumara_cent2131.csv
# [('onó', "ba'či"), ('onó', 'boní'), ('onó', "go'či"), ('onó', 'wayé'), ('kurichi', "ra'téchiwa"), ("ra'té", "ra'techi"), ('kumú-či', 'boní'), ('soró', 'boní'), ('apó', 'boní'), ('onó', 'biní')]
# Tohono_O_odham_toho1245.csv
# None
# Tubar_tuba1279.csv
# None
# Tübatülabal_tuba1278.csv
# None
# Tümpisha_Shoshoni_pana1305.csv
# [('appü', 'patsi'), ('appü', 'nammi(ttsi)'), ('piasamoppu', 'tangumpua'), ('piasamoppu', 'samoppu'), ('tsukuna', 'tangumpua'), ('tsukuna', 'samoppu'), ('tokkwattsi', 'tangumpua'), ('tokkwattsi', 'samoppu'), ('pahwa', 'tangumpua'), ('pahwa', 'samoppu'), ('appü', 'papi'), ('appü', 'tami(ttsi)')]
# Western_Shoshoni_west2622.csv
# None
# White_Mesa_Ute_utee1244b.csv
# None
# Yaqui_yaqu1251.csv
# None
# 506
#                           language language_family      code simulation_code  \
# 0    Maguindanao_(Magindonao_Moro)    Austronesian  magu1243   magu1243_REAL
# 1                        Malua_Bay    Austronesian  malu1245   malu1245_REAL
# 2                      Mangarevans    Austronesian  mang1401   mang1401_REAL
# 3                   Mangei_(Sobjo)    Austronesian  mang1407   mang1407_REAL
# 4                            Maori    Austronesian  maor1246   maor1246_REAL
# ..                             ...             ...       ...             ...
# 501                        Serrano     Uto-Aztecan  serr1255   serr1255_REAL
# 502         Southeastern_Tepehuano     Uto-Aztecan  sout2976   sout2976_REAL
# 503                Southern_Paiute     Uto-Aztecan  sout2969   sout2969_REAL
# 504                     Tarahumara     Uto-Aztecan  cent2131   cent2131_REAL
# 505              Tümpisha_Shoshoni     Uto-Aztecan  pana1305   pana1305_REAL
#
#     simulation  mutual_information  entropy_gn  entropy_gn1  \
# 0            N            0.721928    0.921928     1.521928
# 1            N            1.500000    2.750000     1.500000
# 2            N            0.661705    1.483832     2.128085
# 3            N            0.000000   -0.000000     1.000000
# 4            N            0.001340    1.940286     0.985228
# ..         ...                 ...         ...          ...
# 501          N            2.084963    3.251629     2.418296
# 502          N            0.540852    1.040852     2.251629
# 503          N            1.000000    2.000000     1.750000
# 504          N            1.360964    2.521928     2.160964
# 505          N            0.918296    2.251629     2.251629
#
#      conditional_entropy  variation_gn  variation_gn1  number_of_pairs
# 0               0.800000             3              3                4
# 1              -0.000000             7              3                7
# 2               1.466380             4              5                8
# 3               1.000000             1              2                2
# 4               0.983888             4              2                8
# ..                   ...           ...            ...              ...
# 501             0.333333            10              6               12
# 502             1.710777             3              5                7
# 503             0.750000             5              4                7
# 504             0.800000             7              6               10
# 505             1.333333             6              5               12
#
# [506 rows x 12 columns]

# %% [markdown]
# And for the simulations:

# %%
ics_simulation(families,filtered_filepath,1000)
# Out:
#                              language language_family      code  \
# 0       Maguindanao_(Magindonao_Moro)    Austronesian  magu1243
# 1       Maguindanao_(Magindonao_Moro)    Austronesian  magu1243
# 2       Maguindanao_(Magindonao_Moro)    Austronesian  magu1243
# 3       Maguindanao_(Magindonao_Moro)    Austronesian  magu1243
# 4       Maguindanao_(Magindonao_Moro)    Austronesian  magu1243
# ...                               ...             ...       ...
# 505995              Tümpisha_Shoshoni     Uto-Aztecan  pana1305
# 505996              Tümpisha_Shoshoni     Uto-Aztecan  pana1305
# 505997              Tümpisha_Shoshoni     Uto-Aztecan  pana1305
# 505998              Tümpisha_Shoshoni     Uto-Aztecan  pana1305
# 505999              Tümpisha_Shoshoni     Uto-Aztecan  pana1305
#
#        simulation_code simulation  mutual_information  entropy_gn  \
# 0           magu1243_0          Y            0.321928    0.921928
# 1           magu1243_1          Y            0.321928    0.921928
# 2           magu1243_2          Y            0.397417    0.921928
# 3           magu1243_3          Y            0.397417    0.921928
# 4           magu1243_4          Y            0.321928    0.921928
# ...                ...        ...                 ...         ...
# 505995    pana1305_995          Y            1.251629    2.251629
# 505996    pana1305_996          Y            1.481203    2.251629
# 505997    pana1305_997          Y            1.084963    2.251629
# 505998    pana1305_998          Y            1.251629    2.251629
# 505999    pana1305_999          Y            1.314536    2.251629
#
#         entropy_gn1  conditional_entropy  variation_gn  variation_gn1  \
# 0          1.521928             1.200000             3              3
# 1          1.521928             1.200000             3              3
# 2          1.521928             1.124511             3              3
# 3          1.521928             1.124511             3              3
# 4          1.521928             1.200000             3              3
# ...             ...                  ...           ...            ...
# 505995     2.251629             1.000000             6              5
# 505996     2.251629             0.770426             6              5
# 505997     2.251629             1.166667             6              5
# 505998     2.251629             1.000000             6              5
# 505999     2.251629             0.937093             6              5
#
#         number_of_pairs
# 0                     5
# 1                     5
# 2                     5
# 3                     5
# 4                     5
# ...                 ...
# 505995               10
# 505996                9
# 505997               11
# 505998               10
# 505999               10
#
# [506000 rows x 12 columns]

# %% [markdown]
# For comparison, let's also create datasets for the full kinbank data, pre-filtering for duplicates:

# %%
families = ['Austronesian','Cariban','Dravidian','Indo-European','Nakh-Daghestanian','Nuclear Trans New Guinea',
            'Other','Pama-Nyungan','Pano-Tacanan','Salishan','Sino-Tibetan','Tai-Kadai','Tupian',
            'Turkic','Uralic','Uto-Aztecan']

family_filepath = '../languages/kinbank-family/'

# %%
ics_real(families,family_filepath)
# ics_real(aus_filepath,filtered_aus_files)
# Out:
# Maguindanao_(Magindonao_Moro)_magu1243.csv
# [('ina', 'kaka'), ('ina', 'ali'), ('ama', 'kaka'), ('ama', 'ali'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('ina', 'kakal'), ('ina', 'kaka'), ('ina', 'ali'), ('ama', 'kakal'), ('ama', 'kaka'), ('ama', 'ali'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut')]
# Malua_Bay_malu1245.csv
# [('pepe', 'tisuk'), ('pepe', 'söghösök dövat'), ('pepe', 'söghösök dövat'), ('tate', 'tisuk'), ('tate', 'söghösök dövat'), ('tate', 'söghösök dövat'), ('bini', 'natök'), ('bini', 'natök'), ('bini', 'natök'), ('bini', 'natök'), ('vavwe', 'tate'), ('vavwe', 'vavwe'), ('vavwe', 'tate'), ('vavwe', 'vavwe'), ('pepe', 'söghösök'), ('pepe', 'söghösök'), ('pepe', 'lelei'), ('pepe', 'tisuk waven'), ('tate', 'söghösök'), ('tate', 'söghösök'), ('tate', 'lelei'), ('tate', 'tisuk waven'), ('bini', 'natök'), ('bini', 'natök'), ('bini', 'natök'), ('bini', 'natök'), ('vavwe', 'tate'), ('vavwe', 'vavwe'), ('vavwe', 'tate'), ('vavwe', 'vavwe')]
# Manam_mana1295.csv
# [('tina', "to'a, marau"), ('tina', 'tari'), ('tina', "to'a"), ('tama', "to'a, marau"), ('tama', 'tari'), ('tama', "to'a"), ('tina', 'tari'), ('tina', "to'a"), ('tina', "a'a"), ('tina', "to'a, marau"), ('tama', 'tari'), ('tama', "to'a"), ('tama', "a'a"), ('tama', "to'a, marau")]
# Mangaia_mang1402.csv
# [("metua va'ine", 'teina'), ("metua va'ine", "tua-'ine"), ("metua va'ine", "tua-'ine"), ('metua tane', 'teina'), ('metua tane', "tua-'ine"), ('metua tane', "tua-'ine"), ("metua va'ine", 'tu-ngane'), ("metua va'ine", 'tu-ngane'), ("metua va'ine", 'tua-kana'), ("metua va'ine", 'teina'), ('metua tane', 'tu-ngane'), ('metua tane', 'tu-ngane'), ('metua tane', 'tua-kana'), ('metua tane', 'teina')]
# Mangarevans_mang1401.csv
# [('kui', 'tuakana'), ('kui', 'teina'), ('kui', "tue'ine"), ('kui', "tue'ine"), ('motua', 'tuakana'), ('motua', 'teina'), ('motua', "tue'ine"), ('motua', "tue'ine"), ('motua', 'tuakana'), ('motua', 'teina'), ('motua', "tue'ine"), ('motua', "tue'ine"), ('motua', "tue'ine"), ('motua-nui', "tue'ine"), ('motua-iti', "tue'ine"), ('motua', 'tuakana'), ('motua', 'teina'), ('motua', "tue'ine"), ('motua', "tue'ine"), ('motua', "tue'ine"), ('motua-nui', "tue'ine"), ('motua-iti', "tue'ine"), ('kui', 'tuakana'), ('kui', 'teina'), ('kui', "tue'ine"), ('kui', "tue'ine"), ('kui', "tue'ine"), ('kui-nui', "tue'ine"), ('kui-iti', "tue'ine"), ('kui', 'tuakana'), ('kui', 'teina'), ('kui', "tue'ine"), ('kui', "tue'ine"), ('kui', "tue'ine"), ('kui-nui', "tue'ine"), ('kui-iti', "tue'ine"), ('kui', 'tuagane'), ('kui', 'tuagane'), ('kui', 'tuagane'), ('kui', 'tuakana'), ('kui', 'teina'), ('motua', 'tuagane'), ('motua', 'tuagane'), ('motua', 'tuagane'), ('motua', 'tuakana'), ('motua', 'teina'), ('motua', 'tugane'), ('motua', 'tugane'), ('motua', 'tugane'), ('motua', 'tuakana'), ('motua', 'teina'), ('motua-nui', 'tugane'), ('motua-iti', 'tugane'), ('motua', 'tugane'), ('motua', 'tugane'), ('motua', 'tugane'), ('motua', 'tuakana'), ('motua', 'teina'), ('motua-nui', 'tugane'), ('motua-iti', 'tugane'), ('kui', 'tugane'), ('kui', 'tugane'), ('kui', 'tugane'), ('kui', 'tuakana'), ('kui', 'teina'), ('kui-nui', 'tugane'), ('kui-iti', 'tugane'), ('kui', 'tugane'), ('kui', 'tugane'), ('kui', 'tugane'), ('kui', 'tuakana'), ('kui', 'teina'), ('kui-nui', 'tugane'), ('kui-iti', 'tugane')]
# Mangareva_mang1401.csv
# Mangei_(Sobjo)_mang1407.csv
# [('ina', 'naha'), ('ina', 'naha'), ('ina', 'foto'), ('ina', 'foto'), ('soesoe', 'kaka'), ('soesoe', 'oeli'), ('soesoe', 'kaka'), ('soesoe', 'oeli'), ('kolo', 'kaka'), ('kolo', 'oeli'), ('kolo', 'kaka'), ('kolo', 'oeli'), ('ina', 'naha'), ('ina', 'naha'), ('ina', 'foto'), ('ina', 'foto'), ('soesoe', 'kaka'), ('soesoe', 'oeli'), ('soesoe', 'kaka'), ('soesoe', 'oeli'), ('kolo', 'kaka'), ('kolo', 'oeli'), ('kolo', 'kaka'), ('kolo', 'oeli')]
# Manggarai_mang1405.csv
# [('iné', 'asé'), ('iné', 'weta'), ('iné', 'weta'), ('amé', 'asé'), ('amé', 'weta'), ('amé', 'weta'), ('iné', 'nara'), ('iné', 'nara'), ('iné', 'weta'), ('iné', 'weta'), ('amé', 'nara'), ('amé', 'nara'), ('amé', 'weta'), ('amé', 'weta')]
# Maori_maor1246.csv
# [('matua wahine', 'teina'), ('matua wahine', 'tuahine'), ('matua wahine', 'tuahine'), ('matua', 'teina'), ('matua', 'tuahine'), ('matua', 'tuahine'), ('matua', 'tuakana'), ('matua', 'tuahine'), ('matua, matua keekee, matakeekee', 'teina'), ('matua, matua keekee, matakeekee', 'tuahine'), ('matua', 'tuakana'), ('matua', 'tuahine'), ('matua, matua keekee, matakeekee', 'teina'), ('matua, matua keekee, matakeekee', 'tuahine'), ('whaea', 'tuakana'), ('whaea', 'tuahine'), ('whaea, matua keekee, matakeekee', 'teina'), ('whaea, matua keekee, matakeekee', 'tuahine'), ('whaea', 'tuakana'), ('whaea', 'tuahine'), ('whaea, matua keekee, matakeekee', 'teina'), ('whaea, matua keekee, matakeekee', 'tuahine'), ('matua wahine', 'tungaane'), ('matua wahine', 'tungaane'), ('matua wahine', 'tuakana'), ('matua wahine', 'teina'), ('matua', 'tungaane'), ('matua', 'tungaane'), ('matua', 'tuakana'), ('matua', 'teina'), ('matua, matua keekee, matakeekee', 'tungaane'), ('matua, matua keekee, matakeekee', 'tuakana'), ('matua, matua keekee, matakeekee', 'tungaane'), ('matua, matua keekee, matakeekee', 'teina'), ('matua, matua keekee, matakeekee', 'tungaane'), ('matua, matua keekee, matakeekee', 'tuakana'), ('matua, matua keekee, matakeekee', 'tungaane'), ('matua, matua keekee, matakeekee', 'teina'), ('whaea, matua keekee, matakeekee', 'tungaane'), ('whaea, matua keekee, matakeekee', 'tuakana'), ('whaea, matua keekee, matakeekee', 'tungaane'), ('whaea, matua keekee, matakeekee', 'teina'), ('whaea, matua keekee, matakeekee', 'tungaane'), ('whaea, matua keekee, matakeekee', 'tuakana'), ('whaea, matua keekee, matakeekee', 'tungaane'), ('whaea, matua keekee, matakeekee', 'teina')]
# Maragus_(Tape)_mara1399.csv
# [('nunu', 'vevnën'), ('nunu', 'vevnën'), ('etmen', 'vevnën'), ('etmen', 'vevnën'), ('nunu', 'mamwe'), ('etmen', 'mamwe')]
# Maranao_(Lanao_Moro)_mara1404.csv
# [('ina', 'ari'), ('ina', 'kaka'), ('ina', 'ari'), ('ama', 'ari'), ('ama', 'kaka'), ('ama', 'ari'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('ina', 'kaka'), ('ina', 'ari'), ('ina', 'kaka'), ('ina', 'ari'), ('ama', 'kaka'), ('ama', 'ari'), ('ama', 'kaka'), ('ama', 'ari'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('bapa', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut'), ('babu', 'tüngud, tǔngǔd, tungut')]
# Marquesas_marq1246.csv
# [('kui', 'teina'), ('kui', 'tuehine'), ('kui', 'tuehine'), ('mootua', 'teina'), ('mootua', 'tuehine'), ('mootua', 'tuehine'), ('kui', 'tunane'), ('kui', 'tunane'), ('kui', "tua'ana"), ('kui', 'teina'), ('mootua', 'tunane'), ('mootua', 'tunane'), ('mootua', "tua'ana"), ('mootua', 'teina')]
# Marshallese_mars1254.csv
# [('jinu', 'jetu'), ('jinu', 'jeu'), ('jinu', 'jetu'), ('jema', 'jetu'), ('jema', 'jeu'), ('jema', 'jetu'), ('jinu', 'jeu'), ('jinu', 'jetu'), ('jinu', 'jeu'), ('jinu', 'jetu'), ('jema', 'jeu'), ('jema', 'jetu'), ('jema', 'jeu'), ('jema', 'jetu')]
# Maskelynes_mask1242.csv
# [('ana-', 'ava-, wawa'), ('ana-', 'wawa'), ('ana-', 'wawa'), ('atəma-', 'ava-, wawa'), ('atəma-', 'wawa'), ('atəma-', 'wawa'), ('tata', 'ava-'), ('tata', 'ava-'), ('ana-', 'wawa'), ('ana-', 'wawa'), ('ana-', 'wawa'), ('ana-', 'wawa'), ('atəma-', 'wawa'), ('atəma-', 'wawa'), ('atəma-', 'wawa'), ('atəma-', 'wawa'), ('tata', 'tata'), ('tata', 'tata')]
# Matukar_matu1261.csv
# [('tinau', 'te, teiu'), ('tinau', 'lu'), ('tinau', 'lu'), ('tamau', 'te, teiu'), ('tamau', 'lu'), ('tamau', 'lu'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('tinau', 'lu'), ('tinau', 'lu'), ('tinau', 'ka'), ('tinau', 'te'), ('tamau', 'lu'), ('tamau', 'lu'), ('tamau', 'ka'), ('tamau', 'te'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol')]
# Mekeo_(East)_meke1243d.csv
# None
# Mekeo_(North)_meke1243c.csv
# None
# Mekeo_(North-West)_meke1243a.csv
# None
# Mekeo_(West)_meke1243b.csv
# None
# Mekeo_meke1243.csv
# [('ina', 'akina'), ('ina', 'anga'), ('ina', 'akina'), ('ama', 'akina'), ('ama', 'anga'), ('ama', 'akina'), ('ina', 'anga'), ('ina', 'akina'), ('ina', 'anga'), ('ina', 'akina'), ('ama', 'anga'), ('ama', 'akina'), ('ama', 'anga'), ('ama', 'akina')]
# Mekongga_meko1237.csv
# [('ina', 'hai'), ('ina', 'kaka'), ('ina', 'hai'), ('ama', 'hai'), ('ama', 'kaka'), ('ama', 'hai'), ('ina', 'kaka'), ('ina', 'hai'), ('ina', 'kaka'), ('ina', 'hai'), ('ama', 'kaka'), ('ama', 'hai'), ('ama', 'kaka'), ('ama', 'hai')]
# Mele-Fila_(Ifira-Mele)_mele1250.csv
# [('etata', 'taina'), ('etata', 'kave'), ('etata', 'kave'), ('emama', 'taina'), ('emama', 'kave'), ('emama', 'kave'), ('aua', 'kaleka'), ('aua', 'kaleka'), ('aua', 'kaleka'), ('aua', 'kaleka'), ('mamau', 'kaleka'), ('mamau', 'kaleka'), ('mamau', 'kaleka'), ('mamau', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('etata', 'kave'), ('etata', 'kave'), ('etata', 'taina'), ('etata', 'taina'), ('emama', 'kave'), ('emama', 'kave'), ('emama', 'taina'), ('emama', 'taina'), ('aua', 'kaleka'), ('aua', 'kaleka'), ('aua', 'kaleka'), ('aua', 'kaleka'), ('mamau', 'kaleka'), ('mamau', 'kaleka'), ('mamau', 'kaleka'), ('mamau', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka')]
# Menui_menu1237.csv
# [('nina', 'tuɸai'), ('nina', 'tukaka'), ('nina', 'tuɸai'), ('tama', 'tuɸai'), ('tama', 'tukaka'), ('tama', 'tuɸai'), ('nina', 'tukaka'), ('nina', 'tuɸai'), ('nina', 'tukaka'), ('nina', 'tuɸai'), ('tama', 'tukaka'), ('tama', 'tuɸai'), ('tama', 'tukaka'), ('tama', 'tuɸai')]
# Merei_mere1242.csv
# None
# Merlav_merl1237.csv
# [('ivev', 'tasi'), ('ivev', 'tata'), ('ivev', 'tata'), ('imama', 'tasi'), ('imama', 'tata'), ('imama', 'tata'), ('moru', 'natu'), ('moru', 'natu'), ('moru', 'natu'), ('moru', 'natu'), ('ivev', 'natu'), ('ivev', 'natu'), ('ivev', 'natu'), ('ivev', 'natu'), ('ivev', 'tata'), ('ivev', 'tata'), ('imama', 'tata'), ('imama', 'tata'), ('moru', 'natu'), ('moru', 'natu'), ('moru', 'natu'), ('moru', 'natu'), ('ivev', 'natu'), ('ivev', 'natu'), ('ivev', 'natu'), ('ivev', 'natu')]
# Minangkabau_mina1268.csv
# [('mandai', 'adiek'), ('mandai', 'adiek'), ('bapak', 'adiek'), ('bapak', 'adiek'), ('mandai', 'adiek'), ('mandai', 'kakak'), ('mandai', 'adiek'), ('bapak', 'adiek'), ('bapak', 'kakak'), ('bapak', 'adiek')]
# Miningir_(Lunga)_mini1251.csv
# [("'na", 'turaná'), ("'na", 'tasiná'), ("'na", 'tasiná'), ('tamaná', 'turaná'), ('tamaná', 'tasiná'), ('tamaná', 'tasiná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ("'na", 'tasiná'), ("'na", 'tasiná'), ("'na", 'tasinavaviná'), ("'na", 'tasinavaviná'), ('tamaná', 'tasiná'), ('tamaná', 'tasiná'), ('tamaná', 'tasinavaviná'), ('tamaná', 'tasinavaviná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná')]
# Mono-Alu_mono1273.csv
# None
# Morgan1871_Hawaiian_hawa1245.csv
# [("kǔ´-ǔ mä-kǔ'-ǎ kä´-na", 'kǔ´-ǔ käǐ´-kǔ-ä-ä´-nä'), ("kǔ´-ǔ mä-kǔ'-ǎ kä´-na", 'kǔ´-ǔ käǐ´ käǐ´-nä'), ("kǔ´-ǔ mä-kǔ'-ǎ kä´-na", 'kǔ´-ǔ käǐ´-kǔ wä-hee´-na'), ("kǔ´-ǔ mä-kǔ'-ǎ kä´-na", 'kǔ´-ǔ käǐ´-kǔ wä-heé-nä'), ("kǔ´-ǔ mä-kǔ'-ǎ kä'-na", 'kǔ´-ǔ käǐ´-kǔ-ä-ä´-nä'), ("kǔ´-ǔ mä-kǔ'-ǎ kä'-na", 'kǔ´-ǔ käǐ´ käǐ´-nä'), ("kǔ´-ǔ mä-kǔ'-ǎ kä'-na", 'kǔ´-ǔ käǐ´-kǔ wä-hee´-na'), ("kǔ´-ǔ mä-kǔ'-ǎ kä'-na", 'kǔ´-ǔ käǐ´-kǔ wä-heé-nä'), ("kǔ´-ǔ mä-kǔ'-ǎ kä´-na", 'kǔ´-ǔ käǐ´-kǔ-nǎ´-na'), ("kǔ´-ǔ mä-kǔ'-ǎ kä´-na", 'kǔ´-ǔ käǐ´-kǔ-nä´-nä'), ("kǔ´-ǔ mä-kǔ'-ǎ kä´-na", 'kǔ´-ǔ käǐ´-kǔ-ä-ä`-nä'), ("kǔ´-ǔ mä-kǔ'-ǎ kä´-na", 'kǔ´-ǔ käǐ´-läǐ-nä'), ("kǔ´-ǔ mä-kǔ'-ǎ kä'-na", 'kǔ´-ǔ käǐ´-kǔ-nǎ´-na'), ("kǔ´-ǔ mä-kǔ'-ǎ kä'-na", 'kǔ´-ǔ käǐ´-kǔ-nä´-nä'), ("kǔ´-ǔ mä-kǔ'-ǎ kä'-na", 'kǔ´-ǔ käǐ´-kǔ-ä-ä`-nä'), ("kǔ´-ǔ mä-kǔ'-ǎ kä'-na", 'kǔ´-ǔ käǐ´-läǐ-nä')]
# Morgan1871_Kings_Mill_Islands_gilb1244.csv
# Morgan1871_Kusaien_kosr1238.csv
# Morgan1871_Maori_maor1246.csv
# Mori_Atas_mori1269.csv
# [('ine', 'andi'), ('ine', 'kaka'), ('ine', 'andi'), ('uma', 'andi'), ('uma', 'kaka'), ('uma', 'andi'), ('ine', 'kaka'), ('ine', 'andi'), ('ine', 'kaka'), ('ine', 'andi'), ('uma', 'kaka'), ('uma', 'andi'), ('uma', 'kaka'), ('uma', 'andi')]
# Mori_Bawah_mori1268.csv
# [('ine', 'uai'), ('ine', 'aka'), ('ine', 'uai'), ('ama', 'uai'), ('ama', 'aka'), ('ama', 'uai'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('ine', 'aka'), ('ine', 'uai'), ('ine', 'aka'), ('ine', 'uai'), ('ama', 'aka'), ('ama', 'uai'), ('ama', 'aka'), ('ama', 'uai'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha')]
# Moronene_moro1287.csv
# [('tina', 'tuai'), ('tina', 'tukaka'), ('tina', 'tuai'), ('tama', 'tuai'), ('tama', 'tukaka'), ('tama', 'tuai'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('tina', 'tukaka'), ('tina', 'tuai'), ('tina', 'tukaka'), ('tina', 'tuai'), ('tama', 'tukaka'), ('tama', 'tuai'), ('tama', 'tukaka'), ('tama', 'tuai'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa')]
# Mortlockese_mort1237.csv
# [('iin', 'pwiipwi'), ('iin', 'mwengeang'), ('iin', 'mwengeang'), ('saam', 'pwiipwi'), ('saam', 'mwengeang'), ('saam', 'mwengeang'), ('tattalin saam', 'tattalin pwiipwi'), ('tattalin saam', 'tattalin mwengeang'), ('tattalin saam', 'tattalin pwiipwi'), ('tattalin saam', 'tattalin mwengeang'), ('tattalin saam', 'tattalin pwiipwi'), ('tattalin saam', 'tattalin mwengeang'), ('tattalin saam', 'tattalin pwiipwi'), ('tattalin saam', 'tattalin mwengeang'), ('tattalin iin', 'tattalin pwiipwi'), ('tattalin iin', 'tattalin mwengeang'), ('tattalin iin', 'tattalin pwiipwi'), ('tattalin iin', 'tattalin mwengeang'), ('tattalin iin', 'tattalin pwiipwi'), ('tattalin iin', 'tattalin mwengeang'), ('tattalin iin', 'tattalin pwiipwi'), ('tattalin iin', 'tattalin mwengeang'), ('iin', 'mwengeang'), ('iin', 'mwengeang'), ('iin', 'pwiipwi'), ('iin', 'pwiipwi'), ('saam', 'mwengeang'), ('saam', 'mwengeang'), ('saam', 'pwiipwi'), ('saam', 'pwiipwi'), ('tattalin saam', 'tattalin pwiipwi'), ('tattalin saam', 'tattalin mwengeang'), ('tattalin saam', 'tattalin pwiipwi'), ('tattalin saam', 'tattalin mwengeang'), ('tattalin saam', 'tattalin pwiipwi'), ('tattalin saam', 'tattalin mwengeang'), ('tattalin saam', 'tattalin pwiipwi'), ('tattalin saam', 'tattalin mwengeang'), ('tattalin iin', 'tattalin pwiipwi'), ('tattalin iin', 'tattalin mwengeang'), ('tattalin iin', 'tattalin pwiipwi'), ('tattalin iin', 'tattalin mwengeang'), ('tattalin iin', 'tattalin pwiipwi'), ('tattalin iin', 'tattalin mwengeang'), ('tattalin iin', 'tattalin pwiipwi'), ('tattalin iin', 'tattalin mwengeang')]
# Mota_mota1237.csv
# [('veve', 'tasiu, tasmatagaraqa'), ('veve', 'tutuai'), ('veve', 'tutuai'), ('tamak', 'tasiu, tasmatagaraqa'), ('tamak', 'tutuai'), ('tamak', 'tutuai'), ('maraui', 'natui'), ('maraui', 'natui'), ('maraui', 'natui'), ('maraui', 'natui'), ('vevegae', 'tamai'), ('vevegae', 'veve'), ('vevegae', 'tamai'), ('vevegae', 'veve'), ('veve', 'tutuai'), ('veve', 'tutuai'), ('veve', 'tuaga'), ('veve', 'tasiu'), ('tamak', 'tutuai'), ('tamak', 'tutuai'), ('tamak', 'tuaga'), ('tamak', 'tasiu'), ('maraui', 'natui'), ('maraui', 'natui'), ('maraui', 'natui'), ('maraui', 'natui'), ('vevegae', 'tamai'), ('vevegae', 'veve'), ('vevegae', 'tamai'), ('vevegae', 'veve')]
# Motu_motu1246.csv
# [('sinagu', 'tadigu'), ('sinagu', 'taihugu'), ('sinagu', 'taihugu'), ('tamagu', 'tadigu'), ('tamagu', 'taihugu'), ('tamagu', 'taihugu'), ('sinagu', 'taihugu'), ('sinagu', 'taihugu'), ('sinagu', 'kakagu'), ('sinagu', 'tadigu'), ('tamagu', 'taihugu'), ('tamagu', 'taihugu'), ('tamagu', 'kakagu'), ('tamagu', 'tadigu')]
# Mouk_mouk1240.csv
# [('ide', 'agatno'), ('ide', 'lutno'), ('ide', 'lutno'), ('ilau', 'agatno'), ('ilau', 'lutno'), ('ilau', 'lutno'), ('tumno', 'adou'), ('tumno', 'lutno'), ('tumno', 'adou'), ('tumno', 'lutno'), ('babu', 'aten'), ('babu', 'aten'), ('babu, ide', 'aten'), ('babu, ide', 'aten'), ('babu', 'adou'), ('babu', 'lutno'), ('babu', 'adou'), ('babu', 'lutno'), ('ide', 'lutno'), ('ide', 'lutno'), ('ide', 'atua'), ('ide', 'agatno'), ('ilau', 'lutno'), ('ilau', 'lutno'), ('ilau', 'atua'), ('ilau', 'agatno'), ('tumno', 'lutno'), ('tumno', 'adou'), ('tumno', 'lutno'), ('tumno', 'adou'), ('babu, ide', 'adou'), ('babu, ide', 'aten'), ('babu, ide', 'adou'), ('babu, ide', 'aten'), ('babu', 'lutno'), ('babu', 'adou'), ('babu', 'lutno'), ('babu', 'adou')]
# Muduapa_(Vitu)_mudu1242.csv
# [('titina-na', 'tazi-na'), ('titina-na', 'livuk-'), ('titina-na', 'livuk-'), ('tama-na', 'tazi-na'), ('tama-na', 'livuk-'), ('tama-na', 'livuk-'), ('tama-na', 'tazi kapou'), ('tama-na', 'tazi kapou'), ('tama-na', 'tazi kapou'), ('tama-na', 'tazi kapou'), ('vahapa-na', 'tazi kapou'), ('vahapa-na', 'tazi kapou'), ('vahapa-na', 'tazi kapou'), ('vahapa-na', 'tazi kapou'), ('titina-na', 'livuk-'), ('titina-na', 'livuk-'), ('titina-na', 'tazi-na'), ('titina-na', 'tazi-na'), ('tama-na', 'livuk-'), ('tama-na', 'livuk-'), ('tama-na', 'tazi-na'), ('tama-na', 'tazi-na'), ('tama-na', 'tazi kapou'), ('tama-na', 'tazi kapou'), ('tama-na', 'tazi kapou'), ('tama-na', 'tazi kapou'), ('vahapa-na', 'tazi kapou'), ('vahapa-na', 'tazi kapou'), ('vahapa-na', 'tazi kapou'), ('vahapa-na', 'tazi kapou')]
# Muna_muna1247.csv
# [('ina', 'ai'), ('ina', 'isa'), ('ina', 'ai'), ('ama', 'ai'), ('ama', 'isa'), ('ama', 'ai'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('ina', 'isa'), ('ina', 'ai'), ('ina', 'isa'), ('ina', 'ai'), ('ama', 'isa'), ('ama', 'ai'), ('ama', 'isa'), ('ama', 'ai'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa')]
# Munggava_(Rennell)_mung1271.csv
# [('tinana', 'taina'), ('tinana', 'tua-hine'), ('tinana', 'tua-hine'), ('tamana', 'taina'), ('tamana', 'tua-hine'), ('tamana', 'tua-hine'), ('tua-tina', "ha'anga"), ('tua-tina', "ha'anga"), ("tua-tina, tau tu'aatina", "ha'anga"), ("tua-tina, tau tu'aatina", "ha'anga"), ('tinau', "ha'anga"), ('tinau', "ha'anga"), ('tinau', "ha'anga"), ('tinau', "ha'anga"), ('tinana', "tua-nga'ane"), ('tinana', "tua-nga'ane"), ('tinana', 'tau-kete'), ('tinana', 'taina'), ('tamana', "tua-nga'ane"), ('tamana', "tua-nga'ane"), ('tamana', 'tau-kete'), ('tamana', 'taina'), ("tua-tina, tau tu'aatina", "ha'anga"), ("tua-tina, tau tu'aatina", "ha'anga"), ("tua-tina, tau tu'aatina", "ha'anga"), ("tua-tina, tau tu'aatina", "ha'anga"), ('tinau', "ha'anga"), ('tinau', "ha'anga"), ('tinau', "ha'anga"), ('tinau', "ha'anga")]
# Mungiki_(Bellona)_mung1270.csv
# None
# Mussau-Emira_muss1246.csv
# [('kina-', 'nenga-'), ('kina-', 'tue-'), ('kina-', 'nenga-'), ('tama-', 'nenga-'), ('tama-', 'tue-'), ('tama-', 'nenga-'), ('kina-', 'tue-'), ('kina-', 'nenga-'), ('kina-', 'tue-'), ('kina-', 'nenga-'), ('tama-', 'tue-'), ('tama-', 'nenga-'), ('tama-', 'tue-'), ('tama-', 'nenga-')]
# Mwotlap_motl1237.csv
# [('ivēk', 'ithik'), ('ivēk', 'tētek'), ('ivēk', 'tētek'), ('itmek', 'ithik'), ('itmek', 'tētek'), ('itmek', 'tētek'), ('itat', 'ithik'), ('itat', 'tētek'), ('itat', 'ithik'), ('itat', 'tētek'), ('itmek', 'ithik'), ('itmek', 'tētek'), ('itmek, imam', 'ithik'), ('itmek, imam', 'tētek'), ('ivēk', 'ithik'), ('ivēk', 'tētek'), ('ivēk, tita', 'ithik'), ('ivēk, tita', 'tētek'), ('titamas', 'ithik'), ('titamas', 'tētek'), ('titamas, ivep', 'ithik'), ('titamas, ivep', 'tētek'), ('ivēk', 'tētek'), ('ivēk', 'tētek'), ('ivēk', 'ithik'), ('ivēk', 'ithik'), ('itmek', 'tētek'), ('itmek', 'tētek'), ('itmek', 'ithik'), ('itmek', 'ithik'), ('itat', 'tētek'), ('itat', 'ithik'), ('itat', 'tētek'), ('itat', 'ithik'), ('itmek, imam', 'tētek'), ('itmek, imam', 'ithik'), ('itmek, imam', 'tētek'), ('itmek, imam', 'ithik'), ('ivēk, tita', 'tētek'), ('ivēk, tita', 'ithik'), ('ivēk, tita', 'tētek'), ('ivēk, tita', 'ithik'), ('titamas, ivep', 'tētek'), ('titamas, ivep', 'ithik'), ('titamas, ivep', 'tētek'), ('titamas, ivep', 'ithik')]
# Māori_maor1246.csv
# Nafsan_sout2856.csv
# [('iak', 'tai ses'), ('iak', 'tet kpur'), ('iak', 'tet ses'), ('apap', 'tai ses'), ('apap', 'tet kpur'), ('apap', 'tet ses'), ('iak', 'tai'), ('iak', 'tai ses'), ('iak', 'tet kpur'), ('iak', 'tet ses'), ('apap', 'tai'), ('apap', 'tai ses'), ('apap', 'tet kpur'), ('apap', 'tet ses')]
# Nage_nage1237.csv
# [('ine', 'azi'), ('ine', 'weta'), ('ine', 'weta'), ('ame', 'azi'), ('ame', 'weta'), ('ame', 'weta'), ('ine', 'na'), ('ine', 'na'), ('ine', "ka'e"), ('ine', 'azi'), ('ame', 'na'), ('ame', 'na'), ('ame', "ka'e"), ('ame', 'azi')]
# Nahavaq_sout2857.csv
# [('hine-', 'hala-, tesi-'), ('hine-', 'vene-'), ('hine-', 'vene-'), ('teme-', 'hala-, tesi-'), ('teme-', 'vene-'), ('teme-', 'vene-'), ('hine-', 'mwene-'), ('hine-', 'mwene-'), ('hine-', 'hala-'), ('hine-', 'hala-'), ('teme-', 'mwene-'), ('teme-', 'mwene-'), ('teme-', 'hala-'), ('teme-', 'hala-')]
# Nakanai_naka1262.csv
# [('tila', 'e-hatamale-(la)'), ('tila', 'hatavile-(la)'), ('tila', 'hatavile-(la)'), ('tama-(la)', 'e-hatamale-(la)'), ('tama-(la)', 'hatavile-(la)'), ('tama-(la)', 'hatavile-(la)'), ('hala-(la)', 'e-hatamale-(la)'), ('hala-(la)', 'hatavile-(la)'), ('hala-(la)', 'e-hatamale-(la)'), ('hala-(la)', 'hatavile-(la)'), ('tama-(la) uru', 'e-hatamale-(la)'), ('tama-(la) uru', 'hatavile-(la)'), ('tama-(la) bisi', 'e-hatamale-(la)'), ('tama-(la) bisi', 'hatavile-(la)'), ('tila uru', 'e-hatamale-(la)'), ('tila uru', 'hatavile-(la)'), ('tila bisi', 'e-hatamale-(la)'), ('tila bisi', 'hatavile-(la)'), ('hala-(la)', 'e-hatamale-(la)'), ('hala-(la)', 'hatavile-(la)'), ('hala-(la), isa-(la)', 'e-hatamale-(la)'), ('hala-(la), isa-(la)', 'hatavile-(la)'), ('tila', 'e-hatamale-(la)'), ('tila', 'e-hatamale-(la)'), ('tila', 'hatavile-(la)'), ('tila', 'hatavile-(la)'), ('tama-(la)', 'e-hatamale-(la)'), ('tama-(la)', 'e-hatamale-(la)'), ('tama-(la)', 'hatavile-(la)'), ('tama-(la)', 'hatavile-(la)'), ('hala-(la)', 'e-hatamale-(la)'), ('hala-(la)', 'hatavile-(la)'), ('hala-(la)', 'e-hatamale-(la)'), ('hala-(la)', 'hatavile-(la)'), ('tama-(la) uru, tete uru', 'e-hatamale-(la)'), ('tama-(la) uru, tete uru', 'hatavile-(la)'), ('tama-(la) bisi, tete bisi', 'e-hatamale-(la)'), ('tama-(la) bisi, tete bisi', 'hatavile-(la)'), ('tila uru', 'e-hatamale-(la)'), ('tila uru', 'hatavile-(la)'), ('tila bisi', 'e-hatamale-(la)'), ('tila bisi', 'hatavile-(la)'), ('hala-(la), isa-(la)', 'e-hatamale-(la)'), ('hala-(la), isa-(la)', 'hatavile-(la)'), ('hala-(la), isa-(la)', 'e-hatamale-(la)'), ('hala-(la), isa-(la)', 'hatavile-(la)')]
# Nalik_(Lukuramau)_nali1244.csv
# [('namg', 'diagu'), ('namg', 'dimafingu'), ('namg', 'dimafingu'), ('tamang', 'diagu'), ('tamang', 'dimafingu'), ('tamang', 'dimafingu'), ('mogorugu', 'fagu'), ('mogorugu', 'kaiasgu'), ('mogorugu', 'fagu'), ('mogorugu', 'kaiasgu'), ('tamang', 'diagu'), ('tamang', 'dimafingu'), ('tamang', 'diagu'), ('tamang', 'dimafingu'), ('kogol', 'fagu'), ('kogol', 'kaiasgu'), ('kogol', 'fagu'), ('kogol', 'kaiasgu'), ('namg', 'diagu'), ('namg', 'diagu'), ('namg', 'diagu'), ('namg', 'diagu'), ('tamang', 'diagu'), ('tamang', 'diagu'), ('tamang', 'diagu'), ('tamang', 'diagu'), ('tamang', 'dimafingu'), ('tamang', 'dimafingu'), ('kogol', 'fagu'), ('kogol', 'kaiasgu, aiamung'), ('kogol', 'fagu'), ('kogol', 'kaiasgu, aiamung')]
# Nalik_(Madina)_nali1244b.csv
# [('naga', 'dasigu'), ('naga', 'fafnagu'), ('naga', 'fafnagu'), ('mago', 'dasigu'), ('mago', 'fafnagu'), ('mago', 'fafnagu'), ('mogorugu', 'fagu'), ('mogorugu', 'agasugu'), ('mogorugu', 'fagu'), ('mogorugu', 'agasugu'), ('mago', 'fafnagu'), ('mago, mama', 'fafnagu'), ('naga', 'fafnagu'), ('naga', 'fafnagu'), ('naga', 'duagu'), ('naga', 'duagu'), ('mago', 'fafnagu'), ('mago', 'fafnagu'), ('mago', 'duagu'), ('mago', 'duagu'), ('mogorugu', 'fagu, agasugu'), ('mogorugu', 'agasugu, alismara, karasigu'), ('mogorugu', 'fagu, agasugu'), ('mogorugu', 'agasugu, alismara, karasigu'), ('mago, mama', 'fafnagu'), ('mago, mama', 'fafnagu'), ('mago, mama', 'fafnagu'), ('mago, mama', 'fafnagu')]
# Namakura_nama1268.csv
# [('anuh', 'suan, titi'), ('anuh', 'ngkoren'), ('anuh', 'ngkoren, nana'), ('taman', 'suan, titi'), ('taman', 'ngkoren'), ('taman', 'ngkoren, nana'), ('lolo', 'hivang'), ('lolo', 'vain'), ('lolo, tavalin', 'hivang'), ('lolo, tavalin', 'vain'), ('taman', 'hivang'), ('taman', 'vain'), ('taman, aba, poop', 'hivang'), ('taman, aba, poop', 'vain'), ('anuh', 'hivang'), ('anuh', 'vain'), ('anuh, bwilamw', 'hivang'), ('anuh, bwilamw', 'vain'), ('miim', 'hivang'), ('miim', 'vain'), ('miim, vingon', 'hivang'), ('miim, vingon', 'vain'), ('anuh', 'suan'), ('anuh', 'suan, titi'), ('anuh', 'ngkoren, nana'), ('anuh', 'ngkoren, nana'), ('taman', 'suan'), ('taman', 'suan, titi'), ('taman', 'ngkoren, nana'), ('taman', 'ngkoren, nana'), ('lolo, tavalin', 'hivang, tawian'), ('lolo, tavalin', 'vain, tawian'), ('lolo, tavalin', 'hivang, tawian'), ('lolo, tavalin', 'vain, tawian'), ('taman, aba, poop', 'hivang, tawian'), ('taman, aba, poop', 'vain, tawian'), ('taman, aba, poop', 'hivang, tawian'), ('taman, aba, poop', 'vain, tawian'), ('anuh, bwilamw', 'hivang, tawian'), ('anuh, bwilamw', 'vain, tawian'), ('anuh, bwilamw', 'hivang, tawian'), ('anuh, bwilamw', 'vain, tawian'), ('miim, vingon', 'hivang, tawian'), ('miim, vingon', 'vain, tawian'), ('miim, vingon', 'hivang, tawian'), ('miim, vingon', 'vain, tawian')]
# Namakura_nama1268b.csv
# [('anu', 'suaŋ'), ('anu', 'alik'), ('anu', 'alik, ngoreŋ'), ('tama', 'suaŋ'), ('tama', 'alik'), ('tama', 'alik, ngoreŋ'), ('anu', 'titih'), ('anu', 'titih'), ('anu', 'nana'), ('anu', 'nana'), ('tama', 'titih'), ('tama', 'titih'), ('tama', 'nana'), ('tama', 'nana')]
# Naman_litz1237.csv
# [('nane', 'havungk'), ('nane', 'vövönungk'), ('nane', 'vövönungk'), ('tate', 'havungk'), ('tate', 'vövönungk'), ('tate', 'vövönungk'), ('bimbi', 'netungk'), ('bimbi', 'netungk'), ('bimbi', 'netungk'), ('bimbi', 'netungk'), ('vave', 'tat uve'), ('vave', 'vave'), ('vave', 'tat uve'), ('vave', 'vave'), ('nane', 'manungk'), ('nane', 'manungk'), ('nane', 'tugangk'), ('nane', 'naaruongk'), ('tate', 'manungk'), ('tate', 'manungk'), ('tate', 'tugangk'), ('tate', 'naaruongk'), ('bimbi', 'netungk'), ('bimbi', 'netungk'), ('bimbi', 'netungk'), ('bimbi', 'netungk'), ('vave', 'tat uve'), ('vave', 'vave'), ('vave', 'tat uve'), ('vave', 'vave')]
# Nanggu_nang1262.csv
# [('ite', 'myei'), ('ite', 'plapyei'), ('ite', 'plapyei'), ('yei', 'myei'), ('yei', 'plapyei'), ('yei', 'plapyei'), ('ite', 'wei'), ('ite', 'wei'), ('ite', 'opyei'), ('ite', 'opyei'), ('yei', 'wei'), ('yei', 'wei'), ('yei', 'opyei'), ('yei', 'opyei')]
# Nehan_neha1247.csv
# [('tinan', 'tahin'), ('tinan', 'tatahinalik'), ('tinan', 'tatahinalik'), ('taman', 'tahin'), ('taman', 'tatahinalik'), ('taman', 'tatahinalik'), ('kabin', 'turak'), ('kabin', 'turak'), ('kabin', 'turak'), ('kabin', 'turak'), ('kabin', 'matmatatahinaliki'), ('kabin', 'turak'), ('kabin', 'matmatatahinaliki'), ('kabin', 'turak'), ('tinan', 'tatahinalik'), ('tinan', 'tatahinalik'), ('tinan', 'tahinalik'), ('tinan', 'tahinalik'), ('taman', 'tatahinalik'), ('taman', 'tatahinalik'), ('taman', 'tahinalik'), ('taman', 'tahinalik'), ('totuen', 'turak'), ('totuen', 'turak'), ('totuen', 'turak'), ('totuen', 'turak'), ('totuen', 'matmatatahinaliki'), ('totuen', 'turak'), ('totuen', 'matmatatahinaliki'), ('totuen', 'turak')]
# Nengone_neng1238.csv
# [('hmaien', 'cel, celuaien'), ('hmaien', 'mama'), ('hmaien', 'resingen'), ('caca', 'cel, celuaien'), ('caca', 'mama'), ('caca', 'resingen'), ('caca', 'reisingen'), ('caca', 'reisingen'), ('caca', 'reisingen'), ('caca, cicango', 'reisingen'), ('hmaien', 'reisingen'), ('hmaien', 'reisingen'), ('cekin', 'reisingen'), ('cekin', 'reisingen'), ('hmaien', 'mama'), ('hmaien', 'cel'), ('hmaien', 'mama'), ('caca', 'mama'), ('caca', 'cel'), ('caca', 'mama'), ('caca', 'reisingen'), ('caca', 'reisingen'), ('caca, cicango', 'reisingen'), ('caca, cicango', 'reisingen'), ('hmaien', 'reisingen'), ('hmaien', 'reisingen'), ('cekin', 'reisingen'), ('cekin', 'reisingen')]
# Nese_nese1235.csv
# [("b'ev'e", 'tas-'), ("b'ev'e", 'jokhos-'), ("b'ev'e", 'jokhos-'), ('nerra-', 'tas-'), ('nerra-', 'jokhos-'), ('nerra-', 'jokhos-'), ('vave', 'vave vakharru'), ('vave', 'vave vakharru'), ("b'ev'e", 'tua-'), ("b'ev'e", 'tua-'), ("b'ev'e", 'tua-'), ("b'ev'e", 'tas-'), ('nerra-', 'tua-'), ('nerra-', 'tua-'), ('nerra-', 'tua-'), ('nerra-', 'tas-'), ('vave', 'vave vakharru'), ('vave', 'vave vakharru')]
# Neve'ei_vinm1237.csv
# [('nangk', 'tasungk'), ('nangk', 'vivinungk'), ('nangk', 'vivinungk'), ('mamwe', 'tasungk'), ('mamwe', 'vivinungk'), ('mamwe', 'vivinungk'), ('vimbi', 'natungk'), ('vimbi', 'natungk'), ('vimbi', 'natungk'), ('vimbi', 'natungk'), ('mamwe lamp', 'tuangk'), ('mamwe lamp', 'vivinungk'), ('mamwe', 'tasungk'), ('mamwe', 'vivinungk'), ('vavwe', 'lelel'), ('vavwe', 'vavwe'), ('vavwe', 'lelel'), ('vavwe', 'vavwe'), ('nangk', 'manungk'), ('nangk', 'manungk'), ('nangk', 'tuangk'), ('nangk', 'tasungk'), ('mamwe', 'manungk'), ('mamwe', 'manungk'), ('mamwe', 'tuangk'), ('mamwe', 'tasungk'), ('vimbi', 'natungk'), ('vimbi', 'natungk'), ('vimbi', 'natungk'), ('vimbi', 'natungk'), ('mamwe lamp', 'manungk'), ('mamwe lamp', 'tuangk'), ('mamwe', 'manungk'), ('mamwe', 'tasungk'), ('vavwe', 'lelel'), ('vavwe', 'vavwe'), ('vavwe', 'lelel'), ('vavwe', 'vavwe')]
# Neve'ei_vinm1237a.csv
# None
# Neverver_ling1265.csv
# [('nida', 'tas(t)n'), ('nida', 'vivin'), ('nida', 'vivin'), ('mama', 'tas(t)n'), ('mama', 'vivin'), ('mama', 'vivin'), ('bibi tokhtokh', 'salan'), ('bibi tokhtokh', 'salan'), ('bibi lele', 'salan'), ('bibi lele', 'salan'), ('mama tokhtokh', 'salan'), ('mama tokhtokh', 'salan'), ('mama lele', 'salan'), ('mama lele', 'salan'), ('nida tokhtokh', 'salan'), ('nida tokhtokh', 'salan'), ('nida lele', 'salan'), ('nida lele', 'salan'), ('nida tokhtokh', 'mama'), ('nida tokhtokh', 'nida'), ('nida lele', 'mama'), ('nida lele', 'nida'), ('nida', 'tatan'), ('nida', 'tas(t)n'), ('nida', 'vivin'), ('nida', 'vivin'), ('mama', 'tatan'), ('mama', 'tas(t)n'), ('mama', 'vivin'), ('mama', 'vivin'), ('bibi tokhtokh', 'salan'), ('bibi tokhtokh', 'salan'), ('bibi lele', 'salan'), ('bibi lele', 'salan'), ('mama tokhtokh', 'salan'), ('mama tokhtokh', 'salan'), ('mama lele', 'salan'), ('mama lele', 'salan'), ('nida tokhtokh', 'salan'), ('nida tokhtokh', 'salan'), ('nida lele', 'salan'), ('nida lele', 'salan'), ('nida tokhtokh', 'mama'), ('nida tokhtokh', 'nida'), ('nida lele', 'mama'), ('nida lele', 'nida')]
# Nguna_ngun1274.csv
# [('tétè', 'tay'), ('tétè', 'ngoreng'), ('tétè', 'ngoreng'), ('mama', 'tay'), ('mama', 'ngoreng'), ('mama', 'ngoreng'), ('aloa', 'natungu nanoay'), ('aloa', 'nanungu nangoroy'), ('aloa', 'natungu nanoay'), ('aloa', 'nanungu nangoroy'), ('tétè', 'tay'), ('tétè', 'ngoreng'), ('tétè', 'tay'), ('tétè', 'ngoreng'), ('mimi', 'mama'), ('mimi', 'mimi'), ('mimi', 'mama'), ('mimi', 'mimi'), ('tétè', 'tay'), ('tétè', 'tay'), ('tétè', 'ngoreng'), ('tétè', 'ngoreng'), ('mama', 'tay'), ('mama', 'tay'), ('mama', 'ngoreng'), ('mama', 'ngoreng'), ('aloa', 'natungu nanoay'), ('aloa', 'nanungu nangoroy'), ('aloa', 'natungu nanoay'), ('aloa', 'nanungu nangoroy'), ('tétè', 'tay'), ('tétè', 'ngoreng'), ('tétè', 'tay'), ('tétè', 'ngoreng'), ('mimi', 'mama'), ('mimi', 'mimi'), ('mimi', 'mama'), ('mimi', 'mimi')]
# Niuafo'ou_niua1240.csv
# [("fa'ee", 'tokoua'), ("fa'ee", 'tuafafine'), ("fa'ee", 'tuafafine'), ('tamai', 'tokoua'), ('tamai', 'tuafafine'), ('tamai', 'tuafafine'), ("fa'ee", "tuaga'ane"), ("fa'ee", "tuaga'ane"), ("fa'ee", 'tokoua'), ("fa'ee", 'tokoua'), ('tamai', "tuaga'ane"), ('tamai', "tuaga'ane"), ('tamai', 'tokoua'), ('tamai', 'tokoua')]
# Niueans_niue1239.csv
# [('matua fifine', 'taokete'), ('matua fifine', 'tehina'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua tane', 'taokete'), ('matua tane', 'tehina'), ('matua tane', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'taokete'), ('matua tane', 'tehina'), ('matua tane', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'taokete'), ('matua tane', 'tehina'), ('matua tane', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'taokete'), ('matua fifine', 'tehina'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'taokete'), ('matua fifine', 'tehina'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'taokete'), ('matua fifine', 'tehina'), ('matua tane', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'taokete'), ('matua tane', 'tehina'), ('matua tane', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'taokete'), ('matua tane', 'tehina'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'taokete'), ('matua tane', 'tehina'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'taokete'), ('matua fifine', 'tehina'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'taokete'), ('matua fifine', 'tehina'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga')]
# Niue_niue1239.csv
# North_Ambrym_nort2839.csv
# [('ina', 'taovjen'), ('ina', 'talang'), ('ina', 'talang'), ('teta', 'taovjen'), ('teta', 'talang'), ('teta', 'talang'), ('mesong', 'mesong'), ('mesong', 'mesong'), ('raheng', 'tubiung'), ('raheng', 'tubiung'), ('ina', 'talang'), ('ina', 'talang'), ('ina', 'talang'), ('ina', 'talang'), ('teta', 'talang'), ('teta', 'talang'), ('teta', 'talang'), ('teta', 'talang'), ('mesong', 'tubiung'), ('mesong', 'jaleng wehen'), ('mesong', 'tubiung'), ('mesong', 'jaleng wehen')]
# North_Efate_(Nguna,_Nakanamanga)_nort2836.csv
# [('tete', 'tay'), ('tete', 'ngoreng'), ('tete', 'ngoreng'), ('mama', 'tay'), ('mama', 'ngoreng'), ('mama', 'ngoreng'), ('tete', 'tay'), ('tete', 'tay'), ('tete', 'ngoreng'), ('tete', 'ngoreng'), ('mama', 'tay'), ('mama', 'tay'), ('mama', 'ngoreng'), ('mama', 'ngoreng')]
# North_Marquesan_nort2845.csv
# [('motua', 'Tuaana'), ('motua', 'teina'), ('motua', 'tuehine'), ('motua', 'tuehine'), ('tunane', 'Tuaana'), ('tunane', 'teina'), ('tunane', 'tuehine'), ('tunane', 'tuehine'), ('tunane', 'tuehine'), ('tunane', 'tuehine'), ('tunane', 'Tuaana'), ('tunane', 'tuehine'), ('motua', 'Tuaana'), ('motua', 'teina'), ('motua', 'tuehine'), ('motua', 'tuehine'), ('motua', 'tuehine'), ('motua', 'tuehine'), ('teina motua', 'Tuaana'), ('teina motua', 'tuehine'), ("Tu'ana kui", 'tuehine'), ('tuehine', 'Tuaana'), ('tuehine', 'teina'), ('tuehine', 'tuehine'), ('tuehine', 'tuehine'), ('tuehine', 'tuehine'), ('tuehine', 'tuehine'), ('tuehine', 'Tuaana'), ('tuehine', 'tuehine'), ('motua', 'tunane'), ('motua', 'tunane'), ('motua', 'tunane'), ('motua', 'Tuaana'), ('motua', 'teina'), ('tunane', 'tunane'), ('tunane', 'tunane'), ('tunane', 'tunane'), ('tunane', 'Tuaana'), ('tunane', 'teina'), ('tunane', 'tunane'), ('tunane', 'tunane'), ('tunane', 'Tuaana'), ('motua', 'tunane'), ('motua', 'tunane'), ('motua', 'tunane'), ('motua', 'Tuaana'), ('motua', 'teina'), ('motua', 'tunane'), ('teina motua', 'tunane'), ('teina motua', 'Tuaana'), ("Tu'ana kui", 'tunane'), ('tuehine', 'tunane'), ('tuehine', 'tunane'), ('tuehine', 'tunane'), ('tuehine', 'Tuaana'), ('tuehine', 'teina'), ('tuehine', 'tunane'), ('tuehine', 'tunane'), ('tuehine', 'Tuaana')]
# North_Tanna_nort2847.csv
# [('itə', 'notah'), ('itə', 'kaka'), ('itə', 'kaka, wɨnɨ'), ('tɨm', 'notah'), ('tɨm', 'kaka'), ('tɨm', 'kaka, wɨnɨ'), ('etəmaa', 'rəh iel'), ('etəmaa', 'rəh iel'), ('etəmaa', 'rəh iel'), ('etəmaa', 'rəh iel'), ('itə', 'kaka'), ('itə', 'kaka'), ('itə', 'tu p̃ia'), ('itə', 'notah'), ('tɨm', 'kaka'), ('tɨm', 'kaka'), ('tɨm', 'tu p̃ia'), ('tɨm', 'notah'), ('etəmaa', 'rəh iel'), ('etəmaa', 'rəh iel'), ('etəmaa', 'rəh iel'), ('etəmaa', 'rəh iel')]
# Numbami_numb1247.csv
# [('tina', 'kapa'), ('tina', 'lunewe'), ('tina', 'lunewe'), ('tama', 'kapa'), ('tama', 'lunewe'), ('tama', 'lunewe'), ('wowa', 'gode'), ('wowa', 'godenewe'), ('wowa', 'gode'), ('wowa', 'godenewe'), ('tama', 'sika'), ('tama', 'lunewe'), ('mama kae', 'kapa'), ('mama kae', 'lunewe'), ('tina', 'sika'), ('tina', 'lunewe'), ('awa kae', 'kapa'), ('awa kae', 'lunewe'), ('wawe', 'gode'), ('wawe', 'godenewe'), ('wawe', 'gode'), ('wawe', 'godenewe'), ('tina', 'lu'), ('tina', 'lu'), ('tina', 'sikanewe'), ('tina', 'kapowe'), ('tama', 'lu'), ('tama', 'lu'), ('tama', 'sikanewe'), ('tama', 'kapowe'), ('wowa', 'gode'), ('wowa', 'godenewe'), ('wowa', 'gode'), ('wowa', 'godenewe'), ('tama, mama', 'lu'), ('tama, mama', 'sikanewe'), ('mama kae', 'lu'), ('mama kae', 'kapowe'), ('tina, awa', 'lu'), ('tina, awa', 'sikanewe'), ('awa kae', 'lu'), ('awa kae', 'kapowe'), ('wawe', 'gode'), ('wawe', 'godenewe'), ('wawe', 'gode'), ('wawe', 'godenewe')]
# Olal_olal1237.csv
# [('erahing', 'taling'), ('erahing', 'taling'), ('erahing', 'taling'), ('tete', 'taling'), ('tete', 'taling'), ('tete', 'taling'), ('mosong', 'tubung'), ('mosong', 'tubung'), ('mosong', 'tubung'), ('mosong', 'tubung'), ('idning', 'mabung'), ('idning', 'mabung'), ('idning', 'mabung'), ('idning', 'mabung'), ('erahing', 'maningeri'), ('erahing', 'maningeri'), ('erahing', 'taling'), ('erahing', 'taling'), ('tete', 'maningeri'), ('tete', 'maningeri'), ('tete', 'taling'), ('tete', 'taling'), ('mosong', 'tubung'), ('mosong', 'wurung'), ('mosong', 'tubung'), ('mosong', 'wurung'), ('idning', 'wurung'), ('idning', 'wurung'), ('idning', 'wurung'), ('idning', 'wurung')]
# Old_Javanese_(Kawi)_kawi1241.csv
# None
# Old_Rapa_(Rapa)_rapa1245.csv
# [('metuua vahine', 'teina'), ('metuua vahine', 'tauahine'), ('metuua vahine', 'tauahine'), ('metuua taane', 'teina'), ('metuua taane', 'tauahine'), ('metuua taane', 'tauahine'), ('metuua vahine', "tu'aane"), ('metuua vahine', "tu'aane"), ('metuua vahine', "tua'ana"), ('metuua vahine', 'teina'), ('metuua taane', "tu'aane"), ('metuua taane', "tu'aane"), ('metuua taane', "tua'ana"), ('metuua taane', 'teina')]
# Ontong_Java_onto1237.csv
# [('kiŋa', 'kaiŋa'), ('kiŋa', 'kaiŋa'), ('kiŋa', 'kaiŋa'), ('kiŋa', "'ave"), ('kiŋa', "'ave"), ('kiŋa', "'ave"), ('kamaŋa', 'kaiŋa'), ('kamaŋa', 'kaiŋa'), ('kamaŋa', 'kaiŋa'), ('kamaŋa', "'ave"), ('kamaŋa', "'ave"), ('kamaŋa', "'ave"), ('lamoku', 'kaiŋa'), ('lamoku', 'ɧaŋau'), ('lamoku', 'ɧaŋau'), ('lamoku', "'ave"), ('lamoku', "'ave"), ('lamoku', "'ave"), ('lamoku', 'kaiŋa'), ('lamoku', "'ave"), ('lamoku', 'kaiŋa'), ('lamoku', "'ave"), ('kamaŋa', 'kaiŋa'), ('kamaŋa', 'ɧaŋau'), ('kamaŋa', 'ɧaŋau'), ('kamaŋa', "'ave"), ('kamaŋa', "'ave"), ('kamaŋa', "'ave"), ('kamaŋa', 'kaiŋa'), ('kamaŋa', "'ave"), ('kamaŋa', 'kaiŋa'), ('kamaŋa', "'ave"), ('kiŋa', 'kaiŋa'), ('kiŋa', 'ɧaŋau'), ('kiŋa', 'ɧaŋau'), ('kiŋa', "'ave"), ('kiŋa', "'ave"), ('kiŋa', "'ave"), ('kiŋa', 'kaiŋa'), ('kiŋa', "'ave"), ('kiŋa', 'kaiŋa'), ('kiŋa', "'ave"), ('kiŋa', 'kaiŋa'), ('kiŋa', 'ɧaŋau'), ('kiŋa', 'ɧaŋau'), ('kiŋa', "'ave"), ('kiŋa', "'ave"), ('kiŋa', "'ave"), ('kiŋa', 'kaiŋa'), ('kiŋa', "'ave"), ('kiŋa', 'kaiŋa'), ('kiŋa', "'ave"), ('kiŋa', "'ave"), ('kiŋa', "'ave"), ('kiŋa', "'ave"), ('kiŋa', 'kaiŋa'), ('kiŋa', 'kaiŋa'), ('kiŋa', 'kaiŋa'), ('kamaŋa', "'ave"), ('kamaŋa', "'ave"), ('kamaŋa', "'ave"), ('kamaŋa', 'kaiŋa'), ('kamaŋa', 'kaiŋa'), ('kamaŋa', 'kaiŋa'), ('lamoku', "'ave"), ('lamoku', "'ave"), ('lamoku', "'ave"), ('lamoku', 'kaiŋa'), ('lamoku', 'ɧaŋau'), ('lamoku', 'ɧaŋau'), ('lamoku', "'ave"), ('lamoku', 'kaiŋa'), ('lamoku', "'ave"), ('lamoku', 'kaiŋa')]
# Owa_(Santa_Ana)_owaa1237.csv
# [('enana', 'wafaisina, esina, farigoana, goana mereana, sika'), ('enana', 'kafaisina'), ('enana', 'kafaisina'), ('emana', 'wafaisina, esina, farigoana, goana mereana, sika'), ('emana', 'kafaisina'), ('emana', 'kafaisina'), ('enana', 'wafaisina'), ('enana', 'wafaisina'), ('enana', 'kafaisina, ewana, farigoana, goana mereana'), ('enana', 'kafaisina'), ('emana', 'wafaisina'), ('emana', 'wafaisina'), ('emana', 'kafaisina, ewana, farigoana, goana mereana'), ('emana', 'kafaisina')]
# Padoe_pado1242.csv
# [('ine', 'hai'), ('ine', 'kaka'), ('ine', 'hai'), ('uma', 'hai'), ('uma', 'kaka'), ('uma', 'hai'), ('ine', 'kaka'), ('ine', 'hai'), ('ine', 'kaka'), ('ine', 'hai'), ('uma', 'kaka'), ('uma', 'hai'), ('uma', 'kaka'), ('uma', 'hai')]
# Paici_paic1239.csv
# [('nyââ', 'aajii, pwi jii'), ('nyââ', 'ciè'), ('nyââ', 'aajii'), ('caa', 'aajii, pwi jii'), ('caa', 'ciè'), ('caa', 'aajii'), ('aunîa', 'böru'), ('aunîa', 'böru'), ('aunîa, aunéaa', 'böru'), ('aunîa, aunéaa', 'böru'), ('caa', 'ciè'), ('caa', 'ciè'), ('caa', 'ciè'), ('caa', 'ciè'), ('nyââ', 'aajii'), ('nyââ', 'aajii'), ('nyââ', 'aajii'), ('nyââ', 'aajii'), ('pankaa', 'böru'), ('pankaa', 'böru'), ('pankaa, köaa', 'böru'), ('pankaa, köaa', 'böru'), ('nyââ', 'ciè'), ('nyââ', 'aajii'), ('nyââ', 'ciè'), ('nyââ', 'aajii'), ('caa', 'ciè'), ('caa', 'aajii'), ('caa', 'ciè'), ('caa', 'aajii'), ('aunîa, aunéaa', 'böru'), ('aunîa, aunéaa', 'böru'), ('aunîa, aunéaa', 'böru'), ('aunîa, aunéaa', 'böru'), ('caa', 'ciè'), ('caa', 'ciè'), ('caa', 'ciè'), ('caa', 'ciè'), ('nyââ', 'aajii'), ('nyââ', 'aajii'), ('nyââ', 'aajii'), ('nyââ', 'aajii'), ('pankaa, köaa', 'böru'), ('pankaa, köaa', 'böru'), ('pankaa, köaa', 'böru'), ('pankaa, köaa', 'böru')]
# Paiwan_paiw1248.csv
# None
# Palauan_pala1344.csv
# [('chadíl', 'merreng(ék), chochel(ék)'), ('chadíl', 'chochad(ák)'), ('chadíl', 'chochad(ák)'), ('chadám', 'merreng(ék), chochel(ék)'), ('chadám', 'chochad(ák)'), ('chadám', 'chochad(ák)'), ('desik', 'ngelekir a ruchad'), ('desik', 'ngelekir a ruchad'), ('desik, kladesióil', 'ngelekir a ruchad'), ('desik, kladesióil', 'ngelekir a ruchad'), ('desik', 'ngalekodám'), ('desik', 'ngalekodám'), ('desik, kladesióil', 'ngalekodám'), ('desik, kladesióil', 'ngalekodám'), ('chadíl', 'chochad(ák)'), ('chadíl', 'chochad(ák)'), ('chadíl', 'chudel(ék)'), ('chadíl', 'merreng(ék)'), ('chadám', 'chochad(ák)'), ('chadám', 'chochad(ák)'), ('chadám', 'chudel(ék)'), ('chadám', 'merreng(ék)'), ('desik', 'ngalekdós'), ('desik', 'ngalekdós'), ('desik, kladesióil', 'ngalekdós'), ('desik, kladesióil', 'ngalekdós'), ('desik', 'ngelekir a ruchad'), ('desik', 'ngelekir a ruchad'), ('desik, kladesióil', 'ngelekir a ruchad'), ('desik, kladesióil', 'ngelekir a ruchad')]
# Paluai_balu1257.csv
# ...
# Hopi_S__hopi1249b.csv
# None
# Huastec_Nahuatl_huas1257.csv
# None
# Huichol_huic1243.csv
# None
# Kawaiisu_kawa1283.csv
# [('piya', "čaka'i"), ('piya', 'pazi'), ('piya', "nami'i"), ('muwa', "čaka'i"), ('muwa', 'pazi'), ('muwa', "nami'i"), ('piya', 'pavi'), ('piya', "čaka'i"), ('piya', 'pazi'), ('piya', "nami'i"), ('muwa', 'pavi'), ('muwa', "čaka'i"), ('muwa', 'pazi'), ('muwa', "nami'i")]
# Kitanemuk_serr1255b.csv
# None
# Lower_Pima_Pima_Bajo_pima1248.csv
# None
# Luiseńo_luis1253.csv
# [('yó', "páá'aʂ"), ('yó', 'péét'), ('yó', "qee'is"), ('yó', 'píít'), ("-ná'", "páá'aʂ"), ("-ná'", 'péét'), ("-ná'", "qee'is"), ("-ná'", 'píít'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ('kamú', 'kwámay'), ('máʂ', 'má$'), ('núʂ', 'máay'), ('núʂ', 'máay'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('yó', "páá'aʂ"), ('yó', 'péét'), ('yó', "qee'is"), ('yó', 'píít'), ("-ná'", "páá'aʂ"), ("-ná'", 'péét'), ("-ná'", "qee'is"), ("-ná'", 'píít'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ("táá'aʂ", 'yúkʂum'), ('kamú', 'kwámay'), ('máʂ', 'má$'), ('núʂ', 'máay'), ('núʂ', 'máay'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum'), ('páa-may', 'yúkʂum')]
# Mayo_mayo1264.csv
# [('aiye', 'waáyi'), ('hapči', 'waáyi'), ('aiye', 'ábači'), ('aiye', 'ákoro'), ('aiye', 'waáyi'), ('hapči', 'ábači'), ('hapči', 'ákoro'), ('hapči', 'waáyi')]
# Mono_mono1275.csv
# [('píya', 'pabí'), ('píya', 'waná'), ('píya', 'sau'), ('píya', 'hama'), ('píya', "pïnni'(a)"), ('nawa', 'pabí'), ('nawa', 'waná'), ('nawa', 'sau'), ('nawa', 'hama'), ('nawa', "pïnni'(a)"), ('píya', 'sau'), ('píya', 'pabí'), ('píya', 'waná'), ('píya', 'boso'), ('píya', "pïnni'(a)"), ('nawa', 'sau'), ('nawa', 'pabí'), ('nawa', 'waná'), ('nawa', 'boso'), ('nawa', "pïnni'(a)")]
# Morgan1871_Utahs_(Tabegwaches)_utes1238.csv
# Nevome_pima1248b.csv
# None
# Northern_Paiute_nort2954.csv
# [('pia', "wannka'a"), ('pia', "pïni'i"), ("naa'a", "wannka'a"), ("naa'a", "pïni'i"), ('pia', "pabi'i"), ('pia', "wannka'a"), ('pia', "pïni'i"), ("naa'a", "pabi'i"), ("naa'a", "wannka'a"), ("naa'a", "pïni'i")]
# Northern_Tepehuan_nort2959.csv
# [('naan', 'šiïïgï'), ('naan', 'sisi'), ('óóka', 'šiïïgï'), ('óóka', 'sisi'), ('naan', 'šiïïgï'), ('naan', 'sisi'), ('óóka', 'šiïïgï'), ('óóka', 'sisi')]
# North_Northern_Paiute_nort1551.csv
# [('pīa', "bañá'a"), ('pīa', "amá'"), ('pīa', "böní'i"), ("iná'a", "bañá'a"), ("iná'a", "amá'"), ("iná'a", "böní'i"), ("āts'i", "bāBí'i"), ("āts'i", "bañá'a"), ("āts'i", "amá'"), ("āts'i", "böní'i"), ("hɛ᷅'i", "bāBí'i"), ("hɛ᷅'i", "bañá'a"), ("hɛ᷅'i", "amá'"), ("hɛ᷅'i", "böní'i"), ("pirú'u", "bāBí'i"), ("pirú'u", "bañá'a"), ("pirú'u", "amá'"), ("pirú'u", "böní'i"), ("pa'wá", "bāBí'i"), ("pa'wá", "bañá'a"), ("pa'wá", "amá'"), ("pa'wá", "böní'i"), ('pīa', "bāBí'i"), ('pīa', "bañá'a"), ('pīa', "amá'"), ('pīa', "böní'i"), ("iná'a", "bāBí'i"), ("iná'a", "bañá'a"), ("iná'a", "amá'"), ("iná'a", "böní'i"), ("āts'i", "bāBí'i"), ("āts'i", "bañá'a"), ("āts'i", "amá'"), ("āts'i", "böní'i"), ("hɛ᷅'i", "bāBí'i"), ("hɛ᷅'i", "bañá'a"), ("hɛ᷅'i", "amá'"), ("hɛ᷅'i", "böní'i"), ("pirú'u", "bāBí'i"), ("pirú'u", "bañá'a"), ("pirú'u", "amá'"), ("pirú'u", "böní'i"), ("pa'wá", "bāBí'i"), ("pa'wá", "bañá'a"), ("pa'wá", "amá'"), ("pa'wá", "böní'i")]
# Opata_opat1246.csv
# [('deguat', 'vapaci'), ('deguat', 'vonigua'), ('deguat', 'cotziguat'), ('deguat', 'viniwa'), ('mas', 'vapaci'), ('mas', 'vonigua'), ('mas', 'cotziguat'), ('mas', 'viniwa'), ('cutziguat', 'maguât'), ('cutziguat', 'maguât'), ('taiguat', 'maguât'), ('taiguat', 'maguât'), ('cumuguat', 'maguât'), ('cumuguat', 'maguât'), ('teviriguat', 'maguât'), ('teviriguat', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('tepó', 'maguât'), ('tepó', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deguat', 'vapaci'), ('deguat', 'vonigua'), ('deguat', 'cochiguat'), ('deguat', 'cotziguat'), ('deguat', 'viniwa'), ('mas', 'vapaci'), ('mas', 'vonigua'), ('mas', 'cochiguat'), ('mas', 'cotziguat'), ('mas', 'viniwa'), ('cutziguat', 'maguât'), ('cutziguat', 'maguât'), ('aiguat', 'maguât'), ('aiguat', 'maguât'), ('cumuguat', 'maguât'), ('cumuguat', 'maguât'), ('teviriguat', 'maguât'), ('teviriguat', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('tepó', 'maguât'), ('tepó', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât'), ('deri-', 'maguât')]
# Pima_de_Yepáchic_chih1238.csv
# None
# Pipil_pipi1250.csv
# None
# Serrano_serr1255.csv
# [("yï'", 'paar'), ("yï'", 'pö˞it'), ("yï'", '-qöö˞r'), ("yï'", 'piit'), ("-na'", 'paar'), ("-na'", 'pö˞it'), ("-na'", '-qöö˞r'), ("-na'", 'piit'), ('taar', "puyu'"), ('taar', "puyu'"), ('taar', "puyu'"), ('taar', "noko'"), ('taar', "noko'"), ('taar', "noko'"), ('taar', "puyu'"), ('taar', "noko'"), ('taar', "puyu'"), ('taar', "noko'"), ('kuumu', 'pas'), ('kuumu', 'kör'), ('maq', 'prit'), ('maq', 'pit'), ('nïm', 'pas'), ('yïïr', 'prit'), ("yï'", 'hamut'), ("yï'", 'paar'), ("yï'", 'pö˞it'), ("yï'", '-qöö˞r'), ("yï'", 'piit'), ("-na'", 'hamut'), ("-na'", 'paar'), ("-na'", 'pö˞it'), ("-na'", '-qöö˞r'), ("-na'", 'piit'), ('kuumu', "puyu'"), ('kuumu', "noko'"), ('taar', 'pas'), ('taar', 'kör'), ('maq', 'prit'), ('maq', 'pit'), ('nïm', 'pas'), ('yür', 'prit'), ('pah', "puyu'"), ('pah', "puyu'"), ('pah', "puyu'"), ('pah', "noko'"), ('pah', "noko'"), ('pah', "noko'"), ('pah', "puyu'"), ('pah', "noko'"), ('yïïr', "puyu'"), ('yïïr', "noko'")]
# Shoshoni_shos1248.csv
# [('pii', 'tami'), ('pii', 'paci'), ('pii', 'nammi'), ('appï', 'tami'), ('appï', 'paci'), ('appï', 'nammi'), ('pii', 'papi'), ('pii', 'tami'), ('pii', 'paci'), ('pii', 'nammi'), ('appï', 'papi'), ('appï', 'tami'), ('appï', 'paci'), ('appï', 'nammi')]
# Southeastern_Tepehuano_sout2976.csv
# [('naan', 'jaduuñ'), ('naan', 'xiix'), ('naan', 'xiku'), ('naan', 'jaduuñ'), ('naan', 'xiix'), ('naan', 'jaduuñ'), ('taat', 'jaduuñ'), ('taat', 'xiix'), ('taat', 'xiku'), ('taat', 'jaduuñ'), ('taat', 'xiix'), ('taat', 'jaduuñ'), ('kuuxi', 'jaduuñ'), ('kuuxi', 'jaduuñ'), ('tataalh', 'jaduuñ'), ('tataalh', 'jaduuñ'), ('kilhi', 'jaduuñ'), ('kilhi', 'jaduuñ'), ('jiikulh', 'jaduuñ'), ('jiikulh', 'jaduuñ'), ("o'kix", 'jaduuñ'), ("o'kix", 'jaduuñ'), ('paasulh', 'jaduuñ'), ('paasulh', 'jaduuñ'), ('naan', 'jaduuñ'), ('naan', 'xiix'), ('naan', 'xiku'), ('naan', 'jaduuñ'), ('naan', 'xiix'), ('naan', 'jaduuñ'), ('taat', 'jaduuñ'), ('taat', 'xiix'), ('taat', 'xiku'), ('taat', 'jaduuñ'), ('taat', 'xiix'), ('taat', 'jaduuñ'), ('kuuxi', 'jaduuñ'), ('kuuxi', 'jaduuñ'), ('tataalh', 'jaduuñ'), ('tataalh', 'jaduuñ'), ('kilhi', 'jaduuñ'), ('kilhi', 'jaduuñ'), ('jiikulh', 'jaduuñ'), ('jiikulh', 'jaduuñ'), ("o'kix", 'jaduuñ'), ("o'kix", 'jaduuñ'), ('paasulh', 'jaduuñ'), ('paasulh', 'jaduuñ')]
# Southern_Paiute_sout2969.csv
# [('pia', 'cahkai'), ('pia', 'paci-'), ('pia', 'nami-(n)ci'), ('moa', 'cahkai'), ('moa', 'paci-'), ('moa', 'nami-(n)ci'), ('ai-', 'ai-'), ('ai-', 'ai-'), ('ai-', 'ai-'), ('ai-', 'ai-'), ('ai-', 'ai-'), ('ai-', 'ai-'), ('ai-', 'ai-'), ('ai-', 'ai-'), ('ai-', 'ai-'), ('ai-', 'ai-'), ('paha', 'ai-'), ('paha', 'ai-'), ('paha', 'ai-'), ('paha', 'ai-'), ('paha', 'ai-'), ('paá', 'ai-'), ('paá', 'ai-'), ('paá', 'ai-'), ('paá', 'ai-'), ('paá', 'ai-'), ('pia', 'papi-ci'), ('pia', 'cahkai'), ('pia', 'paci-'), ('pia', 'nami-(n)ci'), ('moa', 'papi-ci'), ('moa', 'cahkai'), ('moa', 'paci-'), ('moa', 'nami-(n)ci')]
# Southern_Tepehuan_sout2975.csv
# [('innan', "sïpji'n"), ('innan', 'šiiš'), ('innan', "sïpji'n"), ("'oo'", "sïpji'n"), ("'oo'", 'šiiš'), ("'oo'", "sïpji'n"), ('innan', 'šiiš'), ('innan', "sïpji'n"), ('innan', 'šiiš'), ('innan', "sïpji'n"), ("'oo'", 'šiiš'), ("'oo'", "sïpji'n"), ("'oo'", 'šiiš'), ("'oo'", "sïpji'n")]
# Southern_Tepehuan_W__sout2977.csv
# None
# Southern_Ute_utee1244.csv
# [('piany', 'cahkany'), ('muany', 'cahkany'), ('pany', 'papiny'), ('pany', 'cahkany'), ('pany', 'paciny'), ('pany', 'naminy'), ('piany', 'papiny'), ('piany', 'cahkany'), ('muany', 'papiny'), ('muany', 'cahkany'), ('pany', 'papiny'), ('pany', 'cahkany'), ('pany', 'paciny'), ('pany', 'naminy')]
# Tarahumara_cent2131.csv
# [('(y)eyé', 'rijimara'), ('(y)eyé', "ba'či"), ('(y)eyé', 'boní'), ('(y)eyé', "go'či"), ('(y)eyé', 'wayé'), ('onó', 'rijimara'), ('onó', "ba'či"), ('onó', 'boní'), ('onó', "go'či"), ('onó', 'wayé'), ("ri'chirá", 'boní'), ("ri'chirá", 'boní'), ("ri'chirá", "ra'terá"), ('kurichi', "ra'téchiwa"), ("ra'té", "ra'techi"), ('kumú-či', 'boní'), ('kumú-či', 'boní'), ('kumú-či', 'boní'), ('kumú-či', 'boní'), ('kumú-či', 'boní'), ('baporá', 'boní'), ('baporá', 'boní'), ('baporá', 'boní'), ('soró', 'boní'), ('apó', 'boní'), ('(y)eyé', 'rijimara'), ('(y)eyé', "ba'či"), ('(y)eyé', 'boní'), ('(y)eyé', "go'či"), ('(y)eyé', 'biní'), ('onó', 'rijimara'), ('onó', "ba'či"), ('onó', 'boní'), ('onó', "go'či"), ('onó', 'biní'), ("ri'chirá", 'boní'), ("ri'chirá", 'boní'), ("ri'chirá", "ra'terá"), ('kurichi', "ra'techiwa"), ("ri'chirá", "ra'techi"), ('kumú-či', 'boní'), ('kumú-či', 'boní'), ('kumú-či', 'boní'), ('kumú-či', 'boní'), ('kumú-či', 'boní'), ('baporá', 'boní'), ('baporá', 'boní'), ('baporá', 'boní'), ('soró', 'boní'), ('apó', 'boní')]
# Tohono_O_odham_toho1245.csv
# None
# Tubar_tuba1279.csv
# [('inyá-r', 'woní'), ('inyá-r', 'kocí'), ('inyá-r', 'wací-r'), ('inyá-r', 'woní'), ('inyá-r', 'kocí')]
# Tübatülabal_tuba1278.csv
# [("'aabuu", 'kuudzin'), ("'aanaa", 'kuudzin'), ("'aabuu", 'paadzi'), ("'aabuu", 'kuudzin'), ("'aanaa", 'paadzi'), ("'aanaa", 'kuudzin')]
# Tümpisha_Shoshoni_pana1305.csv
# [('pia', 'tami(ttsi)'), ('pia', 'patsi'), ('pia', 'nammi(ttsi)'), ('appü', 'tami(ttsi)'), ('appü', 'patsi'), ('appü', 'nammi(ttsi)'), ('piasamoppu', 'tangumpua'), ('piasamoppu', 'papi'), ('piasamoppu', 'tami'), ('piasamoppu', 'samoppu'), ('piasamoppu', 'samoppu'), ('piasamoppu', 'samoppu'), ('piasamoppu', 'tangumpua'), ('piasamoppu', 'samoppu'), ('piasamoppu', 'tangumpua'), ('piasamoppu', 'samoppu'), ('tsukuna', 'tangumpua'), ('tsukuna', 'papi'), ('tsukuna', 'tami'), ('tsukuna', 'samoppu'), ('tsukuna', 'samoppu'), ('tsukuna', 'samoppu'), ('tsukuna', 'tangumpua'), ('tsukuna', 'samoppu'), ('tsukuna', 'tangumpua'), ('tsukuna', 'samoppu'), ('tokkwattsi', 'tangumpua'), ('tokkwattsi', 'papi'), ('tokkwattsi', 'tami'), ('tokkwattsi', 'samoppu'), ('tokkwattsi', 'samoppu'), ('tokkwattsi', 'samoppu'), ('tokkwattsi', 'tangumpua'), ('tokkwattsi', 'samoppu'), ('tokkwattsi', 'tangumpua'), ('tokkwattsi', 'samoppu'), ('pahwa', 'tangumpua'), ('pahwa', 'papi'), ('pahwa', 'tami'), ('pahwa', 'samoppu'), ('pahwa', 'samoppu'), ('pahwa', 'samoppu'), ('pahwa', 'tangumpua'), ('pahwa', 'samoppu'), ('pahwa', 'tangumpua'), ('pahwa', 'samoppu'), ('pia', 'samompu'), ('pia', 'papi'), ('pia', 'tami(ttsi)'), ('pia', 'patsi'), ('pia', 'nammi(ttsi)'), ('appü', 'samompu'), ('appü', 'papi'), ('appü', 'tami(ttsi)'), ('appü', 'patsi'), ('appü', 'nammi(ttsi)'), ('piasamoppu', 'tangumpua'), ('piasamoppu', 'papi'), ('piasamoppu', 'tami'), ('piasamoppu', 'samoppu'), ('piasamoppu', 'samoppu'), ('piasamoppu', 'samoppu'), ('piasamoppu', 'tangumpua'), ('piasamoppu', 'samoppu'), ('piasamoppu', 'tangumpua'), ('piasamoppu', 'samoppu'), ('tsukuna', 'tangumpua'), ('tsukuna', 'papi'), ('tsukuna', 'tami'), ('tsukuna', 'samoppu'), ('tsukuna', 'samoppu'), ('tsukuna', 'samoppu'), ('tsukuna', 'tangumpua'), ('tsukuna', 'samoppu'), ('tsukuna', 'tangumpua'), ('tsukuna', 'samoppu'), ('tokkwattsi', 'tangumpua'), ('tokkwattsi', 'papi'), ('tokkwattsi', 'tami'), ('tokkwattsi', 'samoppu'), ('tokkwattsi', 'samoppu'), ('tokkwattsi', 'samoppu'), ('tokkwattsi', 'tangumpua'), ('tokkwattsi', 'samoppu'), ('tokkwattsi', 'tangumpua'), ('tokkwattsi', 'samoppu'), ('pahwa', 'tangumpua'), ('pahwa', 'papi'), ('pahwa', 'tami'), ('pahwa', 'samoppu'), ('pahwa', 'samoppu'), ('pahwa', 'samoppu'), ('pahwa', 'tangumpua'), ('pahwa', 'samoppu'), ('pahwa', 'tangumpua'), ('pahwa', 'samoppu')]
# Western_Shoshoni_west2622.csv
# None
# White_Mesa_Ute_utee1244b.csv
# None
# Yaqui_yaqu1251.csv
# [('áewa', 'pale'), ('áewa', 'ako'), ('áewa', 'wai'), ('achai', 'pale'), ('achai', 'ako'), ('achai', 'wai'), ('áewa', 'abachi'), ('áewa', 'wai'), ('áewa', 'ako'), ('áewa', 'wai'), ('achai', 'abachi'), ('achai', 'wai'), ('achai', 'ako'), ('achai', 'wai')]
# 789
#                           language language_family      code simulation_code  \
# 0    Maguindanao_(Magindonao_Moro)    Austronesian  magu1243   magu1243_REAL
# 1                        Malua_Bay    Austronesian  malu1245   malu1245_REAL
# 2                            Manam    Austronesian  mana1295   mana1295_REAL
# 3                          Mangaia    Austronesian  mang1402   mang1402_REAL
# 4                      Mangarevans    Austronesian  mang1401   mang1401_REAL
# ..                             ...             ...       ...             ...
# 784                     Tarahumara     Uto-Aztecan  cent2131   cent2131_REAL
# 785                          Tubar     Uto-Aztecan  tuba1279   tuba1279_REAL
# 786                    Tübatülabal     Uto-Aztecan  tuba1278   tuba1278_REAL
# 787              Tümpisha_Shoshoni     Uto-Aztecan  pana1305   pana1305_REAL
# 788                          Yaqui     Uto-Aztecan  yaqu1251   yaqu1251_REAL
#
#     simulation  mutual_information  entropy_gn  entropy_gn1  \
# 0            N        7.918584e-01    1.916127     1.791858
# 1            N        1.530125e+00    2.840224     1.996792
# 2            N        2.220446e-16    1.950212     1.000000
# 3            N        2.220446e-16    1.950212     1.000000
# 4            N        1.929532e-01    2.182068     1.969414
# ..         ...                 ...         ...          ...
# 784          N        1.069937e+00    2.311737     2.827474
# 785          N        0.000000e+00    1.521928    -0.000000
# 786          N        0.000000e+00    0.918296     1.000000
# 787          N        5.748216e-01    2.354384     2.483356
# 788          N        0.000000e+00    1.842371     1.000000
#
#      conditional_entropy  variation_gn  variation_gn1  number_of_pairs
# 0               1.000000             5              4               10
# 1               0.466667             8              4               13
# 2               1.000000             4              2                8
# 3               1.000000             4              2                8
# 4               1.776461             5              6               18
# ..                   ...           ...            ...              ...
# 784             1.757538            10              9               22
# 785            -0.000000             3              1                3
# 786             1.000000             2              2                4
# 787             1.908534             8              6               26
# 788             1.000000             4              2                8
#
# [789 rows x 12 columns]

# %% [markdown]
# And if we want to run a simulation on a single language family:

# %%
ics_simulation(['Austronesian'],family_filepath,10)
# Out:
# [{'language': 'Sa',
#   'language_family': 'Austronesian',
#   'code': 'saaa1241',
#   'simulation_code': 'saaa1241_0',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Sa',
#   'language_family': 'Austronesian',
#   'code': 'saaa1241',
#   'simulation_code': 'saaa1241_1',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Sa',
#   'language_family': 'Austronesian',
#   'code': 'saaa1241',
#   'simulation_code': 'saaa1241_2',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Sa',
#   'language_family': 'Austronesian',
#   'code': 'saaa1241',
#   'simulation_code': 'saaa1241_3',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Sa',
#   'language_family': 'Austronesian',
#   'code': 'saaa1241',
#   'simulation_code': 'saaa1241_4',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Sa',
#   'language_family': 'Austronesian',
#   'code': 'saaa1241',
#   'simulation_code': 'saaa1241_5',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Sa',
#   'language_family': 'Austronesian',
#   'code': 'saaa1241',
#   'simulation_code': 'saaa1241_6',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Sa',
#   'language_family': 'Austronesian',
#   'code': 'saaa1241',
#   'simulation_code': 'saaa1241_7',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Sa',
#   'language_family': 'Austronesian',
#   'code': 'saaa1241',
#   'simulation_code': 'saaa1241_8',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Sa',
#   'language_family': 'Austronesian',
#   'code': 'saaa1241',
#   'simulation_code': 'saaa1241_9',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Namakura',
#   'language_family': 'Austronesian',
#   'code': 'nama1268b',
#   'simulation_code': 'nama1268b_0',
#   'simulation': 'Y',
#   'mutual_information': 0.20689978230284023,
#   'entropy_gn': 2.235926350629032,
#   'entropy_gn1': 1.4926140680171256,
#   'conditional_entropy': 1.2857142857142854,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 12},
#  {'language': 'Namakura',
#   'language_family': 'Austronesian',
#   'code': 'nama1268b',
#   'simulation_code': 'nama1268b_1',
#   'simulation': 'Y',
#   'mutual_information': 0.4926140680171258,
#   'entropy_gn': 2.235926350629032,
#   'entropy_gn1': 1.4926140680171256,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 10},
#  {'language': 'Namakura',
#   'language_family': 'Austronesian',
#   'code': 'nama1268b',
#   'simulation_code': 'nama1268b_2',
#   'simulation': 'Y',
#   'mutual_information': 0.4926140680171258,
#   'entropy_gn': 2.235926350629032,
#   'entropy_gn1': 1.4926140680171256,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 10},
#  {'language': 'Namakura',
#   'language_family': 'Austronesian',
#   'code': 'nama1268b',
#   'simulation_code': 'nama1268b_3',
#   'simulation': 'Y',
#   'mutual_information': 0.4926140680171258,
#   'entropy_gn': 2.235926350629032,
#   'entropy_gn1': 1.4926140680171256,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 10},
#  {'language': 'Namakura',
#   'language_family': 'Austronesian',
#   'code': 'nama1268b',
#   'simulation_code': 'nama1268b_4',
#   'simulation': 'Y',
#   'mutual_information': 0.20689978230284023,
#   'entropy_gn': 2.235926350629032,
#   'entropy_gn1': 1.4926140680171256,
#   'conditional_entropy': 1.2857142857142854,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 12},
#  {'language': 'Namakura',
#   'language_family': 'Austronesian',
#   'code': 'nama1268b',
#   'simulation_code': 'nama1268b_5',
#   'simulation': 'Y',
#   'mutual_information': 0.349756925159983,
#   'entropy_gn': 2.235926350629032,
#   'entropy_gn1': 1.4926140680171256,
#   'conditional_entropy': 1.1428571428571426,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 11},
#  {'language': 'Namakura',
#   'language_family': 'Austronesian',
#   'code': 'nama1268b',
#   'simulation_code': 'nama1268b_6',
#   'simulation': 'Y',
#   'mutual_information': 0.4926140680171258,
#   'entropy_gn': 2.235926350629032,
#   'entropy_gn1': 1.4926140680171256,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 10},
#  {'language': 'Namakura',
#   'language_family': 'Austronesian',
#   'code': 'nama1268b',
#   'simulation_code': 'nama1268b_7',
#   'simulation': 'Y',
#   'mutual_information': 0.349756925159983,
#   'entropy_gn': 2.235926350629032,
#   'entropy_gn1': 1.4926140680171256,
#   'conditional_entropy': 1.1428571428571426,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 11},
#  {'language': 'Namakura',
#   'language_family': 'Austronesian',
#   'code': 'nama1268b',
#   'simulation_code': 'nama1268b_8',
#   'simulation': 'Y',
#   'mutual_information': 0.349756925159983,
#   'entropy_gn': 2.235926350629032,
#   'entropy_gn1': 1.4926140680171256,
#   'conditional_entropy': 1.1428571428571426,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 11},
#  {'language': 'Namakura',
#   'language_family': 'Austronesian',
#   'code': 'nama1268b',
#   'simulation_code': 'nama1268b_9',
#   'simulation': 'Y',
#   'mutual_information': 0.349756925159983,
#   'entropy_gn': 2.235926350629032,
#   'entropy_gn1': 1.4926140680171256,
#   'conditional_entropy': 1.1428571428571426,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 11},
#  {'language': 'Woleaian',
#   'language_family': 'Austronesian',
#   'code': 'wole1240',
#   'simulation_code': 'wole1240_0',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': -0.0,
#   'entropy_gn1': 1.9182958340544896,
#   'conditional_entropy': 1.9182958340544893,
#   'variation_gn': 1,
#   'variation_gn1': 4,
#   'number_of_pairs': 4},
#  {'language': 'Woleaian',
#   'language_family': 'Austronesian',
#   'code': 'wole1240',
#   'simulation_code': 'wole1240_1',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': -0.0,
#   'entropy_gn1': 1.9182958340544896,
#   'conditional_entropy': 1.9182958340544893,
#   'variation_gn': 1,
#   'variation_gn1': 4,
#   'number_of_pairs': 4},
#  {'language': 'Woleaian',
#   'language_family': 'Austronesian',
#   'code': 'wole1240',
#   'simulation_code': 'wole1240_2',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': -0.0,
#   'entropy_gn1': 1.9182958340544896,
#   'conditional_entropy': 1.9182958340544893,
#   'variation_gn': 1,
#   'variation_gn1': 4,
#   'number_of_pairs': 4},
#  {'language': 'Woleaian',
#   'language_family': 'Austronesian',
#   'code': 'wole1240',
#   'simulation_code': 'wole1240_3',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': -0.0,
#   'entropy_gn1': 1.9182958340544896,
#   'conditional_entropy': 1.9182958340544893,
#   'variation_gn': 1,
#   'variation_gn1': 4,
#   'number_of_pairs': 4},
#  {'language': 'Woleaian',
#   'language_family': 'Austronesian',
#   'code': 'wole1240',
#   'simulation_code': 'wole1240_4',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': -0.0,
#   'entropy_gn1': 1.9182958340544896,
#   'conditional_entropy': 1.9182958340544893,
#   'variation_gn': 1,
#   'variation_gn1': 4,
#   'number_of_pairs': 4},
#  {'language': 'Woleaian',
#   'language_family': 'Austronesian',
#   'code': 'wole1240',
#   'simulation_code': 'wole1240_5',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': -0.0,
#   'entropy_gn1': 1.9182958340544896,
#   'conditional_entropy': 1.9182958340544893,
#   'variation_gn': 1,
#   'variation_gn1': 4,
#   'number_of_pairs': 4},
#  {'language': 'Woleaian',
#   'language_family': 'Austronesian',
#   'code': 'wole1240',
#   'simulation_code': 'wole1240_6',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': -0.0,
#   'entropy_gn1': 1.9182958340544896,
#   'conditional_entropy': 1.9182958340544893,
#   'variation_gn': 1,
#   'variation_gn1': 4,
#   'number_of_pairs': 4},
#  {'language': 'Woleaian',
#   'language_family': 'Austronesian',
#   'code': 'wole1240',
#   'simulation_code': 'wole1240_7',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': -0.0,
#   'entropy_gn1': 1.9182958340544896,
#   'conditional_entropy': 1.9182958340544893,
#   'variation_gn': 1,
#   'variation_gn1': 4,
#   'number_of_pairs': 4},
#  {'language': 'Woleaian',
#   'language_family': 'Austronesian',
#   'code': 'wole1240',
#   'simulation_code': 'wole1240_8',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': -0.0,
#   'entropy_gn1': 1.9182958340544896,
#   'conditional_entropy': 1.9182958340544893,
#   'variation_gn': 1,
#   'variation_gn1': 4,
#   'number_of_pairs': 4},
#  {'language': 'Woleaian',
#   'language_family': 'Austronesian',
#   'code': 'wole1240',
#   'simulation_code': 'wole1240_9',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': -0.0,
#   'entropy_gn1': 1.9182958340544896,
#   'conditional_entropy': 1.9182958340544893,
#   'variation_gn': 1,
#   'variation_gn1': 4,
#   'number_of_pairs': 4},
#  {'language': 'Nengone',
#   'language_family': 'Austronesian',
#   'code': 'neng1238',
#   'simulation_code': 'neng1238_0',
#   'simulation': 'Y',
#   'mutual_information': 0.4577018912487709,
#   'entropy_gn': 1.27187087275341,
#   'entropy_gn1': 2.4532068163114027,
#   'conditional_entropy': 1.9955049250626318,
#   'variation_gn': 5,
#   'variation_gn1': 6,
#   'number_of_pairs': 12},
#  {'language': 'Nengone',
#   'language_family': 'Austronesian',
#   'code': 'neng1238',
#   'simulation_code': 'neng1238_1',
#   'simulation': 'Y',
#   'mutual_information': 0.3616261407106873,
#   'entropy_gn': 1.363120568566631,
#   'entropy_gn1': 2.4532068163114027,
#   'conditional_entropy': 2.0915806756007154,
#   'variation_gn': 5,
#   'variation_gn1': 6,
#   'number_of_pairs': 14},
#  {'language': 'Nengone',
#   'language_family': 'Austronesian',
#   'code': 'neng1238',
#   'simulation_code': 'neng1238_2',
#   'simulation': 'Y',
#   'mutual_information': 0.607114513750296,
#   'entropy_gn': 1.27187087275341,
#   'entropy_gn1': 2.4532068163114027,
#   'conditional_entropy': 1.8460923025611067,
#   'variation_gn': 5,
#   'variation_gn1': 6,
#   'number_of_pairs': 12},
#  {'language': 'Nengone',
#   'language_family': 'Austronesian',
#   'code': 'neng1238',
#   'simulation_code': 'neng1238_3',
#   'simulation': 'Y',
#   'mutual_information': 0.3738263360488867,
#   'entropy_gn': 1.227402569259248,
#   'entropy_gn1': 2.4532068163114027,
#   'conditional_entropy': 2.079380480262516,
#   'variation_gn': 5,
#   'variation_gn1': 6,
#   'number_of_pairs': 13},
#  {'language': 'Nengone',
#   'language_family': 'Austronesian',
#   'code': 'neng1238',
#   'simulation_code': 'neng1238_4',
#   'simulation': 'Y',
#   'mutual_information': 0.320724461149021,
#   'entropy_gn': 1.363120568566631,
#   'entropy_gn1': 2.4532068163114027,
#   'conditional_entropy': 2.1324823551623817,
#   'variation_gn': 5,
#   'variation_gn1': 6,
#   'number_of_pairs': 14},
#  {'language': 'Nengone',
#   'language_family': 'Austronesian',
#   'code': 'neng1238',
#   'simulation_code': 'neng1238_5',
#   'simulation': 'Y',
#   'mutual_information': 0.46715412362342823,
#   'entropy_gn': 1.27187087275341,
#   'entropy_gn1': 2.4532068163114027,
#   'conditional_entropy': 1.9860526926879745,
#   'variation_gn': 5,
#   'variation_gn1': 6,
#   'number_of_pairs': 12},
#  {'language': 'Nengone',
#   'language_family': 'Austronesian',
#   'code': 'neng1238',
#   'simulation_code': 'neng1238_6',
#   'simulation': 'Y',
#   'mutual_information': 0.4739563917009251,
#   'entropy_gn': 1.363120568566631,
#   'entropy_gn1': 2.4532068163114027,
#   'conditional_entropy': 1.9792504246104776,
#   'variation_gn': 5,
#   'variation_gn1': 6,
#   'number_of_pairs': 12},
#  {'language': 'Nengone',
#   'language_family': 'Austronesian',
#   'code': 'neng1238',
#   'simulation_code': 'neng1238_7',
#   'simulation': 'Y',
#   'mutual_information': 0.4330547121392585,
#   'entropy_gn': 1.363120568566631,
#   'entropy_gn1': 2.4532068163114027,
#   'conditional_entropy': 2.020152104172144,
#   'variation_gn': 5,
#   'variation_gn1': 6,
#   'number_of_pairs': 12},
#  {'language': 'Nengone',
#   'language_family': 'Austronesian',
#   'code': 'neng1238',
#   'simulation_code': 'neng1238_8',
#   'simulation': 'Y',
#   'mutual_information': 0.4635874996909328,
#   'entropy_gn': 1.227402569259248,
#   'entropy_gn1': 2.4532068163114027,
#   'conditional_entropy': 1.9896193166204699,
#   'variation_gn': 5,
#   'variation_gn1': 6,
#   'number_of_pairs': 11},
#  {'language': 'Nengone',
#   'language_family': 'Austronesian',
#   'code': 'neng1238',
#   'simulation_code': 'neng1238_9',
#   'simulation': 'Y',
#   'mutual_information': 0.47645167054658355,
#   'entropy_gn': 1.5013397424044415,
#   'entropy_gn1': 2.4532068163114027,
#   'conditional_entropy': 1.9767551457648191,
#   'variation_gn': 5,
#   'variation_gn1': 6,
#   'number_of_pairs': 14},
#  {'language': 'Ontong_Java',
#   'language_family': 'Austronesian',
#   'code': 'onto1237',
#   'simulation_code': 'onto1237_0',
#   'simulation': 'Y',
#   'mutual_information': 0.044733151859731146,
#   'entropy_gn': 0.997772472089982,
#   'entropy_gn1': 1.5304930567574824,
#   'conditional_entropy': 1.4857599048977512,
#   'variation_gn': 2,
#   'variation_gn1': 3,
#   'number_of_pairs': 6},
#  {'language': 'Ontong_Java',
#   'language_family': 'Austronesian',
#   'code': 'onto1237',
#   'simulation_code': 'onto1237_1',
#   'simulation': 'Y',
#   'mutual_information': 0.10094403145492725,
#   'entropy_gn': 0.9910760598382222,
#   'entropy_gn1': 1.5304930567574824,
#   'conditional_entropy': 1.4295490253025551,
#   'variation_gn': 2,
#   'variation_gn1': 3,
#   'number_of_pairs': 6},
#  {'language': 'Ontong_Java',
#   'language_family': 'Austronesian',
#   'code': 'onto1237',
#   'simulation_code': 'onto1237_2',
#   'simulation': 'Y',
#   'mutual_information': 0.019631148872495396,
#   'entropy_gn': 0.997772472089982,
#   'entropy_gn1': 1.5304930567574824,
#   'conditional_entropy': 1.510861907884987,
#   'variation_gn': 2,
#   'variation_gn1': 3,
#   'number_of_pairs': 6},
#  {'language': 'Ontong_Java',
#   'language_family': 'Austronesian',
#   'code': 'onto1237',
#   'simulation_code': 'onto1237_3',
#   'simulation': 'Y',
#   'mutual_information': 0.01173289965472768,
#   'entropy_gn': 1.0,
#   'entropy_gn1': 1.5304930567574824,
#   'conditional_entropy': 1.5187601571027547,
#   'variation_gn': 2,
#   'variation_gn1': 3,
#   'number_of_pairs': 6},
#  {'language': 'Ontong_Java',
#   'language_family': 'Austronesian',
#   'code': 'onto1237',
#   'simulation_code': 'onto1237_4',
#   'simulation': 'Y',
#   'mutual_information': 0.004482886539597608,
#   'entropy_gn': 0.997772472089982,
#   'entropy_gn1': 1.5304930567574824,
#   'conditional_entropy': 1.5260101702178848,
#   'variation_gn': 2,
#   'variation_gn1': 3,
#   'number_of_pairs': 6},
#  {'language': 'Ontong_Java',
#   'language_family': 'Austronesian',
#   'code': 'onto1237',
#   'simulation_code': 'onto1237_5',
#   'simulation': 'Y',
#   'mutual_information': 0.004482886539597386,
#   'entropy_gn': 0.997772472089982,
#   'entropy_gn1': 1.5304930567574824,
#   'conditional_entropy': 1.526010170217885,
#   'variation_gn': 2,
#   'variation_gn1': 3,
#   'number_of_pairs': 6},
#  {'language': 'Ontong_Java',
#   'language_family': 'Austronesian',
#   'code': 'onto1237',
#   'simulation_code': 'onto1237_6',
#   'simulation': 'Y',
#   'mutual_information': 0.047486276237407754,
#   'entropy_gn': 1.0,
#   'entropy_gn1': 1.5304930567574824,
#   'conditional_entropy': 1.4830067805200746,
#   'variation_gn': 2,
#   'variation_gn1': 3,
#   'number_of_pairs': 6},
#  {'language': 'Ontong_Java',
#   'language_family': 'Austronesian',
#   'code': 'onto1237',
#   'simulation_code': 'onto1237_7',
#   'simulation': 'Y',
#   'mutual_information': 0.0805005306402673,
#   'entropy_gn': 0.9910760598382222,
#   'entropy_gn1': 1.5304930567574824,
#   'conditional_entropy': 1.449992526117215,
#   'variation_gn': 2,
#   'variation_gn1': 3,
#   'number_of_pairs': 6},
#  {'language': 'Ontong_Java',
#   'language_family': 'Austronesian',
#   'code': 'onto1237',
#   'simulation_code': 'onto1237_8',
#   'simulation': 'Y',
#   'mutual_information': 0.07196787384156811,
#   'entropy_gn': 0.997772472089982,
#   'entropy_gn1': 1.5304930567574824,
#   'conditional_entropy': 1.4585251829159143,
#   'variation_gn': 2,
#   'variation_gn1': 3,
#   'number_of_pairs': 6},
#  {'language': 'Ontong_Java',
#   'language_family': 'Austronesian',
#   'code': 'onto1237',
#   'simulation_code': 'onto1237_9',
#   'simulation': 'Y',
#   'mutual_information': 0.016836191577401127,
#   'entropy_gn': 1.0,
#   'entropy_gn1': 1.5304930567574824,
#   'conditional_entropy': 1.5136568651800812,
#   'variation_gn': 2,
#   'variation_gn1': 3,
#   'number_of_pairs': 6},
#  {'language': 'Pama_(Paamanese)',
#   'language_family': 'Austronesian',
#   'code': 'paam1238',
#   'simulation_code': 'paam1238_0',
#   'simulation': 'Y',
#   'mutual_information': 0.9852281360342515,
#   'entropy_gn': 2.1280852788913944,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 0.9999999999999999,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 10},
#  {'language': 'Pama_(Paamanese)',
#   'language_family': 'Austronesian',
#   'code': 'paam1238',
#   'simulation_code': 'paam1238_1',
#   'simulation': 'Y',
#   'mutual_information': 0.5916727785823275,
#   'entropy_gn': 2.1280852788913944,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.393555357451924,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 12},
#  {'language': 'Pama_(Paamanese)',
#   'language_family': 'Austronesian',
#   'code': 'paam1238',
#   'simulation_code': 'paam1238_2',
#   'simulation': 'Y',
#   'mutual_information': 0.5916727785823275,
#   'entropy_gn': 2.1280852788913944,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.393555357451924,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 12},
#  {'language': 'Pama_(Paamanese)',
#   'language_family': 'Austronesian',
#   'code': 'paam1238',
#   'simulation_code': 'paam1238_3',
#   'simulation': 'Y',
#   'mutual_information': 0.5916727785823275,
#   'entropy_gn': 2.1280852788913944,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.393555357451924,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 12},
#  {'language': 'Pama_(Paamanese)',
#   'language_family': 'Austronesian',
#   'code': 'paam1238',
#   'simulation_code': 'paam1238_4',
#   'simulation': 'Y',
#   'mutual_information': 0.9852281360342515,
#   'entropy_gn': 2.1280852788913944,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 0.9999999999999999,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 10},
#  {'language': 'Pama_(Paamanese)',
#   'language_family': 'Austronesian',
#   'code': 'paam1238',
#   'simulation_code': 'paam1238_5',
#   'simulation': 'Y',
#   'mutual_information': 0.5916727785823275,
#   'entropy_gn': 2.1280852788913944,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.393555357451924,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 12},
#  {'language': 'Pama_(Paamanese)',
#   'language_family': 'Austronesian',
#   'code': 'paam1238',
#   'simulation_code': 'paam1238_6',
#   'simulation': 'Y',
#   'mutual_information': 0.5916727785823275,
#   'entropy_gn': 2.1280852788913944,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.393555357451924,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 12},
#  {'language': 'Pama_(Paamanese)',
#   'language_family': 'Austronesian',
#   'code': 'paam1238',
#   'simulation_code': 'paam1238_7',
#   'simulation': 'Y',
#   'mutual_information': 0.5916727785823275,
#   'entropy_gn': 2.1280852788913944,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.393555357451924,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 12},
#  {'language': 'Pama_(Paamanese)',
#   'language_family': 'Austronesian',
#   'code': 'paam1238',
#   'simulation_code': 'paam1238_8',
#   'simulation': 'Y',
#   'mutual_information': 0.5916727785823275,
#   'entropy_gn': 2.1280852788913944,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.393555357451924,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 12},
#  {'language': 'Pama_(Paamanese)',
#   'language_family': 'Austronesian',
#   'code': 'paam1238',
#   'simulation_code': 'paam1238_9',
#   'simulation': 'Y',
#   'mutual_information': 0.9852281360342516,
#   'entropy_gn': 2.1280852788913944,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 10},
#  {'language': 'Sa_a',
#   'language_family': 'Austronesian',
#   'code': 'saaa1240',
#   'simulation_code': 'saaa1240_0',
#   'simulation': 'Y',
#   'mutual_information': 0.07993439139382463,
#   'entropy_gn': 0.954434002924965,
#   'entropy_gn1': 2.0,
#   'conditional_entropy': 1.9200656086061754,
#   'variation_gn': 2,
#   'variation_gn1': 4,
#   'number_of_pairs': 8},
#  {'language': 'Sa_a',
#   'language_family': 'Austronesian',
#   'code': 'saaa1240',
#   'simulation_code': 'saaa1240_1',
#   'simulation': 'Y',
#   'mutual_information': 0.013182168842508668,
#   'entropy_gn': 0.8960382325345574,
#   'entropy_gn1': 2.0,
#   'conditional_entropy': 1.9868178311574913,
#   'variation_gn': 2,
#   'variation_gn1': 4,
#   'number_of_pairs': 8},
#  {'language': 'Sa_a',
#   'language_family': 'Austronesian',
#   'code': 'saaa1240',
#   'simulation_code': 'saaa1240_2',
#   'simulation': 'Y',
#   'mutual_information': 0.013182168842508446,
#   'entropy_gn': 0.8960382325345574,
#   'entropy_gn1': 2.0,
#   'conditional_entropy': 1.9868178311574916,
#   'variation_gn': 2,
#   'variation_gn1': 4,
#   'number_of_pairs': 8},
#  {'language': 'Sa_a',
#   'language_family': 'Austronesian',
#   'code': 'saaa1240',
#   'simulation_code': 'saaa1240_3',
#   'simulation': 'Y',
#   'mutual_information': 0.07993439139382463,
#   'entropy_gn': 0.954434002924965,
#   'entropy_gn1': 2.0,
#   'conditional_entropy': 1.9200656086061754,
#   'variation_gn': 2,
#   'variation_gn1': 4,
#   'number_of_pairs': 8},
#  {'language': 'Sa_a',
#   'language_family': 'Austronesian',
#   'code': 'saaa1240',
#   'simulation_code': 'saaa1240_4',
#   'simulation': 'Y',
#   'mutual_information': 0.07993439139382463,
#   'entropy_gn': 0.954434002924965,
#   'entropy_gn1': 2.0,
#   'conditional_entropy': 1.9200656086061754,
#   'variation_gn': 2,
#   'variation_gn1': 4,
#   'number_of_pairs': 8},
#  {'language': 'Sa_a',
#   'language_family': 'Austronesian',
#   'code': 'saaa1240',
#   'simulation_code': 'saaa1240_5',
#   'simulation': 'Y',
#   'mutual_information': 0.009717039086360346,
#   'entropy_gn': 0.9283620723948676,
#   'entropy_gn1': 2.0,
#   'conditional_entropy': 1.9902829609136397,
#   'variation_gn': 2,
#   'variation_gn1': 4,
#   'number_of_pairs': 8},
#  {'language': 'Sa_a',
#   'language_family': 'Austronesian',
#   'code': 'saaa1240',
#   'simulation_code': 'saaa1240_6',
#   'simulation': 'Y',
#   'mutual_information': 0.07993439139382486,
#   'entropy_gn': 0.954434002924965,
#   'entropy_gn1': 2.0,
#   'conditional_entropy': 1.9200656086061751,
#   'variation_gn': 2,
#   'variation_gn1': 4,
#   'number_of_pairs': 8},
#  {'language': 'Sa_a',
#   'language_family': 'Austronesian',
#   'code': 'saaa1240',
#   'simulation_code': 'saaa1240_7',
#   'simulation': 'Y',
#   'mutual_information': 0.09675771509733222,
#   'entropy_gn': 0.8571484374283715,
#   'entropy_gn1': 2.0,
#   'conditional_entropy': 1.9032422849026678,
#   'variation_gn': 2,
#   'variation_gn1': 4,
#   'number_of_pairs': 8},
#  {'language': 'Sa_a',
#   'language_family': 'Austronesian',
#   'code': 'saaa1240',
#   'simulation_code': 'saaa1240_8',
#   'simulation': 'Y',
#   'mutual_information': 0.0375796391902079,
#   'entropy_gn': 0.8960382325345574,
#   'entropy_gn1': 2.0,
#   'conditional_entropy': 1.962420360809792,
#   'variation_gn': 2,
#   'variation_gn1': 4,
#   'number_of_pairs': 8},
#  {'language': 'Sa_a',
#   'language_family': 'Austronesian',
#   'code': 'saaa1240',
#   'simulation_code': 'saaa1240_9',
#   'simulation': 'Y',
#   'mutual_information': 0.09675771509733222,
#   'entropy_gn': 0.8571484374283715,
#   'entropy_gn1': 2.0,
#   'conditional_entropy': 1.9032422849026678,
#   'variation_gn': 2,
#   'variation_gn1': 4,
#   'number_of_pairs': 8},
#  {'language': 'Tigak',
#   'language_family': 'Austronesian',
#   'code': 'tiga1245',
#   'simulation_code': 'tiga1245_0',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Tigak',
#   'language_family': 'Austronesian',
#   'code': 'tiga1245',
#   'simulation_code': 'tiga1245_1',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Tigak',
#   'language_family': 'Austronesian',
#   'code': 'tiga1245',
#   'simulation_code': 'tiga1245_2',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Tigak',
#   'language_family': 'Austronesian',
#   'code': 'tiga1245',
#   'simulation_code': 'tiga1245_3',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Tigak',
#   'language_family': 'Austronesian',
#   'code': 'tiga1245',
#   'simulation_code': 'tiga1245_4',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Tigak',
#   'language_family': 'Austronesian',
#   'code': 'tiga1245',
#   'simulation_code': 'tiga1245_5',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Tigak',
#   'language_family': 'Austronesian',
#   'code': 'tiga1245',
#   'simulation_code': 'tiga1245_6',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Tigak',
#   'language_family': 'Austronesian',
#   'code': 'tiga1245',
#   'simulation_code': 'tiga1245_7',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Tigak',
#   'language_family': 'Austronesian',
#   'code': 'tiga1245',
#   'simulation_code': 'tiga1245_8',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Tigak',
#   'language_family': 'Austronesian',
#   'code': 'tiga1245',
#   'simulation_code': 'tiga1245_9',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Southwest_Tanna',
#   'language_family': 'Austronesian',
#   'code': 'sout2869',
#   'simulation_code': 'sout2869_0',
#   'simulation': 'Y',
#   'mutual_information': 0.3124807982156095,
#   'entropy_gn': 2.1559130951758245,
#   'entropy_gn1': 1.4634582986483033,
#   'conditional_entropy': 1.1509775004326939,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 11},
#  {'language': 'Southwest_Tanna',
#   'language_family': 'Austronesian',
#   'code': 'sout2869',
#   'simulation_code': 'sout2869_1',
#   'simulation': 'Y',
#   'mutual_information': 0.28398903247316465,
#   'entropy_gn': 2.1437621626224823,
#   'entropy_gn1': 1.4634582986483033,
#   'conditional_entropy': 1.1794692661751387,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 11},
#  {'language': 'Southwest_Tanna',
#   'language_family': 'Austronesian',
#   'code': 'sout2869',
#   'simulation_code': 'sout2869_2',
#   'simulation': 'Y',
#   'mutual_information': 0.13989956591870256,
#   'entropy_gn': 2.2779565475879124,
#   'entropy_gn1': 1.4634582986483033,
#   'conditional_entropy': 1.3235587327296008,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 15},
#  {'language': 'Southwest_Tanna',
#   'language_family': 'Austronesian',
#   'code': 'sout2869',
#   'simulation_code': 'sout2869_3',
#   'simulation': 'Y',
#   'mutual_information': 0.032498735534293166,
#   'entropy_gn': 2.241946032206046,
#   'entropy_gn1': 1.4634582986483033,
#   'conditional_entropy': 1.4309595631140102,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 15},
#  {'language': 'Southwest_Tanna',
#   'language_family': 'Austronesian',
#   'code': 'sout2869',
#   'simulation_code': 'sout2869_4',
#   'simulation': 'Y',
#   'mutual_information': 0.15349628855341013,
#   'entropy_gn': 2.2011184861493844,
#   'entropy_gn1': 1.4634582986483033,
#   'conditional_entropy': 1.3099620100948932,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 13},
#  {'language': 'Southwest_Tanna',
#   'language_family': 'Austronesian',
#   'code': 'sout2869',
#   'simulation_code': 'sout2869_5',
#   'simulation': 'Y',
#   'mutual_information': 0.28398903247316487,
#   'entropy_gn': 2.1437621626224823,
#   'entropy_gn1': 1.4634582986483033,
#   'conditional_entropy': 1.1794692661751385,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 11},
#  {'language': 'Southwest_Tanna',
#   'language_family': 'Austronesian',
#   'code': 'sout2869',
#   'simulation_code': 'sout2869_6',
#   'simulation': 'Y',
#   'mutual_information': 0.013505257212751642,
#   'entropy_gn': 2.2108016213311616,
#   'entropy_gn1': 1.4634582986483033,
#   'conditional_entropy': 1.4499530414355517,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 15},
#  {'language': 'Southwest_Tanna',
#   'language_family': 'Austronesian',
#   'code': 'sout2869',
#   'simulation_code': 'sout2869_7',
#   'simulation': 'Y',
#   'mutual_information': 0.23992601975175942,
#   'entropy_gn': 2.2242103996847296,
#   'entropy_gn1': 1.4634582986483033,
#   'conditional_entropy': 1.223532278896544,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 13},
#  {'language': 'Southwest_Tanna',
#   'language_family': 'Austronesian',
#   'code': 'sout2869',
#   'simulation_code': 'sout2869_8',
#   'simulation': 'Y',
#   'mutual_information': 0.13989956591870278,
#   'entropy_gn': 2.2779565475879124,
#   'entropy_gn1': 1.4634582986483033,
#   'conditional_entropy': 1.3235587327296006,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 15},
#  {'language': 'Southwest_Tanna',
#   'language_family': 'Austronesian',
#   'code': 'sout2869',
#   'simulation_code': 'sout2869_9',
#   'simulation': 'Y',
#   'mutual_information': 0.013505257212751642,
#   'entropy_gn': 2.2108016213311616,
#   'entropy_gn1': 1.4634582986483033,
#   'conditional_entropy': 1.4499530414355517,
#   'variation_gn': 5,
#   'variation_gn1': 3,
#   'number_of_pairs': 15},
#  {'language': 'Maranao_(Lanao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'mara1404',
#   'simulation_code': 'mara1404_0',
#   'simulation': 'Y',
#   'mutual_information': 0.0704708714558111,
#   'entropy_gn': 1.6570023930068138,
#   'entropy_gn1': 1.88654089282209,
#   'conditional_entropy': 1.8160700213662788,
#   'variation_gn': 4,
#   'variation_gn1': 4,
#   'number_of_pairs': 14},
#  {'language': 'Maranao_(Lanao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'mara1404',
#   'simulation_code': 'mara1404_1',
#   'simulation': 'Y',
#   'mutual_information': 0.14803166481386332,
#   'entropy_gn': 1.664926914237255,
#   'entropy_gn1': 1.88654089282209,
#   'conditional_entropy': 1.7385092280082266,
#   'variation_gn': 4,
#   'variation_gn1': 4,
#   'number_of_pairs': 13},
#  {'language': 'Maranao_(Lanao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'mara1404',
#   'simulation_code': 'mara1404_2',
#   'simulation': 'Y',
#   'mutual_information': 0.3320375359222538,
#   'entropy_gn': 1.707582158808321,
#   'entropy_gn1': 1.88654089282209,
#   'conditional_entropy': 1.554503356899836,
#   'variation_gn': 4,
#   'variation_gn1': 4,
#   'number_of_pairs': 14},
#  {'language': 'Maranao_(Lanao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'mara1404',
#   'simulation_code': 'mara1404_3',
#   'simulation': 'Y',
#   'mutual_information': 0.1382842514289362,
#   'entropy_gn': 1.664926914237255,
#   'entropy_gn1': 1.88654089282209,
#   'conditional_entropy': 1.7482566413931537,
#   'variation_gn': 4,
#   'variation_gn1': 4,
#   'number_of_pairs': 13},
#  {'language': 'Maranao_(Lanao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'mara1404',
#   'simulation_code': 'mara1404_4',
#   'simulation': 'Y',
#   'mutual_information': 0.24496404997328236,
#   'entropy_gn': 1.6520388657046212,
#   'entropy_gn1': 1.88654089282209,
#   'conditional_entropy': 1.6415768428488076,
#   'variation_gn': 4,
#   'variation_gn1': 4,
#   'number_of_pairs': 14},
#  {'language': 'Maranao_(Lanao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'mara1404',
#   'simulation_code': 'mara1404_5',
#   'simulation': 'Y',
#   'mutual_information': 0.02991241708376391,
#   'entropy_gn': 1.7109768852781746,
#   'entropy_gn1': 1.88654089282209,
#   'conditional_entropy': 1.856628475738326,
#   'variation_gn': 4,
#   'variation_gn1': 4,
#   'number_of_pairs': 16},
#  {'language': 'Maranao_(Lanao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'mara1404',
#   'simulation_code': 'mara1404_6',
#   'simulation': 'Y',
#   'mutual_information': 0.10712511411565284,
#   'entropy_gn': 1.696737275885705,
#   'entropy_gn1': 1.88654089282209,
#   'conditional_entropy': 1.779415778706437,
#   'variation_gn': 4,
#   'variation_gn1': 4,
#   'number_of_pairs': 14},
#  {'language': 'Maranao_(Lanao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'mara1404',
#   'simulation_code': 'mara1404_7',
#   'simulation': 'Y',
#   'mutual_information': 0.11862156493994691,
#   'entropy_gn': 1.6665783579949205,
#   'entropy_gn1': 1.88654089282209,
#   'conditional_entropy': 1.767919327882143,
#   'variation_gn': 4,
#   'variation_gn1': 4,
#   'number_of_pairs': 13},
#  {'language': 'Maranao_(Lanao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'mara1404',
#   'simulation_code': 'mara1404_8',
#   'simulation': 'Y',
#   'mutual_information': 0.07572250015551041,
#   'entropy_gn': 1.6570023930068138,
#   'entropy_gn1': 1.88654089282209,
#   'conditional_entropy': 1.8108183926665795,
#   'variation_gn': 4,
#   'variation_gn1': 4,
#   'number_of_pairs': 14},
#  {'language': 'Maranao_(Lanao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'mara1404',
#   'simulation_code': 'mara1404_9',
#   'simulation': 'Y',
#   'mutual_information': 0.09929116056931009,
#   'entropy_gn': 1.61260386572356,
#   'entropy_gn1': 1.88654089282209,
#   'conditional_entropy': 1.7872497322527798,
#   'variation_gn': 4,
#   'variation_gn1': 4,
#   'number_of_pairs': 12},
#  {'language': 'Wiwirano',
#   'language_family': 'Austronesian',
#   'code': 'wiwi1237',
#   'simulation_code': 'wiwi1237_0',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Wiwirano',
#   'language_family': 'Austronesian',
#   'code': 'wiwi1237',
#   'simulation_code': 'wiwi1237_1',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Wiwirano',
#   'language_family': 'Austronesian',
#   'code': 'wiwi1237',
#   'simulation_code': 'wiwi1237_2',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Wiwirano',
#   'language_family': 'Austronesian',
#   'code': 'wiwi1237',
#   'simulation_code': 'wiwi1237_3',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Wiwirano',
#   'language_family': 'Austronesian',
#   'code': 'wiwi1237',
#   'simulation_code': 'wiwi1237_4',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Wiwirano',
#   'language_family': 'Austronesian',
#   'code': 'wiwi1237',
#   'simulation_code': 'wiwi1237_5',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Wiwirano',
#   'language_family': 'Austronesian',
#   'code': 'wiwi1237',
#   'simulation_code': 'wiwi1237_6',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Wiwirano',
#   'language_family': 'Austronesian',
#   'code': 'wiwi1237',
#   'simulation_code': 'wiwi1237_7',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Wiwirano',
#   'language_family': 'Austronesian',
#   'code': 'wiwi1237',
#   'simulation_code': 'wiwi1237_8',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Wiwirano',
#   'language_family': 'Austronesian',
#   'code': 'wiwi1237',
#   'simulation_code': 'wiwi1237_9',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 0.9852281360342515,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Maguindanao_(Magindonao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'magu1243',
#   'simulation_code': 'magu1243_0',
#   'simulation': 'Y',
#   'mutual_information': 0.31317930831411034,
#   'entropy_gn': 1.588287118459957,
#   'entropy_gn1': 1.9074477090501822,
#   'conditional_entropy': 1.594268400736072,
#   'variation_gn': 5,
#   'variation_gn1': 5,
#   'number_of_pairs': 11},
#  {'language': 'Maguindanao_(Magindonao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'magu1243',
#   'simulation_code': 'magu1243_1',
#   'simulation': 'Y',
#   'mutual_information': 0.1324439730575715,
#   'entropy_gn': 1.588287118459957,
#   'entropy_gn1': 1.9074477090501822,
#   'conditional_entropy': 1.7750037359926107,
#   'variation_gn': 5,
#   'variation_gn1': 5,
#   'number_of_pairs': 14},
#  {'language': 'Maguindanao_(Magindonao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'magu1243',
#   'simulation_code': 'magu1243_2',
#   'simulation': 'Y',
#   'mutual_information': 0.1373679277128208,
#   'entropy_gn': 1.588287118459957,
#   'entropy_gn1': 1.9074477090501822,
#   'conditional_entropy': 1.7700797813373614,
#   'variation_gn': 5,
#   'variation_gn1': 5,
#   'number_of_pairs': 14},
#  {'language': 'Maguindanao_(Magindonao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'magu1243',
#   'simulation_code': 'magu1243_3',
#   'simulation': 'Y',
#   'mutual_information': 0.2972318512788643,
#   'entropy_gn': 1.6553560285204898,
#   'entropy_gn1': 1.9074477090501822,
#   'conditional_entropy': 1.610215857771318,
#   'variation_gn': 5,
#   'variation_gn1': 5,
#   'number_of_pairs': 14},
#  {'language': 'Maguindanao_(Magindonao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'magu1243',
#   'simulation_code': 'magu1243_4',
#   'simulation': 'Y',
#   'mutual_information': 0.18126894157917173,
#   'entropy_gn': 1.58456908470726,
#   'entropy_gn1': 1.9074477090501822,
#   'conditional_entropy': 1.7261787674710105,
#   'variation_gn': 5,
#   'variation_gn1': 5,
#   'number_of_pairs': 14},
#  {'language': 'Maguindanao_(Magindonao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'magu1243',
#   'simulation_code': 'magu1243_5',
#   'simulation': 'Y',
#   'mutual_information': 0.1392036677055679,
#   'entropy_gn': 1.6572653381576483,
#   'entropy_gn1': 1.9074477090501822,
#   'conditional_entropy': 1.7682440413446143,
#   'variation_gn': 5,
#   'variation_gn1': 5,
#   'number_of_pairs': 16},
#  {'language': 'Maguindanao_(Magindonao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'magu1243',
#   'simulation_code': 'magu1243_6',
#   'simulation': 'Y',
#   'mutual_information': 0.08482492543852382,
#   'entropy_gn': 1.588287118459957,
#   'entropy_gn1': 1.9074477090501822,
#   'conditional_entropy': 1.8226227836116584,
#   'variation_gn': 5,
#   'variation_gn1': 5,
#   'number_of_pairs': 15},
#  {'language': 'Maguindanao_(Magindonao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'magu1243',
#   'simulation_code': 'magu1243_7',
#   'simulation': 'Y',
#   'mutual_information': 0.23254069050666226,
#   'entropy_gn': 1.588287118459957,
#   'entropy_gn1': 1.9074477090501822,
#   'conditional_entropy': 1.67490701854352,
#   'variation_gn': 5,
#   'variation_gn1': 5,
#   'number_of_pairs': 13},
#  {'language': 'Maguindanao_(Magindonao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'magu1243',
#   'simulation_code': 'magu1243_8',
#   'simulation': 'Y',
#   'mutual_information': 0.29997292053124225,
#   'entropy_gn': 1.6572653381576483,
#   'entropy_gn1': 1.9074477090501822,
#   'conditional_entropy': 1.60747478851894,
#   'variation_gn': 5,
#   'variation_gn1': 5,
#   'number_of_pairs': 14},
#  {'language': 'Maguindanao_(Magindonao_Moro)',
#   'language_family': 'Austronesian',
#   'code': 'magu1243',
#   'simulation_code': 'magu1243_9',
#   'simulation': 'Y',
#   'mutual_information': 0.1324439730575715,
#   'entropy_gn': 1.588287118459957,
#   'entropy_gn1': 1.9074477090501822,
#   'conditional_entropy': 1.7750037359926107,
#   'variation_gn': 5,
#   'variation_gn1': 5,
#   'number_of_pairs': 14},
#  {'language': 'Penrhyn_(Tongareva)',
#   'language_family': 'Austronesian',
#   'code': 'penr1237',
#   'simulation_code': 'penr1237_0',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Penrhyn_(Tongareva)',
#   'language_family': 'Austronesian',
#   'code': 'penr1237',
#   'simulation_code': 'penr1237_1',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Penrhyn_(Tongareva)',
#   'language_family': 'Austronesian',
#   'code': 'penr1237',
#   'simulation_code': 'penr1237_2',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Penrhyn_(Tongareva)',
#   'language_family': 'Austronesian',
#   'code': 'penr1237',
#   'simulation_code': 'penr1237_3',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Penrhyn_(Tongareva)',
#   'language_family': 'Austronesian',
#   'code': 'penr1237',
#   'simulation_code': 'penr1237_4',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Penrhyn_(Tongareva)',
#   'language_family': 'Austronesian',
#   'code': 'penr1237',
#   'simulation_code': 'penr1237_5',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Penrhyn_(Tongareva)',
#   'language_family': 'Austronesian',
#   'code': 'penr1237',
#   'simulation_code': 'penr1237_6',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Penrhyn_(Tongareva)',
#   'language_family': 'Austronesian',
#   'code': 'penr1237',
#   'simulation_code': 'penr1237_7',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Penrhyn_(Tongareva)',
#   'language_family': 'Austronesian',
#   'code': 'penr1237',
#   'simulation_code': 'penr1237_8',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Penrhyn_(Tongareva)',
#   'language_family': 'Austronesian',
#   'code': 'penr1237',
#   'simulation_code': 'penr1237_9',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Sungwaloge_(Nalemba_Edward)',
#   'language_family': 'Austronesian',
#   'code': 'mari1426g',
#   'simulation_code': 'mari1426g_0',
#   'simulation': 'Y',
#   'mutual_information': 0.027104887312933146,
#   'entropy_gn': 1.5597895278350613,
#   'entropy_gn1': 1.932111567616675,
#   'conditional_entropy': 1.9050066803037418,
#   'variation_gn': 3,
#   'variation_gn1': 4,
#   'number_of_pairs': 12},
#  {'language': 'Sungwaloge_(Nalemba_Edward)',
#   'language_family': 'Austronesian',
#   'code': 'mari1426g',
#   'simulation_code': 'mari1426g_1',
#   'simulation': 'Y',
#   'mutual_information': 0.06605432712591708,
#   'entropy_gn': 1.56444656475117,
#   'entropy_gn1': 1.932111567616675,
# ...
#   'simulation_code': 'puyu1239_6',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 1.0,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Puyuma',
#   'language_family': 'Austronesian',
#   'code': 'puyu1239',
#   'simulation_code': 'puyu1239_7',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 1.0,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Puyuma',
#   'language_family': 'Austronesian',
#   'code': 'puyu1239',
#   'simulation_code': 'puyu1239_8',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 1.0,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Puyuma',
#   'language_family': 'Austronesian',
#   'code': 'puyu1239',
#   'simulation_code': 'puyu1239_9',
#   'simulation': 'Y',
#   'mutual_information': 0.0,
#   'entropy_gn': 1.0,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 1.0,
#   'variation_gn': 2,
#   'variation_gn1': 2,
#   'number_of_pairs': 4},
#  {'language': 'Rakahanga-Manihiki',
#   'language_family': 'Austronesian',
#   'code': 'raka1237',
#   'simulation_code': 'raka1237_0',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Rakahanga-Manihiki',
#   'language_family': 'Austronesian',
#   'code': 'raka1237',
#   'simulation_code': 'raka1237_1',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Rakahanga-Manihiki',
#   'language_family': 'Austronesian',
#   'code': 'raka1237',
#   'simulation_code': 'raka1237_2',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Rakahanga-Manihiki',
#   'language_family': 'Austronesian',
#   'code': 'raka1237',
#   'simulation_code': 'raka1237_3',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Rakahanga-Manihiki',
#   'language_family': 'Austronesian',
#   'code': 'raka1237',
#   'simulation_code': 'raka1237_4',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Rakahanga-Manihiki',
#   'language_family': 'Austronesian',
#   'code': 'raka1237',
#   'simulation_code': 'raka1237_5',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Rakahanga-Manihiki',
#   'language_family': 'Austronesian',
#   'code': 'raka1237',
#   'simulation_code': 'raka1237_6',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Rakahanga-Manihiki',
#   'language_family': 'Austronesian',
#   'code': 'raka1237',
#   'simulation_code': 'raka1237_7',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Rakahanga-Manihiki',
#   'language_family': 'Austronesian',
#   'code': 'raka1237',
#   'simulation_code': 'raka1237_8',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Rakahanga-Manihiki',
#   'language_family': 'Austronesian',
#   'code': 'raka1237',
#   'simulation_code': 'raka1237_9',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Wallisian_(East_Uvea)',
#   'language_family': 'Austronesian',
#   'code': 'wall1257',
#   'simulation_code': 'wall1257_0',
#   'simulation': 'Y',
#   'mutual_information': 0.41379956460568046,
#   'entropy_gn': 2.2359263506290326,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.571428571428571,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 14},
#  {'language': 'Wallisian_(East_Uvea)',
#   'language_family': 'Austronesian',
#   'code': 'wall1257',
#   'simulation_code': 'wall1257_1',
#   'simulation': 'Y',
#   'mutual_information': 0.699513850319966,
#   'entropy_gn': 2.2359263506290326,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.2857142857142854,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 12},
#  {'language': 'Wallisian_(East_Uvea)',
#   'language_family': 'Austronesian',
#   'code': 'wall1257',
#   'simulation_code': 'wall1257_2',
#   'simulation': 'Y',
#   'mutual_information': 0.41379956460568046,
#   'entropy_gn': 2.2359263506290326,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.571428571428571,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 14},
#  {'language': 'Wallisian_(East_Uvea)',
#   'language_family': 'Austronesian',
#   'code': 'wall1257',
#   'simulation_code': 'wall1257_3',
#   'simulation': 'Y',
#   'mutual_information': 0.699513850319966,
#   'entropy_gn': 2.2359263506290326,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.2857142857142854,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 12},
#  {'language': 'Wallisian_(East_Uvea)',
#   'language_family': 'Austronesian',
#   'code': 'wall1257',
#   'simulation_code': 'wall1257_4',
#   'simulation': 'Y',
#   'mutual_information': 0.41379956460568046,
#   'entropy_gn': 2.2359263506290326,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.571428571428571,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 14},
#  {'language': 'Wallisian_(East_Uvea)',
#   'language_family': 'Austronesian',
#   'code': 'wall1257',
#   'simulation_code': 'wall1257_5',
#   'simulation': 'Y',
#   'mutual_information': 0.9852281360342516,
#   'entropy_gn': 2.2359263506290326,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 10},
#  {'language': 'Wallisian_(East_Uvea)',
#   'language_family': 'Austronesian',
#   'code': 'wall1257',
#   'simulation_code': 'wall1257_6',
#   'simulation': 'Y',
#   'mutual_information': 0.41379956460568046,
#   'entropy_gn': 2.2359263506290326,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.571428571428571,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 14},
#  {'language': 'Wallisian_(East_Uvea)',
#   'language_family': 'Austronesian',
#   'code': 'wall1257',
#   'simulation_code': 'wall1257_7',
#   'simulation': 'Y',
#   'mutual_information': 0.41379956460568046,
#   'entropy_gn': 2.2359263506290326,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.571428571428571,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 14},
#  {'language': 'Wallisian_(East_Uvea)',
#   'language_family': 'Austronesian',
#   'code': 'wall1257',
#   'simulation_code': 'wall1257_8',
#   'simulation': 'Y',
#   'mutual_information': 0.699513850319966,
#   'entropy_gn': 2.2359263506290326,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 1.2857142857142854,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 12},
#  {'language': 'Wallisian_(East_Uvea)',
#   'language_family': 'Austronesian',
#   'code': 'wall1257',
#   'simulation_code': 'wall1257_9',
#   'simulation': 'Y',
#   'mutual_information': 0.9852281360342516,
#   'entropy_gn': 2.2359263506290326,
#   'entropy_gn1': 1.9852281360342514,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 5,
#   'variation_gn1': 4,
#   'number_of_pairs': 10},
#  {'language': 'Tikopia',
#   'language_family': 'Austronesian',
#   'code': 'tiko1237a',
#   'simulation_code': 'tiko1237a_0',
#   'simulation': 'Y',
#   'mutual_information': 0.32746944744004236,
#   'entropy_gn': 2.470459173204496,
#   'entropy_gn1': 1.932111567616675,
#   'conditional_entropy': 1.6046421201766325,
#   'variation_gn': 6,
#   'variation_gn1': 4,
#   'number_of_pairs': 19},
#  {'language': 'Tikopia',
#   'language_family': 'Austronesian',
#   'code': 'tiko1237a',
#   'simulation_code': 'tiko1237a_1',
#   'simulation': 'Y',
#   'mutual_information': 0.3063984424381787,
#   'entropy_gn': 2.4843803524295196,
#   'entropy_gn1': 1.932111567616675,
#   'conditional_entropy': 1.6257131251784962,
#   'variation_gn': 6,
#   'variation_gn1': 4,
#   'number_of_pairs': 21},
#  {'language': 'Tikopia',
#   'language_family': 'Austronesian',
#   'code': 'tiko1237a',
#   'simulation_code': 'tiko1237a_2',
#   'simulation': 'Y',
#   'mutual_information': 0.1994487785567871,
#   'entropy_gn': 2.4564626890568175,
#   'entropy_gn1': 1.932111567616675,
#   'conditional_entropy': 1.7326627890598878,
#   'variation_gn': 6,
#   'variation_gn1': 4,
#   'number_of_pairs': 21},
#  {'language': 'Tikopia',
#   'language_family': 'Austronesian',
#   'code': 'tiko1237a',
#   'simulation_code': 'tiko1237a_3',
#   'simulation': 'Y',
#   'mutual_information': 0.17052855724713778,
#   'entropy_gn': 2.514498989486299,
#   'entropy_gn1': 1.932111567616675,
#   'conditional_entropy': 1.7615830103695371,
#   'variation_gn': 6,
#   'variation_gn1': 4,
#   'number_of_pairs': 22},
#  {'language': 'Tikopia',
#   'language_family': 'Austronesian',
#   'code': 'tiko1237a',
#   'simulation_code': 'tiko1237a_4',
#   'simulation': 'Y',
#   'mutual_information': 0.13996891766564779,
#   'entropy_gn': 2.511007012901255,
#   'entropy_gn1': 1.932111567616675,
#   'conditional_entropy': 1.7921426499510271,
#   'variation_gn': 6,
#   'variation_gn1': 4,
#   'number_of_pairs': 22},
#  {'language': 'Tikopia',
#   'language_family': 'Austronesian',
#   'code': 'tiko1237a',
#   'simulation_code': 'tiko1237a_5',
#   'simulation': 'Y',
#   'mutual_information': 0.18693915512025638,
#   'entropy_gn': 2.514498989486299,
#   'entropy_gn1': 1.932111567616675,
#   'conditional_entropy': 1.7451724124964185,
#   'variation_gn': 6,
#   'variation_gn1': 4,
#   'number_of_pairs': 21},
#  {'language': 'Tikopia',
#   'language_family': 'Austronesian',
#   'code': 'tiko1237a',
#   'simulation_code': 'tiko1237a_6',
#   'simulation': 'Y',
#   'mutual_information': 0.21312683253701992,
#   'entropy_gn': 2.4843803524295196,
#   'entropy_gn1': 1.932111567616675,
#   'conditional_entropy': 1.718984735079655,
#   'variation_gn': 6,
#   'variation_gn1': 4,
#   'number_of_pairs': 21},
#  {'language': 'Tikopia',
#   'language_family': 'Austronesian',
#   'code': 'tiko1237a',
#   'simulation_code': 'tiko1237a_7',
#   'simulation': 'Y',
#   'mutual_information': 0.2585782046073144,
#   'entropy_gn': 2.452970712471774,
#   'entropy_gn1': 1.932111567616675,
#   'conditional_entropy': 1.6735333630093605,
#   'variation_gn': 6,
#   'variation_gn1': 4,
#   'number_of_pairs': 20},
#  {'language': 'Tikopia',
#   'language_family': 'Austronesian',
#   'code': 'tiko1237a',
#   'simulation_code': 'tiko1237a_8',
#   'simulation': 'Y',
#   'mutual_information': 0.32013614778055555,
#   'entropy_gn': 2.4564626890568175,
#   'entropy_gn1': 1.932111567616675,
#   'conditional_entropy': 1.6119754198361194,
#   'variation_gn': 6,
#   'variation_gn1': 4,
#   'number_of_pairs': 21},
#  {'language': 'Tikopia',
#   'language_family': 'Austronesian',
#   'code': 'tiko1237a',
#   'simulation_code': 'tiko1237a_9',
#   'simulation': 'Y',
#   'mutual_information': 0.23444096278367432,
#   'entropy_gn': 2.456462689056818,
#   'entropy_gn1': 1.932111567616675,
#   'conditional_entropy': 1.6976706048330006,
#   'variation_gn': 6,
#   'variation_gn1': 4,
#   'number_of_pairs': 21},
#  {'language': 'Tamambo',
#   'language_family': 'Austronesian',
#   'code': 'malo1243',
#   'simulation_code': 'malo1243_0',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Tamambo',
#   'language_family': 'Austronesian',
#   'code': 'malo1243',
#   'simulation_code': 'malo1243_1',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Tamambo',
#   'language_family': 'Austronesian',
#   'code': 'malo1243',
#   'simulation_code': 'malo1243_2',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Tamambo',
#   'language_family': 'Austronesian',
#   'code': 'malo1243',
#   'simulation_code': 'malo1243_3',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Tamambo',
#   'language_family': 'Austronesian',
#   'code': 'malo1243',
#   'simulation_code': 'malo1243_4',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Tamambo',
#   'language_family': 'Austronesian',
#   'code': 'malo1243',
#   'simulation_code': 'malo1243_5',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Tamambo',
#   'language_family': 'Austronesian',
#   'code': 'malo1243',
#   'simulation_code': 'malo1243_6',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Tamambo',
#   'language_family': 'Austronesian',
#   'code': 'malo1243',
#   'simulation_code': 'malo1243_7',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Tamambo',
#   'language_family': 'Austronesian',
#   'code': 'malo1243',
#   'simulation_code': 'malo1243_8',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  {'language': 'Tamambo',
#   'language_family': 'Austronesian',
#   'code': 'malo1243',
#   'simulation_code': 'malo1243_9',
#   'simulation': 'Y',
#   'mutual_information': 2.220446049250313e-16,
#   'entropy_gn': 1.9502120649147465,
#   'entropy_gn1': 1.0,
#   'conditional_entropy': 0.9999999999999998,
#   'variation_gn': 4,
#   'variation_gn1': 2,
#   'number_of_pairs': 8},
#  ...]

# %% [markdown]
# And finally, the full set of simulations from all the kinbank data, run 1000 times on each language.

# %%
ics_simulation(families,family_filepath,1000)
# Out:
#                              language language_family      code  \
# 0       Maguindanao_(Magindonao_Moro)    Austronesian  magu1243
# 1       Maguindanao_(Magindonao_Moro)    Austronesian  magu1243
# 2       Maguindanao_(Magindonao_Moro)    Austronesian  magu1243
# 3       Maguindanao_(Magindonao_Moro)    Austronesian  magu1243
# 4       Maguindanao_(Magindonao_Moro)    Austronesian  magu1243
# ...                               ...             ...       ...
# 788995                          Yaqui     Uto-Aztecan  yaqu1251
# 788996                          Yaqui     Uto-Aztecan  yaqu1251
# 788997                          Yaqui     Uto-Aztecan  yaqu1251
# 788998                          Yaqui     Uto-Aztecan  yaqu1251
# 788999                          Yaqui     Uto-Aztecan  yaqu1251
#
#        simulation_code simulation  mutual_information  entropy_gn  \
# 0           magu1243_0          Y            0.177116    1.916127
# 1           magu1243_1          Y            0.167821    1.916127
# 2           magu1243_2          Y            0.147470    1.916127
# 3           magu1243_3          Y            0.129497    1.916127
# 4           magu1243_4          Y            0.195089    1.916127
# ...                ...        ...                 ...         ...
# 788995    yaqu1251_995          Y            0.088937    1.842371
# 788996    yaqu1251_996          Y            0.196778    1.842371
# 788997    yaqu1251_997          Y            0.196778    1.842371
# 788998    yaqu1251_998          Y            0.196778    1.842371
# 788999    yaqu1251_999          Y            0.177873    1.842371
#
#         entropy_gn1  conditional_entropy  variation_gn  variation_gn1  \
# 0          1.791858             1.614743             5              4
# 1          1.791858             1.624037             5              4
# 2          1.791858             1.644388             5              4
# 3          1.791858             1.662362             5              4
# 4          1.791858             1.596769             5              4
# ...             ...                  ...           ...            ...
# 788995     1.000000             0.911063             4              2
# 788996     1.000000             0.803222             4              2
# 788997     1.000000             0.803222             4              2
# 788998     1.000000             0.803222             4              2
# 788999     1.000000             0.822127             4              2
#
#         number_of_pairs
# 0                    15
# 1                    15
# 2                    16
# 3                    15
# 4                    15
# ...                 ...
# 788995                8
# 788996                7
# 788997                7
# 788998                7
# 788999                7
#
# [789000 rows x 12 columns]

# %% [markdown]
# Let's test our analysis with only one language family, to keep things simple.

# %%
aus_filepath = '../languages/kinbank-family/Austronesian/'
aus_files = get_kb_files(aus_filepath)

for file in aus_files:
    filter_ks('Austronesian',file)

# %%
filtered_aus_files = get_kb_files(aus_filepath)
# Out:
# 226 226

# %%
filtered_aus_filepath = '../languages/kinbank-filter/Austronesian/'

#ics_real(filter_filepath,filtered_kb_files)
ics_real(filtered_aus_filepath,filtered_aus_files)
# Out:
# Maguindanao_(Magindonao_Moro)_magu1243.csv
# [('ama', 'kaka'), ('ama', 'ali'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud')]
# Malua_Bay_malu1245.csv
# [('tate', 'söghösök dövat'), ('bini', 'natök'), ('bini', 'natök'), ('vavwe', 'tate'), ('vavwe', 'vavwe'), ('tate', 'söghösök'), ('tate', 'lelei'), ('tate', 'tisuk waven')]
# Manam_mana1295.csv
# None
# Mangaia_mang1402.csv
# None
# Mangarevans_mang1401.csv
# [('motua', 'tuakana'), ('motua', 'teina'), ('motua', "tue'ine"), ('motua-nui', "tue'ine"), ('motua-iti', "tue'ine"), ('motua-nui', "tue'ine"), ('motua-iti', "tue'ine"), ('kui-nui', "tue'ine"), ('kui-iti', "tue'ine"), ('kui-nui', "tue'ine"), ('kui-iti', "tue'ine"), ('motua', 'tuagane'), ('motua', 'tuakana'), ('motua', 'teina')]
# Mangareva_mang1401.csv
# Mangei_(Sobjo)_mang1407.csv
# [('soesoe', 'kaka'), ('soesoe', 'kaka'), ('kolo', 'kaka'), ('kolo', 'kaka')]
# Manggarai_mang1405.csv
# None
# Maori_maor1246.csv
# [('matua', 'tuahine'), ('matua', 'tuakana'), ('matua', 'tuahine'), ('matua', 'teina'), ('matua', 'tuahine'), ('matua', 'tuakana'), ('matua', 'tuahine'), ('matua', 'teina'), ('matua', 'tuahine'), ('whaea', 'tuakana'), ('whaea', 'tuahine'), ('whaea', 'teina'), ('whaea', 'tuahine'), ('whaea', 'tuakana'), ('whaea', 'tuahine'), ('whaea', 'teina'), ('whaea', 'tuahine'), ('matua', 'tungaane'), ('matua', 'tuakana'), ('matua', 'teina'), ('matua', 'tungaane'), ('matua', 'tuakana'), ('matua', 'tungaane'), ('matua', 'tuakana'), ('whaea', 'tungaane'), ('whaea', 'tuakana'), ('whaea', 'tungaane'), ('whaea', 'tuakana')]
# Maragus_(Tape)_mara1399.csv
# None
# Maranao_(Lanao_Moro)_mara1404.csv
# [('ama', 'kaka'), ('ama', 'ari'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('bapa', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('ama', 'kaka'), ('ama', 'ari')]
# Marquesas_marq1246.csv
# None
# Marshallese_mars1254.csv
# None
# Maskelynes_mask1242.csv
# None
# Matukar_matu1261.csv
# [('tamau', 'lu'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('wau', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('bih', 'kol'), ('tamau', 'lu'), ('tamau', 'ka'), ('tamau', 'te')]
# Mekeo_(East)_meke1243d.csv
# None
# Mekeo_(North)_meke1243c.csv
# None
# Mekeo_(North-West)_meke1243a.csv
# None
# Mekeo_(West)_meke1243b.csv
# None
# Mekeo_meke1243.csv
# None
# Mekongga_meko1237.csv
# None
# Mele-Fila_(Ifira-Mele)_mele1250.csv
# [('emama', 'kave'), ('aua', 'kaleka'), ('aua', 'kaleka'), ('mamau', 'kaleka'), ('mamau', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('mami', 'kaleka'), ('emama', 'kave'), ('emama', 'taina')]
# Menui_menu1237.csv
# None
# Merei_mere1242.csv
# None
# Merlav_merl1237.csv
# [('imama', 'tata'), ('moru', 'natu'), ('moru', 'natu'), ('ivev', 'natu'), ('ivev', 'natu'), ('imama', 'tata')]
# Minangkabau_mina1268.csv
# None
# Miningir_(Lunga)_mini1251.csv
# [('tamaná', 'tasiná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('mátuaná', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('vivianá', 'náuvaná'), ('tamaná', 'tasiná'), ('tamaná', 'tasinavaviná')]
# Mono-Alu_mono1273.csv
# None
# Morgan1871_Hawaiian_hawa1245.csv
# None
# Morgan1871_Kings_Mill_Islands_gilb1244.csv
# Morgan1871_Kusaien_kosr1238.csv
# Morgan1871_Maori_maor1246.csv
# Mori_Atas_mori1269.csv
# None
# Mori_Bawah_mori1268.csv
# [('ama', 'aka'), ('ama', 'uai'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('maama', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('naine', 'poteha'), ('ama', 'aka'), ('ama', 'uai')]
# Moronene_moro1287.csv
# [('tama', 'tukaka'), ('tama', 'tuai'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('topisa', 'topisa'), ('tama', 'tukaka'), ('tama', 'tuai')]
# Mortlockese_mort1237.csv
# [('saam', 'mwengeang'), ('tattalin saam', 'tattalin pwiipwi'), ('tattalin saam', 'tattalin mwengeang'), ('tattalin saam', 'tattalin pwiipwi'), ('tattalin saam', 'tattalin mwengeang'), ('tattalin iin', 'tattalin pwiipwi'), ('tattalin iin', 'tattalin mwengeang'), ('tattalin iin', 'tattalin pwiipwi'), ('tattalin iin', 'tattalin mwengeang'), ('saam', 'mwengeang'), ('saam', 'pwiipwi')]
# Mota_mota1237.csv
# [('tamak', 'tutuai'), ('maraui', 'natui'), ('maraui', 'natui'), ('vevegae', 'tamai'), ('vevegae', 'veve'), ('tamak', 'tutuai'), ('tamak', 'tuaga'), ('tamak', 'tasiu')]
# Motu_motu1246.csv
# None
# Mouk_mouk1240.csv
# [('ilau', 'lutno'), ('tumno', 'adou'), ('tumno', 'lutno'), ('babu', 'aten'), ('babu', 'aten'), ('babu', 'aten'), ('babu', 'aten'), ('babu', 'adou'), ('babu', 'lutno'), ('ilau', 'lutno'), ('ilau', 'atua'), ('ilau', 'agatno'), ('babu', 'adou')]
# Muduapa_(Vitu)_mudu1242.csv
# [('tama-na', 'livuk-'), ('tama-na', 'tazi kapou'), ('tama-na', 'tazi kapou'), ('vahapa-na', 'tazi kapou'), ('vahapa-na', 'tazi kapou'), ('tama-na', 'livuk-'), ('tama-na', 'tazi-na')]
# Muna_muna1247.csv
# [('ama', 'isa'), ('ama', 'ai'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokomau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('fokoinau', 'pisa'), ('ama', 'isa'), ('ama', 'ai')]
# Munggava_(Rennell)_mung1271.csv
# [('tamana', 'tua-hine'), ('tua-tina', "ha'anga"), ('tua-tina', "ha'anga"), ('tua-tina', "ha'anga"), ('tua-tina', "ha'anga"), ('tinau', "ha'anga"), ('tinau', "ha'anga"), ('tamana', "tua-nga'ane"), ('tamana', 'tau-kete'), ('tamana', 'taina')]
# Mungiki_(Bellona)_mung1270.csv
# None
# Mussau-Emira_muss1246.csv
# None
# Mwotlap_motl1237.csv
# [('itmek', 'tētek'), ('itat', 'ithik'), ('itat', 'tētek'), ('itmek', 'ithik'), ('itmek', 'tētek'), ('itmek', 'ithik'), ('itmek', 'tētek'), ('ivēk', 'ithik'), ('ivēk', 'tētek'), ('ivēk', 'ithik'), ('ivēk', 'tētek'), ('titamas', 'ithik'), ('titamas', 'tētek'), ('titamas', 'ithik'), ('titamas', 'tētek'), ('itmek', 'tētek'), ('itmek', 'ithik'), ('itmek', 'tētek'), ('itmek', 'ithik'), ('ivēk', 'tētek'), ('ivēk', 'ithik'), ('titamas', 'tētek'), ('titamas', 'ithik')]
# Māori_maor1246.csv
# Nafsan_sout2856.csv
# None
# Nage_nage1237.csv
# None
# Nahavaq_sout2857.csv
# None
# Nakanai_naka1262.csv
# [('tama-(la)', 'hatavile-(la)'), ('hala-(la)', 'e-hatamale-(la)'), ('hala-(la)', 'hatavile-(la)'), ('tama-(la) uru', 'e-hatamale-(la)'), ('tama-(la) uru', 'hatavile-(la)'), ('tama-(la) bisi', 'e-hatamale-(la)'), ('tama-(la) bisi', 'hatavile-(la)'), ('tila uru', 'e-hatamale-(la)'), ('tila uru', 'hatavile-(la)'), ('tila bisi', 'e-hatamale-(la)'), ('tila bisi', 'hatavile-(la)'), ('hala-(la)', 'e-hatamale-(la)'), ('hala-(la)', 'hatavile-(la)'), ('hala-(la)', 'e-hatamale-(la)'), ('hala-(la)', 'hatavile-(la)'), ('tama-(la)', 'e-hatamale-(la)')]
# Nalik_(Lukuramau)_nali1244.csv
# [('tamang', 'dimafingu'), ('mogorugu', 'fagu'), ('mogorugu', 'kaiasgu'), ('tamang', 'diagu'), ('tamang', 'dimafingu'), ('kogol', 'fagu'), ('kogol', 'kaiasgu'), ('tamang', 'diagu'), ('tamang', 'diagu')]
# Nalik_(Madina)_nali1244b.csv
# [('mago', 'fafnagu'), ('mogorugu', 'fagu'), ('mogorugu', 'agasugu'), ('mago', 'fafnagu'), ('mago', 'fafnagu'), ('mago', 'fafnagu'), ('mago', 'duagu'), ('mago', 'fafnagu')]
# Namakura_nama1268.csv
# [('taman', 'ngkoren'), ('taman', 'ngkoren'), ('lolo', 'hivang'), ('lolo', 'vain'), ('lolo', 'hivang'), ('lolo', 'vain'), ('taman', 'hivang'), ('taman', 'vain'), ('taman', 'hivang'), ('taman', 'vain'), ('anuh', 'hivang'), ('anuh', 'vain'), ('anuh', 'hivang'), ('anuh', 'vain'), ('miim', 'hivang'), ('miim', 'vain'), ('miim', 'hivang'), ('miim', 'vain'), ('taman', 'suan'), ('taman', 'suan'), ('taman', 'ngkoren'), ('lolo', 'hivang'), ('lolo', 'vain'), ('taman', 'hivang'), ('taman', 'vain'), ('anuh', 'hivang'), ('anuh', 'vain'), ('miim', 'hivang'), ('miim', 'vain')]
# Namakura_nama1268b.csv
# None
# Naman_litz1237.csv
# [('tate', 'vövönungk'), ('bimbi', 'netungk'), ('bimbi', 'netungk'), ('vave', 'tat uve'), ('vave', 'vave'), ('tate', 'manungk'), ('tate', 'tugangk'), ('tate', 'naaruongk')]
# Nanggu_nang1262.csv
# None
# Nehan_neha1247.csv
# [('taman', 'tatahinalik'), ('kabin', 'turak'), ('kabin', 'turak'), ('kabin', 'matmatatahinaliki'), ('kabin', 'turak'), ('taman', 'tatahinalik'), ('taman', 'tahinalik')]
# Nengone_neng1238.csv
# [('caca', 'mama'), ('caca', 'resingen'), ('caca', 'reisingen'), ('caca', 'reisingen'), ('caca', 'reisingen'), ('hmaien', 'reisingen'), ('cekin', 'reisingen'), ('caca', 'mama'), ('caca', 'cel'), ('caca', 'reisingen')]
# Nese_nese1235.csv
# None
# Neve'ei_vinm1237.csv
# [('mamwe', 'vivinungk'), ('vimbi', 'natungk'), ('vimbi', 'natungk'), ('mamwe lamp', 'tuangk'), ('mamwe lamp', 'vivinungk'), ('mamwe', 'tasungk'), ('mamwe', 'vivinungk'), ('vavwe', 'lelel'), ('vavwe', 'vavwe'), ('mamwe', 'manungk'), ('mamwe', 'tuangk'), ('mamwe', 'tasungk')]
# Neve'ei_vinm1237a.csv
# None
# Neverver_ling1265.csv
# [('mama', 'vivin'), ('bibi tokhtokh', 'salan'), ('bibi tokhtokh', 'salan'), ('bibi lele', 'salan'), ('bibi lele', 'salan'), ('mama tokhtokh', 'salan'), ('mama tokhtokh', 'salan'), ('mama lele', 'salan'), ('mama lele', 'salan'), ('nida tokhtokh', 'salan'), ('nida tokhtokh', 'salan'), ('nida lele', 'salan'), ('nida lele', 'salan'), ('nida tokhtokh', 'mama'), ('nida tokhtokh', 'nida'), ('nida lele', 'mama'), ('nida lele', 'nida'), ('mama', 'tatan'), ('mama', 'tas(t)n')]
# Nguna_ngun1274.csv
# [('mama', 'ngoreng'), ('aloa', 'natungu nanoay'), ('aloa', 'nanungu nangoroy'), ('tétè', 'tay'), ('tétè', 'ngoreng'), ('mimi', 'mama'), ('mimi', 'mimi'), ('mama', 'tay')]
# Niuafo'ou_niua1240.csv
# None
# Niueans_niue1239.csv
# [('matua tane', 'taokete'), ('matua tane', 'tehina'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'matakainaga'), ('matua tane', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'mahakainaga'), ('matua fifine', 'matakainaga'), ('matua fifine', 'mahakainaga'), ('matua tane', 'mahakainaga'), ('matua tane', 'taokete'), ('matua tane', 'tehina')]
# Niue_niue1239.csv
# North_Ambrym_nort2839.csv
# [('teta', 'talang'), ('mesong', 'mesong'), ('raheng', 'tubiung'), ('teta', 'talang')]
# North_Efate_(Nguna,_Nakanamanga)_nort2836.csv
# None
# North_Marquesan_nort2845.csv
# [('tunane', 'tuehine'), ('motua', 'tuehine'), ('teina motua', 'Tuaana'), ('teina motua', 'tuehine'), ('tuehine', 'tuehine')]
# North_Tanna_nort2847.csv
# None
# Numbami_numb1247.csv
# [('tama', 'lunewe'), ('wowa', 'gode'), ('wowa', 'godenewe'), ('tama', 'sika'), ('tama', 'lunewe'), ('mama kae', 'kapa'), ('mama kae', 'lunewe'), ('tina', 'sika'), ('tina', 'lunewe'), ('awa kae', 'kapa'), ('awa kae', 'lunewe'), ('wawe', 'gode'), ('wawe', 'godenewe'), ('tama', 'lu'), ('tama', 'sikanewe'), ('tama', 'kapowe'), ('tama', 'lu'), ('tama', 'sikanewe'), ('tina', 'lu'), ('tina', 'sikanewe')]
# Olal_olal1237.csv
# [('tete', 'taling'), ('mosong', 'tubung'), ('mosong', 'tubung'), ('idning', 'mabung'), ('idning', 'mabung'), ('tete', 'maningeri')]
# Old_Javanese_(Kawi)_kawi1241.csv
# None
# Old_Rapa_(Rapa)_rapa1245.csv
# None
# Ontong_Java_onto1237.csv
# [('kamaŋa', 'kaiŋa'), ('kamaŋa', "'ave"), ('lamoku', 'kaiŋa'), ('lamoku', "'ave"), ('kamaŋa', 'kaiŋa'), ('kamaŋa', "'ave"), ('kiŋa', 'kaiŋa'), ('kiŋa', "'ave"), ('kiŋa', 'kaiŋa'), ('kiŋa', "'ave"), ('kamaŋa', "'ave"), ('kamaŋa', 'kaiŋa')]
# Owa_(Santa_Ana)_owaa1237.csv
# None
# Padoe_pado1242.csv
# None
# Paici_paic1239.csv
# [('caa', 'ciè'), ('caa', 'aajii'), ('aunîa', 'böru'), ('aunîa', 'böru'), ('aunîa', 'böru'), ('aunîa', 'böru'), ('caa', 'ciè'), ('caa', 'ciè'), ('nyââ', 'aajii'), ('nyââ', 'aajii'), ('pankaa', 'böru'), ('pankaa', 'böru'), ('pankaa', 'böru'), ('pankaa', 'böru'), ('caa', 'ciè'), ('caa', 'aajii')]
# Paiwan_paiw1248.csv
# [('kama', 'kaka'), ('kama', 'kaka'), ('kama', 'kaka'), ('kama', 'kaka'), ('kama', 'kaka'), ('kina', 'kaka'), ('kina', 'kaka'), ('kina', 'kaka'), ('kina', 'kaka'), ('kama', 'kaka')]
# Palauan_pala1344.csv
# [('chadám', 'chochad(ák)'), ('desik', 'ngelekir a ruchad'), ('desik', 'ngelekir a ruchad'), ('desik', 'ngelekir a ruchad'), ('desik', 'ngelekir a ruchad'), ('desik', 'ngalekodám'), ('desik', 'ngalekodám'), ('desik', 'ngalekodám'), ('desik', 'ngalekodám'), ('chadám', 'chochad(ák)'), ('chadám', 'chudel(ék)'), ('chadám', 'merreng(ék)')]
# Paluai_balu1257.csv
# [('tama', 'patne'), ('nukna', 'pwai'), ('nukna', 'pwai'), ('tama', 'tou'), ('tama', 'patne'), ('tina', 'tou'), ('tina', 'patne'), ('sae', 'pwai'), ('sae', 'pwai'), ('tama', 'mwane'), ('tama', 'tou'), ('tama', 'nae')]
# Pama_(Paamanese)_paam1238.csv
# None
# Pampanga_(Kampampangan)_pamp1243.csv
# [('tatá', 'capatát á babaí'), ('bápa', 'písan'), ('bápa', 'písan'), ('bápa', 'písan'), ('bápa', 'písan'), ('dára', 'písan'), ('dára', 'písan'), ('dára', 'písan'), ('dára', 'písan'), ('tatá', 'capatát á laláqui')]
# Pangasinan_pang1290.csv
# [('pangamaen', 'eapinsan'), ('pangamaen', 'eapinsan'), ('pangamaen', 'eapinsan'), ('pangamaen', 'eapinsan'), ('panginaen', 'eapinsan'), ('panginaen', 'eapinsan'), ('panginaen', 'eapinsan'), ('panginaen', 'eapinsan'), ('ama', 'aguin laki')]
# Patani_pata1260.csv
# [('mama toewa', 'fono'), ('mama toewa', 'fono mpin'), ('mama toewa', 'fono'), ('mama toewa', 'fono mpin'), ('gowa', 'fono'), ('gowa', 'fono mpin'), ('gowa', 'fono'), ('gowa', 'fono mpin')]
# Pendau_pend1242.csv
# [('siama', "sia'ang"), ('siama', 'tuai'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('siama', "sia'ang"), ('siama', 'tuai')]
# Penrhyn_(Tongareva)_penr1237.csv
# None
# Petapa_Taje_taje1237a.csv
# None
# Pohnpeian_pohn1238.csv
# None
# Pohnpeian_pohn1238a.csv
# [('pahpa', 'rīali'), ('pahpa', 'wahn ohl pirien'), ('pahpa', 'wahn ohl pirien'), ('pahpa', 'wahn ohl pirien'), ('pahpa', 'wahn ohl pirien'), ('ihn', 'wahn lih pirien'), ('ihn', 'wahn lih pirien'), ('ihn', 'wahn lih pirien'), ('ihn', 'wahn lih pirien'), ('pahpa', 'rī')]
# Port_Sandwich_port1285.csv
# None
# Proto-Oceanic_ocea1241.csv
# None
# Pukapuka_puka1242.csv
# [('matua tane', 'kainga'), ('matua tane', 'taina'), ('matua tane', 'kainga wakama'), ('matua tane', 'taina'), ('matua tane', 'kainga wakama'), ('matua wawine', 'taina'), ('matua wawine', 'kainga wakama'), ('matua wawine', 'taina'), ('matua wawine', 'kainga wakama'), ('matua tane', 'kainga'), ('matua tane', 'taina')]
# Puluwatese_(Puluwat)_pulu1242.csv
# [('haam', 'mwéngeyáng'), ('pwi-', 'nawú-'), ('pwi-', 'nawú-'), ('haam', 'pwi-'), ('haam', 'mwéngeyáng'), ('yiin', 'pwi-'), ('yiin', 'mwéngeyáng'), ('yiin', 'haam'), ('yiin', 'yiin'), ('haam', 'mwéngeyáng'), ('haam', 'pwi-')]
# Puyuma_puyu1239.csv
# None
# Rade_(Rhade)_rade1240.csv
# None
# Raga_(Hano)_hano1246.csv
# [('tama', 'hogosi'), ('tama', 'tihi'), ('tarabe', 'nitu'), ('tarabe', 'nitu'), ('vwavwa', 'tama'), ('vwavwa', 'vwavwa'), ('tama', 'hogosi'), ('tama', 'tihi'), ('tama', 'tua')]
# Raga_(Hano_Thomas_Ennever)_hano1246b.csv
# [('tata', 'oɣosi'), ('bena', 'kuku'), ('bena', 'kuku'), ('tata', 'tua-mʷa'), ('tata', 'oɣosi'), ('mʷua', 'tua-mʷa'), ('mʷua', 'oɣosi'), ('fafʷa', 'tata'), ('fafʷa', 'fafʷa'), ('tata', 'oɣosi'), ('tata', 'tua-mʷa')]
# Rahambuu_raha1237.csv
# None
# Rakahanga-Manihiki_raka1237.csv
# None
# Rangiora_(NW_Tuamotus)_tuam1242.csv
# None
# Rapanui_(Easter_Island)_rapa1244.csv
# None
# Raroians_tuam1242.csv
# Rarotongan_(Cook_Islands_Maori)_raro1241.csv
# [('metua', "tua'ine"), ("'akapāpā", 'tuakana'), ("'akapāpā", "tua'ine"), ("'akapāpā", 'tuakana'), ("'akapāpā", "tua'ine"), ('metua', 'tungāne'), ('metua', 'tuakana'), ('metua', 'teina')]
# Ratagnon_rata1245.csv
# [('amang', 'magkabukto'), ('tiyo', 'pinsan'), ('tiyo', 'pinsan'), ('tiyo', 'pinsan'), ('tiyo', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('tiya', 'pinsan'), ('amang', 'magkabukto'), ('amang', 'magkabukto'), ('amang', 'magkabukto')]
# Rejang_(Rejangese)_reja1240.csv
# None
# Rennell_Islanders_renn1242.csv
# [('tamana', 'tuhahine'), ("tu'aatina", "ha'anga"), ("tu'aatina", 'tuhahine'), ('tamana', "tu'aatina"), ('tamana', 'tuhahine'), ('tinana', "tu'aatina"), ('tinana', 'tuhahine'), ('tinana', "ha'anga"), ('tinana', "ha'anga"), ('tamana', "tunga'ane"), ('tamana', "ta'okete"), ('tamana', 'taina')]
# Riuk_Bekati'_(Dayak)_beka1241.csv
# None
# Rotinese_Termanu__term1237.csv
# [('amak', 'kaäk'), ('amak', 'fadik'), ('amak', 'tolanok'), ('toök', 'feto selek'), ('ama kaäk', 'kaäk'), ('ama kaäk', 'feto daek'), ('ama fadik', 'fadik'), ('ama fadik', 'feto daek'), ('teök', 'tolano dadik'), ('teök', 'feto dadik'), ('amak', 'tolanok'), ('amak', 'kaäk'), ('amak', 'fadik')]
# Rotumans_rotu1241.csv
# [('oifā', 'sasigi mafua'), ('oifā', 'sasigi mokoī'), ('oifā', 'saghoni'), ('oifā', 'saghoni mokoī'), ('oifā', 'sasigi'), ('oifā', 'saghoni'), ('oifā', 'sasigi'), ('oifā', 'saghoni'), ('oihoni', 'sasigi'), ('oihoni', 'saghoni'), ('oihoni', 'sasigi'), ('oihoni', 'saghoni'), ('oifā', "sag'veveni"), ('oifā', "sag'veveni mokoī"), ('oifā', 'sasigi mafua'), ('oifā', 'sasigi mokoī')]
# Rotuman_rotu1241.csv
# Routa_rout1237.csv
# None
# Roviana_rovi1238.csv
# [('tama-na', 'vavene-na'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('buhina', 'tasi-na karokarovo'), ('tinana karokarovo', 'tasi-na karokarovo'), ('tinana karokarovo', 'tasi-na karokarovo'), ('tinana karokarovo', 'tasi-na karokarovo'), ('tinana karokarovo', 'tasi-na karokarovo'), ('tama-na', 'tasi-na'), ('tama-na', 'tasi-na')]
# Saaroa_saar1237.csv
# [("ama'a", 'alhalua alhaina'), ("ama'a", 'ilhimilavae alhaina'), ('tamalengale', 'turuua'), ('tamalengale', 'turuua'), ('tamalengale', 'turuua'), ('tamalengale', 'turuua'), ('tavanau', 'turuua'), ('tavanau', 'turuua'), ('tavanau', 'turuua'), ('tavanau', 'turuua'), ("ama'a", 'alhalua lhalhusa'), ("ama'a", 'lhimilavae lhalhusa')]
# Samoan_samo1305.csv
# [('tamā', 'uso'), ('tamā', 'tuafafine'), ('le tuagane o le tinā', 'uso'), ('le tuagane o le tinā', 'tuafafine'), ('le uso o le tamā', 'uso'), ('le uso o le tamā', 'tuafafine'), ('ilamutu', 'uso'), ('ilamutu', 'tuafafine'), ('tamā', 'tuagane'), ('tamā', 'use')]
# Samoan_samo1305a.csv
# None
# Sarangani_Blaan_sara1326.csv
# None
# Satawalese_sata1237.csv
# None
# Sawai_sawa1247.csv
# [('toea', 'fonoe'), ('toea', 'fonoe mepin'), ('toea', 'fonoe'), ('toea', 'fonoe mepin'), ('baba', 'fonoe'), ('baba', 'fonoe mepin'), ('baba', 'fonoe'), ('baba', 'fonoe mepin')]
# Sa_a_saaa1240.csv
# [("ma'a", 'asi-'), ("ma'a", 'asi-'), ('uweli', "di'i"), ('uweli', "di'i"), ('nike', "di'i"), ('nike', "di'i")]
# Sa_saaa1241.csv
# None
# Seke_(Ske)_seke1241.csv
# [('zmia', 'seze'), ('zmia', 'seze'), ('meza', 'mware'), ('meza', 'seze'), ('zmia', 'mware'), ('zmia', 'seze'), ('dahe', 'mware'), ('dahe', 'seze'), ('wwa', 'mware'), ('wwa', 'seze'), ('zmia', 'seze'), ('zmia', 'mware'), ('zmia', 'mware')]
# Senbarei_unua1237.csv
# [('tomongk', 'vevenungk'), ('metungk', 'natungk'), ('metungk', 'natungk'), ('resyongk', 'tomongk'), ('tomongk', 'avwa sungk'), ('tomongk', 'mwenengk'), ('tomongk', 'avwa sungk'), ('tomongk', 'tasingk')]
# Sie_(Sye)_siee1239.csv
# [('etmen', 'veven'), ('metan', 'alwon'), ('metan', 'alwon'), ('namou viroc', 'alwon'), ('namou viroc', 'alwon'), ('namou viroc', 'alwon'), ('namou viroc', 'alwon'), ('etmen', 'man'), ('etmen', 'avenhai')]
# Sikaiana_sika1261.csv
# [('tamana', 'kave'), ('tamana', 'taina'), ('tamana', 'kave'), ('tamana', 'taina'), ('tamana', 'kave'), ('tamana', 'taina'), ('tamana', 'kave'), ('tinna', 'taina'), ('tinna', 'kave'), ('tinna', 'taina'), ('tinna', 'kave'), ('tamana', 'kave'), ('tamana', 'taina'), ('tamana', 'kave'), ('tamana', 'taina')]
# Sika_sika1262.csv
# None
# Sonsorol_sons1242.csv
# [('tama-i', 'meaŋa-i'), ('bwidi ri neira-i', 'bwidi'), ('bwidi ri neira-i', 'bwidi'), ('bwidi ri papa-i', 'bwidi'), ('bwidi ri papa-i', 'bwidi'), ('tama-i', 'meaŋa-i')]
# Southeast_Ambrym_sout2859.csv
# [('tame', 'hinne'), ('metuo', 'mase'), ('metuo', 'avukokon'), ('pap', 'tu'), ('pap', 'hinne'), ('nine', 'tu'), ('nine', 'hinne'), ('tine', 'mase'), ('tine', 'avukokon'), ('tame', 'hinne'), ('tame', 'tu')]
# Southeast_Babar_sout2883.csv
# None
# Southwest_Tanna_sout2869.csv
# [('rɨm', 'kakə'), ('mɨra', 'kapa ier'), ('mɨra', 'kapa ier'), ('mɨra', 'p̃ia karɨn'), ('mɨra', 'kaka'), ('rɨm', 'kakə'), ('rɨm', 'p̃ia')]
# South_Efate_sout2856a.csv
# None
# South_Marquesan_sout2866.csv
# None
# South_Tuvaluan_(Vaitupu)_sout2865.csv
# [('tamana', 'tuangane'), ('tuatina', 'taina'), ('tuatina', 'tuangane'), ('tamana', 'taina'), ('tamana', 'tuangane'), ('matua', 'taina'), ('matua', 'tuangane'), ('matua', 'taina'), ('matua', 'tuangane'), ('tamana', 'tuangane'), ('tamana', 'loko'), ('tamana', 'loko')]
# Sula_Fagudu_sula1245.csv
# None
# Sula_Mangoli_mang1408.csv
# [('baba kōkō', 'akoe foekī nana'), ('baba tīnga', 'akoe foekī nana'), ('baba kōkō', 'akoe foekī nana'), ('goentamī nana', 'akoe foekī nana'), ('goentamī nana', 'akoe foekī nana')]
# Sundanese_sund1252.csv
# [('abah', 'lanceuk'), ('abah', 'adi'), ('ua', 'akang misan'), ('ua', 'akang misan'), ('emang', 'adi misan'), ('emang', 'adi misan'), ('ua', 'akang misan'), ('ua', 'akang misan'), ('emang', 'adi misan'), ('emang', 'adi misan'), ('ua', 'teteh misan'), ('ua', 'teteh misan'), ('embi', 'adi misan'), ('embi', 'adi misan'), ('ua', 'teteh misan'), ('ua', 'teteh misan'), ('embi', 'adi misan'), ('embi', 'adi misan'), ('abah', 'lanceuk'), ('abah', 'adi'), ('abah', 'lanceuk')]
# Sungagage_mari1426i.csv
# [('tata', 'soɣoti'), ('taˈrambe', 'ᵐboi'), ('taˈrambe', 'ᵐboi'), ('tata', 'tue-ŋgu'), ('tata', 'soɣoti'), ('ᵐbou', 'tue-ŋgu'), ('ᵐbou', 'soɣoti'), ('ᵐbʷarai', 'tata'), ('ᵐbʷarai', 'ᵐbʷarai'), ('tata', 'soɣoti'), ('tata', 'tue-ŋgu')]
# Sungwadaga_mari1426b.csv
# [('tata', 'totua'), ('tata', 'totua'), ('tata', 'ɸuβu'), ('tata', 'ɸuβu'), ('tata', 'tua'), ('tata', 'tutua'), ('toa', 'tua'), ('toa', 'tutua'), ('toa', 'ɸuβu'), ('toa', 'ɸuβu'), ('tata', 'totua'), ('tata', 'totua'), ('tata', 'tua'), ('ᵑgʷau', 'tutua'), ('ᵑgʷau', 'tua')]
# Sungwadia_mari1426a.csv
# [('ˈtata', 'ˈtotu'), ('mou', 'ᵐbua (mambisa)'), ('mou', 'ᵐbua (mambisa)'), ('tata', 'ˈβalu'), ('tata', 'ˈtotu'), ('ɸeβe', 'ˈβalu'), ('ɸeβe', 'ˈtotu'), ('ɸeɸe kuru', 'ᵐbua (mambisa)'), ('ɸeɸe kuru', 'ᵐbua (mambisa)'), ('ˈtata', 'ˈtotu'), ('ˈtata', 'ɸalu')]
# Sungwaloge_(Nalemba_Edward)_mari1426g.csv
# [('tata', 'finfiⁿdi'), ('taraᵐbe', 'tuatua tavalaxum'), ('taraᵐbe', 'tuatua tavalaxum'), ('tata', 'tua'), ('tata', 'finfiⁿdi'), ('ᵐbotai', 'tua'), ('ᵐbotai', 'finfiⁿdi'), ('raβe', 'tuatua tavalaxum'), ('raβe', 'tuatua tavalaxum'), ('tata', 'finfiⁿdi'), ('tata', 'tua')]
# Sungwaloge_(Nalemba_Simeone_Tari)_mari1426f.csv
# [('tata', 'fndĭŋ'), ('taraᵐbe', 'tə̆m'), ('taraᵐbe', 'tə̆m'), ('tata', 'tua'), ('tata', 'findiŋ'), ('ᵐbotai', 'tua'), ('ᵐbotai', 'findiŋ'), ('raβe', 'tə̆m'), ('raβe', 'tə̆m'), ('tata', 'fndĭŋ'), ('tata', 'tua')]
# Sungwaloge_(Navenvene)_mari1426d.csv
# [('tata', 'ɸindik'), ('mamou', 'tumtum'), ('mamou', 'tumtum'), ('toa', 'tumtum'), ('toa', 'tumtum'), ('tata', 'ɸindik'), ('tata', 'tua')]
# Sungwaloge_(Tauta)_mari1426e.csv
# [('tata', 'ɸindik'), ('mamou', 'tumtum'), ('mamou', 'tumtum'), ('tata', 'tua'), ('tata', 'ɸindik'), ('ᵐbʷau', 'tua'), ('ᵐbʷau', 'ɸindik'), ('blaktoa', 'tumtum'), ('blaktoa', 'tumtum'), ('tata', 'ɸindik'), ('tata', 'tuak'), ('tai (?)', 'ɸindik'), ('tai (?)', 'tua')]
# Sungwaloge_(Tawet)_mari1426c.csv
# [('ˈtata', 'ɸindi-k'), ('mamou', 'tumtum'), ('mamou', 'tumtum'), ('ˈtata', 'tua-k'), ('ˈtata', 'ɸindik'), ('ˈᵐbʷau', 'tua-k'), ('ˈᵐbʷau', 'ɸindi-k'), ('ˈraβe ˈkuru', 'tumtum'), ('ˈraβe ˈkuru', 'tumtum'), ('ˈtata', 'ɸindi-k'), ('ˈtata', 'tua-k')]
# Sunwadia_mari1426.csv
# None
# Tadyawan_tady1237.csv
# [('amang', 'tayali'), ('tayakí', 'talagbáy'), ('tayakí', 'talagbáy'), ('tayakí', 'talagbáy'), ('tayakí', 'talagbáy'), ('bî', 'talagbáy'), ('bî', 'talagbáy'), ('bî', 'talagbáy'), ('bî', 'talagbáy'), ('amang', 'tayali'), ('amang', 'tayali'), ('amang', 'tayali')]
# Tagalog_taga1270.csv
# [('ama-in', 'pinsan'), ('ama-in', 'pinsan'), ('ama-in', 'pinsan'), ('ama-in', 'pinsan'), ('ali', 'pinsan'), ('ali', 'pinsan'), ('ali', 'pinsan'), ('ali', 'pinsan')]
# Tahitians_tahi1242.csv
# [('metua tane', "tua'ana"), ('metua tane', 'teina'), ('metua tane', 'tuahine'), ('metua tane', 'tuahine'), ('metua tane', 'tuahine'), ('metua vahine', 'tuahine'), ('metua vahine', 'tuahine'), ('metua tane', "tua'ane"), ('metua tane', "tua'ana"), ('metua tane', 'teina')]
# Tahitian_tahi1242.csv
# Tajio_taji1246.csv
# [('siama', "sia'a"), ('siama', 'tuai'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posiamaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('posinaong', 'rurus sangganing'), ('siama', "sia'a"), ('siama', 'tuai')]
# Takia_taki1248.csv
# [('tama-', 'lu-'), ('ngai', 'tei-'), ('ngai', 'lu-'), ('tama-', 'tei-'), ('tama-', 'lu-'), ('tna-', 'tei-'), ('tna-', 'lu-'), ('nbi', 'tei-'), ('nbi', 'lu-'), ('tama-', 'lu-'), ('tama-', 'tei-')]
# Takuu_taku1257.csv
# [('ilaamotu', 'kave'), ('ilaamotu', 'kave'), ('tamana', 'kave'), ('tamana', 'kave'), ('tamana', 'kave'), ('tamana', 'kave'), ('tinna', 'kave'), ('tinna', 'kave'), ('tamana', 'soa')]
# Talibabu_tali1262.csv
# None
# Talise_(Tolo)_tali1259.csv
# [('kaka', 'vavinena'), ('tsagina', 'kasina gare'), ('tsagina', 'vavinena'), ('kaka', 'kasina gare'), ('kaka', 'vavinena'), ('kaka', 'kasina gare'), ('kaka', 'vavinena'), ('lake', 'kasina gare'), ('lake', 'vavinena'), ('lake', 'kasina gare'), ('lake', 'vavinena'), ('tsagina', 'kasina gare'), ('tsagina', 'vavinena'), ('kaka', 'vavinena'), ('kaka', 'kasina daki'), ('kaka', 'vavinena'), ('kaka', 'kasina daki'), ('lake', 'vavinena'), ('lake', 'kasina daki')]
# Tamambo_malo1243.csv
# None
# Tanala_tana1285.csv
# [('anadhiandreny', 'anjaravady'), ('anadhiandreny', 'anjaravady'), ('rahalahiandraiko', 'rahalahy'), ('rahalahiandraiko', 'anabavy'), ('rahavaviandreny', 'rahalahy'), ('rahavaviandreny', 'anabavy'), ('anabavanbaba', 'anjaravady'), ('anabavanbaba', 'anabavy')]
# Tanampedagi_Taje_taje1237b.csv
# [('siama', "sia'ang"), ('siama', 'tuai'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posiamao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('posinao', 'sampesuwu'), ('siama', "sia'ang"), ('siama', 'tuai')]
# Tangoa_(Movono)_tang1347.csv
# None
# Tasiko_tasi1237.csv
# [('arima', 'vino'), ('arima', 'naru'), ('arima', 'naru'), ('ane', 'naru'), ('ane', 'naru'), ('arima', 'ŋmano'), ('arima', 'ina')]
# Taumako_taum1237.csv
# [('hama', 'tahini'), ('ingoa', 'kave'), ('ingoa', 'tahini-kave'), ('hama', 'tokana'), ('hama', 'tahini'), ('hina', 'tokana'), ('hina', 'tahini'), ('hina', 'kave'), ('hina', 'tahini-kave'), ('hama', 'tungane'), ('hama', 'tokana'), ('hama', 'teina')]
# Tausug_(Sulu_Moro)_taus1251.csv
# [('ama', 'kaka'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('ama', 'kaka'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud'), ('babu', 'tüngud')]
# Tausug_taus1251a.csv
# [("ama'", 'magulang'), ("ama'", 'manghud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapa'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("bapu'", 'patungud'), ("ama'", 'magulang'), ("ama'", 'manghud')]
# Tetum_(Tetun)_tetu1245.csv
# [('pai', 'abi'), ('pai', 'alin'), ('pai', 'maun'), ('pai', 'alin'), ('pai', 'alin'), ('aman', 'naan'), ('aman', 'naan'), ('inan', 'naan'), ('inan', 'naan')]
# Tetun_Dili_(Tetum)_tetu1246.csv
# None
# Thao_thao1240.csv
# None
# Tiale_tial1239.csv
# None
# Tialo_(Tomini)_tomi1243.csv
# [('siama -nyo', "sia'a"), ('siama -nyo', 'tuai -nyo'), ('ponsiamaan', 'soungaunga sepisa'), ('ponsiamaan', 'soungaunga sepisa'), ('ponsiamaan', 'soungaunga sepisa'), ('ponsiamaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('ponsinaan', 'soungaunga sepisa'), ('siama -nyo', "sia'a"), ('siama -nyo', 'tuai -nyo')]
# Tigak_tiga1245.csv
# None
# Tikopia_tiko1237.csv
# [('tamana', 'taina'), ('tamana', 'kave'), ('tuatina', 'taina'), ('tuatina', 'kave'), ('tamana', 'taina'), ('tamana', 'kave'), ('tinana', 'taina'), ('tinana', 'kave'), ('masikitaŋa', 'taina'), ('masikitaŋa', 'kave'), ('tamana', 'kave'), ('tamana', 'taina')]
# Tikopia_tiko1237a.csv
# [('tamana', 'kave'), ('tuatina', 'taina faka-pariki'), ('tuatina', 'kave faka-pariki'), ('tamana', 'taina faka-laui'), ('tamana', 'kave faka-laui'), ('tinana', 'taina faka-laui'), ('tinana', 'kave faka-laui'), ('masikitanga', 'taina faka-pariki'), ('masikitanga', 'kave faka-pariki'), ('tamana', 'kave'), ('tamana', 'taina')]
# Tirax_(Mae)_maee1241.csv
# None
# Tiri-Mea_(Grand_Couli)_tiri1258.csv
# [('audẽ', 'auhẽřẽ'), ('panea', 'auvae'), ('panea', 'auvae'), ('panea', 'auvae'), ('panea', 'auvae'), ('audẽ', 'auhẽřẽ'), ('audẽ', 'aušoo'), ('audẽ', 'auti'), ('panea', 'auvae'), ('panea', 'auvae')]
# Tokelau_toke1240.csv
# [('tamana', 'taina'), ('tamana', 'tuafafine'), ('tuatina', 'tuatina'), ('tuatina', 'tuatina'), ('tamana', 'taina'), ('tamana', 'tuafafine'), ('matua', 'taina'), ('matua', 'tuafafine'), ('matua', 'fakatau tuatina'), ('matua', 'fakatau tuatina'), ('tamana', 'tuagāne'), ('tamana', 'taina')]
# Tokelau_toke1240a.csv
# [('tamana', 'tua-fafine'), ('tamana', 'taina'), ('tamana', 'taina fetau taina'), ('maatua', 'taina'), ('maatua', 'tuafafine fetau taina'), ('matua sa', 'ilamutu'), ('matua sa', 'ilamutu'), ('matua sa', 'ilamutu'), ('matua sa', 'ilamutu'), ('tamana', 'tua-gane'), ('tamana', 'fetau-taina'), ('tamana', 'fetau-taina')]
# Tokotu'a_(Kabaena)_kaba1285.csv
# None
# Tolaki_tola1247.csv
# [('tama', 'kaka'), ('tama', 'andi'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('pinoli', 'poteha'), ('tama', 'kaka'), ('tama', 'andi')]
# Tomadino_toma1248.csv
# None
# Tombulu_tomb1243.csv
# [("ama'", "kaka' wēwēnē"), ("ama'", 'tuari wēwēnē'), ("ito'", "oki'-nē-mahtuari"), ("ito'", "oki'-nē-mahtuari"), ("ito'", "oki'-nē-mahtuari"), ("ito'", "oki'-nē-mahtuari"), ('mui', "oki'-nē-mahtuari"), ('mui', "oki'-nē-mahtuari"), ('mui', "oki'-nē-mahtuari"), ('mui', "oki'-nē-mahtuari"), ("ama'", "kaka' tuama"), ("ama'", 'tuari tuama')]
# Tongan_tong1325.csv
# [('tamai', "ta'okete"), ('tamai', 'tehina'), ('tamai', 'tuofefine'), ("fa'e tangata", 'tokoua'), ("fa'e tangata", 'tuofefine'), ("tu'asina", 'tokoua'), ("tu'asina", 'tuofefine'), ('tamai', 'tokoua'), ('tamai', 'tuofefine'), ("fa'e", 'tokoua'), ("fa'e", 'tuofefine'), ('mehekitanga', 'tokoua'), ('mehekitanga', 'tuofefine'), ('tamai', "tuonga'ane"), ('tamai', "ta'okete"), ('tamai', 'tehina')]
# Tongarevans_penr1237.csv
# Tonga_(Tonga_Islands)_tong1325.csv
# Tonsea_tons1240.csv
# [("ama'", 'kakak wewene'), ("ama'", 'tuari wewene'), ('ito', 'kasudu'), ('ito', 'kasudu'), ('ito', 'kasudu'), ('ito', 'kasudu'), ('mui', 'kasudu'), ('mui', 'kasudu'), ('mui', 'kasudu'), ('mui', 'kasudu'), ("ama'", "kaka' tuama"), ("ama'", 'tuari tuama')]
# Toqabaqita_toab1237.csv
# [('maamaqa', 'doqora'), ('maamaqa', 'doqora'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua'), ('kookoqo', 'doqorarua')]
# Torete_tore1237.csv
# None
# Totoli_toto1304.csv
# [('amang ko-', 'tukka'), ('amang ko-', 'tuali'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('amang ko-', 'tukka'), ('amang ko-', 'tuali'), ('amang ko-', 'tukka'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguamangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan'), ('poguinangan', 'montoliusat komiinjan')]
# Tubuai_tubu1240.csv
# None
# Tukang_Besi_South_tuka1249.csv
# None
# Tulambatu_tula1253.csv
# None
# Tungag_tung1290.csv
# None
# Tuvalu_(Nanumea)_tuva1244.csv
# [('tamana', 'tuagane'), ('laamutu', 'fakataina'), ('laamutu', 'fakatuagane'), ('laamutu', 'fakataina'), ('laamutu', 'fakatuagane'), ('tamana', 'fakataina'), ('tamana', 'fakatuagane'), ('fakamaatua', 'fakataina'), ('fakamaatua', 'fakatuagane'), ('fakamaatua', 'fakataina'), ('fakamaatua', 'fakatuagane'), ('tamana', 'tuagane'), ('tamana', 'taina'), ('laamutu', 'fakatuagane'), ('laamutu', 'fakataina')]
# Ulawa_ulaw1237.csv
# [("ma'a", 'inie-'), ("ma'a", 'inie-'), ('uweli', 'ula-'), ('uweli', 'ula-'), ('nike', 'ula-'), ('nike', 'ula-')]
# Uma_Juman_(Kayan)_umaj1240.csv
# [('tama+n', '(pə)hari?+n duh (aiəŋ) aya?'), ('tama+n', '(pə)hari?+n duh (aiəŋ) (du)?uk'), ('tama+n', '(pə)hari?+n higət'), ('tama+n', '(pə)hari?+n higət'), ('tama+n', '(pə)hari?+n higət'), ('tama+n', '(pə)hari?+n higət'), ('hina+n', '(pə)hari?+n higət'), ('hina+n', '(pə)hari?+n higət'), ('hina+n', '(pə)hari?+n higət'), ('hina+n', '(pə)hari?+n higət'), ('tama+n', '(pə)hari?+n (l)aki? (aiəŋ) aya?'), ('tama+n', '(pə)hari?+n (l)aki (aiəŋ) (du)?uk')]
# Umiray_Dumaget_Agta_umir1236.csv
# None
# Unua_unua1237.csv
# Urak_Lawoi_urak1238.csv
# None
# Ura_urav1235.csv
# None
# Uripiv-Wala-Rano-Atchin_urip1239.csv
# [('tata suk', 'tsotsik'), ('mituk', 'natuk'), ('mituk', 'natuk'), ('tasu suk', 'tata suk'), ('tasu suk', 'tasu suk'), ('tata suk', 'tuak'), ('tata suk', 'tasik')]
# Vaekau-Taumako_pile1238.csv
# [('tamana', 'thuohine'), ('ingoa', 'kave'), ('ingoa', 'thuohine'), ('tamana', 'kave'), ('tamana', 'thuohine'), ('tamana', 'kave'), ('tamana', 'thuohine'), ('hinana', 'kave'), ('hinana', 'thuohine'), ('hinana', 'kave'), ('hinana', 'thuohine'), ('hinana', 'kave'), ('hinana', 'thuohine'), ('hinana', 'kave'), ('hinana', 'thuohine'), ('tamana', 'thungane'), ('tamana', 'thokana'), ('tamana', 'teina'), ('tamana', 'thungane'), ('tamana', 'kave'), ('hinana', 'thungane'), ('hinana', 'kave'), ('hinana', 'thungane'), ('hinana', 'kave')]
# Vao_vaoo1237.csv
# None
# Varisi_vari1239.csv
# None
# Vera'a_vera1241.csv
# None
# Vures_vure1239.csv
# None
# Waia_waia1242.csv
# None
# Wallisian_(East_Uvea)_wall1257.csv
# None
# Waropen_waro1242.csv
# None
# Waru_waru1266.csv
# None
# Watut_watu1246.csv
# [('lamaŋg', 'lewiŋg'), ('lamaŋg', 'laseŋg'), ('lamaŋg', 'jeniŋg kefi'), ('esiŋg', 'araŋg'), ('esiŋg', 'nafoŋg'), ('lamaŋg', 'lewiŋg'), ('lamaŋg', 'nafoŋg'), ('lenaŋg', 'lewiŋg'), ('lenaŋg', 'nafoŋg'), ('wagag', 'araŋg'), ('wagag', 'nafoŋg'), ('lamaŋg', 'lewiŋg'), ('lamaŋg', 'laseŋg')]
# Wawonii_wawo1239.csv
# [('tama', 'tukaka'), ('tama', 'tußai'), ('maama', 'topisa'), ('maama', 'topisa'), ('maama', 'topisa'), ('maama', 'topisa'), ('naina', 'topisa'), ('naina', 'topisa'), ('naina', 'topisa'), ('naina', 'topisa'), ('tama', 'tukaka'), ('tama', 'tußai')]
# Weda_weda1240.csv
# [('momo', 'fono'), ('momo', 'fono-meping'), ('momo', 'fono'), ('momo', 'fono-meping'), ('momo', 'fono'), ('momo', 'fono-meping'), ('momo', 'fono'), ('momo', 'fono-meping'), ('baba', 'fono'), ('baba', 'fono-meping'), ('baba', 'fono'), ('baba', 'fono-meping'), ('baba', 'fono'), ('baba', 'fono-meping'), ('baba', 'fono'), ('baba', 'fono-meping')]
# Western_Bukidnon_Manobo_west2555.csv
# [('amey', 'etevey'), ('anggam', 'suled'), ('anggam', 'etevey'), ('anggam', 'suled'), ('anggam', 'etevey'), ("aya'", 'suled'), ("aya'", 'etevey'), ("aya'", 'suled'), ("aya'", 'etevey'), ('amey', "me'emahan"), ('amey', 'suled')]
# Western_Tawbuid_(Batangan)_west2559.csv
# [('mama', 'duksayan'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('sai', 'lagbä'), ('baáy', 'lagbä'), ('baáy', 'lagbä'), ('baáy', 'lagbä'), ('baáy', 'lagbä'), ('mama', 'duksayan'), ('mama', 'duksayan'), ('mama', 'duksayan')]
# West_Coast_Bajau_west2560.csv
# [("emma'", "ka'"), ("emma'", "di'"), ("pa'", 'kaki'), ("pa'", 'kaki'), ("pa'", 'kaki'), ("pa'", 'kaki'), ("bu'", 'kaki'), ("bu'", 'kaki'), ("bu'", 'kaki'), ("bu'", 'kaki'), ("emma'", "ka'"), ("emma'", "di'")]
# West_Futuna_west2515.csv
# [('tamana', 'kave'), ('tojinana', 'safe'), ('tojinana', 'fakau magaro'), ('tamana', 'soa'), ('tamana', 'kave'), ('jinana', 'soa'), ('jinana', 'kave'), ('jinana', 'soa'), ('jinana', 'kave'), ('jina-ha-vae', 'safe'), ('jina-ha-vae', 'fakau magaro'), ('jina-ha-vae. maha-vae', 'safe'), ('jina-ha-vae. maha-vae', 'fakau magaro'), ('tamana', 'kave'), ('tamana', 'soa'), ('jinana', 'kave'), ('jinana', 'soa'), ('jina-ha-vae', 'fakau magaro'), ('jina-ha-vae', 'maa')]
# Whitesands_whit1269.csv
# None
# Wiwirano_wiwi1237.csv
# None
# Wogeo_woge1237.csv
# None
# Woleaian_wole1240.csv
# None
# Wolio_woli1241.csv
# None
# Wuvulu_Aua_wuvu1239.csv
# [('ʔama', 'lofu'), ('ʔama', 'ʔari'), ('ama', 'lofu'), ('ama', 'ʔari'), ('ʔama', 'lofu'), ('ʔama', 'ʔari'), ('ʔina', 'lofu'), ('ʔina', 'ʔari'), ('ʔina', 'lofu'), ('ʔina', 'ʔari'), ('ʔama', 'ʔari'), ('ʔama', 'tafi')]
# Xalangi_(Maevo_Vanuatu)_mari1426h.csv
# [('tita', 'fiⁿdae'), ('(j)aᵐbe', 'natu'), ('(j)aᵐbe', 'natu'), ('tita', 'tua'), ('tita', 'fiⁿdae'), ('ᵐbotai', 'tua'), ('ᵐbotai', 'fiⁿdae'), ('toa', 'toa'), ('toa', 'toa'), ('tita', 'fiⁿdae'), ('tita', 'tua')]
# Xaracuu_(Canala)_xara1244.csv
# None
# Yabem_yabe1254.csv
# [('tama', 'luò'), ('sa laŋgwa', 'gwadê'), ('sa laŋgwa', 'gwadêò'), ('sa laŋgwa', 'gwadê'), ('sa laŋgwa', 'gwadêò'), ('tamasêga', 'têwa'), ('tamasêga', 'têwaò'), ('tamasêga', 'têwa'), ('tamasêga', 'têwaò'), ('tênasêga', 'têwa'), ('tênasêga', 'luò'), ('tênasêga', 'têwa'), ('tênasêga', 'luò'), ('saò àwêsêga', 'gwadê'), ('saò àwêsêga', 'gwadêò'), ('saò àwêsêga', 'gwadê'), ('saò àwêsêga', 'gwadêò'), ('tama', 'luŋac'), ('tama', 'luŋac'), ('tama', 'têwaò'), ('tama', 'têwaò'), ('tamasêga', 'têwa'), ('tamasêga', 'têwaò'), ('tênasêga', 'têwa'), ('tênasêga', 'luò')]
# Yakan_yaka1277.csv
# [('amma', "pongtina'i"), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ("si'it", 'danganakan'), ('amma', "pongtina'i"), ('amma', 'kakka'), ('amma', 'sali')]
# Yamdena_yamd1240.csv
# [('ame', ''), ('ame', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', ''), ('', '')]
# Yami_Tao__yami1254.csv
# [('ama', 'kaka'), ('ama', 'wari'), ('ama', 'kaka'), ('ama', 'wari'), ('maran', 'kaposing'), ('maran', 'kaposing'), ('kaminan', 'kaposing'), ('kaminan', 'kaposing'), ('kaminan', 'kateysa'), ('kaminan', 'kateysa')]
# Zabana_(Kia)_zaba1237.csv
# None
# 120
#                           language       code simulation_code simulation  \
# 0    Maguindanao_(Magindonao_Moro)   magu1243   magu1243_REAL          N
# 1                        Malua_Bay   malu1245   malu1245_REAL          N
# 2                      Mangarevans   mang1401   mang1401_REAL          N
# 3                   Mangei_(Sobjo)   mang1407   mang1407_REAL          N
# 4                            Maori   maor1246   maor1246_REAL          N
# ..                             ...        ...             ...        ...
# 115        Xalangi_(Maevo_Vanuatu)  mari1426h  mari1426h_REAL          N
# 116                          Yabem   yabe1254   yabe1254_REAL          N
# 117                          Yakan   yaka1277   yaka1277_REAL          N
# 118                        Yamdena   yamd1240   yamd1240_REAL          N
# 119                      Yami_Tao_   yami1254   yami1254_REAL          N
#
#      mutual_information  entropy_gn  entropy_gn1  conditional_entropy  \
# 0              0.721928    0.921928     1.521928             0.800000
# 1              1.500000    2.750000     1.500000            -0.000000
# 2              0.661705    1.483832     2.128085             1.466380
# 3              0.000000   -0.000000     1.000000             1.000000
# 4              0.001340    1.940286     0.985228             0.983888
# ..                  ...         ...          ...                  ...
# 115            1.313101    1.936260     1.858555             0.545455
# 116            1.414694    2.519080     2.298689             0.883995
# 117            0.811278    1.186278     0.811278            -0.000000
# 118            0.000000   -0.000000     0.721928             0.721928
# 119            1.121928    1.921928     1.521928             0.400000
#
#      variation_gn  variation_gn1  number_of_pairs
# 0               3              3                4
# 1               7              3                7
# 2               4              5                8
# 3               1              2                2
# 4               4              2                8
# ..            ...            ...              ...
# 115             4              4                6
# 116             6              5               11
# 117             4              2                4
# 118             1              2                2
# 119             4              3                5
#
# [120 rows x 11 columns]

# %%
ics_simulation(filtered_aus_filepath,filtered_aus_files,1000)
# Out:
#                              language      code simulation_code simulation  \
# 0       Maguindanao_(Magindonao_Moro)  magu1243      magu1243_0          Y
# 1       Maguindanao_(Magindonao_Moro)  magu1243      magu1243_1          Y
# 2       Maguindanao_(Magindonao_Moro)  magu1243      magu1243_2          Y
# 3       Maguindanao_(Magindonao_Moro)  magu1243      magu1243_3          Y
# 4       Maguindanao_(Magindonao_Moro)  magu1243      magu1243_4          Y
# ...                               ...       ...             ...        ...
# 119995                      Yami_Tao_  yami1254    yami1254_995          Y
# 119996                      Yami_Tao_  yami1254    yami1254_996          Y
# 119997                      Yami_Tao_  yami1254    yami1254_997          Y
# 119998                      Yami_Tao_  yami1254    yami1254_998          Y
# 119999                      Yami_Tao_  yami1254    yami1254_999          Y
#
#         mutual_information  entropy_gn  entropy_gn1  conditional_entropy  \
# 0                 0.397417    0.921928     1.521928             1.124511
# 1                 0.272906    0.921928     1.521928             1.249022
# 2                 0.272906    0.921928     1.521928             1.249022
# 3                 0.272906    0.921928     1.521928             1.249022
# 4                 0.397417    0.921928     1.521928             1.124511
# ...                    ...         ...          ...                  ...
# 119995            0.721928    1.921928     1.521928             0.800000
# 119996            0.597417    1.921928     1.521928             0.924511
# 119997            0.721928    1.921928     1.521928             0.800000
# 119998            0.521928    1.921928     1.521928             1.000000
# 119999            0.721928    1.921928     1.521928             0.800000
#
#         variation_gn  variation_gn1  number_of_pairs
# 0                  3              3                5
# 1                  3              3                5
# 2                  3              3                5
# 3                  3              3                5
# 4                  3              3                5
# ...              ...            ...              ...
# 119995             4              3                7
# 119996             4              3                8
# 119997             4              3                7
# 119998             4              3                8
# 119999             4              3                7
#
# [120000 rows x 11 columns]

# %%
tgn1 = ['anu','tana']
tgn = ['titih','nana','alik']
tpairs = [('anu','titih'),('anu','nana'),('anu','alik'),('tana','titih'),('tana','nana'),('tana','alik')]

te = entropy(tgn1)

tce = conditional_entropy(tgn,tpairs)

te - tce

tce
# Out:
# 0.9999999999999999

# %%
tgn1 = ['anu']
tgn = ['titih','nana','alik']
tpairs = [('anu','titih'),('anu','nana'),('anu','alik'),('tana','titih'),('tana','nana'),('tana','alik')]

te = entropy(tgn1)

tce = conditional_entropy(tgn,tpairs)

te - tce

tce
# Out:
# 0.9999999999999999

# %%
tgn1 = ['anu','tana']
tgn = ['a','b']
tpairs = [('anu','a'),('anu','a'),('anu','a'),
          ('tana','a'),('tana','a'),('tana','a')]

te = entropy(tgn1)

tce = conditional_entropy(tgn,tpairs)

te - tce

tce
# Out:
# -0.0

# %%
tgn1 = ['anu','tana']
tgn = ['a','b']
tpairs = [('anu','a'),('anu','a'),('anu','a'),
          ('tana','a'),('tana','a')]

te = entropy(tgn1)

tce = conditional_entropy(tgn,tpairs)

te - tce

tce
# Out:
# -0.029049405545331364
